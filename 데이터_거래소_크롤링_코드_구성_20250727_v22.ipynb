# %% [markdown]
# <a href="https://colab.research.google.com/github/srkwon/data-curator/blob/main/%EB%8D%B0%EC%9D%B4%ED%84%B0_%EA%B1%B0%EB%9E%98%EC%86%8C_%ED%81%AC%EB%A1%A4%EB%A7%81_%EC%BD%94%EB%93%9C_%EA%B5%AC%EC%84%B1_20250727_v22.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # BeautifulSoup 기반 크롤링

# %%
import requests
from bs4 import BeautifulSoup
import time

base_url = "https://kdx.kr"

start_url = "https://kdx.kr/data/product-list?specs_id=MA17200002&corp_id=CORP000036&category_id=CA000002"

print(f"리스트 페이지 접근: {start_url}")
res = requests.get(start_url)
if res.status_code != 200:
    print("❌ 리스트 페이지 로드 실패")
    exit()

soup = BeautifulSoup(res.text, "html.parser")

# ✅ BeautifulSoup는 비표준 구조를 교정 → li 안에 a가 들어가게 됨
list_items = soup.select("ul.card-list li.list-item")

print(f"✅ 리스트 아이템 개수: {len(list_items)}")

links = []

for li in list_items:
    a_tag = li.find("a", href=True)
    if a_tag:
        href = a_tag["href"]
        links.append(href)
        print(base_url + href)

print(f"\n✅ 최종 추출된 링크 개수: {len(links)}")


data_list = []

for idx, li in enumerate(items, start=1):
    # li의 부모 <a> 태그 탐색
    parent_a = li.find_parent("a")
    if not parent_a or not parent_a.get("href"):
        print(f"⚠️ [{idx}] 링크 없음, 건너뜀")
        continue

    href = parent_a.get("href")
    detail_url = base_url + href
    print(f"\n--- [{idx}] 상세 페이지 접근: {detail_url}")

    detail_res = requests.get(detail_url)
    if detail_res.status_code != 200:
        print(f"❌ [{idx}] 상세 페이지 로드 실패: {detail_url}")
        continue

    detail_soup = BeautifulSoup(detail_res.text, "html.parser")

    # 총 구매금액
    purchase_elem = detail_soup.select_one("#dataView > div.container > div.detail-wrap > div.item-right > div.purchaseIs > p")
    if purchase_elem:
        purchase_amount = purchase_elem.get_text(strip=True)
        print(f"💰 총 구매금액: {purchase_amount}")
    else:
        purchase_amount = "N/A"
        print("⚠️ 총 구매금액 정보 없음")

    # 스키마(샘플 데이터 테이블)
    schema_table = detail_soup.select_one("#dataView > div.container > div.detail-wrap > div.item-left > div.inner > div.table-wrap.preview_wrap.expand > div.sample_data > table")
    if schema_table:
        schema_text = schema_table.get_text(separator=" | ", strip=True)
        print(f"📄 스키마(샘플 데이터) 요약: {schema_text[:100]}...")
    else:
        schema_text = "N/A"
        print("⚠️ 스키마 정보 없음")

    # 결과 저장
    data_list.append({
        "url": detail_url,
        "purchase_amount": purchase_amount,
        "schema": schema_text,
    })

    time.sleep(1)

print("\n✅ 전체 크롤링 완료")
print(f"총 수집된 데이터 수: {len(data_list)}")
for d in data_list[:3]:
    print("\n📝 예시 데이터")
    print(d)
# Out:
# 리스트 페이지 접근: https://kdx.kr/data/product-list?specs_id=MA17200002&corp_id=CORP000036&category_id=CA000002
# ✅ 리스트 아이템 개수: 0
#
# ✅ 최종 추출된 링크 개수: 0
#
# ✅ 전체 크롤링 완료
# 총 수집된 데이터 수: 0

# %% [markdown]
# # Selenium 기반 크롤링

# %%
# !apt-get update
# !apt install -y wget unzip curl

# 크롬 설치
# !wget https://dl.google.com/linux/direct/google-chrome-stable_current_amd64.deb
# !dpkg -i google-chrome-stable_current_amd64.deb || apt-get -fy install

# 크롬 버전 확인
# !google-chrome --version

# 크롬 버전에 맞는 드라이버 버전 가져오기
# !CHROME_VERSION=$(google-chrome --version | cut -d ' ' -f 3 | cut -d '.' -f 1) \
 && echo "Using Chrome major version: $CHROME_VERSION" \
 && DRIVER_VERSION=$(curl -sS "https://chromedriver.storage.googleapis.com/LATEST_RELEASE_${CHROME_VERSION}") \
 && echo "Matching chromedriver version: $DRIVER_VERSION" \
 && wget -O /tmp/chromedriver.zip "https://chromedriver.storage.googleapis.com/${DRIVER_VERSION}/chromedriver_linux64.zip" \
 && unzip /tmp/chromedriver.zip chromedriver -d /usr/bin/

# !chmod +x /usr/bin/chromedriver
# !pip install selenium
# Out:
# Hit:1 http://security.ubuntu.com/ubuntu jammy-security InRelease
# Get:2 https://dl.google.com/linux/chrome/deb stable InRelease [1,825 B]
# Hit:3 https://cloud.r-project.org/bin/linux/ubuntu jammy-cran40/ InRelease
# Hit:4 http://archive.ubuntu.com/ubuntu jammy InRelease
# Hit:5 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2204/x86_64  InRelease
# Hit:6 https://ppa.launchpadcontent.net/deadsnakes/ppa/ubuntu jammy InRelease
# Hit:7 https://ppa.launchpadcontent.net/graphics-drivers/ppa/ubuntu jammy InRelease
# Hit:8 https://ppa.launchpadcontent.net/ubuntugis/ppa/ubuntu jammy InRelease
# Hit:9 http://archive.ubuntu.com/ubuntu jammy-updates InRelease
# Hit:10 http://archive.ubuntu.com/ubuntu jammy-backports InRelease
# Get:11 https://dl.google.com/linux/chrome/deb stable/main amd64 Packages [1,212 B]
# Hit:12 https://r2u.stat.illinois.edu/ubuntu jammy InRelease
# Fetched 3,037 B in 2s (1,366 B/s)
# Reading package lists... Done
# W: Skipping acquire of configured file 'main/source/Sources' as repository 'https://r2u.stat.illinois.edu/ubuntu jammy InRelease' does not seem to provide it (sources.list entry misspelt?)
# Reading package lists... Done
# Building dependency tree... Done
# Reading state information... Done
# curl is already the newest version (7.81.0-1ubuntu1.20).
# unzip is already the newest version (6.0-26ubuntu3.2).
# wget is already the newest version (1.21.2-2ubuntu1.1).
# 0 upgraded, 0 newly installed, 0 to remove and 35 not upgraded.
# --2025-06-29 03:06:21--  https://dl.google.com/linux/direct/google-chrome-stable_current_amd64.deb
# Resolving dl.google.com (dl.google.com)... 172.217.218.91, 172.217.218.136, 172.217.218.93, ...
# Connecting to dl.google.com (dl.google.com)|172.217.218.91|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 118033016 (113M) [application/x-debian-package]
# Saving to: ‘google-chrome-stable_current_amd64.deb.1’
#
# google-chrome-stabl 100%[===================>] 112.56M   356MB/s    in 0.3s
#
# 2025-06-29 03:06:22 (356 MB/s) - ‘google-chrome-stable_current_amd64.deb.1’ saved [118033016/118033016]
#
# (Reading database ... 126921 files and directories currently installed.)
# Preparing to unpack google-chrome-stable_current_amd64.deb ...
# Unpacking google-chrome-stable (138.0.7204.49-1) over (138.0.7204.49-1) ...
# Setting up google-chrome-stable (138.0.7204.49-1) ...
# Processing triggers for mailcap (3.70+nmu1ubuntu1) ...
# Processing triggers for man-db (2.10.2-1) ...
# Google Chrome 138.0.7204.49
# Using Chrome major version: 138
# Matching chromedriver version: <?xml version='1.0' encoding='UTF-8'?><Error><Code>NoSuchKey</Code><Message>The specified key does not exist.</Message><Details>No such object: chromedriver/LATEST_RELEASE_138</Details></Error>
# --2025-06-29 03:06:38--  https://chromedriver.storage.googleapis.com/%3C?xml%20version='1.0'%20encoding='UTF-8'?%3E%3CError%3E%3CCode%3ENoSuchKey%3C/Code%3E%3CMessage%3EThe%20specified%20key%20does%20not%20exist.%3C/Message%3E%3CDetails%3ENo%20such%20object:%20chromedriver/LATEST_RELEASE_138%3C/Details%3E%3C/Error%3E/chromedriver_linux64.zip
# Resolving chromedriver.storage.googleapis.com (chromedriver.storage.googleapis.com)... 172.217.218.207, 142.251.31.207, 192.178.156.207, ...
# Connecting to chromedriver.storage.googleapis.com (chromedriver.storage.googleapis.com)|172.217.218.207|:443... connected.
# HTTP request sent, awaiting response... 404 Not Found
# 2025-06-29 03:06:38 ERROR 404: Not Found.
#
# Requirement already satisfied: selenium in /usr/local/lib/python3.11/dist-packages (4.33.0)
# Requirement already satisfied: urllib3~=2.4.0 in /usr/local/lib/python3.11/dist-packages (from urllib3[socks]~=2.4.0->selenium) (2.4.0)
# Requirement already satisfied: trio~=0.30.0 in /usr/local/lib/python3.11/dist-packages (from selenium) (0.30.0)
# Requirement already satisfied: trio-websocket~=0.12.2 in /usr/local/lib/python3.11/dist-packages (from selenium) (0.12.2)
# Requirement already satisfied: certifi>=2025.4.26 in /usr/local/lib/python3.11/dist-packages (from selenium) (2025.6.15)
# Requirement already satisfied: typing_extensions~=4.13.2 in /usr/local/lib/python3.11/dist-packages (from selenium) (4.13.2)
# Requirement already satisfied: websocket-client~=1.8.0 in /usr/local/lib/python3.11/dist-packages (from selenium) (1.8.0)
# Requirement already satisfied: attrs>=23.2.0 in /usr/local/lib/python3.11/dist-packages (from trio~=0.30.0->selenium) (25.3.0)
# Requirement already satisfied: sortedcontainers in /usr/local/lib/python3.11/dist-packages (from trio~=0.30.0->selenium) (2.4.0)
# Requirement already satisfied: idna in /usr/local/lib/python3.11/dist-packages (from trio~=0.30.0->selenium) (3.10)
# Requirement already satisfied: outcome in /usr/local/lib/python3.11/dist-packages (from trio~=0.30.0->selenium) (1.3.0.post0)
# Requirement already satisfied: sniffio>=1.3.0 in /usr/local/lib/python3.11/dist-packages (from trio~=0.30.0->selenium) (1.3.1)
# Requirement already satisfied: wsproto>=0.14 in /usr/local/lib/python3.11/dist-packages (from trio-websocket~=0.12.2->selenium) (1.2.0)
# Requirement already satisfied: pysocks!=1.5.7,<2.0,>=1.5.6 in /usr/local/lib/python3.11/dist-packages (from urllib3[socks]~=2.4.0->selenium) (1.7.1)
# Requirement already satisfied: h11<1,>=0.9.0 in /usr/local/lib/python3.11/dist-packages (from wsproto>=0.14->trio-websocket~=0.12.2->selenium) (0.16.0)

# %%
# 🌟 셀 2: 크롤링 코드

from selenium import webdriver
from selenium.webdriver.chrome.service import Service
from selenium.webdriver.chrome.options import Options
from selenium.webdriver.common.by import By
import time

# URL 설정
base_url = "https://kdx.kr"
start_url = "https://kdx.kr/data/product-list?specs_id=MA17200002&corp_id=CORP000036&category_id=CA000002"

# 옵션 설정
chrome_options = Options()
chrome_options.add_argument("--headless")
chrome_options.add_argument("--no-sandbox")
chrome_options.add_argument("--disable-dev-shm-usage")
chrome_options.add_argument("--remote-debugging-port=9222")
chrome_options.binary_location = "/usr/bin/google-chrome"

# 드라이버 경로 설정
service = Service("/usr/bin/chromedriver")

# 드라이버 초기화
driver = webdriver.Chrome(service=service, options=chrome_options)

print(f"접근: {start_url}")
driver.get(start_url)
time.sleep(2)

# 상품 링크 추출
a_tags = driver.find_elements(By.CSS_SELECTOR, "ul.card-list > a")
print(f"세부 링크 개수: {len(a_tags)}")

links = []

for idx, a in enumerate(a_tags, start=1):
    href = a.get_attribute("href")
    if href:
        full_url = base_url + href
        print(f"[{idx}] {full_url}")
        links.append(full_url)

# 첫 번째 상세 페이지 예제 접근
if links:
    driver.get(links[0])
    time.sleep(1.5)

    try:
        purchase_elem = driver.find_element(By.CSS_SELECTOR, "#dataView > div.container > div.detail-wrap > div.item-right > div.purchaseIs > p")
        purchase_amount = purchase_elem.text.strip()
        print(f"\n💰 총 구매금액: {purchase_amount}")
    except:
        print("⚠️ 총 구매금액 정보 없음")

    try:
        schema_elem = driver.find_element(By.CSS_SELECTOR, "#dataView > div.container > div.detail-wrap > div.item-left > div.inner > div.table-wrap.preview_wrap.expand > div.sample_data > table")
        schema_text = schema_elem.text.strip()
        print(f"📄 스키마 요약: {schema_text[:100]}...")
    except:
        print("⚠️ 스키마 정보 없음")

driver.quit()
print("\n✅ Selenium 크롤링 완료")
# Out:
# ---------------------------------------------------------------------------
# WebDriverException                        Traceback (most recent call last)
# /tmp/ipython-input-9-58847391.py in <cell line: 0>()
#      23
#      24 # 드라이버 초기화
# ---> 25 driver = webdriver.Chrome(service=service, options=chrome_options)
#      26
#      27 print(f"접근: {start_url}")
#
# /usr/local/lib/python3.11/dist-packages/selenium/webdriver/chrome/webdriver.py in __init__(self, options, service, keep_alive)
#      45         options = options if options else Options()
#      46
# ---> 47         super().__init__(
#      48             browser_name=DesiredCapabilities.CHROME["browserName"],
#      49             vendor_prefix="goog",
#
# /usr/local/lib/python3.11/dist-packages/selenium/webdriver/chromium/webdriver.py in __init__(self, browser_name, vendor_prefix, options, service, keep_alive)
#      56
#      57         self.service.path = self.service.env_path() or finder.get_driver_path()
# ---> 58         self.service.start()
#      59
#      60         executor = ChromiumRemoteConnection(
#
# /usr/local/lib/python3.11/dist-packages/selenium/webdriver/common/service.py in start(self)
#     104         count = 0
#     105         while True:
# --> 106             self.assert_process_still_running()
#     107             if self.is_connectable():
#     108                 break
#
# /usr/local/lib/python3.11/dist-packages/selenium/webdriver/common/service.py in assert_process_still_running(self)
#     117         return_code = self.process.poll()
#     118         if return_code:
# --> 119             raise WebDriverException(f"Service {self._path} unexpectedly exited. Status code was: {return_code}")
#     120
#     121     def is_connectable(self) -> bool:
#
# WebDriverException: Message: Service /usr/bin/chromedriver unexpectedly exited. Status code was: 1

# %% [markdown]
# # Playwright 기반 크롤링

# %%
# !pip install playwright
# !playwright install
# Out:
# Collecting playwright
#   Downloading playwright-1.53.0-py3-none-manylinux1_x86_64.whl.metadata (3.5 kB)
# Collecting pyee<14,>=13 (from playwright)
#   Downloading pyee-13.0.0-py3-none-any.whl.metadata (2.9 kB)
# Requirement already satisfied: greenlet<4.0.0,>=3.1.1 in /usr/local/lib/python3.11/dist-packages (from playwright) (3.2.3)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.11/dist-packages (from pyee<14,>=13->playwright) (4.13.2)
# Downloading playwright-1.53.0-py3-none-manylinux1_x86_64.whl (45.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 45.8/45.8 MB 21.1 MB/s eta 0:00:00
# Downloading pyee-13.0.0-py3-none-any.whl (15 kB)
# Installing collected packages: pyee, playwright
# Successfully installed playwright-1.53.0 pyee-13.0.0
# Downloading Chromium 138.0.7204.23 (playwright build v1179) from https://cdn.playwright.dev/dbazure/download/playwright/builds/chromium/1179/chromium-linux.zip
# 171.6 MiB [] 0% 0.0s171.6 MiB [] 0% 94.9s171.6 MiB [] 0% 108.1s171.6 MiB [] 0% 71.3s171.6 MiB [] 0% 52.9s171.6 MiB [] 0% 40.6s171.6 MiB [] 0% 31.2s171.6 MiB [] 0% 22.2s171.6 MiB [] 0% 16.0s171.6 MiB [] 1% 11.4s171.6 MiB [] 2% 8.4s171.6 MiB [] 2% 7.0s171.6 MiB [] 3% 6.3s171.6 MiB [] 3% 5.9s171.6 MiB [] 4% 5.5s171.6 MiB [] 4% 5.6s171.6 MiB [] 5% 5.1s171.6 MiB [] 5% 5.5s171.6 MiB [] 6% 4.9s171.6 MiB [] 6% 4.7s171.6 MiB [] 7% 4.4s171.6 MiB [] 7% 4.3s171.6 MiB [] 8% 4.2s171.6 MiB [] 9% 4.0s171.6 MiB [] 10% 3.7s171.6 MiB [] 11% 3.6s171.6 MiB [] 12% 3.4s171.6 MiB [] 13% 3.2s171.6 MiB [] 14% 3.0s171.6 MiB [] 15% 2.9s171.6 MiB [] 16% 2.9s171.6 MiB [] 16% 2.8s171.6 MiB [] 17% 2.7s171.6 MiB [] 18% 2.6s171.6 MiB [] 19% 2.5s171.6 MiB [] 21% 2.4s171.6 MiB [] 21% 2.3s171.6 MiB [] 21% 2.4s171.6 MiB [] 22% 2.4s171.6 MiB [] 23% 2.3s171.6 MiB [] 24% 2.2s171.6 MiB [] 25% 2.1s171.6 MiB [] 27% 2.0s171.6 MiB [] 28% 2.0s171.6 MiB [] 29% 1.9s171.6 MiB [] 30% 1.8s171.6 MiB [] 31% 1.8s171.6 MiB [] 32% 1.7s171.6 MiB [] 33% 
iB [] 20% 1.3s93.7 MiB [] 22% 1.3s93.7 MiB [] 23% 1.2s93.7 MiB [] 24% 1.2s93.7 MiB [] 25% 1.2s93.7 MiB [] 26% 1.2s93.7 MiB [] 27% 1.2s93.7 MiB [] 28% 1.2s93.7 MiB [] 29% 1.1s93.7 MiB [] 30% 1.2s93.7 MiB [] 31% 1.1s93.7 MiB [] 32% 1.1s93.7 MiB [] 33% 1.1s93.7 MiB [] 34% 1.1s93.7 MiB [] 35% 1.1s93.7 MiB [] 36% 1.0s93.7 MiB [] 38% 1.0s93.7 MiB [] 40% 0.9s93.7 MiB [] 41% 0.9s93.7 MiB [] 43% 0.9s93.7 MiB [] 45% 0.8s93.7 MiB [] 46% 0.8s93.7 MiB [] 47% 0.8s93.7 MiB [] 49% 0.8s93.7 MiB [] 51% 0.8s93.7 MiB [] 53% 0.7s93.7 MiB [] 54% 0.7s93.7 MiB [] 55% 0.7s93.7 MiB [] 57% 0.7s93.7 MiB [] 58% 0.7s93.7 MiB [] 61% 0.6s93.7 MiB [] 63% 0.6s93.7 MiB [] 65% 0.5s93.7 MiB [] 66% 0.5s93.7 MiB [] 67% 0.5s93.7 MiB [] 69% 0.5s93.7 MiB [] 71% 0.4s93.7 MiB [] 73% 0.4s93.7 MiB [] 75% 0.4s93.7 MiB [] 77% 0.3s93.7 MiB [] 79% 0.3s93.7 MiB [] 81% 0.3s93.7 MiB [] 83% 0.2s93.7 MiB [] 84% 0.2s93.7 MiB [] 86% 0.2s93.7 MiB [] 88% 0.2s93.7 MiB [] 90% 0.1s93.7 MiB [] 92% 0.1s93.7 MiB [] 94% 0.1s93.7 MiB [] 96% 0.0s93.7 MiB [] 98% 0.0s93.7 MiB [] 100% 0.0s
# Webkit 18.5 (playwright build v2182) downloaded to /root/.cache/ms-playwright/webkit-2182
# Downloading FFMPEG playwright build v1011 from https://cdn.playwright.dev/dbazure/download/playwright/builds/ffmpeg/1011/ffmpeg-linux.zip
# 2.3 MiB [] 0% 0.0s2.3 MiB [] 2% 1.1s2.3 MiB [] 6% 0.8s2.3 MiB [] 12% 0.5s2.3 MiB [] 21% 0.3s2.3 MiB [] 37% 0.2s2.3 MiB [] 58% 0.1s2.3 MiB [] 90% 0.0s2.3 MiB [] 100% 0.0s
# FFMPEG playwright build v1011 downloaded to /root/.cache/ms-playwright/ffmpeg-1011
# Playwright Host validation warning:
# ╔══════════════════════════════════════════════════════╗
# ║ Host system is missing dependencies to run browsers. ║
# ║ Missing libraries:                                   ║
# ║     libwoff2dec.so.1.0.2                             ║
# ║     libgstgl-1.0.so.0                                ║
# ║     libgstcodecparsers-1.0.so.0                      ║
# ║     libavif.so.13                                    ║
# ║     libharfbuzz-icu.so.0                             ║
# ║     libenchant-2.so.2                                ║
# ║     libsecret-1.so.0                                 ║
# ║     libhyphen.so.0                                   ║
# ║     libmanette-0.2.so.0                              ║
# ╚══════════════════════════════════════════════════════╝
#     at validateDependenciesLinux (/usr/local/lib/python3.11/dist-packages/playwright/driver/package/lib/server/registry/dependencies.js:269:9)
#     at process.processTicksAndRejections (node:internal/process/task_queues:105:5)
#     at async Registry._validateHostRequirements (/usr/local/lib/python3.11/dist-packages/playwright/driver/package/lib/server/registry/index.js:927:14)
#     at async Registry._validateHostRequirementsForExecutableIfNeeded (/usr/local/lib/python3.11/dist-packages/playwright/driver/package/lib/server/registry/index.js:1049:7)
#     at async Registry.validateHostRequirementsForExecutablesIfNeeded (/usr/local/lib/python3.11/dist-packages/playwright/driver/package/lib/server/registry/index.js:1038:7)
#     at async t.<anonymous> (/usr/local/lib/python3.11/dist-packages/playwright/driver/package/lib/cli/program.js:217:7)

# %%
import asyncio
from playwright.async_api import async_playwright

base_url = "https://kdx.kr"
start_url = "https://kdx.kr/data/product-list?specs_id=MA17200002&corp_id=CORP000036&category_id=CA000002"

async def run():
    async with async_playwright() as p:
        browser = await p.chromium.launch(headless=True)
        page = await browser.new_page()
        print(f"접근: {start_url}")
        await page.goto(start_url)
        await page.wait_for_timeout(3000)  # 3초 대기

        a_tags = await page.query_selector_all("ul.card-list > a")
        print(f"세부 링크 개수: {len(a_tags)}")

        links = []
        for idx, a in enumerate(a_tags, start=1):
            href = await a.get_attribute("href")
            if href:
                full_url = base_url + href
                print(f"[{idx}] {full_url}")
                links.append(full_url)

        # 첫 번째 상세 페이지 예제
        if links:
            await page.goto(links[0])
            await page.wait_for_timeout(3000)

            try:
                purchase_elem = await page.query_selector("#dataView > div.container > div.detail-wrap > div.item-right > div.purchaseIs > p")
                purchase_amount = await purchase_elem.inner_text()
                print(f"\n💰 총 구매금액: {purchase_amount.strip()}")
            except:
                print("⚠️ 총 구매금액 정보 없음")

            try:
                schema_elem = await page.query_selector("#dataView > div.container > div.detail-wrap > div.item-left > div.inner > div.table-wrap.preview_wrap.expand > div.sample_data > table")
                schema_text = await schema_elem.inner_text()
                print(f"📄 스키마 요약: {schema_text.strip()[:100]}...")
            except:
                print("⚠️ 스키마 정보 없음")

        await browser.close()
        print("\n✅ Playwright 크롤링 완료")

# 코랩 환경에서 asyncio 루프 돌리기
await run()
# Out:
# 접근: https://kdx.kr/data/product-list?specs_id=MA17200002&corp_id=CORP000036&category_id=CA000002
# 세부 링크 개수: 4
# [1] https://kdx.kr/data/view/41601
# [2] https://kdx.kr/data/view/41600
# [3] https://kdx.kr/data/view/41599
# [4] https://kdx.kr/data/view/41475
#
# 💰 총 구매금액: 22,000,000원
# ⚠️ 스키마 정보 없음
#
# ✅ Playwright 크롤링 완료

# %%
import asyncio
from playwright.async_api import async_playwright

base_url = "https://kdx.kr"
start_url = "https://kdx.kr/data/product-list?specs_id=MA17200002&corp_id=CORP000036&category_id=CA000002"

async def run():
    async with async_playwright() as p:
        browser = await p.chromium.launch(headless=True)
        page = await browser.new_page()
        print(f"접근: {start_url}")
        await page.goto(start_url)
        await page.wait_for_timeout(3000)

        a_tags = await page.query_selector_all("ul.card-list > a")
        print(f"세부 링크 개수: {len(a_tags)}")

        links = []
        for idx, a in enumerate(a_tags, start=1):
            href = await a.get_attribute("href")
            if href:
                full_url = base_url + href
                print(f"[{idx}] {full_url}")
                links.append(full_url)

        # ✅ 각 세부 페이지 반복
        for detail_idx, detail_url in enumerate(links, start=1):
            print(f"\n--- [{detail_idx}] 상세 페이지 접근: {detail_url}")
            await page.goto(detail_url)
            await page.wait_for_timeout(2000)

            # 총 구매금액
            try:
                purchase_elem = await page.query_selector("#dataView > div.container > div.detail-wrap > div.item-right > div.purchaseIs > p")
                purchase_amount = await purchase_elem.inner_text()
                print(f"💰 총 구매금액: {purchase_amount.strip()}")
            except:
                purchase_amount = "N/A"
                print("⚠️ 총 구매금액 정보 없음")

            # 데이터 스키마 컬럼 추출
            try:
                th_elements = await page.query_selector_all("#dataView > div.container > div.detail-wrap > div.item-left > div.inner > div.table-wrap.preview_wrap > div.sample_data > table > thead > tr > th")
                schema_columns = []
                for th in th_elements:
                    text = await th.inner_text()
                    schema_columns.append(text.strip())

                schema_text_clean = " | ".join(schema_columns)
                print(f"📄 데이터 스키마(컬럼): {schema_text_clean}")
            except:
                schema_text_clean = "N/A"
                print("⚠️ 데이터 스키마 정보 없음")

        await browser.close()
        print("\n✅ Playwright 크롤링 완료")

await run()
# Out:
# 접근: https://kdx.kr/data/product-list?specs_id=MA17200002&corp_id=CORP000036&category_id=CA000002
# 세부 링크 개수: 4
# [1] https://kdx.kr/data/view/41601
# [2] https://kdx.kr/data/view/41600
# [3] https://kdx.kr/data/view/41599
# [4] https://kdx.kr/data/view/41475
#
# --- [1] 상세 페이지 접근: https://kdx.kr/data/view/41601
# 💰 총 구매금액: 22,000,000원
# 📄 데이터 스키마(컬럼): STD_YM | BLCK_SP_CD | CTPV_CD | CTPV_NM | CTGG_CD | CTGG_NM | ADSTRD_CD | ADSTRD_NM | SEXD_CD | AGGRD_CD | JOBG_CD | TOT_ASST_AMT | NET_ASST_AMT
#
# --- [2] 상세 페이지 접근: https://kdx.kr/data/view/41600
# 💰 총 구매금액: 17,600,000원
# 📄 데이터 스키마(컬럼): STD_YM | BLCK_SP_CD | CTPV_CD | CTPV_NM | CTGG_CD | CTGG_NM | SEXD_CD | AGGRD_CD | JOBG_CD | TOT_ASST_AMT | NET_ASST_AMT
#
# --- [3] 상세 페이지 접근: https://kdx.kr/data/view/41599
# ⚠️ 총 구매금액 정보 없음
# 📄 데이터 스키마(컬럼): STD_YM | BLCK_SP_CD | CTPV_CD | CTPV_NM | TOT_ASST_AMT | NET_ASST_AMT | ONW_HOUS_RATIO | PLU_HOUS_RATIO | APT_RES_RATIO
#
# --- [4] 상세 페이지 접근: https://kdx.kr/data/view/41475
# 💰 총 구매금액: 22,000,000원
# 📄 데이터 스키마(컬럼): STD_YM | BLCK_SP_CD | CTPV_CD | CTPV_NM | CTGG_CD | CTGG_NM | ADSTRD_CD | ADSTRD_NM | SEXD_CD | AGGRD_CD | JOBG_CD | TOT_ASST_AMT | NET_ASST_AMT
#
# ✅ Playwright 크롤링 완료

# %%
import asyncio
import json
import re
from playwright.async_api import async_playwright

base_url = "https://kdx.kr"
start_url = "https://kdx.kr/data/product-list?specs_id=MA17200002&corp_id=CORP000036&category_id=CA000002"

async def run():
    async with async_playwright() as p:
        browser = await p.chromium.launch(headless=True)
        page = await browser.new_page()
        print(f"접근: {start_url}")
        await page.goto(start_url)
        await page.wait_for_timeout(3000)

        a_tags = await page.query_selector_all("ul.card-list > a")
        print(f"세부 링크 개수: {len(a_tags)}")

        links = []
        for idx, a in enumerate(a_tags, start=1):
            href = await a.get_attribute("href")
            if href:
                full_url = base_url + href
                print(f"[{idx}] {full_url}")
                links.append(full_url)

        # 파일 준비
        output_file = "output.jsonl"
        with open(output_file, "w", encoding="utf-8") as f:
            # 각 상세 페이지 접근
            for detail_idx, detail_url in enumerate(links, start=1):
                print(f"\n--- [{detail_idx}] 상세 페이지 접근: {detail_url}")
                await page.goto(detail_url)
                await page.wait_for_timeout(2000)

                # 총 구매금액
                try:
                    purchase_elem = await page.query_selector("#dataView > div.container > div.detail-wrap > div.item-right > div.purchaseIs > p")
                    purchase_text = await purchase_elem.inner_text()
                    # 문자열에서 숫자 추출
                    price_num = int(re.sub(r"[^\d]", "", purchase_text))
                    print(f"💰 총 구매금액(숫자): {price_num}")
                except:
                    price_num = 0
                    print("⚠️ 총 구매금액 정보 없음, 0 처리")

                # 데이터 스키마 컬럼 추출
                try:
                    th_elements = await page.query_selector_all("#dataView > div.container > div.detail-wrap > div.item-left > div.inner > div.table-wrap.preview_wrap > div.sample_data > table > thead > tr > th")
                    schema_columns = []
                    for th in th_elements:
                        text = await th.inner_text()
                        schema_columns.append(text.strip())
                    print(f"📄 컬럼: {schema_columns}")
                except:
                    schema_columns = []
                    print("⚠️ 데이터 스키마 정보 없음, 빈 리스트 처리")

                # JSON 객체 생성
                data = {
                    "columns": schema_columns,
                    "price": price_num
                }

                # 파일에 한 줄씩 기록
                f.write(json.dumps(data, ensure_ascii=False) + "\n")

        await browser.close()
        print(f"\n✅ 크롤링 및 파일 작성 완료! ➜ {output_file}")

await run()
# Out:
# 접근: https://kdx.kr/data/product-list?specs_id=MA17200002&corp_id=CORP000036&category_id=CA000002
# 세부 링크 개수: 4
# [1] https://kdx.kr/data/view/41601
# [2] https://kdx.kr/data/view/41600
# [3] https://kdx.kr/data/view/41599
# [4] https://kdx.kr/data/view/41475
#
# --- [1] 상세 페이지 접근: https://kdx.kr/data/view/41601
# 💰 총 구매금액(숫자): 22000000
# 📄 컬럼: ['STD_YM', 'BLCK_SP_CD', 'CTPV_CD', 'CTPV_NM', 'CTGG_CD', 'CTGG_NM', 'ADSTRD_CD', 'ADSTRD_NM', 'SEXD_CD', 'AGGRD_CD', 'JOBG_CD', 'TOT_ASST_AMT', 'NET_ASST_AMT']
#
# --- [2] 상세 페이지 접근: https://kdx.kr/data/view/41600
# 💰 총 구매금액(숫자): 17600000
# 📄 컬럼: ['STD_YM', 'BLCK_SP_CD', 'CTPV_CD', 'CTPV_NM', 'CTGG_CD', 'CTGG_NM', 'SEXD_CD', 'AGGRD_CD', 'JOBG_CD', 'TOT_ASST_AMT', 'NET_ASST_AMT']
#
# --- [3] 상세 페이지 접근: https://kdx.kr/data/view/41599
# ⚠️ 총 구매금액 정보 없음, 0 처리
# 📄 컬럼: ['STD_YM', 'BLCK_SP_CD', 'CTPV_CD', 'CTPV_NM', 'TOT_ASST_AMT', 'NET_ASST_AMT', 'ONW_HOUS_RATIO', 'PLU_HOUS_RATIO', 'APT_RES_RATIO']
#
# --- [4] 상세 페이지 접근: https://kdx.kr/data/view/41475
# 💰 총 구매금액(숫자): 22000000
# 📄 컬럼: ['STD_YM', 'BLCK_SP_CD', 'CTPV_CD', 'CTPV_NM', 'CTGG_CD', 'CTGG_NM', 'ADSTRD_CD', 'ADSTRD_NM', 'SEXD_CD', 'AGGRD_CD', 'JOBG_CD', 'TOT_ASST_AMT', 'NET_ASST_AMT']
#
# ✅ 크롤링 및 파일 작성 완료! ➜ output.jsonl

# %%
import asyncio
import json
import re
from playwright.async_api import async_playwright

base_url = "https://kdx.kr"
start_url = "https://kdx.kr/data/product-list?specs_id=MA17200002&corp_id=CORP000036&category_id=CA000002"

async def run():
    async with async_playwright() as p:
        browser = await p.chromium.launch(headless=True)
        page = await browser.new_page()
        print(f"접근: {start_url}")
        await page.goto(start_url)
        await page.wait_for_timeout(3000)

        a_tags = await page.query_selector_all("ul.card-list > a")
        print(f"세부 링크 개수: {len(a_tags)}")

        links = []
        for idx, a in enumerate(a_tags, start=1):
            href = await a.get_attribute("href")
            if href:
                full_url = base_url + href
                print(f"[{idx}] {full_url}")
                links.append(full_url)

        output_file = "output.jsonl"
        with open(output_file, "w", encoding="utf-8") as f:
            for detail_idx, detail_url in enumerate(links, start=1):
                print(f"\n--- [{detail_idx}] 상세 페이지 접근: {detail_url}")
                await page.goto(detail_url)
                await page.wait_for_timeout(2000)

                # 총 구매금액
                try:
                    purchase_elem = await page.query_selector("#dataView > div.container > div.detail-wrap > div.item-right > div.purchaseIs > p")
                    purchase_text = await purchase_elem.inner_text()
                    price_num = int(re.sub(r"[^\d]", "", purchase_text))
                    print(f"💰 총 구매금액(숫자): {price_num}")
                except:
                    price_num = 0
                    print("⚠️ 총 구매금액 정보 없음, 0 처리")

                # 데이터 스키마 컬럼 추출
                try:
                    th_elements = await page.query_selector_all("#dataView > div.container > div.detail-wrap > div.item-left > div.inner > div.table-wrap.preview_wrap > div.sample_data > table > thead > tr > th")
                    schema_columns = []
                    for th in th_elements:
                        text = await th.inner_text()
                        schema_columns.append(text.strip())
                    print(f"📄 컬럼: {schema_columns}")
                except:
                    schema_columns = []
                    print("⚠️ 데이터 스키마 정보 없음, 빈 리스트 처리")

                # 상품명
                try:
                    name_elem = await page.query_selector("#dataView > div.container > div.detail-wrap > div.item-left > div.inner > table:nth-child(2) > tbody > tr:nth-child(2) > td")
                    name_text = await name_elem.inner_text()
                except:
                    name_text = "N/A"

                # 카테고리
                try:
                    category_elem = await page.query_selector("#dataView > div.container > div.detail-wrap > div.item-left > div.inner > table:nth-child(2) > tbody > tr:nth-child(1) > td")
                    category_text = await category_elem.inner_text()
                except:
                    category_text = "N/A"

                # 데이터 포맷
                try:
                    format_elem = await page.query_selector("#dataView > div.container > div.detail-wrap > div.item-left > div.inner > table:nth-child(2) > tbody > tr:nth-child(6) > td")
                    format_text = await format_elem.inner_text()
                except:
                    format_text = "N/A"

                # 데이터 사이즈
                try:
                    size_elem = await page.query_selector("#dataView > div.container > div.detail-wrap > div.item-left > div.inner > table:nth-child(2) > tbody > tr:nth-child(7) > td")
                    size_text = await size_elem.inner_text()
                except:
                    size_text = "N/A"

                # JSON 객체 구성
                data = {
                    "columns": schema_columns,
                    "price": price_num,
                    "name": name_text.strip(),
                    "category": category_text.strip(),
                    "format": format_text.strip(),
                    "size": size_text.strip()
                }

                # 파일에 기록
                f.write(json.dumps(data, ensure_ascii=False) + "\n")

        await browser.close()
        print(f"\n✅ 크롤링 및 파일 작성 완료! ➜ {output_file}")

await run()
# Out:
# 접근: https://kdx.kr/data/product-list?specs_id=MA17200002&corp_id=CORP000036&category_id=CA000002
# 세부 링크 개수: 4
# [1] https://kdx.kr/data/view/41601
# [2] https://kdx.kr/data/view/41600
# [3] https://kdx.kr/data/view/41599
# [4] https://kdx.kr/data/view/41475
#
# --- [1] 상세 페이지 접근: https://kdx.kr/data/view/41601
# 💰 총 구매금액(숫자): 22000000
# 📄 컬럼: ['STD_YM', 'BLCK_SP_CD', 'CTPV_CD', 'CTPV_NM', 'CTGG_CD', 'CTGG_NM', 'ADSTRD_CD', 'ADSTRD_NM', 'SEXD_CD', 'AGGRD_CD', 'JOBG_CD', 'TOT_ASST_AMT', 'NET_ASST_AMT']
#
# --- [2] 상세 페이지 접근: https://kdx.kr/data/view/41600
# 💰 총 구매금액(숫자): 17600000
# 📄 컬럼: ['STD_YM', 'BLCK_SP_CD', 'CTPV_CD', 'CTPV_NM', 'CTGG_CD', 'CTGG_NM', 'SEXD_CD', 'AGGRD_CD', 'JOBG_CD', 'TOT_ASST_AMT', 'NET_ASST_AMT']
#
# --- [3] 상세 페이지 접근: https://kdx.kr/data/view/41599
# ⚠️ 총 구매금액 정보 없음, 0 처리
# 📄 컬럼: ['STD_YM', 'BLCK_SP_CD', 'CTPV_CD', 'CTPV_NM', 'TOT_ASST_AMT', 'NET_ASST_AMT', 'ONW_HOUS_RATIO', 'PLU_HOUS_RATIO', 'APT_RES_RATIO']
#
# --- [4] 상세 페이지 접근: https://kdx.kr/data/view/41475
# 💰 총 구매금액(숫자): 22000000
# 📄 컬럼: ['STD_YM', 'BLCK_SP_CD', 'CTPV_CD', 'CTPV_NM', 'CTGG_CD', 'CTGG_NM', 'ADSTRD_CD', 'ADSTRD_NM', 'SEXD_CD', 'AGGRD_CD', 'JOBG_CD', 'TOT_ASST_AMT', 'NET_ASST_AMT']
#
# ✅ 크롤링 및 파일 작성 완료! ➜ output.jsonl

# %%
import asyncio
import json
import re
from playwright.async_api import async_playwright

base_url = "https://kdx.kr"
start_url = "https://kdx.kr/data/product-list?specs_id=MA17200002&corp_id=CORP000036&category_id=CA000002"

async def run():
    async with async_playwright() as p:
        browser = await p.chromium.launch(headless=True)
        page = await browser.new_page()
        await page.goto(start_url)
        await page.wait_for_timeout(3000)

        output_file = "output.jsonl"
        with open(output_file, "w", encoding="utf-8") as f:

            # 페이지네이션 버튼 전체 가져오기
            page_buttons = await page.query_selector_all("#pagination > a.tui-page-btn")
            total_pages = len(page_buttons)
            print(f"총 페이지 개수: {total_pages}")

            # 페이지 순회
            for page_idx in range(1, total_pages + 1):
                print(f"\n✅ [페이지 {page_idx}] 수집 시작")
                await page.wait_for_timeout(2000)

                a_tags = await page.query_selector_all("ul.card-list > a")
                print(f"상품 링크 개수: {len(a_tags)}")

                links = []
                for a in a_tags:
                    href = await a.get_attribute("href")
                    if href:
                        full_url = base_url + href
                        links.append(full_url)

                for detail_idx, detail_url in enumerate(links, start=1):
                    print(f"\n--- [페이지 {page_idx}, 상품 {detail_idx}] 상세 페이지: {detail_url}")
                    await page.goto(detail_url)
                    await page.wait_for_timeout(1500)

                    try:
                        purchase_elem = await page.query_selector("#dataView > div.container > div.detail-wrap > div.item-right > div.purchaseIs > p")
                        purchase_text = await purchase_elem.inner_text()
                        price_num = int(re.sub(r"[^\d]", "", purchase_text))
                    except:
                        price_num = 0

                    try:
                        th_elements = await page.query_selector_all("#dataView > div.container > div.detail-wrap > div.item-left > div.inner > div.table-wrap.preview_wrap > div.sample_data > table > thead > tr > th")
                        schema_columns = [await th.inner_text() for th in th_elements]
                        schema_columns = [col.strip() for col in schema_columns]
                    except:
                        schema_columns = []

                    try:
                        name_elem = await page.query_selector("#dataView > div.container > div.detail-wrap > div.item-left > div.inner > table:nth-child(2) > tbody > tr:nth-child(2) > td")
                        name_text = await name_elem.inner_text()
                    except:
                        name_text = "N/A"

                    try:
                        category_elem = await page.query_selector("#dataView > div.container > div.detail-wrap > div.item-left > div.inner > table:nth-child(2) > tbody > tr:nth-child(1) > td")
                        category_text = await category_elem.inner_text()
                    except:
                        category_text = "N/A"

                    try:
                        format_elem = await page.query_selector("#dataView > div.container > div.detail-wrap > div.item-left > div.inner > table:nth-child(2) > tbody > tr:nth-child(6) > td")
                        format_text = await format_elem.inner_text()
                    except:
                        format_text = "N/A"

                    try:
                        size_elem = await page.query_selector("#dataView > div.container > div.detail-wrap > div.item-left > div.inner > table:nth-child(2) > tbody > tr:nth-child(7) > td")
                        size_text = await size_elem.inner_text()
                    except:
                        size_text = "N/A"

                    data = {
                        "columns": schema_columns,
                        "price": price_num,
                        "name": name_text.strip(),
                        "category": category_text.strip(),
                        "format": format_text.strip(),
                        "size": size_text.strip()
                    }

                    f.write(json.dumps(data, ensure_ascii=False) + "\n")

                    await page.goto(start_url)
                    await page.wait_for_timeout(1500)

                # 다음 페이지 클릭
                if page_idx < total_pages:
                    next_btn = await page.query_selector(f"#pagination > a.tui-page-btn:nth-child({page_idx + 3})")  # index 조정 필요
                    if next_btn:
                        await next_btn.click()
                        await page.wait_for_timeout(3000)
                    else:
                        print("\n⚡ 다음 버튼 없음 — 종료")
                        break

        await browser.close()
        print(f"\n✅ 전체 페이지 크롤링 및 파일 저장 완료 ➜ {output_file}")

await run()
# Out:
# 총 페이지 개수: 7
#
# ✅ [페이지 1] 수집 시작
# 상품 링크 개수: 4
#
# --- [페이지 1, 상품 1] 상세 페이지: https://kdx.kr/data/view/41601
#
# --- [페이지 1, 상품 2] 상세 페이지: https://kdx.kr/data/view/41600
#
# --- [페이지 1, 상품 3] 상세 페이지: https://kdx.kr/data/view/41599
#
# --- [페이지 1, 상품 4] 상세 페이지: https://kdx.kr/data/view/41475
#
# ✅ [페이지 2] 수집 시작
# 상품 링크 개수: 4
#
# --- [페이지 2, 상품 1] 상세 페이지: https://kdx.kr/data/view/41474
#
# --- [페이지 2, 상품 2] 상세 페이지: https://kdx.kr/data/view/41473
#
# --- [페이지 2, 상품 3] 상세 페이지: https://kdx.kr/data/view/41414
#
# --- [페이지 2, 상품 4] 상세 페이지: https://kdx.kr/data/view/41413
#
# ✅ [페이지 3] 수집 시작
# 상품 링크 개수: 4
#
# --- [페이지 3, 상품 1] 상세 페이지: https://kdx.kr/data/view/41412
#
# --- [페이지 3, 상품 2] 상세 페이지: https://kdx.kr/data/view/41287
#
# --- [페이지 3, 상품 3] 상세 페이지: https://kdx.kr/data/view/41286
#
# --- [페이지 3, 상품 4] 상세 페이지: https://kdx.kr/data/view/41285
#
# ✅ [페이지 4] 수집 시작
# 상품 링크 개수: 4
#
# --- [페이지 4, 상품 1] 상세 페이지: https://kdx.kr/data/view/41193
#
# --- [페이지 4, 상품 2] 상세 페이지: https://kdx.kr/data/view/41192
#
# --- [페이지 4, 상품 3] 상세 페이지: https://kdx.kr/data/view/41191
#
# --- [페이지 4, 상품 4] 상세 페이지: https://kdx.kr/data/view/41104
#
# ✅ [페이지 5] 수집 시작
# 상품 링크 개수: 4
#
# --- [페이지 5, 상품 1] 상세 페이지: https://kdx.kr/data/view/41103
#
# --- [페이지 5, 상품 2] 상세 페이지: https://kdx.kr/data/view/41102
#
# --- [페이지 5, 상품 3] 상세 페이지: https://kdx.kr/data/view/41072
#
# --- [페이지 5, 상품 4] 상세 페이지: https://kdx.kr/data/view/41071
#
# ✅ [페이지 6] 수집 시작
# 상품 링크 개수: 4
#
# --- [페이지 6, 상품 1] 상세 페이지: https://kdx.kr/data/view/41070
#
# --- [페이지 6, 상품 2] 상세 페이지: https://kdx.kr/data/view/40968
#
# --- [페이지 6, 상품 3] 상세 페이지: https://kdx.kr/data/view/40967
#
# --- [페이지 6, 상품 4] 상세 페이지: https://kdx.kr/data/view/40966
#
# ✅ [페이지 7] 수집 시작
# 상품 링크 개수: 4
#
# --- [페이지 7, 상품 1] 상세 페이지: https://kdx.kr/data/view/41474
#
# --- [페이지 7, 상품 2] 상세 페이지: https://kdx.kr/data/view/41473
#
# --- [페이지 7, 상품 3] 상세 페이지: https://kdx.kr/data/view/41414
#
# --- [페이지 7, 상품 4] 상세 페이지: https://kdx.kr/data/view/41413
#
# ✅ 전체 페이지 크롤링 및 파일 저장 완료 ➜ output.jsonl

# %%
import asyncio
import json
import re
from playwright.async_api import async_playwright

# ✅ 여기에 직접 제공할 리스트 입력
start_urls = [
    "https://kdx.kr/data/product-list?specs_id=MA17200004&corp_id=CORP000036&category_id=CA000002",
    "https://kdx.kr/data/product-list?specs_id=MA17200003&corp_id=CORP000036&category_id=CA000002",
    "https://kdx.kr/data/product-list?specs_id=MA17200002&corp_id=CORP000036&category_id=CA000002",
    "https://kdx.kr/data/product-list?specs_id=MA17200001&corp_id=CORP000036&category_id=CA000002",
    "https://kdx.kr/data/product-list?specs_id=MA17190001&corp_id=CORP000036&category_id=CA000002",
    "https://kdx.kr/data/product-list?specs_id=MA17190002&corp_id=CORP000036&category_id=CA000002",
    "https://kdx.kr/data/product-list?specs_id=MA17190003&corp_id=CORP000036&category_id=CA000002",
    "https://kdx.kr/data/product-list?specs_id=MA17190004&corp_id=CORP000036&category_id=CA000001%7CCA000002",
    "https://kdx.kr/data/product-list?specs_id=MA08210022&corp_id=CORP000007&category_id=CA000012",
    "https://kdx.kr/data/product-list?specs_id=MA04240002&corp_id=CORP000004&category_id=CA000003",
    "https://kdx.kr/data/product-list?specs_id=MA55230002&corp_id=CORP000048&category_id=CA000003",
    "https://kdx.kr/data/product-list?specs_id=MA55230001&corp_id=CORP000048&category_id=CA000003",
    "https://kdx.kr/data/product-list?specs_id=MA57240003&corp_id=CORP000050&category_id=CA000010",
    "https://kdx.kr/data/product-list?specs_id=MA20230001&corp_id=CORP000017&category_id=CA000001",
    "https://kdx.kr/data/product-list?specs_id=MA57240001&corp_id=CORP000050&category_id=CA000010",
    "https://kdx.kr/data/product-list?specs_id=MA55240002&corp_id=CORP000048&category_id=CA000003",
    "https://kdx.kr/data/product-list?specs_id=MA19220002&corp_id=CORP000016&category_id=CA000001",
    "https://kdx.kr/data/product-list?specs_id=MA54230001&corp_id=CORP000047&category_id=CA000001",
    "https://kdx.kr/data/product-list?specs_id=MA54230003&corp_id=CORP000047&category_id=CA000001",
    "https://kdx.kr/data/product-list?specs_id=MA19220003&corp_id=CORP000016&category_id=CA000001",
    "https://kdx.kr/data/product-list?specs_id=MA19230002&corp_id=CORP000016&category_id=CA000001",
    "https://kdx.kr/data/product-list?specs_id=MA20210011&corp_id=CORP000017&category_id=CA000001",
    "https://kdx.kr/data/product-list?specs_id=MA02200003&corp_id=CORP000002&category_id=CA000004"
]

base_url = "https://kdx.kr"

async def run():
    async with async_playwright() as p:
        browser = await p.chromium.launch(headless=True)
        page = await browser.new_page()

        output_file = "output.jsonl"
        with open(output_file, "w", encoding="utf-8") as f:

            for list_idx, start_url in enumerate(start_urls, start=1):
                print(f"\n✅ [리스트 {list_idx}] URL 접근: {start_url}")
                await page.goto(start_url)
                await page.wait_for_timeout(3000)

                a_tags = await page.query_selector_all("ul.card-list > a")
                print(f"상품 링크 개수: {len(a_tags)}")

                links = []
                for a in a_tags:
                    href = await a.get_attribute("href")
                    if href:
                        full_url = base_url + href
                        links.append(full_url)

                for detail_idx, detail_url in enumerate(links, start=1):
                    print(f"\n--- [리스트 {list_idx}, 상품 {detail_idx}] 상세 페이지: {detail_url}")
                    await page.goto(detail_url)
                    await page.wait_for_timeout(1500)

                    try:
                        purchase_elem = await page.query_selector("#dataView > div.container > div.detail-wrap > div.item-right > div.purchaseIs > p")
                        purchase_text = await purchase_elem.inner_text()
                        price_num = int(re.sub(r"[^\d]", "", purchase_text))
                    except:
                        price_num = 0

                    try:
                        th_elements = await page.query_selector_all("#dataView > div.container > div.detail-wrap > div.item-left > div.inner > div.table-wrap.preview_wrap > div.sample_data > table > thead > tr > th")
                        schema_columns = [await th.inner_text() for th in th_elements]
                        schema_columns = [col.strip() for col in schema_columns]
                    except:
                        schema_columns = []

                    try:
                        name_elem = await page.query_selector("#dataView > div.container > div.detail-wrap > div.item-left > div.inner > table:nth-child(2) > tbody > tr:nth-child(2) > td")
                        name_text = await name_elem.inner_text()
                    except:
                        name_text = "N/A"

                    try:
                        category_elem = await page.query_selector("#dataView > div.container > div.detail-wrap > div.item-left > div.inner > table:nth-child(2) > tbody > tr:nth-child(1) > td")
                        category_text = await category_elem.inner_text()
                    except:
                        category_text = "N/A"

                    try:
                        format_elem = await page.query_selector("#dataView > div.container > div.detail-wrap > div.item-left > div.inner > table:nth-child(2) > tbody > tr:nth-child(6) > td")
                        format_text = await format_elem.inner_text()
                    except:
                        format_text = "N/A"

                    try:
                        size_elem = await page.query_selector("#dataView > div.container > div.detail-wrap > div.item-left > div.inner > table:nth-child(2) > tbody > tr:nth-child(7) > td")
                        size_text = await size_elem.inner_text()
                    except:
                        size_text = "N/A"

                    data = {
                        "columns": schema_columns,
                        "price": price_num,
                        "name": name_text.strip(),
                        "category": category_text.strip(),
                        "format": format_text.strip(),
                        "size": size_text.strip(),
                        "url": detail_url
                    }

                    f.write(json.dumps(data, ensure_ascii=False) + "\n")

        await browser.close()
        print(f"\n✅ 전체 리스트 크롤링 및 파일 저장 완료 ➜ {output_file}")

await run()
# Out:
# ✅ [리스트 1] URL 접근: https://kdx.kr/data/product-list?specs_id=MA17200004&corp_id=CORP000036&category_id=CA000002
# ERROR:asyncio:Future exception was never retrieved
# future: <Future finished exception=TargetClosedError('Target page, context or browser has been closed')>
# playwright._impl._errors.TargetClosedError: Target page, context or browser has been closed
# 상품 링크 개수: 4
#
# --- [리스트 1, 상품 1] 상세 페이지: https://kdx.kr/data/view/41607
#
# --- [리스트 1, 상품 2] 상세 페이지: https://kdx.kr/data/view/41606
#
# --- [리스트 1, 상품 3] 상세 페이지: https://kdx.kr/data/view/41605
#
# --- [리스트 1, 상품 4] 상세 페이지: https://kdx.kr/data/view/41481
#
# ✅ [리스트 2] URL 접근: https://kdx.kr/data/product-list?specs_id=MA17200003&corp_id=CORP000036&category_id=CA000002
# 상품 링크 개수: 4
#
# --- [리스트 2, 상품 1] 상세 페이지: https://kdx.kr/data/view/41604
#
# --- [리스트 2, 상품 2] 상세 페이지: https://kdx.kr/data/view/41603
#
# --- [리스트 2, 상품 3] 상세 페이지: https://kdx.kr/data/view/41602
#
# --- [리스트 2, 상품 4] 상세 페이지: https://kdx.kr/data/view/41478
#
# ✅ [리스트 3] URL 접근: https://kdx.kr/data/product-list?specs_id=MA17200002&corp_id=CORP000036&category_id=CA000002
# 상품 링크 개수: 4
#
# --- [리스트 3, 상품 1] 상세 페이지: https://kdx.kr/data/view/41601
#
# --- [리스트 3, 상품 2] 상세 페이지: https://kdx.kr/data/view/41600
#
# --- [리스트 3, 상품 3] 상세 페이지: https://kdx.kr/data/view/41599
#
# --- [리스트 3, 상품 4] 상세 페이지: https://kdx.kr/data/view/41475
#
# ✅ [리스트 4] URL 접근: https://kdx.kr/data/product-list?specs_id=MA17
URL 접근: https://kdx.kr/data/product-list?specs_id=MA19230002&corp_id=CORP000016&category_id=CA000001
# 상품 링크 개수: 4
#
# --- [리스트 21, 상품 1] 상세 페이지: https://kdx.kr/data/view/39370
#
# --- [리스트 21, 상품 2] 상세 페이지: https://kdx.kr/data/view/39369
#
# --- [리스트 21, 상품 3] 상세 페이지: https://kdx.kr/data/view/39368
#
# --- [리스트 21, 상품 4] 상세 페이지: https://kdx.kr/data/view/39362
#
# ✅ [리스트 22] URL 접근: https://kdx.kr/data/product-list?specs_id=MA20210011&corp_id=CORP000017&category_id=CA000001
# 상품 링크 개수: 2
#
# --- [리스트 22, 상품 1] 상세 페이지: https://kdx.kr/data/view/31884
#
# --- [리스트 22, 상품 2] 상세 페이지: https://kdx.kr/data/view/31216
#
# ✅ [리스트 23] URL 접근: https://kdx.kr/data/product-list?specs_id=MA02200003&corp_id=CORP000002&category_id=CA000004
# 상품 링크 개수: 2
#
# --- [리스트 23, 상품 1] 상세 페이지: https://kdx.kr/data/view/31608
#
# --- [리스트 23, 상품 2] 상세 페이지: https://kdx.kr/data/view/27275
#
# ✅ 전체 리스트 크롤링 및 파일 저장 완료 ➜ output.jsonl

# %%
import asyncio
import json
import re
from playwright.async_api import async_playwright

# ✅ 여기에 직접 제공할 리스트 입력
start_urls = [
    "https://kdx.kr/data/product-list?specs_id=MA17200004&corp_id=CORP000036&category_id=CA000002",
    "https://kdx.kr/data/product-list?specs_id=MA17200003&corp_id=CORP000036&category_id=CA000002",
    "https://kdx.kr/data/product-list?specs_id=MA17200002&corp_id=CORP000036&category_id=CA000002",
    "https://kdx.kr/data/product-list?specs_id=MA17200001&corp_id=CORP000036&category_id=CA000002",
    "https://kdx.kr/data/product-list?specs_id=MA17190001&corp_id=CORP000036&category_id=CA000002",
    "https://kdx.kr/data/product-list?specs_id=MA17190002&corp_id=CORP000036&category_id=CA000002",
    "https://kdx.kr/data/product-list?specs_id=MA17190003&corp_id=CORP000036&category_id=CA000002",
    "https://kdx.kr/data/product-list?specs_id=MA17190004&corp_id=CORP000036&category_id=CA000001%7CCA000002",
    "https://kdx.kr/data/product-list?specs_id=MA08210022&corp_id=CORP000007&category_id=CA000012",
    "https://kdx.kr/data/product-list?specs_id=MA04240002&corp_id=CORP000004&category_id=CA000003",
    "https://kdx.kr/data/product-list?specs_id=MA55230002&corp_id=CORP000048&category_id=CA000003",
    "https://kdx.kr/data/product-list?specs_id=MA55230001&corp_id=CORP000048&category_id=CA000003",
    "https://kdx.kr/data/product-list?specs_id=MA57240003&corp_id=CORP000050&category_id=CA000010",
    "https://kdx.kr/data/product-list?specs_id=MA20230001&corp_id=CORP000017&category_id=CA000001",
    "https://kdx.kr/data/product-list?specs_id=MA57240001&corp_id=CORP000050&category_id=CA000010",
    "https://kdx.kr/data/product-list?specs_id=MA55240002&corp_id=CORP000048&category_id=CA000003",
    "https://kdx.kr/data/product-list?specs_id=MA19220002&corp_id=CORP000016&category_id=CA000001",
    "https://kdx.kr/data/product-list?specs_id=MA54230001&corp_id=CORP000047&category_id=CA000001",
    "https://kdx.kr/data/product-list?specs_id=MA54230003&corp_id=CORP000047&category_id=CA000001",
    "https://kdx.kr/data/product-list?specs_id=MA19220003&corp_id=CORP000016&category_id=CA000001",
    "https://kdx.kr/data/product-list?specs_id=MA19230002&corp_id=CORP000016&category_id=CA000001",
    "https://kdx.kr/data/product-list?specs_id=MA20210011&corp_id=CORP000017&category_id=CA000001",
    "https://kdx.kr/data/product-list?specs_id=MA02200003&corp_id=CORP000002&category_id=CA000004"
]

base_url = "https://kdx.kr"


async def run():
    async with async_playwright() as p:
        browser = await p.chromium.launch(headless=True)
        page = await browser.new_page()

        output_file = "output.jsonl"
        with open(output_file, "w", encoding="utf-8") as f:

            for list_idx, start_url in enumerate(start_urls, start=1):
                print(f"\n✅ [리스트 {list_idx}] URL 접근: {start_url}")
                await page.goto(start_url)
                await page.wait_for_timeout(3000)

                all_links = []

                # 페이지네이션 루프
                while True:
                    a_tags = await page.query_selector_all("ul.card-list > a")
                    print(f"상품 링크 개수 (현재 페이지): {len(a_tags)}")

                    for a in a_tags:
                        href = await a.get_attribute("href")
                        if href:
                            full_url = base_url + href
                            all_links.append(full_url)

                    # 다음 페이지 버튼 확인
                    next_button = await page.query_selector("#pagination > a.tui-page-btn.tui-next > span")
                    if next_button:
                        parent_button = await next_button.evaluate_handle("el => el.parentElement")
                        disabled = await parent_button.get_attribute("class")
                        if disabled and "disabled" in disabled:
                            break
                        await parent_button.click()
                        await page.wait_for_timeout(2000)
                    else:
                        break

                print(f"총 수집된 링크 개수: {len(all_links)}")

                for detail_idx, detail_url in enumerate(all_links, start=1):
                    print(f"\n--- [리스트 {list_idx}, 상품 {detail_idx}] 상세 페이지: {detail_url}")
                    await page.goto(detail_url)
                    await page.wait_for_timeout(1500)

                    try:
                        purchase_elem = await page.query_selector("#dataView > div.container > div.detail-wrap > div.item-right > div.purchaseIs > p")
                        purchase_text = await purchase_elem.inner_text()
                        price_num = int(re.sub(r"[^\d]", "", purchase_text))
                    except:
                        price_num = 0

                    try:
                        th_elements = await page.query_selector_all("#dataView > div.container > div.detail-wrap > div.item-left > div.inner > div.table-wrap.preview_wrap > div.sample_data > table > thead > tr > th")
                        schema_columns = [await th.inner_text() for th in th_elements]
                        schema_columns = [col.strip() for col in schema_columns]
                    except:
                        schema_columns = []

                    try:
                        name_elem = await page.query_selector("#dataView > div.container > div.detail-wrap > div.item-left > div.inner > table:nth-child(2) > tbody > tr:nth-child(2) > td")
                        name_text = await name_elem.inner_text()
                    except:
                        name_text = "N/A"

                    try:
                        category_elem = await page.query_selector("#dataView > div.container > div.detail-wrap > div.item-left > div.inner > table:nth-child(2) > tbody > tr:nth-child(1) > td")
                        category_text = await category_elem.inner_text()
                    except:
                        category_text = "N/A"

                    try:
                        format_elem = await page.query_selector("#dataView > div.container > div.detail-wrap > div.item-left > div.inner > table:nth-child(2) > tbody > tr:nth-child(6) > td")
                        format_text = await format_elem.inner_text()
                    except:
                        format_text = "N/A"

                    try:
                        size_elem = await page.query_selector("#dataView > div.container > div.detail-wrap > div.item-left > div.inner > table:nth-child(2) > tbody > tr:nth-child(7) > td")
                        size_text = await size_elem.inner_text()
                    except:
                        size_text = "N/A"

                    data = {
                        "columns": schema_columns,
                        "price": price_num,
                        "name": name_text.strip(),
                        "category": category_text.strip(),
                        "format": format_text.strip(),
                        "size": size_text.strip(),
                        "url": detail_url
                    }

                    f.write(json.dumps(data, ensure_ascii=False) + "\n")

        await browser.close()
        print(f"\n✅ 전체 리스트 크롤링 및 파일 저장 완료 ➜ {output_file}")

await run()
# Out:
# ✅ [리스트 1] URL 접근: https://kdx.kr/data/product-list?specs_id=MA17200004&corp_id=CORP000036&category_id=CA000002
# 상품 링크 개수 (현재 페이지): 4
# 상품 링크 개수 (현재 페이지): 4
# 상품 링크 개수 (현재 페이지): 4
# 상품 링크 개수 (현재 페이지): 4
# 상품 링크 개수 (현재 페이지): 4
# 상품 링크 개수 (현재 페이지): 4
# 상품 링크 개수 (현재 페이지): 4
# 상품 링크 개수 (현재 페이지): 4
# 상품 링크 개수 (현재 페이지): 4
# 상품 링크 개수 (현재 페이지): 4
# 상품 링크 개수 (현재 페이지): 4
# 상품 링크 개수 (현재 페이지): 4
# 상품 링크 개수 (현재 페이지): 4
# 상품 링크 개수 (현재 페이지): 4
# 상품 링크 개수 (현재 페이지): 4
# 상품 링크 개수 (현재 페이지): 4
# 상품 링크 개수 (현재 페이지): 4
# 상품 링크 개수 (현재 페이지): 4
# 상품 링크 개수 (현재 페이지): 4
# 상품 링크 개수 (현재 페이지): 4
# 상품 링크 개수 (현재 페이지): 4
# 상품 링크 개수 (현재 페이지): 4
# 상품 링크 개수 (현재 페이지): 4
# 상품 링크 개수 (현재 페이지): 4
# 상품 링크 개수 (현재 페이지): 4
# 상품 링크 개수 (현재 페이지): 4
# 상품 링크 개수 (현재 페이지): 4
# 상품 링크 개수 (현재 페이지): 4
# 상품 링크 개수 (현재 페이지): 4
# 상품 링크 개수 (현재 페이지): 4
# 상품 링크 개수 (현재 페이지): 4
# 상품 링크 개수 (현재 페이지): 4
# 상품 링크 개수 (현재 페이지): 4
# 상품 링크 개수 (현재 페이지): 4
# 상품 링크 개수 (현재 페이지): 4
# 상품 링크 개수 (현재 페이지): 4
# 상품 링크 개수 (현재 페이지): 4
# 상품 링크 개수 (현재 페이지): 4
# 상품 링크 개수 (현재 페이지): 4
# 상품 링크 개수 (현재 페이지): 1
# 총 수집된 링크 개수: 157
#
# --- [리스트 1, 상품 1] 상세 페이지: https://kdx.kr/data/view/41607
#
# --- [리스트 1, 상품 2] 상세 페이지: https://kdx.kr/data/view/41606
#
# --- [리스트 1, 상품 3] 상세 페이지: https://kdx.kr/data/view/41605
#
# --- [리스트 1, 상품 4] 상세 페이지: https://kdx.kr/data/view/41481
#
# --- [리스트 1, 상품 5] 상세 페이지: https://kdx.kr/data/view/41480
#
# --- [리스트 1, 상품 6] 상세 페이지: https://kdx.kr/data/view/41479
#
# --- [리스트 1, 상품 7] 상세 페이지: https://kdx.kr/data/view/41420
#
# --- [리스트 1, 상품 8] 상세 페이지: https://kdx.kr/data/view/41419
#
# --- [리스트 1, 상품 9] 상세 페이지: https://kdx.kr/data/view/41418
#
# --- [리스트 1, 상품 10] 상세 페이지: https://kdx.kr/data/view/41293
#
# --- [리스트 1, 상품 11] 상세 페이지: https://kdx.kr/data/view/41292
#
# --- [리스트 1, 상품 12] 상세 페이지: https://kdx.kr/data/view/41291
#
# --- [리스트 1, 상품 13] 상세 페이지: https://kdx.kr/data/view/41199
# 상품 링크 개수 (현재 페이지): 2
# 총 수집된 링크 개수: 2
#
# --- [리스트 23, 상품 1] 상세 페이지: https://kdx.kr/data/view/31608
#
# --- [리스트 23, 상품 2] 상세 페이지: https://kdx.kr/data/view/27275
#
# ✅ 전체 리스트 크롤링 및 파일 저장 완료 ➜ output.jsonl

# %% [markdown]
# # 데이터 시각화 수행

# %%
# ✅ 한글 폰트 설치
# !apt-get update -qq
# !apt-get install -qq fonts-nanum

# ✅ Matplotlib 캐시 삭제 (중요!)
import matplotlib as mpl
import shutil

mpl_dir = mpl.get_cachedir()
print("Matplotlib 캐시 디렉토리:", mpl_dir)
shutil.rmtree(mpl_dir, ignore_errors=True)

# ✅ 런타임 재시작 필요 안내 (Colab 상에서)
print("✅ ⚠️ 폰트 설치 후 Colab 런타임을 '런타임 > 런타임 다시 시작' 메뉴로 재시작하세요!")

# ✅ 이후 재시작 후 아래 코드 실행
# Out:
# W: Skipping acquire of configured file 'main/source/Sources' as repository 'https://r2u.stat.illinois.edu/ubuntu jammy InRelease' does not seem to provide it (sources.list entry misspelt?)
# Matplotlib 캐시 디렉토리: /root/.cache/matplotlib
# ✅ ⚠️ 폰트 설치 후 Colab 런타임을 '런타임 > 런타임 다시 시작' 메뉴로 재시작하세요!

# %%
import matplotlib.pyplot as plt
import matplotlib.font_manager as fm

# ✅ NanumGothic 폰트 경로 확인
font_path = '/usr/share/fonts/truetype/nanum/NanumGothic.ttf'
print("폰트 파일 경로:", font_path)

# ✅ 폰트 전역 설정
plt.rc('font', family='NanumGothic')
plt.rcParams['axes.unicode_minus'] = False

# ✅ 폰트 확인
for f in fm.fontManager.ttflist:
    if 'NanumGothic' in f.name:
        print("✔️ NanumGothic 폰트 로드됨:", f.fname)
# Out:
# 폰트 파일 경로: /usr/share/fonts/truetype/nanum/NanumGothic.ttf
# ✔️ NanumGothic 폰트 로드됨: /usr/share/fonts/truetype/nanum/NanumGothicBold.ttf
# ✔️ NanumGothic 폰트 로드됨: /usr/share/fonts/truetype/nanum/NanumGothicCodingBold.ttf
# ✔️ NanumGothic 폰트 로드됨: /usr/share/fonts/truetype/nanum/NanumGothic.ttf
# ✔️ NanumGothic 폰트 로드됨: /usr/share/fonts/truetype/nanum/NanumGothicCoding.ttf

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import re
import json

# ✅ price 숫자 표기 옵션 설정
import matplotlib.ticker as mticker

# ✅ 구글 드라이브 마운트
from google.colab import drive
drive.mount('/content/drive')

# ✅ JSONL 로드
file_path = '/content/drive/MyDrive/00. 대학원/data-price-20250629-v1.jsonl'

records = []
with open(file_path, 'r', encoding='utf-8') as f:
    for line in f:
        line = line.strip()
        if not line:
            continue
        try:
            json_part = re.search(r'\{.*\}', line)
            if json_part:
                obj = json.loads(json_part.group())
                records.append(obj)
        except json.JSONDecodeError as e:
            print(f"⚠️ JSON 디코드 에러: {e}")
            continue

df = pd.DataFrame(records)

# ✅ 'price' 컬럼 숫자형 변환
df['price'] = pd.to_numeric(df['price'], errors='coerce')

# ✅ 'size' 컬럼 KB 단위로 변환 (개선된 버전)
def convert_size(size_str):
    if isinstance(size_str, str):
        size_str = size_str.strip().upper().replace(",", "")
        # 숫자 추출
        match = re.search(r"[\d.]+", size_str)
        if not match:
            return None
        num = float(match.group())
        if "KB" in size_str:
            return num
        elif "MB" in size_str:
            return num * 1024
        elif "GB" in size_str:
            return num * 1024 * 1024
        elif "B" in size_str:
            return num / 1024
    return None

df['size_kb'] = df['size'].apply(convert_size)

# ✅ 범주형 컬럼 클린업
def clean_category(val):
    if isinstance(val, str):
        val = re.sub(r'[^가-힣a-zA-Z0-9 ]', '', val)
        return val
    return val

df['category'] = df['category'].apply(clean_category)
df['format'] = df['format'].apply(clean_category)

# ✅ 'price' 시각화
plt.figure(figsize=(10, 6))
sns.boxplot(x=df['price'])
plt.title("Price 사분위수(Boxplot)")
plt.gca().xaxis.set_major_formatter(mticker.StrMethodFormatter('{x:,.0f}'))
plt.xlabel("Price")
plt.show()

plt.figure(figsize=(10, 6))
sns.histplot(df['price'].dropna(), kde=True)
plt.title("Price 분포(Histogram)")
plt.gca().xaxis.set_major_formatter(mticker.StrMethodFormatter('{x:,.0f}'))
plt.xlabel("Price")
plt.ylabel("Frequency")
plt.show()

# ✅ 'size_kb' 시각화
plt.figure(figsize=(10, 6))
sns.boxplot(x=df['size_kb'])
plt.title("Size(KB) 사분위수(Boxplot)")
plt.gca().xaxis.set_major_formatter(mticker.StrMethodFormatter('{x:,.0f}'))
plt.xlabel("Size (KB)")
plt.show()

plt.figure(figsize=(10, 6))
sns.histplot(df['size_kb'].dropna(), kde=True)
plt.title("Size(KB) 분포(Histogram)")
plt.gca().xaxis.set_major_formatter(mticker.StrMethodFormatter('{x:,.0f}'))
plt.xlabel("Size (KB)")
plt.ylabel("Frequency")
plt.show()

# ✅ 'category' 시각화
plt.figure(figsize=(10, 6))
order = df['category'].value_counts().index
sns.countplot(y='category', data=df, order=order)
plt.title("Category 빈도수")
plt.xlabel("Count")
plt.ylabel("Category")
plt.show()

# ✅ 'format' 시각화
plt.figure(figsize=(10, 6))
order = df['format'].value_counts().index
sns.countplot(y='format', data=df, order=order)
plt.title("Format 빈도수")
plt.xlabel("Count")
plt.ylabel("Format")
plt.show()

# 기존 size_kb → size_mb 추가
df['size_mb'] = df['size_kb'] / 1024

# ✅ 'size_mb' 시각화
plt.figure(figsize=(10, 6))
sns.boxplot(x=df['size_mb'])
plt.title("Size(MB) 사분위수(Boxplot)")
plt.gca().xaxis.set_major_formatter(mticker.StrMethodFormatter('{x:,.1f}'))
plt.xlabel("Size (MB)")
plt.show()

plt.figure(figsize=(10, 6))
sns.histplot(df['size_mb'].dropna(), kde=True)
plt.title("Size(MB) 분포(Histogram)")
plt.gca().xaxis.set_major_formatter(mticker.StrMethodFormatter('{x:,.1f}'))
plt.xlabel("Size (MB)")
plt.ylabel("Frequency")
plt.show()

# ✅ 상위/하위 10% 제외한 데이터 필터링
lower = df['size_mb'].quantile(0.10)
upper = df['size_mb'].quantile(0.90)
filtered_df = df[(df['size_mb'] >= lower) & (df['size_mb'] <= upper)]

# ✅ 박스플롯 시각화
plt.figure(figsize=(10, 6))
sns.boxplot(x=filtered_df['size_mb'])
plt.title("Size(MB) 사분위수(Boxplot, 상·하단 10% 제외)")
plt.xlabel("Size (MB)")
plt.gca().xaxis.set_major_formatter(mticker.StrMethodFormatter('{x:,.1f}'))
plt.show()


print("\n✅ 시각화 완료!")
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# ✅ 시각화 완료!

# %% [markdown]
# # 20250705 - 1차 기능 수정 및 확인 진행
# - 판매자 정보 및 데이터 상품 상세 정보를 포함하는 데이터 가치를 판단하는데 도움이되는 자료 추가 수집
# - 카테고리, 포맷, 컬럼 등 주요 컬럼의 정규화 => 정규화 사전을 미리 구축 진행
# - 데이터셋의 가격이 어떤 요인에 의해서 결정되는지 파악하기 위하여 카테고리별 및 포맷별 가격 분포 확인

# %%
# !pip install playwright
# !playwright install
# Out:
# Collecting playwright
#   Downloading playwright-1.53.0-py3-none-manylinux1_x86_64.whl.metadata (3.5 kB)
# Collecting pyee<14,>=13 (from playwright)
#   Downloading pyee-13.0.0-py3-none-any.whl.metadata (2.9 kB)
# Requirement already satisfied: greenlet<4.0.0,>=3.1.1 in /usr/local/lib/python3.11/dist-packages (from playwright) (3.2.3)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.11/dist-packages (from pyee<14,>=13->playwright) (4.14.0)
# Downloading playwright-1.53.0-py3-none-manylinux1_x86_64.whl (45.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 45.8/45.8 MB 12.5 MB/s eta 0:00:00
# Downloading pyee-13.0.0-py3-none-any.whl (15 kB)
# Installing collected packages: pyee, playwright
# Successfully installed playwright-1.53.0 pyee-13.0.0
# Downloading Chromium 138.0.7204.23 (playwright build v1179) from https://cdn.playwright.dev/dbazure/download/playwright/builds/chromium/1179/chromium-linux.zip
# 171.6 MiB [] 0% 0.0s171.6 MiB [] 0% 81.7s171.6 MiB [] 0% 86.0s171.6 MiB [] 0% 64.4s171.6 MiB [] 0% 43.8s171.6 MiB [] 0% 30.3s171.6 MiB [] 0% 20.7s171.6 MiB [] 0% 14.2s171.6 MiB [] 1% 9.3s171.6 MiB [] 2% 7.9s171.6 MiB [] 2% 6.6s171.6 MiB [] 3% 5.6s171.6 MiB [] 4% 5.0s171.6 MiB [] 4% 4.7s171.6 MiB [] 4% 4.8s171.6 MiB [] 5% 4.2s171.6 MiB [] 6% 4.0s171.6 MiB [] 7% 3.7s171.6 MiB [] 8% 3.5s171.6 MiB [] 8% 3.3s171.6 MiB [] 9% 3.2s171.6 
from https://cdn.playwright.dev/dbazure/download/playwright/builds/webkit/2182/webkit-ubuntu-22.04.zip
# 93.7 MiB [] 0% 0.0s93.7 MiB [] 0% 44.3s93.7 MiB [] 0% 47.5s93.7 MiB [] 0% 33.3s93.7 MiB [] 0% 23.2s93.7 MiB [] 0% 16.5s93.7 MiB [] 0% 11.5s93.7 MiB [] 1% 7.6s93.7 MiB [] 2% 5.3s93.7 MiB [] 3% 4.0s93.7 MiB [] 5% 2.9s93.7 MiB [] 6% 2.5s93.7 MiB [] 8% 2.2s93.7 MiB [] 9% 2.2s93.7 MiB [] 10% 2.0s93.7 MiB [] 11% 1.9s93.7 MiB [] 12% 1.8s93.7 MiB [] 14% 1.7s93.7 MiB [] 15% 1.6s93.7 MiB [] 16% 1.6s93.7 MiB [] 18% 1.5s93.7 MiB [] 20% 1.4s93.7 MiB [] 22% 1.3s93.7 MiB [] 24% 1.2s93.7 MiB [] 26% 1.1s93.7 MiB [] 28% 1.1s93.7 MiB [] 30% 1.0s93.7 MiB [] 32% 0.9s93.7 MiB [] 34% 0.9s93.7 MiB [] 36% 0.8s93.7 MiB [] 37% 0.8s93.7 MiB [] 39% 0.8s93.7 MiB [] 41% 0.7s93.7 MiB [] 44% 0.7s93.7 MiB [] 46% 0.7s93.7 MiB [] 48% 0.6s93.7 MiB [] 49% 0.6s93.7 MiB [] 51% 0.6s93.7 MiB [] 52% 0.6s93.7 MiB [] 53% 0.6s93.7 MiB [] 55% 0.5s93.7 MiB [] 57% 0.5s93.7 MiB [] 60% 0.5s93.7 MiB [] 62% 0.4s93.7 MiB [] 64% 0.4s93.7 MiB [] 67% 0.4s93.7 MiB [] 69% 0.3s93.7 MiB [] 71% 0.3s93.7 MiB [] 73% 0.3s93.7 MiB [] 75% 0.3s93.7 MiB [] 77% 0.2s93.7 MiB [] 80% 0.2s93.7 MiB [] 82% 0.2s93.7 MiB [] 85% 0.1s93.7 MiB [] 88% 0.1s93.7 MiB [] 90% 0.1s93.7 MiB [] 91% 0.1s93.7 MiB [] 93% 0.1s93.7 MiB [] 95% 0.0s93.7 MiB [] 97% 0.0s93.7 MiB [] 100% 0.0s
# Webkit 18.5 (playwright build v2182) downloaded to /root/.cache/ms-playwright/webkit-2182
# Downloading FFMPEG playwright build v1011 from https://cdn.playwright.dev/dbazure/download/playwright/builds/ffmpeg/1011/ffmpeg-linux.zip
# 2.3 MiB [] 0% 0.0s2.3 MiB [] 2% 0.7s2.3 MiB [] 2% 1.1s2.3 MiB [] 6% 0.7s2.3 MiB [] 12% 0.5s2.3 MiB [] 21% 0.3s2.3 MiB [] 38% 0.2s2.3 MiB [] 66% 0.1s2.3 MiB [] 100% 0.0s
# FFMPEG playwright build v1011 downloaded to /root/.cache/ms-playwright/ffmpeg-1011
# Playwright Host validation warning:
# ╔══════════════════════════════════════════════════════╗
# ║ Host system is missing dependencies to run browsers. ║
# ║ Missing libraries:                                   ║
# ║     libwoff2dec.so.1.0.2                             ║
# ║     libgstgl-1.0.so.0                                ║
# ║     libgstcodecparsers-1.0.so.0                      ║
# ║     libavif.so.13                                    ║
# ║     libharfbuzz-icu.so.0                             ║
# ║     libenchant-2.so.2                                ║
# ║     libsecret-1.so.0                                 ║
# ║     libhyphen.so.0                                   ║
# ║     libmanette-0.2.so.0                              ║
# ╚══════════════════════════════════════════════════════╝
#     at validateDependenciesLinux (/usr/local/lib/python3.11/dist-packages/playwright/driver/package/lib/server/registry/dependencies.js:269:9)
#     at process.processTicksAndRejections (node:internal/process/task_queues:105:5)
#     at async Registry._validateHostRequirements (/usr/local/lib/python3.11/dist-packages/playwright/driver/package/lib/server/registry/index.js:927:14)
#     at async Registry._validateHostRequirementsForExecutableIfNeeded (/usr/local/lib/python3.11/dist-packages/playwright/driver/package/lib/server/registry/index.js:1049:7)
#     at async Registry.validateHostRequirementsForExecutablesIfNeeded (/usr/local/lib/python3.11/dist-packages/playwright/driver/package/lib/server/registry/index.js:1038:7)
#     at async t.<anonymous> (/usr/local/lib/python3.11/dist-packages/playwright/driver/package/lib/cli/program.js:217:7)

# %%
import asyncio
import json
import re
from playwright.async_api import async_playwright

start_urls = [
    "https://kdx.kr/data/product-list?specs_id=MA04240002&corp_id=CORP000004&category_id=CA000003"
]

base_url = "https://kdx.kr"

async def run():
    async with async_playwright() as p:
        browser = await p.chromium.launch(headless=True)
        page = await browser.new_page()

        output_file = "output.jsonl"
        with open(output_file, "w", encoding="utf-8") as f:

            for list_idx, start_url in enumerate(start_urls, start=1):
                print(f"\n✅ [리스트 {list_idx}] URL 접근: {start_url}")
                await page.goto(start_url)
                await page.wait_for_timeout(3000)

                all_links = []

                # 페이지네이션 루프
                while True:
                    a_tags = await page.query_selector_all("ul.card-list > a")
                    print(f"상품 링크 개수 (현재 페이지): {len(a_tags)}")

                    for a in a_tags:
                        href = await a.get_attribute("href")
                        if href:
                            full_url = base_url + href
                            all_links.append(full_url)

                    # 다음 페이지 버튼 확인
                    next_button = await page.query_selector("#pagination > a.tui-page-btn.tui-next > span")
                    if next_button:
                        parent_button = await next_button.evaluate_handle("el => el.parentElement")
                        disabled = await parent_button.get_attribute("class")
                        if disabled and "disabled" in disabled:
                            break
                        await parent_button.click()
                        await page.wait_for_timeout(2000)
                    else:
                        break

                print(f"총 수집된 링크 개수: {len(all_links)}")

                for detail_idx, detail_url in enumerate(all_links, start=1):
                    print(f"\n--- [리스트 {list_idx}, 상품 {detail_idx}] 상세 페이지: {detail_url}")
                    await page.goto(detail_url)
                    await page.wait_for_timeout(1500)

                    try:
                        purchase_elem = await page.query_selector("#dataView > div.container > div.detail-wrap > div.item-right > div.purchaseIs > p")
                        purchase_text = await purchase_elem.inner_text()
                        price_num = int(re.sub(r"[^\d]", "", purchase_text))
                    except:
                        price_num = 0

                    try:
                        th_elements = await page.query_selector_all("#dataView > div.container > div.detail-wrap > div.item-left > div.inner > div.table-wrap.preview_wrap > div.sample_data > table > thead > tr > th")
                        schema_columns = [await th.inner_text() for th in th_elements]
                        schema_columns = [col.strip() for col in schema_columns]
                    except:
                        schema_columns = []

                    try:
                        name_elem = await page.query_selector("#dataView > div.container > div.detail-wrap > div.item-left > div.inner > table:nth-child(2) > tbody > tr:nth-child(2) > td")
                        name_text = await name_elem.inner_text()
                    except:
                        name_text = "N/A"

                    try:
                        category_elem = await page.query_selector("#dataView > div.container > div.detail-wrap > div.item-left > div.inner > table:nth-child(2) > tbody > tr:nth-child(1) > td")
                        category_text = await category_elem.inner_text()
                    except:
                        category_text = "N/A"

                    try:
                        format_elem = await page.query_selector("#dataView > div.container > div.detail-wrap > div.item-left > div.inner > table:nth-child(2) > tbody > tr:nth-child(6) > td")
                        format_text = await format_elem.inner_text()
                    except:
                        format_text = "N/A"

                    try:
                        size_elem = await page.query_selector("#dataView > div.container > div.detail-wrap > div.item-left > div.inner > table:nth-child(2) > tbody > tr:nth-child(7) > td")
                        size_text = await size_elem.inner_text()
                    except:
                        size_text = "N/A"

                    # ✅ 상품요약
                    try:
                        summary_elem = await page.query_selector("#dataView > div.container > div.detail-wrap > div.item-left > div.inner > table:nth-child(2) > tbody > tr:nth-child(3) > td")
                        summary_text = await summary_elem.inner_text()
                    except:
                        summary_text = "N/A"

                    # ✅ 상품상세
                    try:
                        detail_elem = await page.query_selector("#dataView > div.container > div.detail-wrap > div.item-left > div.inner > table:nth-child(2) > tbody > tr:nth-child(4) > td")
                        detail_text = await detail_elem.inner_text()
                    except:
                        detail_text = "N/A"

                    # ✅ 판매자
                    try:
                        seller_elem = await page.query_selector("#dataView > div.container > div.detail-wrap > div.item-left > div.inner > table:nth-child(4) > tbody > tr:nth-child(1) > td")
                        seller_text = await seller_elem.inner_text()
                    except:
                        seller_text = "N/A"

                    # ✅ 상품등록일
                    try:
                        reg_elem = await page.query_selector("#dataView > div.container > div.detail-wrap > div.item-right > div.info > div:nth-child(6) > span")
                        reg_text = await reg_elem.inner_text()
                    except:
                        reg_text = "N/A"

                    # ✅ 상품수정일
                    try:
                        mod_elem = await page.query_selector("#dataView > div.container > div.detail-wrap > div.item-right > div.info > div:nth-child(7) > span")
                        mod_text = await mod_elem.inner_text()
                    except:
                        mod_text = "N/A"

                    data = {
                        "columns": schema_columns,
                        "price": price_num,
                        "name": name_text.strip(),
                        "category": category_text.strip(),
                        "format": format_text.strip(),
                        "size": size_text.strip(),
                        "summary": summary_text.strip(),
                        "detail": detail_text.strip(),
                        "seller": seller_text.strip(),
                        "register_date": reg_text.strip(),
                        "modify_date": mod_text.strip(),
                        "url": detail_url
                    }

                    f.write(json.dumps(data, ensure_ascii=False) + "\n")

        await browser.close()
        print(f"\n✅ 전체 리스트 크롤링 및 파일 저장 완료 ➜ {output_file}")

await run()
# Out:
# ✅ [리스트 1] URL 접근: https://kdx.kr/data/product-list?specs_id=MA04240002&corp_id=CORP000004&category_id=CA000003
# 상품 링크 개수 (현재 페이지): 2
# 총 수집된 링크 개수: 2
#
# --- [리스트 1, 상품 1] 상세 페이지: https://kdx.kr/data/view/41422
#
# --- [리스트 1, 상품 2] 상세 페이지: https://kdx.kr/data/view/41421
#
# ✅ 전체 리스트 크롤링 및 파일 저장 완료 ➜ output.jsonl

# %%
import asyncio
import json
import re
from playwright.async_api import async_playwright

start_urls = [
    "https://kdx.kr/data/product-list?specs_id=MA04240002&corp_id=CORP000004&category_id=CA000003"
    # 필요 시 추가
]

base_url = "https://kdx.kr"

async def run():
    async with async_playwright() as p:
        browser = await p.chromium.launch(headless=True)
        page = await browser.new_page()

        output_file = "output.jsonl"
        with open(output_file, "w", encoding="utf-8") as f:

            for list_idx, start_url in enumerate(start_urls, start=1):
                print(f"\n✅ [리스트 {list_idx}] URL 접근: {start_url}")
                await page.goto(start_url)
                await page.wait_for_timeout(3000)

                all_links = []

                # 페이지네이션 루프
                while True:
                    a_tags = await page.query_selector_all("ul.card-list > a")
                    print(f"상품 링크 개수 (현재 페이지): {len(a_tags)}")

                    for a in a_tags:
                        href = await a.get_attribute("href")
                        if href:
                            full_url = base_url + href
                            all_links.append(full_url)

                    # 다음 페이지 버튼 확인
                    next_button = await page.query_selector("#pagination > a.tui-page-btn.tui-next > span")
                    if next_button:
                        parent_button = await next_button.evaluate_handle("el => el.parentElement")
                        disabled = await parent_button.get_attribute("class")
                        if disabled and "disabled" in disabled:
                            break
                        await parent_button.click()
                        await page.wait_for_timeout(2000)
                    else:
                        break

                print(f"총 수집된 링크 개수: {len(all_links)}")

                for detail_idx, detail_url in enumerate(all_links, start=1):
                    print(f"\n--- [리스트 {list_idx}, 상품 {detail_idx}] 상세 페이지: {detail_url}")
                    await page.goto(detail_url)
                    await page.wait_for_timeout(1500)

                    # ✅ 가격 파싱 로직
                    price_num = None
                    min_price = None
                    max_price = None
                    price_type = "고정"

                    try:
                        purchase_elem = await page.query_selector("#dataView > div.container > div.detail-wrap > div.item-right > div.purchaseIs > p")
                        price_text = await purchase_elem.inner_text()

                        if "무료" in price_text:
                            price_num = 0
                            price_type = "무료"
                        elif "협의" in price_text:
                            price_type = "협의"
                        elif "~" in price_text:
                            price_range = re.findall(r"[\d,]+", price_text)
                            if len(price_range) == 2:
                                min_price = int(price_range[0].replace(",", ""))
                                max_price = int(price_range[1].replace(",", ""))
                                price_num = (min_price + max_price) // 2
                                price_type = "범위"
                        else:
                            num_match = re.search(r"[\d,]+", price_text)
                            if num_match:
                                price_num = int(num_match.group(0).replace(",", ""))
                    except:
                        price_num = None
                        price_type = "에러"

                    # ✅ 스키마 컬럼
                    try:
                        th_elements = await page.query_selector_all("#dataView > div.container > div.detail-wrap > div.item-left > div.inner > div.table-wrap.preview_wrap > div.sample_data > table > thead > tr > th")
                        schema_columns = [await th.inner_text() for th in th_elements]
                        schema_columns = [col.strip() for col in schema_columns]
                    except:
                        schema_columns = []

                    try:
                        name_elem = await page.query_selector("#dataView > div.container > div.detail-wrap > div.item-left > div.inner > table:nth-child(2) > tbody > tr:nth-child(2) > td")
                        name_text = await name_elem.inner_text()
                    except:
                        name_text = "N/A"

                    try:
                        category_elem = await page.query_selector("#dataView > div.container > div.detail-wrap > div.item-left > div.inner > table:nth-child(2) > tbody > tr:nth-child(1) > td")
                        category_text = await category_elem.inner_text()
                    except:
                        category_text = "N/A"

                    try:
                        format_elem = await page.query_selector("#dataView > div.container > div.detail-wrap > div.item-left > div.inner > table:nth-child(2) > tbody > tr:nth-child(6) > td")
                        format_text = await format_elem.inner_text()
                    except:
                        format_text = "N/A"

                    try:
                        size_elem = await page.query_selector("#dataView > div.container > div.detail-wrap > div.item-left > div.inner > table:nth-child(2) > tbody > tr:nth-child(7) > td")
                        size_text = await size_elem.inner_text()
                    except:
                        size_text = "N/A"

                    try:
                        summary_elem = await page.query_selector("#dataView > div.container > div.detail-wrap > div.item-left > div.inner > table:nth-child(2) > tbody > tr:nth-child(3) > td")
                        summary_text = await summary_elem.inner_text()
                    except:
                        summary_text = "N/A"

                    try:
                        detail_elem = await page.query_selector("#dataView > div.container > div.detail-wrap > div.item-left > div.inner > table:nth-child(2) > tbody > tr:nth-child(4) > td")
                        detail_text = await detail_elem.inner_text()
                    except:
                        detail_text = "N/A"

                    try:
                        seller_elem = await page.query_selector("#dataView > div.container > div.detail-wrap > div.item-left > div.inner > table:nth-child(4) > tbody > tr:nth-child(1) > td")
                        seller_text = await seller_elem.inner_text()
                    except:
                        seller_text = "N/A"

                    try:
                        reg_elem = await page.query_selector("#dataView > div.container > div.detail-wrap > div.item-right > div.info > div:nth-child(6) > span")
                        reg_text = await reg_elem.inner_text()
                    except:
                        reg_text = "N/A"

                    try:
                        mod_elem = await page.query_selector("#dataView > div.container > div.detail-wrap > div.item-right > div.info > div:nth-child(7) > span")
                        mod_text = await mod_elem.inner_text()
                    except:
                        mod_text = "N/A"

                    data = {
                        "price_num": price_num,
                        "min_price": min_price,
                        "max_price": max_price,
                        "price_type": price_type,
                        "columns": schema_columns,
                        "name": name_text.strip(),
                        "category": category_text.strip(),
                        "format": format_text.strip(),
                        "size": size_text.strip(),
                        "summary": summary_text.strip(),
                        "detail": detail_text.strip(),
                        "seller": seller_text.strip(),
                        "register_date": reg_text.strip(),
                        "modify_date": mod_text.strip(),
                        "url": detail_url
                    }

                    f.write(json.dumps(data, ensure_ascii=False) + "\n")

        await browser.close()
        print(f"\n✅ 전체 리스트 크롤링 및 파일 저장 완료 ➜ {output_file}")

await run()
# Out:
# ✅ [리스트 1] URL 접근: https://kdx.kr/data/product-list?specs_id=MA04240002&corp_id=CORP000004&category_id=CA000003
# 상품 링크 개수 (현재 페이지): 2
# 총 수집된 링크 개수: 2
#
# --- [리스트 1, 상품 1] 상세 페이지: https://kdx.kr/data/view/41422
#
# --- [리스트 1, 상품 2] 상세 페이지: https://kdx.kr/data/view/41421
#
# ✅ 전체 리스트 크롤링 및 파일 저장 완료 ➜ output.jsonl

# %%
import asyncio
import json
import re
from datetime import datetime
from playwright.async_api import async_playwright

start_urls = [
    "https://kdx.kr/data/product-list?specs_id=MA08210022&corp_id=CORP000007&category_id=CA000012",
    "https://kdx.kr/data/product-list?specs_id=MA54230003&corp_id=CORP000047&category_id=CA000001",
    "https://kdx.kr/data/product-list?specs_id=MA54230001&corp_id=CORP000047&category_id=CA000001",
    "https://kdx.kr/data/product-list?specs_id=MA17220002&corp_id=CORP000036&category_id=CA000001%7CCA000002",
    "https://kdx.kr/data/product-list?specs_id=MA17190004&corp_id=CORP000036&category_id=CA000001%7CCA000002",
    "https://kdx.kr/data/product-list?specs_id=MA17200002&corp_id=CORP000036&category_id=CA000002",
    "https://kdx.kr/data/product-list?specs_id=MA55230002&corp_id=CORP000048&category_id=CA000003",
    "https://kdx.kr/data/product-list?specs_id=MA55230001&corp_id=CORP000048&category_id=CA000003",
    "https://kdx.kr/data/product-list?specs_id=MA04240002&corp_id=CORP000004&category_id=CA000003",
    "https://kdx.kr/data/product-list?specs_id=MA56240001&corp_id=CORP000049&category_id=CA000004",
    "https://kdx.kr/data/product-list?specs_id=MA38210002&corp_id=CORP000024&category_id=CA000005",
    "https://kdx.kr/data/product-list?specs_id=MA02190001&corp_id=CORP000002&category_id=CA000004%7CCA000006",
    "https://kdx.kr/data/product-list?specs_id=MA15190001&corp_id=CORP000035&category_id=CA000008",
    "https://kdx.kr/data/product-list?specs_id=MA08210022&corp_id=CORP000007&category_id=CA000012",
    "https://kdx.kr/data/product-list?specs_id=MA58240001&corp_id=CORP000051&category_id=CA000013",
    "https://kdx.kr/data/product-list?specs_id=MA57240002&corp_id=CORP000050&category_id=CA000010",
    "https://kdx.kr/data/product-list?specs_id=MA57240003&corp_id=CORP000050&category_id=CA000010",
    "https://kdx.kr/data/product-list?specs_id=MA57240001&corp_id=CORP000050&category_id=CA000010",
    "https://kdx.kr/data/product-list?specs_id=MA08230002&corp_id=CORP000007&category_id=CA000014%7CCA000015",
    "https://kdx.kr/data/product-list?specs_id=MA15190002&corp_id=CORP000035&category_id=CA000008",
    "https://kdx.kr/data/product-list?specs_id=MA17190001&corp_id=CORP000036&category_id=CA000002",
    "https://kdx.kr/data/product-list?specs_id=MA17190002&corp_id=CORP000036&category_id=CA000002"
]

base_url = "https://kdx.kr"

async def run():
    async with async_playwright() as p:
        browser = await p.chromium.launch(headless=True)
        page = await browser.new_page()

        # 파일명에 시간 정보 추가 - 연월일시분
        now_str = datetime.now().strftime("%Y%m%d%H%M")
        output_file = f"output-{now_str}.jsonl"
        print(f"출력 파일: {output_file}")
        with open(output_file, "w", encoding="utf-8") as f:

            for list_idx, start_url in enumerate(start_urls, start=1):
                print(f"\n✅ [리스트 {list_idx}] URL 접근: {start_url}")
                await page.goto(start_url)
                await page.wait_for_timeout(3000)

                all_links = []

                # 페이지네이션 루프
                while True:
                    a_tags = await page.query_selector_all("ul.card-list > a")
                    print(f"상품 링크 개수 (현재 페이지): {len(a_tags)}")

                    for a in a_tags:
                        href = await a.get_attribute("href")
                        if href:
                            full_url = base_url + href
                            all_links.append(full_url)

                    next_button = await page.query_selector("#pagination > a.tui-page-btn.tui-next > span")
                    if next_button:
                        parent_button = await next_button.evaluate_handle("el => el.parentElement")
                        disabled = await parent_button.get_attribute("class")
                        if disabled and "disabled" in disabled:
                            break
                        await parent_button.click()
                        await page.wait_for_timeout(2000)
                    else:
                        break

                print(f"총 수집된 링크 개수: {len(all_links)}")

                for detail_idx, detail_url in enumerate(all_links, start=1):
                    print(f"\n--- [리스트 {list_idx}, 상품 {detail_idx}] 상세 페이지: {detail_url}")
                    await page.goto(detail_url)
                    await page.wait_for_timeout(1500)

                    # ✅ 가격 처리
                    price_num = None
                    price_type = "고정"

                    try:
                        # 해당 태그는 가격이 1개거나, 무료, 협의의 경우 태그에 해당
                        purchase_elem = await page.query_selector("#dataView > div.container > div.detail-wrap > div.item-right > div.purchaseIs > p")

                        if purchase_elem is None: # 값이 없으면 범위에 해당하는 가격으로 적용
                            purchase_elem = await page.query_selector("#dataView > div.container > div.detail-wrap > div.item-right > div.purchase > p")
                            print("⚠️ 기본 selector에 없음 — 범위 selector 사용")

                        if purchase_elem is None:
                            print("⚠️ 가격 정보 없음 — purchase_elem is None")
                            price_num = None
                            price_type = "에러"
                        else:
                            price_text = await purchase_elem.inner_text()
                            # price_text = re.sub(r"\s+", "", price_text)
                            # print(f">>> price_text 전처리 후: [{price_text}]")

                            if "무료" in price_text:
                                price_num = 0
                                price_type = "무료"
                            elif "협의" in price_text:
                                price_num = 0
                                price_type = "협의"
                            elif "~" in price_text:
                                price_num = price_text
                                price_type = "범위"
                            else:
                                num_match = re.search(r"[\d,]+", price_text)
                                if num_match:
                                    price_num = int(num_match.group(0).replace(",", ""))
                    except Exception as e:
                        print(f"⚠️ 가격 파싱 오류: {e}")
                        price_num = None
                        price_type = "에러"


                    # ✅ 스키마 컬럼
                    try:
                        th_elements = await page.query_selector_all("#dataView > div.container > div.detail-wrap > div.item-left > div.inner > div.table-wrap.preview_wrap > div.sample_data > table > thead > tr > th")
                        schema_columns = [await th.inner_text() for th in th_elements]
                        schema_columns = [col.strip() for col in schema_columns]
                    except:
                        schema_columns = []

                    try:
                        name_elem = await page.query_selector("#dataView > div.container > div.detail-wrap > div.item-left > div.inner > table:nth-child(2) > tbody > tr:nth-child(2) > td")
                        name_text = await name_elem.inner_text()
                    except:
                        name_text = "N/A"

                    try:
                        category_elem = await page.query_selector("#dataView > div.container > div.detail-wrap > div.item-left > div.inner > table:nth-child(2) > tbody > tr:nth-child(1) > td")
                        category_text = await category_elem.inner_text()
                    except:
                        category_text = "N/A"

                    try:
                        format_elem = await page.query_selector("#dataView > div.container > div.detail-wrap > div.item-left > div.inner > table:nth-child(2) > tbody > tr:nth-child(6) > td")
                        format_text = await format_elem.inner_text()
                    except:
                        format_text = "N/A"

                    try:
                        size_elem = await page.query_selector("#dataView > div.container > div.detail-wrap > div.item-left > div.inner > table:nth-child(2) > tbody > tr:nth-child(7) > td")
                        size_text = await size_elem.inner_text()
                    except:
                        size_text = "N/A"

                    try:
                        summary_elem = await page.query_selector("#dataView > div.container > div.detail-wrap > div.item-left > div.inner > table:nth-child(2) > tbody > tr:nth-child(3) > td")
                        summary_text = await summary_elem.inner_text()
                    except:
                        summary_text = "N/A"

                    try:
                        detail_elem = await page.query_selector("#dataView > div.container > div.detail-wrap > div.item-left > div.inner > table:nth-child(2) > tbody > tr:nth-child(4) > td")
                        detail_text = await detail_elem.inner_text()
                    except:
                        detail_text = "N/A"

                    try:
                        seller_elem = await page.query_selector("#dataView > div.container > div.detail-wrap > div.item-left > div.inner > table:nth-child(4) > tbody > tr:nth-child(1) > td")
                        seller_text = await seller_elem.inner_text()
                    except:
                        seller_text = "N/A"

                    try:
                        reg_elem = await page.query_selector("#dataView > div.container > div.detail-wrap > div.item-right > div.info > div:nth-child(6) > span")
                        reg_text = await reg_elem.inner_text()
                    except:
                        reg_text = "N/A"

                    try:
                        mod_elem = await page.query_selector("#dataView > div.container > div.detail-wrap > div.item-right > div.info > div:nth-child(7) > span")
                        mod_text = await mod_elem.inner_text()
                    except:
                        mod_text = "N/A"

                    # ✅ 태그 정보
                    try:
                        tag_elements = await page.query_selector_all(
                            "#dataView > div.container > div.detail-wrap > div.item-right > div.info > div.tag div.tag[data-text]"
                        )
                        tag_list = []
                        for tag in tag_elements:
                            data_text = await tag.get_attribute("data-text")
                            if data_text and data_text.strip():
                                tag_list.append(data_text.strip())
                    except:
                        tag_list = []


                    # ✅ 데이터 딕셔너리
                    data = {
                        "price_num": price_num,
                        "price_type": price_type,
                        "columns": schema_columns,
                        "name": name_text.strip(),
                        "category": category_text.strip(),
                        "format": format_text.strip(),
                        "size": size_text.strip(),
                        "summary": summary_text.strip(),
                        "detail": detail_text.strip(),
                        "seller": seller_text.strip(),
                        "register_date": reg_text.strip(),
                        "modify_date": mod_text.strip(),
                        "tags": tag_list,
                        "url": detail_url
                    }

                    f.write(json.dumps(data, ensure_ascii=False) + "\n")

        await browser.close()
        print(f"\n✅ 전체 리스트 크롤링 및 파일 저장 완료 ➜ {output_file}")

await run()
# Out:
# ERROR:asyncio:Future exception was never retrieved
# future: <Future finished exception=TargetClosedError('Target page, context or browser has been closed')>
# playwright._impl._errors.TargetClosedError: Target page, context or browser has been closed
# 출력 파일: output-202507051508.jsonl
#
# ✅ [리스트 1] URL 접근: https://kdx.kr/data/product-list?specs_id=MA08210022&corp_id=CORP000007&category_id=CA000012
# 상품 링크 개수 (현재 페이지): 4
# 상품 링크 개수 (현재 페이지): 4
# 상품 링크 개수 (현재 페이지): 4
# 상품 링크 개수 (현재 페이지): 4
# 상품 링크 개수 (현재 페이지): 4
# 상품 링크 개수 (현재 페이지): 4
# 상품 링크 개수 (현재 페이지): 4
# 상품 링크 개수 (현재 페이지): 4
# 상품 링크 개수 (현재 페이지): 4
# 상품 링크 개수 (현재 페이지): 4
# 상품 링크 개수 (현재 페이지): 4
# 상품 링크 개수 (현재 페이지): 4
# 상품 링크 개수 (현재 페이지): 4
# 상품 링크 개수 (현재 페이지): 4
# 상품 링크 개수 (현재 페이지): 4
# 상품 링크 개수 (현재 페이지): 4
# 상품 링크 개수 (현재 페이지): 4
# 상품 링크 개수 (현재 페이지): 4
# 상품 링크 개수 (현재 페이지): 4
# 상품 링크 개수 (현재 페이지): 2
# 총 수집된 링크 개수: 78
#
# --- [리스트 1, 상품 1] 상세 페이지: https://kdx.kr/data/view/41583
# ⚠️ 기본 selector에 없음 — 범위 selector 사용
#
# --- [리스트 1, 상품 2] 상세 페이지: https://kdx.kr/data/view/41582
# ⚠️ 기본 selector에 없음 — 범위 selector 사용
#
# --- [리스트 1, 상품 3] 상세 페이지: https://kdx.kr/data/view/41581
# ⚠️ 기본 selector에 없음 — 범위 selector 사용
#
# --- [리스트 1, 상품 4] 상세 페이지: https://kdx.kr/data/view/41580
# ⚠️ 기본 selector에 없음 — 범위 selector 사용
#
# --- [리스트 1, 상품 5] 상세 페이지: https://kdx.kr/data/view/41579
# ⚠️ 기본 selector에 없음 — 범위 selector 사용
#
# --- [리스트 1, 상품 6] 상세 페이지: https://kdx.kr/data/view/41578
# ⚠️ 기본 selector에 없음 — 범위 selector 사용
#
# --- [리스트 1, 상품 7] 상세 페이지: https://kdx.kr/data/view/41577
# ⚠️ 기본 selector에 없음 — 범위 selector 사용
#
# --- [리스트 1, 상품 8] 상세 페이지: https://kdx.kr/data/view/41576
# ⚠️ 기본 selector에 없음 — 범위 selector 사용
#
# --- [리스트 1, 상품 9] 상세 페이지: https://kdx.kr/data/view/41575
# ⚠️ 기본 selector에 없음 — 범위 selector 사용
#
# --- [리스트 1, 상품 10] 상세 페이지: https://kdx.kr/data/view/41574
# ⚠️ 기본 selector에 없음 — 범위 selector 사용
#
# --- [리스트 1, 상품 11] 상세 페이지: https://kdx.kr/data/view/41573
# ⚠️ 기본 selector에 없음 — 범위 selector 사용
#
# --- [리스트 1, 상품 12] 상세 페이지: https://kdx.kr/data/view/41572
# ⚠️ 기본 selector에 없음 — 범위 selector 사용
#
# --- [리스트 1, 상품 13] 상세 페이지: https://kdx.kr/data/view/41571
# ⚠️ 기본 selector에 없음 — 범위 selector 사용
#
# --- [리스트 1, 상품 14] 상세 페이지: https://kdx.kr/data/view/41570
# ⚠️ 기본 selector에 없음 — 범위 selector 사용
#
# --- [리스트 1, 상품 15] 상세 페이지: https://kdx.kr/data/view/41569
# ⚠️ 기본 selector에 없음 — 범위 selector 사용
#
# --- [리스트 1, 상품 16] 상세 페이지: https://kdx.kr/data/view/41568
# ⚠️ 기본 selector에 없음 — 범위 selector 사용
#
# --- [리스트 1, 상품 17] 상세 페이지: https://kdx.kr/data/view/41567
# ⚠️ 기본 selector에 없음 — 범위 selector 사용
#
# --- [리스트 1, 상품 18] 상세 페이지: https://kdx.kr/data/view/41566
# ⚠️ 기본 selector에 없음 — 범위 selector 사용
#
# --- [리스트 1, 상품 19] 상세 페이지: https://kdx.kr/data/view/41565
# ⚠️ 기본 selector에 없음 — 범위 selector 사용
#
# --- [리스트 1, 상품 20] 상세 페이지: https://kdx.kr/data/view/41564
# ⚠️ 기본 selector에 없음 — 범위 selector 사용
#
# --- [리스트 1, 상품 21] 상세 페이지: https://kdx.kr/data/view/41563
# ⚠️ 기본 selector에 없음 — 범위 selector 사용
#
# --- [리스트 1, 상품 22] 상세 페이지: https://kdx.kr/data/view/41562
# ⚠️ 기본 selector에 없음 — 범위 selector 사용
#
# --- [리스트 1, 상품 23] 상세 페이지: https://kdx.kr/data/view/41561
# ⚠️ 기본 selector에 없음 — 범위 selector 사용
#
# --- [리스트 1, 상품 24] 상세 페이지: https://kdx.kr/data/view/41560
# ⚠️ 기본 selector에 없음 — 범위 selector 사용
#
# --- [리스트 1, 상품 25] 상세 페이지: https://kdx.kr/data/view/41559
# ⚠️ 기본 selector에 없음 — 범위 selector 사용
#
# --- [리스트 1, 상품 26] 상세 페이지: https://kdx.kr/data/view/41558
# ⚠️ 기본 selector에 없음 — 범위 selector 사용
#
# --- [리스트 1, 상품 27] 상세 페이지: https://kdx.kr/data/view/41557
# ⚠️ 기본 selector에 없음 — 범위 selector 사용
#
# --- [리스트 1, 상품
(f"\n--- [리스트 {list_idx}, 상품 {detail_idx}] 상세 페이지: {detail_url}")
# ---> 78                     await page.goto(detail_url)
#      79                     await page.wait_for_timeout(1500)
#      80
#
# /usr/local/lib/python3.11/dist-packages/playwright/async_api/_generated.py in goto(self, url, timeout, wait_until, referer)
#    8973
#    8974         return mapping.from_impl_nullable(
# -> 8975             await self._impl_obj.goto(
#    8976                 url=url, timeout=timeout, waitUntil=wait_until, referer=referer
#    8977             )
#
# /usr/local/lib/python3.11/dist-packages/playwright/_impl/_page.py in goto(self, url, timeout, waitUntil, referer)
#     554         referer: str = None,
#     555     ) -> Optional[Response]:
# --> 556         return await self._main_frame.goto(**locals_to_params(locals()))
#     557
#     558     async def reload(
#
# /usr/local/lib/python3.11/dist-packages/playwright/_impl/_frame.py in goto(self, url, timeout, waitUntil, referer)
#     144             Optional[Response],
#     145             from_nullable_channel(
# --> 146                 await self._channel.send(
#     147                     "goto", self._navigation_timeout, locals_to_params(locals())
#     148                 )
#
# /usr/local/lib/python3.11/dist-packages/playwright/_impl/_connection.py in send(self, method, timeout_calculator, params, is_internal, title)
#      67         title: str = None,
#      68     ) -> Any:
# ---> 69         return await self._connection.wrap_api_call(
#      70             lambda: self._inner_send(method, timeout_calculator, params, False),
#      71             is_internal,
#
# /usr/local/lib/python3.11/dist-packages/playwright/_impl/_connection.py in wrap_api_call(self, cb, is_internal, title)
#     554         self._api_zone.set(parsed_st)
#     555         try:
# --> 556             return await cb()
#     557         except Exception as error:
#     558             raise rewrite_error(error, f"{parsed_st['apiName']}: {error}") from None
#
# /usr/local/lib/python3.11/dist-packages/playwright/_impl/_connection.py in _inner_send(self, method, timeout_calculator, params, return_as_dict)
#     121             self._object, method, _augment_params(params, timeout_calculator)
#     122         )
# --> 123         done, _ = await asyncio.wait(
#     124             {
#     125                 self._connection._transport.on_error_future,
#
# /usr/lib/python3.11/asyncio/tasks.py in wait(fs, timeout, return_when)
#     426
#     427     loop = events.get_running_loop()
# --> 428     return await _wait(fs, timeout, return_when, loop)
#     429
#     430
#
# /usr/lib/python3.11/asyncio/tasks.py in _wait(fs, timeout, return_when, loop)
#     533
#     534     try:
# --> 535         await waiter
#     536     finally:
#     537         if timeout_handle is not None:
#
# CancelledError:

# %%
import asyncio
import json
import re
from datetime import datetime
from playwright.async_api import async_playwright

start_urls = [
    "https://kdx.kr/data/product-list?specs_id=MA08210022&corp_id=CORP000007&category_id=CA000012",
    "https://kdx.kr/data/product-list?specs_id=MA54230003&corp_id=CORP000047&category_id=CA000001",
    "https://kdx.kr/data/product-list?specs_id=MA54230001&corp_id=CORP000047&category_id=CA000001",
    "https://kdx.kr/data/product-list?specs_id=MA17220002&corp_id=CORP000036&category_id=CA000001%7CCA000002",
    "https://kdx.kr/data/product-list?specs_id=MA17190004&corp_id=CORP000036&category_id=CA000001%7CCA000002",
    "https://kdx.kr/data/product-list?specs_id=MA17200002&corp_id=CORP000036&category_id=CA000002",
    "https://kdx.kr/data/product-list?specs_id=MA55230002&corp_id=CORP000048&category_id=CA000003",
    "https://kdx.kr/data/product-list?specs_id=MA55230001&corp_id=CORP000048&category_id=CA000003",
    "https://kdx.kr/data/product-list?specs_id=MA04240002&corp_id=CORP000004&category_id=CA000003",
    "https://kdx.kr/data/product-list?specs_id=MA56240001&corp_id=CORP000049&category_id=CA000004",
    "https://kdx.kr/data/product-list?specs_id=MA38210002&corp_id=CORP000024&category_id=CA000005",
    "https://kdx.kr/data/product-list?specs_id=MA02190001&corp_id=CORP000002&category_id=CA000004%7CCA000006",
    "https://kdx.kr/data/product-list?specs_id=MA15190001&corp_id=CORP000035&category_id=CA000008",
    "https://kdx.kr/data/product-list?specs_id=MA08210022&corp_id=CORP000007&category_id=CA000012",
    "https://kdx.kr/data/product-list?specs_id=MA58240001&corp_id=CORP000051&category_id=CA000013",
    "https://kdx.kr/data/product-list?specs_id=MA57240002&corp_id=CORP000050&category_id=CA000010",
    "https://kdx.kr/data/product-list?specs_id=MA57240003&corp_id=CORP000050&category_id=CA000010",
    "https://kdx.kr/data/product-list?specs_id=MA57240001&corp_id=CORP000050&category_id=CA000010",
    "https://kdx.kr/data/product-list?specs_id=MA08230002&corp_id=CORP000007&category_id=CA000014%7CCA000015",
    "https://kdx.kr/data/product-list?specs_id=MA15190002&corp_id=CORP000035&category_id=CA000008",
    "https://kdx.kr/data/product-list?specs_id=MA17190001&corp_id=CORP000036&category_id=CA000002",
    "https://kdx.kr/data/product-list?specs_id=MA17190002&corp_id=CORP000036&category_id=CA000002"
]

base_url = "https://kdx.kr"

async def run():
    async with async_playwright() as p:
        browser = await p.chromium.launch(headless=True)
        page = await browser.new_page()

        # 파일명에 시간 정보 추가 - 연월일시분
        now_str = datetime.now().strftime("%Y%m%d%H%M")
        output_file = f"output-{now_str}.jsonl"
        print(f"출력 파일: {output_file}")
        with open(output_file, "w", encoding="utf-8") as f:

            for list_idx, start_url in enumerate(start_urls, start=1):
                print(f"\n✅ [리스트 {list_idx}] URL 접근: {start_url}")
                await page.goto(start_url)
                await page.wait_for_timeout(3000)

                all_links = []

                # 페이지네이션 루프
                while True:
                    a_tags = await page.query_selector_all("ul.card-list > a")
                    print(f"상품 링크 개수 (현재 페이지): {len(a_tags)}")

                    for a in a_tags:
                        href = await a.get_attribute("href")
                        if href:
                            full_url = base_url + href
                            all_links.append(full_url)

                    next_button = await page.query_selector("#pagination > a.tui-page-btn.tui-next > span")
                    if next_button:
                        parent_button = await next_button.evaluate_handle("el => el.parentElement")
                        disabled = await parent_button.get_attribute("class")
                        if disabled and "disabled" in disabled:
                            break
                        await parent_button.click()
                        await page.wait_for_timeout(2000)
                    else:
                        break

                print(f"총 수집된 링크 개수: {len(all_links)}")

                for detail_idx, detail_url in enumerate(all_links, start=1):
                    print(f"\n--- [리스트 {list_idx}, 상품 {detail_idx}] 상세 페이지: {detail_url}")
                    await page.goto(detail_url)
                    await page.wait_for_timeout(1500)

                    # ✅ 가격 처리
                    price_num = None
                    price_type = "고정"

                    try:
                        # 해당 태그는 가격이 1개거나, 무료, 협의의 경우 태그에 해당
                        # 먼저 purchaseIs selector 기다리기
                        try:
                            await page.wait_for_selector("#dataView > div.container > div.detail-wrap > div.item-right > div.purchaseIs > p", timeout=5000)
                            purchase_elem = await page.query_selector("#dataView > div.container > div.detail-wrap > div.item-right > div.purchaseIs > p")
                        except:
                            # 없으면 purchase selector 기다리기
                            print("⚠️ 기본 selector에 없음 — 범위 selector 사용")
                            try:
                                await page.wait_for_selector("#dataView > div.container > div.detail-wrap > div.item-right > div.purchase > p", timeout=5000)
                                purchase_elem = await page.query_selector("#dataView > div.container > div.detail-wrap > div.item-right > div.purchase > p")
                            except:
                                print("⚠️ 가격 정보 없음 — selector 찾기 실패")
                                purchase_elem = None

                        # 읽어온 구매가격에 대한 객체 정보를 확인
                        if purchase_elem is None:
                            print("⚠️ 가격 정보 없음 — purchase_elem is None")
                            price_num = None
                            price_type = "에러"
                        else:
                            price_text = await purchase_elem.inner_text()
                            # price_text = re.sub(r"\s+", "", price_text)
                            # print(f">>> price_text 전처리 후: [{price_text}]")

                            if "무료" in price_text:
                                price_num = 0
                                price_type = "무료"
                            elif "협의" in price_text:
                                price_num = 0
                                price_type = "협의"
                            elif "~" in price_text:
                                price_num = price_text
                                price_type = "범위"
                            else:
                                num_match = re.search(r"[\d,]+", price_text)
                                if num_match:
                                    price_num = int(num_match.group(0).replace(",", ""))
                    except Exception as e:
                        print(f"⚠️ 가격 파싱 오류: {e}")
                        price_num = None
                        price_type = "에러"


                    # ✅ 스키마 컬럼
                    try:
                        th_elements = await page.query_selector_all("#dataView > div.container > div.detail-wrap > div.item-left > div.inner > div.table-wrap.preview_wrap > div.sample_data > table > thead > tr > th")
                        schema_columns = [await th.inner_text() for th in th_elements]
                        schema_columns = [col.strip() for col in schema_columns]
                    except:
                        schema_columns = []

                    try:
                        name_elem = await page.query_selector("#dataView > div.container > div.detail-wrap > div.item-left > div.inner > table:nth-child(2) > tbody > tr:nth-child(2) > td")
                        name_text = await name_elem.inner_text()
                    except:
                        name_text = "N/A"

                    try:
                        category_elem = await page.query_selector("#dataView > div.container > div.detail-wrap > div.item-left > div.inner > table:nth-child(2) > tbody > tr:nth-child(1) > td")
                        category_text = await category_elem.inner_text()
                    except:
                        category_text = "N/A"

                    try:
                        format_elem = await page.query_selector("#dataView > div.container > div.detail-wrap > div.item-left > div.inner > table:nth-child(2) > tbody > tr:nth-child(6) > td")
                        format_text = await format_elem.inner_text()
                    except:
                        format_text = "N/A"

                    try:
                        size_elem = await page.query_selector("#dataView > div.container > div.detail-wrap > div.item-left > div.inner > table:nth-child(2) > tbody > tr:nth-child(7) > td")
                        size_text = await size_elem.inner_text()
                    except:
                        size_text = "N/A"

                    try:
                        summary_elem = await page.query_selector("#dataView > div.container > div.detail-wrap > div.item-left > div.inner > table:nth-child(2) > tbody > tr:nth-child(3) > td")
                        summary_text = await summary_elem.inner_text()
                    except:
                        summary_text = "N/A"

                    try:
                        detail_elem = await page.query_selector("#dataView > div.container > div.detail-wrap > div.item-left > div.inner > table:nth-child(2) > tbody > tr:nth-child(4) > td")
                        detail_text = await detail_elem.inner_text()
                    except:
                        detail_text = "N/A"

                    try:
                        seller_elem = await page.query_selector("#dataView > div.container > div.detail-wrap > div.item-left > div.inner > table:nth-child(4) > tbody > tr:nth-child(1) > td")
                        seller_text = await seller_elem.inner_text()
                    except:
                        seller_text = "N/A"

                    try:
                        reg_elem = await page.query_selector("#dataView > div.container > div.detail-wrap > div.item-right > div.info > div:nth-child(6) > span")
                        reg_text = await reg_elem.inner_text()
                    except:
                        reg_text = "N/A"

                    try:
                        mod_elem = await page.query_selector("#dataView > div.container > div.detail-wrap > div.item-right > div.info > div:nth-child(7) > span")
                        mod_text = await mod_elem.inner_text()
                    except:
                        mod_text = "N/A"

                    # ✅ 태그 정보
                    try:
                        tag_elements = await page.query_selector_all(
                            "#dataView > div.container > div.detail-wrap > div.item-right > div.info > div.tag div.tag[data-text]"
                        )
                        tag_list = []
                        for tag in tag_elements:
                            data_text = await tag.get_attribute("data-text")
                            if data_text and data_text.strip():
                                tag_list.append(data_text.strip())
                    except:
                        tag_list = []


                    # ✅ 데이터 딕셔너리
                    data = {
                        "price_num": price_num,
                        "price_type": price_type,
                        "columns": schema_columns,
                        "name": name_text.strip(),
                        "category": category_text.strip(),
                        "format": format_text.strip(),
                        "size": size_text.strip(),
                        "summary": summary_text.strip(),
                        "detail": detail_text.strip(),
                        "seller": seller_text.strip(),
                        "register_date": reg_text.strip(),
                        "modify_date": mod_text.strip(),
                        "tags": tag_list,
                        "url": detail_url
                    }

                    f.write(json.dumps(data, ensure_ascii=False) + "\n")

        await browser.close()
        print(f"\n✅ 전체 리스트 크롤링 및 파일 저장 완료 ➜ {output_file}")
category_id=CA000006",
    "https://kdx.kr/data/product-list?specs_id=MA17200005&corp_id=CORP000036&category_id=CA000004",
    "https://kdx.kr/data/product-list?specs_id=MA38210002&corp_id=CORP000024&category_id=CA000005",
    "https://kdx.kr/data/product-list?specs_id=MA15190002&corp_id=CORP000035&category_id=CA000008",
    "https://kdx.kr/data/product-list?specs_id=MA02190001&corp_id=CORP000002&category_id=CA000004%7CCA000006",
    "https://kdx.kr/data/product-list?specs_id=MA36210001&corp_id=CORP000030&category_id=CA000003",
    "https://kdx.kr/data/product-list?specs_id=MA15210002&corp_id=CORP000035&category_id=CA000006",
    "https://kdx.kr/data/product-list?specs_id=MA12200001&corp_id=CORP000011&category_id=CA000006",
    "https://kdx.kr/data/product-list?specs_id=MA12190001&corp_id=CORP000011&category_id=CA000006",
    "https://kdx.kr/data/product-list?specs_id=MA12190002&corp_id=CORP000011&category_id=CA000006",
    "https://kdx.kr/data/product-list?specs_id=MA15190001&corp_id=CORP000035&category_id=CA000008",
    "https://kdx.kr/data/product-list?specs_id=MA15190003&corp_id=CORP000035&category_id=CA000008",
    "https://kdx.kr/data/product-list?specs_id=MA15190002&corp_id=CORP000035&category_id=CA000008",
    "https://kdx.kr/data/product-list?specs_id=MA15210004&corp_id=CORP000035&category_id=CA000008",
    "https://kdx.kr/data/product-list?specs_id=MA15200001&corp_id=CORP000035&category_id=CA000008",
    "https://kdx.kr/data/product-list?specs_id=MA57240002&corp_id=CORP000050&category_id=CA000010",
    "https://kdx.kr/data/product-list?specs_id=MA57240003&corp_id=CORP000050&category_id=CA000010",
    "https://kdx.kr/data/product-list?specs_id=MA57240001&corp_id=CORP000050&category_id=CA000010",
    "https://kdx.kr/data/product-list?specs_id=MA11200008&corp_id=CORP000010&category_id=CA000014",
    "https://kdx.kr/data/product-list?specs_id=MA11200008&corp_id=CORP000010&category_id=CA000014",
    "https://kdx.kr/data/product-list?specs_id=MA08210022&corp_id=CORP000007&category_id=CA000012",
    "https://kdx.kr/data/product-list?specs_id=MA58240001&corp_id=CORP000051&category_id=CA000013",
    "https://kdx.kr/data/product-list?specs_id=MA08230002&corp_id=CORP000007&category_id=CA000014%7CCA000015",
    "https://kdx.kr/data/product-list?specs_id=MA36210003&corp_id=CORP000030&category_id=CA000014",
    "https://kdx.kr/data/product-list?specs_id=MA36210002&corp_id=CORP000030&category_id=CA000014",
    "https://kdx.kr/data/product-list?specs_id=MA11210001&corp_id=CORP000010&category_id=CA000014",
    "https://kdx.kr/data/product-list?specs_id=MA11210002&corp_id=CORP000010&category_id=CA000014",
    "https://kdx.kr/data/product-list?specs_id=MA54230003&corp_id=CORP000047&category_id=CA000001",
    "https://kdx.kr/data/product-list?specs_id=MA54230001&corp_id=CORP000047&category_id=CA000001",
    "https://kdx.kr/data/product-list?specs_id=MA19220002&corp_id=CORP000016&category_id=CA000001",
    "https://kdx.kr/data/product-list?specs_id=MA17220002&corp_id=CORP000036&category_id=CA000001%7CCA000002",
    "https://kdx.kr/data/product-list?specs_id=MA17190004&corp_id=CORP000036&category_id=CA000001%7CCA000002",
    "https://kdx.kr/data/product-list?specs_id=MA08210028&corp_id=CORP000007&category_id=CA000015",
]

base_url = "https://kdx.kr"

async def run():
    async with async_playwright() as p:
        browser = await p.chromium.launch(headless=True)
        page = await browser.new_page()

        now_str = datetime.now().strftime("%Y%m%d%H%M")
        output_file = f"output-{now_str}.jsonl"
        print(f"출력 파일: {output_file}")

        with open(output_file, "w", encoding="utf-8") as f:
            for list_idx, start_url in enumerate(start_urls, start=1):
                print(f"\n✅ [리스트 {list_idx}] URL 접근: {start_url}")
                await page.goto(start_url)
                await page.wait_for_timeout(3000)

                all_links = []
                while True:
                    a_tags = await page.query_selector_all("ul.card-list > a")
                    print(f"상품 링크 개수 (현재 페이지): {len(a_tags)}")

                    for a in a_tags:
                        href = await a.get_attribute("href")
                        if href:
                            full_url = base_url + href
                            all_links.append(full_url)

                    next_button = await page.query_selector("#pagination > a.tui-page-btn.tui-next > span")
                    if next_button:
                        parent_button = await next_button.evaluate_handle("el => el.parentElement")
                        disabled = await parent_button.get_attribute("class")
                        if disabled and "disabled" in disabled:
                            break
                        await parent_button.click()
                        await page.wait_for_timeout(2000)
                    else:
                        break

                print(f"총 수집된 링크 개수: {len(all_links)}")

                for detail_idx, detail_url in enumerate(all_links, start=1):
                    print(f"\n--- [리스트 {list_idx}, 상품 {detail_idx}] 상세 페이지: {detail_url}")
                    await page.goto(detail_url)
                    await page.wait_for_timeout(1500)

                    # ✅ 가격 처리
                    price_num = None
                    price_type = "고정"

                    try:
                        price_text = None

                        # 첫 번째 시도: 무료 또는 협의
                        try:
                            await page.wait_for_selector("#dataView > div.container > div.detail-wrap > div.item-right > div.purchaseIs > h4 > p", timeout=3000)
                            purchase_elem = await page.query_selector("#dataView > div.container > div.detail-wrap > div.item-right > div.purchaseIs > h4 > p")
                            price_text = await purchase_elem.inner_text()

                            if "무료" in price_text:
                                price_num = 0
                                price_type = "무료"
                                print("✔️ 무료 유형 탐지")
                            elif "협의" in price_text:
                                price_num = 0
                                price_type = "협의"
                                print("✔️ 협의 유형 탐지")
                        except:
                            pass

                        # 두 번째 시도: 범위
                        if price_text is None:
                            try:
                                await page.wait_for_selector("#dataView > div.container > div.detail-wrap > div.item-right > div.purchase > p", timeout=3000)
                                purchase_elem = await page.query_selector("#dataView > div.container > div.detail-wrap > div.item-right > div.purchase > p")
                                price_text = await purchase_elem.inner_text()
                                price_num = price_text
                                price_type = "범위"
                                print("✔️ 범위 유형 탐지")
                            except:
                                pass

                        # 세 번째 시도: 고정
                        if price_text is None:
                            try:
                                await page.wait_for_selector("#dataView > div.container > div.detail-wrap > div.item-right > div.purchaseIs > p", timeout=3000)
                                purchase_elem = await page.query_selector("#dataView > div.container > div.detail-wrap > div.item-right > div.purchaseIs > p")
                                price_text = await purchase_elem.inner_text()
                                num_match = re.search(r"[\d,]+", price_text)
                                if num_match:
                                    price_num = int(num_match.group(0).replace(",", ""))
                                price_type = "고정"
                                print("✔️ 고정 유형 탐지")
                            except:
                                pass

                        if price_text is None:
                            print("⚠️ 가격 정보 없음")
                            price_num = None
                            price_type = "에러"

                    except Exception as e:
                        print(f"⚠️ 가격 파싱 오류: {e}")
                        price_num = None
                        price_type = "에러"

                    # ✅ 스키마 컬럼
                    try:
                        th_elements = await page.query_selector_all("#dataView > div.container > div.detail-wrap > div.item-left > div.inner > div.table-wrap.preview_wrap > div.sample_data > table > thead > tr > th")
                        schema_columns = [await th.inner_text() for th in th_elements]
                        schema_columns = [col.strip() for col in schema_columns]
                    except:
                        schema_columns = []

                    # ✅ 기타 정보
                    async def safe_text(selector, default="N/A"):
                        try:
                            elem = await page.query_selector(selector)
                            return (await elem.inner_text()).strip() if elem else default
                        except:
                            return default

                    name_text = await safe_text("#dataView > div.container > div.detail-wrap > div.item-left > div.inner > table:nth-child(2) > tbody > tr:nth-child(2) > td")
                    category_text = await safe_text("#dataView > div.container > div.detail-wrap > div.item-left > div.inner > table:nth-child(2) > tbody > tr:nth-child(1) > td")
                    format_text = await safe_text("#dataView > div.container > div.detail-wrap > div.item-left > div.inner > table:nth-child(2) > tbody > tr:nth-child(6) > td")
                    size_text = await safe_text("#dataView > div.container > div.detail-wrap > div.item-left > div.inner > table:nth-child(2) > tbody > tr:nth-child(7) > td")
                    summary_text = await safe_text("#dataView > div.container > div.detail-wrap > div.item-left > div.inner > table:nth-child(2) > tbody > tr:nth-child(3) > td")
                    detail_text = await safe_text("#dataView > div.container > div.detail-wrap > div.item-left > div.inner > table:nth-child(2) > tbody > tr:nth-child(4) > td")
                    seller_text = await safe_text("#dataView > div.container > div.detail-wrap > div.item-left > div.inner > table:nth-child(4) > tbody > tr:nth-child(1) > td")
                    reg_text = await safe_text("#dataView > div.container > div.detail-wrap > div.item-right > div.info > div:nth-child(6) > span")
                    mod_text = await safe_text("#dataView > div.container > div.detail-wrap > div.item-right > div.info > div:nth-child(7) > span")

                    # ✅ 태그 정보
                    try:
                        tag_elements = await page.query_selector_all("#dataView > div.container > div.detail-wrap > div.item-right > div.info > div.tag div.tag[data-text]")
                        tag_list = []
                        for tag in tag_elements:
                            data_text = await tag.get_attribute("data-text")
                            if data_text and data_text.strip():
                                tag_list.append(data_text.strip())
                    except:
                        tag_list = []

                    data = {
                        "price_num": price_num,
                        "price_type": price_type,
                        "columns": schema_columns,
                        "name": name_text,
                        "category": category_text,
                        "format": format_text,
                        "size": size_text,
                        "summary": summary_text,
                        "detail": detail_text,
                        "seller": seller_text,
                        "register_date": reg_text,
                        "modify_date": mod_text,
                        "tags": tag_list,
                        "url": detail_url
                    }

                    f.write(json.dumps(data, ensure_ascii=False) + "\n")

        await browser.close()
        print(f"\n✅ 전체 리스트 크롤링 및 파일 저장 완료 ➜ {output_file}")

# ✅ 코랩에서는 아래처럼 실행
await run()
# Out:
# 출력 파일: output-202507060045.jsonl
#
# ✅ [리스트 1] URL 접근: https://kdx.kr/data/product-list?specs_id=MA54230002&corp_id=CORP000047&category_id=CA000001
# 상품 링크 개수 (현재 페이지): 4
# 상품 링크 개수 (현재 페이지): 4
# 상품 링크 개수 (현재 페이지): 4
# 상품 링크 개수 (현재 페이지): 4
# 상품 링크 개수 (현재 페이지): 4
# 상품 링크 개수 (현재 페이지): 4
# 상품 링크 개수 (현재 페이지): 4
# 상품 링크 개수 (현재 페이지): 1
# 총 수집된 링크 개수: 29
#
# --- [리스트 1, 상품 1] 상세 페이지: https://kdx.kr/data/view/40657
# ✔️ 무료 유형 탐지
#
# --- [리스트 1, 상품 2] 상세 페이지: https://kdx.kr/data/view/40656
# ✔️ 고정 유형 탐지
#
# --- [리스트 1, 상품 3] 상세 페이지: https://kdx.kr/data/view/37242
# ✔️ 무료 유형 탐지
#
# --- [리스트 1, 상품 4] 상세 페이지: https://kdx.kr/data/view/37237
# ✔️ 무료 유형 탐지
#
# --- [리스트 1, 상품 5] 상세 페이지: https://kdx.kr/data/view/37232
# ✔️ 협의 유형 탐지
#
# --- [리스트 1, 상품 6] 상세 페이지: https://kdx.kr/data/view/37229
# ✔️ 무료 유형 탐지
#
# --- [리스트 1, 상품
# ✔️ 무료 유형 탐지
#
# --- [리스트 76, 상품 149] 상세 페이지: https://kdx.kr/data/view/29537
# ✔️ 고정 유형 탐지
#
# --- [리스트 76, 상품 150] 상세 페이지: https://kdx.kr/data/view/29536
# ✔️ 고정 유형 탐지
#
# --- [리스트 76, 상품 151] 상세 페이지: https://kdx.kr/data/view/29534
# ✔️ 무료 유형 탐지
#
# --- [리스트 76, 상품 152] 상세 페이지: https://kdx.kr/data/view/29121
# ✔️ 고정 유형 탐지
#
# --- [리스트 76, 상품 153] 상세 페이지: https://kdx.kr/data/view/29120
# ✔️ 고정 유형 탐지
#
# --- [리스트 76, 상품 154] 상세 페이지: https://kdx.kr/data/view/29119
# ✔️ 무료 유형 탐지
#
# --- [리스트 76, 상품 155] 상세 페이지: https://kdx.kr/data/view/29097
# ✔️ 고정 유형 탐지
#
# --- [리스트 76, 상품 156] 상세 페이지: https://kdx.kr/data/view/29096
# ✔️ 고정 유형 탐지
#
# --- [리스트 76, 상품 157] 상세 페이지: https://kdx.kr/data/view/29095
# ✔️ 무료 유형 탐지
#
# --- [리스트 76, 상품 158] 상세 페이지: https://kdx.kr/data/view/29073
# ✔️ 고정 유형 탐지
#
# --- [리스트 76, 상품 159] 상세 페이지: https://kdx.kr/data/view/29072
# ✔️ 고정 유형 탐지
#
# --- [리스트 76, 상품 160] 상세 페이지: https://kdx.kr/data/view/29071
# ✔️ 무료 유형 탐지
#
# --- [리스트 76, 상품 161] 상세 페이지: https://kdx.kr/data/view/29049
# ✔️ 고정 유형 탐지
#
# --- [리스트 76, 상품 162] 상세 페이지: https://kdx.kr/data/view/29048
# ✔️ 고정 유형 탐지
#
# --- [리스트 76, 상품 163] 상세 페이지: https://kdx.kr/data/view/29047
# ✔️ 무료 유형 탐지
#
# ✅ [리스트 77] URL 접근: https://kdx.kr/data/product-list?specs_id=MA08210028&corp_id=CORP000007&category_id=CA000015
# 상품 링크 개수 (현재 페이지): 1
# 총 수집된 링크 개수: 1
#
# --- [리스트 77, 상품 1] 상세 페이지: https://kdx.kr/data/view/31086
# ✔️ 고정 유형 탐지
#
# ✅ 전체 리스트 크롤링 및 파일 저장 완료 ➜ output-202507060045.jsonl

# %% [markdown]
# # 20250706 - 데이터 시각화 수행

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import matplotlib.font_manager as fm
import json

# ✅ 한글 폰트 개별 지정 객체 생성
font_path = '/usr/share/fonts/truetype/nanum/NanumGothic.ttf'
prop = fm.FontProperties(fname=font_path)

# ✅ 구글 드라이브 마운트
from google.colab import drive
drive.mount('/content/drive')

# ✅ JSONL 파일 경로
file_path = '/content/drive/MyDrive/00. 대학원/data-price-20250706-v2.jsonl'

# ✅ JSONL 파일 읽기
records = []
with open(file_path, 'r', encoding='utf-8') as f:
    for line in f:
        line = line.strip()
        if line:
            records.append(json.loads(line))

# ✅ DataFrame 변환
df = pd.DataFrame(records)

# ✅ price_num을 숫자로 변환 (문자열 등 오류 시 NaN)
df['price_num'] = pd.to_numeric(df['price_num'], errors='coerce')

# ✅ NaN 제외
df = df.dropna(subset=['price_num'])

# ✅ 가격이 0이거나 협의인 경우는 제외 (선택)
df_filtered = df[(df['price_num'] > 0) & (df['price_type'] == '고정')]

# ✅ seaborn 스타일 설정
sns.set(style="whitegrid")

# ✅ 카테고리별 가격 분포 boxplot
plt.figure(figsize=(12, 6))
ax1 = sns.boxplot(x='category', y='price_num', data=df_filtered)
ax1.set_title('카테고리별 가격 분포', fontproperties=prop)
ax1.set_ylabel('가격 (원)', fontproperties=prop)
ax1.set_xlabel('카테고리', fontproperties=prop)
for label in ax1.get_xticklabels():
    label.set_fontproperties(prop)
for label in ax1.get_yticklabels():
    label.set_fontproperties(prop)
plt.tight_layout()
plt.show()

# ✅ 포맷별 가격 분포 boxplot
plt.figure(figsize=(18, 7))  # 폭을 넓게 (기존 10, 6 → 18, 7)
ax2 = sns.boxplot(x='format', y='price_num', data=df_filtered)
ax2.set_title('포맷별 가격 분포', fontproperties=prop)
ax2.set_ylabel('가격 (원)', fontproperties=prop)
ax2.set_xlabel('포맷', fontproperties=prop)
for label in ax2.get_xticklabels():
    label.set_fontproperties(prop)
for label in ax2.get_yticklabels():
    label.set_fontproperties(prop)
plt.tight_layout()
plt.show()

# ✅ 카테고리 & 포맷 조합별 가격 분포 boxplot
plt.figure(figsize=(14, 6))
ax3 = sns.boxplot(x='category', y='price_num', hue='format', data=df_filtered)
ax3.set_title('카테고리 & 포맷별 가격 분포', fontproperties=prop)
ax3.set_ylabel('가격 (원)', fontproperties=prop)
ax3.set_xlabel('카테고리', fontproperties=prop)
for label in ax3.get_xticklabels():
    label.set_fontproperties(prop)
for label in ax3.get_yticklabels():
    label.set_fontproperties(prop)
leg = ax3.legend(title='포맷', bbox_to_anchor=(1.05, 1), loc='upper left')
leg.set_title('포맷', prop=prop)
for text in leg.get_texts():
    text.set_fontproperties(prop)
plt.tight_layout()
plt.show()

# ✅ 카테고리별 평균 가격 barplot (참고용)
plt.figure(figsize=(12, 6))
avg_prices = df_filtered.groupby('category')['price_num'].mean().reset_index()
ax4 = sns.barplot(x='category', y='price_num', data=avg_prices)
ax4.set_title('카테고리별 평균 가격', fontproperties=prop)
ax4.set_ylabel('평균 가격 (원)', fontproperties=prop)
ax4.set_xlabel('카테고리', fontproperties=prop)
for label in ax4.get_xticklabels():
    label.set_fontproperties(prop)
for label in ax4.get_yticklabels():
    label.set_fontproperties(prop)
plt.tight_layout()
plt.show()
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import matplotlib.font_manager as fm
import matplotlib.ticker as mticker
import json

# ✅ 한글 폰트 개별 지정 객체 생성
font_path = '/usr/share/fonts/truetype/nanum/NanumGothic.ttf'
prop = fm.FontProperties(fname=font_path)

# ✅ 구글 드라이브 마운트
from google.colab import drive
drive.mount('/content/drive')

# ✅ JSONL 파일 경로
file_path = '/content/drive/MyDrive/00. 대학원/data-price-20250706-v2.jsonl'

# ✅ JSONL 파일 읽기
records = []
with open(file_path, 'r', encoding='utf-8') as f:
    for line in f:
        line = line.strip()
        if line:
            records.append(json.loads(line))

# ✅ DataFrame 변환
df = pd.DataFrame(records)

# ✅ price_type별 데이터 건수 집계
type_counts = df['price_type'].value_counts().reset_index()
type_counts.columns = ['price_type', 'count']

plt.figure(figsize=(7, 5))
ax = sns.barplot(x='price_type', y='count', data=type_counts)
ax.set_title('Price Type별 데이터 건수', fontproperties=prop)
ax.set_xlabel('Price Type', fontproperties=prop)
ax.set_ylabel('Count', fontproperties=prop)
for label in ax.get_xticklabels():
    label.set_fontproperties(prop)
for label in ax.get_yticklabels():
    label.set_fontproperties(prop)
plt.tight_layout()
plt.show()


# seller 별 데이터건수 집계
# 판매자별 데이터 상품 건수(상위 20개)
seller_counts = df['seller'].value_counts().reset_index()
seller_counts.columns = ['seller', 'count']

plt.figure(figsize=(12, 6))
ax = sns.barplot(x='seller', y='count', data=seller_counts.head(10))

ax.set_title('판매자별 데이터 상품 건수(상위 10개)', fontproperties=prop)
ax.set_xlabel('판매자', fontproperties=prop)
ax.set_ylabel('상품 개수', fontproperties=prop)

# x축 tick 한글 및 각도, 위치 정렬
plt.xticks(rotation=40, ha='right', fontproperties=prop, fontsize=11)
plt.yticks(fontproperties=prop, fontsize=11)

plt.tight_layout()
plt.show()


# ✅ 고정 또는 무료만 남기기(범위나 협의는 가격이 명확하지 않으므로 제외)
df_filtered = df[ (df['price_type'] == '고정') | (df['price_type'] == '무료') ]

# ✅ seaborn 스타일 설정
sns.set(style="whitegrid")

# ---- 카테고리별 가격 분포 boxplot ----
plt.figure(figsize=(12, 6))
ax1 = sns.boxplot(x='category', y='price_num', data=df_filtered)
ax1.set_title('카테고리별 가격 분포', fontproperties=prop)
ax1.set_ylabel('가격 (원)', fontproperties=prop)
ax1.set_xlabel('카테고리', fontproperties=prop)
for label in ax1.get_xticklabels():
    label.set_fontproperties(prop)
for label in ax1.get_yticklabels():
    label.set_fontproperties(prop)

# Y축 천 단위 콤마 표기 적용
ax1.yaxis.set_major_formatter(mticker.FuncFormatter(lambda x, p: format(int(x), ',')))

# ✅ x축 레이블 45도~60도 기울이기 (여기서 60도 예시)
plt.xticks(rotation=60, ha='right', fontsize=12, fontproperties=prop)

plt.tight_layout()
plt.show()

# ---- 포맷별 가격 분포 boxplot ----
plt.figure(figsize=(18, 7))  # 폭을 넓게 (기존 10, 6 → 18, 7)
ax2 = sns.boxplot(x='format', y='price_num', data=df_filtered)
ax2.set_title('포맷별 가격 분포', fontproperties=prop)
ax2.set_ylabel('가격 (원)', fontproperties=prop)
ax2.set_xlabel('포맷', fontproperties=prop)
for label in ax2.get_xticklabels():
    label.set_fontproperties(prop)
for label in ax2.get_yticklabels():
    label.set_fontproperties(prop)
ax2.yaxis.set_major_formatter(mticker.FuncFormatter(lambda x, p: format(int(x), ',')))

# ✅ x축 레이블 60도 이상 크게 기울이기 (기본 45 → 60 or 75)
plt.xticks(rotation=60, ha='right', fontsize=11, fontproperties=prop)

plt.tight_layout()
plt.show()

# ---- 카테고리 & 포맷 조합별 가격 분포 boxplot ----
plt.figure(figsize=(14, 6))
ax3 = sns.boxplot(x='category', y='price_num', hue='format', data=df_filtered)
ax3.set_title('카테고리 & 포맷별 가격 분포', fontproperties=prop)
ax3.set_ylabel('가격 (원)', fontproperties=prop)
ax3.set_xlabel('카테고리', fontproperties=prop)
for label in ax3.get_xticklabels():
    label.set_fontproperties(prop)
for label in ax3.get_yticklabels():
    label.set_fontproperties(prop)
leg = ax3.legend(title='포맷', bbox_to_anchor=(1.05, 1), loc='upper left')
leg.set_title('포맷', prop=prop)
for text in leg.get_texts():
    text.set_fontproperties(prop)
ax3.yaxis.set_major_formatter(mticker.FuncFormatter(lambda x, p: format(int(x), ',')))
plt.tight_layout()
plt.show()



# ---- 카테고리 & 포맷 조합별 가격 분포 boxplot(subplot 2개) ----
from matplotlib.ticker import FuncFormatter

# ✅ 카테고리 정렬(원하는 순서 지정 가능)
categories = sorted(df_filtered['category'].unique())
n = 2  # subplot마다 표시할 카테고리 수
category_groups = [categories[i:i+n] for i in range(0, len(categories), n)]

fig, axes = plt.subplots(3, 2, figsize=(18, 18), sharey=True)
axes = axes.flatten()

# ✅ y축 1000단위 콤마 formatter 함수
def comma_formatter(x, pos):
    return f"{int(x):,}"

for idx, cat_group in enumerate(category_groups):
    ax = axes[idx]
    data = df_filtered[df_filtered['category'].isin(cat_group)].copy()
    # 카테고리별 상위 3개 포맷만 추출
    data_filtered = pd.DataFrame()
    for category in cat_group:
        temp = data[data['category'] == category]
        top_formats = temp['format'].value_counts().nlargest(3).index
        data_filtered = pd.concat([data_filtered, temp[temp['format'].isin(top_formats)]])
    # Boxplot
    sns.boxplot(
        x='category', y='price_num', hue='format',
        data=data_filtered, ax=ax
    )
    # 제목/축이름 한글
    ax.set_title(f"카테고리: {', '.join(cat_group)}", fontproperties=prop, fontsize=14)
    ax.set_ylabel("가격 (원)", fontproperties=prop)
    ax.set_xlabel("카테고리", fontproperties=prop)
    # x축 ticklabels 한글
    for label in ax.get_xticklabels():
        label.set_fontproperties(prop)
        label.set_fontsize(12)
        label.set_rotation(30)
    # y축 ticklabels 한글 + 콤마 포매팅
    ax.yaxis.set_major_formatter(FuncFormatter(comma_formatter))
    for label in ax.get_yticklabels():
        label.set_fontproperties(prop)
        label.set_fontsize(12)
    # 모든 subplot에서 범례 표시(한글)
    leg = ax.legend(title='포맷', fontsize=10, prop=prop, title_fontproperties=prop, bbox_to_anchor=(1.02, 1), loc='upper left')
    if leg is not None:
        leg.get_title().set_fontproperties(prop)
        for text in leg.get_texts():
            text.set_fontproperties(prop)

# 남는 subplot은 숨김 처리(카테고리 개수 짝수가 아니면)
for j in range(idx+1, len(axes)):
    axes[j].set_visible(False)

plt.tight_layout()
plt.show()



# ---- 카테고리별 평균 가격 barplot ----
plt.figure(figsize=(12, 6))
avg_prices = df_filtered.groupby('category')['price_num'].mean().reset_index()
ax4 = sns.barplot(x='category', y='price_num', data=avg_prices)
ax4.set_title('카테고리별 평균 가격', fontproperties=prop)
ax4.set_ylabel('평균 가격 (원)', fontproperties=prop)
ax4.set_xlabel('카테고리', fontproperties=prop)
for label in ax4.get_xticklabels():
    label.set_fontproperties(prop)
for label in ax4.get_yticklabels():
    label.set_fontproperties(prop)
ax4.yaxis.set_major_formatter(mticker.FuncFormatter(lambda x, p: format(int(x), ',')))
plt.tight_layout()
plt.show()


# 카테고리별 가격 박스플롯 (한글폰트 적용)

plt.figure(figsize=(14, 7))
ax = sns.boxplot(x='category', y='price_num', data=df_filtered)
ax.set_title('카테고리별 가격 분포', fontproperties=prop, fontsize=16)
ax.set_xlabel('카테고리', fontproperties=prop, fontsize=13)
ax.set_ylabel('가격 (원)', fontproperties=prop, fontsize=13)

# x축 레이블 한글, 기울이기, 사이즈
for label in ax.get_xticklabels():
    label.set_fontproperties(prop)
    label.set_fontsize(11)
    label.set_rotation(40)
    label.set_ha('right')

# y축 레이블 한글, 콤마 포매팅
from matplotlib.ticker import FuncFormatter
def comma_formatter(x, pos):
    return f"{int(x):,}"
ax.yaxis.set_major_formatter(FuncFormatter(comma_formatter))
for label in ax.get_yticklabels():
    label.set_fontproperties(prop)
    label.set_fontsize(11)

plt.tight_layout()
plt.show()


# ✅ 상위 N개 판매자만 추출
top_n = 10
top_sellers = df_filtered['seller'].value_counts().nlargest(top_n).index
df_top_sellers = df_filtered[df_filtered['seller'].isin(top_sellers)].copy()

plt.figure(figsize=(14, 6))
ax = sns.boxplot(x='seller', y='price_num', data=df_top_sellers)
ax.set_title(f'상위 판매자별 가격 분포 TOP {top_n}', fontproperties=prop, fontsize=15)
ax.set_xlabel('판매자', fontproperties=prop, fontsize=13)
ax.set_ylabel('가격 (원)', fontproperties=prop, fontsize=13)
plt.xticks(rotation=30, ha='right', fontproperties=prop, fontsize=11)
ax.yaxis.set_major_formatter(FuncFormatter(lambda x, _: f'{int(x):,}'))
for label in ax.get_yticklabels():
    label.set_fontproperties(prop)
    label.set_fontsize(11)
plt.tight_layout()
plt.show()
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %% [markdown]
# # 20250719 - 금융데이터거래소 크롤링

# %%
# ✅ 코랩 환경에서 필요한 패키지 설치
# !pip install playwright nest_asyncio

# ✅ Playwright 초기화 (처음 한 번만 실행하면 됨)
# !playwright install
# Out:
# Collecting playwright
#   Downloading playwright-1.53.0-py3-none-manylinux1_x86_64.whl.metadata (3.5 kB)
# Requirement already satisfied: nest_asyncio in /usr/local/lib/python3.11/dist-packages (1.6.0)
# Collecting pyee<14,>=13 (from playwright)
#   Downloading pyee-13.0.0-py3-none-any.whl.metadata (2.9 kB)
# Requirement already satisfied: greenlet<4.0.0,>=3.1.1 in /usr/local/lib/python3.11/dist-packages (from playwright) (3.2.3)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.11/dist-packages (from pyee<14,>=13->playwright) (4.14.1)
# Downloading playwright-1.53.0-py3-none-manylinux1_x86_64.whl (45.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 45.8/45.8 MB 18.7 MB/s eta 0:00:00
# Downloading pyee-13.0.0-py3-none-any.whl (15 kB)
# Installing collected packages: pyee, playwright
# Successfully installed playwright-1.53.0 pyee-13.0.0
# Downloading Chromium 138.0.7204.23 (playwright build v1179) from https://cdn.playwright.dev/dbazure/download/playwright/builds/chromium/
] 78% 0.4s93.7 MiB [] 79% 0.4s93.7 MiB [] 80% 0.4s93.7 MiB [] 81% 0.4s93.7 MiB [] 82% 0.3s93.7 MiB [] 83% 0.3s93.7 MiB [] 84% 0.3s93.7 MiB [] 85% 0.3s93.7 MiB [] 86% 0.3s93.7 MiB [] 87% 0.2s93.7 MiB [] 88% 0.2s93.7 MiB [] 89% 0.2s93.7 MiB [] 90% 0.2s93.7 MiB [] 91% 0.2s93.7 MiB [] 92% 0.1s93.7 MiB [] 93% 0.1s93.7 MiB [] 94% 0.1s93.7 MiB [] 95% 0.1s93.7 MiB [] 96% 0.1s93.7 MiB [] 97% 0.0s93.7 MiB [] 98% 0.0s93.7 MiB [] 99% 0.0s93.7 MiB [] 100% 0.0s
# Webkit 18.5 (playwright build v2182) downloaded to /root/.cache/ms-playwright/webkit-2182
# Downloading FFMPEG playwright build v1011 from https://cdn.playwright.dev/dbazure/download/playwright/builds/ffmpeg/1011/ffmpeg-linux.zip
# 2.3 MiB [] 0% 0.0s2.3 MiB [] 2% 0.7s2.3 MiB [] 3% 0.9s2.3 MiB [] 6% 0.7s2.3 MiB [] 13% 0.4s2.3 MiB [] 23% 0.3s2.3 MiB [] 43% 0.1s2.3 MiB [] 75% 0.0s2.3 MiB [] 100% 0.0s
# FFMPEG playwright build v1011 downloaded to /root/.cache/ms-playwright/ffmpeg-1011
# Playwright Host validation warning:
# ╔══════════════════════════════════════════════════════╗
# ║ Host system is missing dependencies to run browsers. ║
# ║ Missing libraries:                                   ║
# ║     libwoff2dec.so.1.0.2                             ║
# ║     libgstgl-1.0.so.0                                ║
# ║     libgstcodecparsers-1.0.so.0                      ║
# ║     libavif.so.13                                    ║
# ║     libharfbuzz-icu.so.0                             ║
# ║     libenchant-2.so.2                                ║
# ║     libsecret-1.so.0                                 ║
# ║     libhyphen.so.0                                   ║
# ║     libmanette-0.2.so.0                              ║
# ╚══════════════════════════════════════════════════════╝
#     at validateDependenciesLinux (/usr/local/lib/python3.11/dist-packages/playwright/driver/package/lib/server/registry/dependencies.js:269:9)
#     at process.processTicksAndRejections (node:internal/process/task_queues:105:5)
#     at async Registry._validateHostRequirements (/usr/local/lib/python3.11/dist-packages/playwright/driver/package/lib/server/registry/index.js:927:14)
#     at async Registry._validateHostRequirementsForExecutableIfNeeded (/usr/local/lib/python3.11/dist-packages/playwright/driver/package/lib/server/registry/index.js:1049:7)
#     at async Registry.validateHostRequirementsForExecutablesIfNeeded (/usr/local/lib/python3.11/dist-packages/playwright/driver/package/lib/server/registry/index.js:1038:7)
#     at async t.<anonymous> (/usr/local/lib/python3.11/dist-packages/playwright/driver/package/lib/cli/program.js:217:7)

# %%
import nest_asyncio
import asyncio
import json
from datetime import datetime
from playwright.async_api import async_playwright

nest_asyncio.apply()

BASE_URL = "https://www.findatamall.or.kr"
START_URL = "https://www.findatamall.or.kr/market/dataProdList?menuNo=28"

async def run():
    async with async_playwright() as p:
        browser = await p.chromium.launch(headless=True)
        page = await browser.new_page()

        now_str = datetime.now().strftime("%Y%m%d%H%M")
        output_file = f"findatamall_output-{now_str}.jsonl"
        print(f"출력 파일: {output_file}")

        # 1. 리스트 페이지 진입
        await page.goto(START_URL)
        await page.wait_for_timeout(2000)

        # 2. 상품 리스트 추출
        # 상품 div들을 모두 추출
        goods_divs = await page.query_selector_all("#container > div.contents > div > div.goodsList > div")

        detail_links = []
        for goods_div in goods_divs:
            # 각 상품 div에서 상세 페이지로 이동하는 a 태그 추출
            a_tag = await goods_div.query_selector("div:nth-child(2) > a")
            if a_tag:
                href = await a_tag.get_attribute("href")
                if href:
                    detail_links.append(BASE_URL + href)
        print(f"총 수집된 상품 링크: {len(detail_links)}")

        with open(output_file, "w", encoding="utf-8") as f:
            # 3. 상세 페이지 반복 접근
            for idx, detail_url in enumerate(detail_links, start=1):
                print(f"\n[{idx}] 상세 페이지: {detail_url}")
                await page.goto(detail_url)
                await page.wait_for_timeout(1200)

                # ✅ 각 필드별 selector 접근
                async def safe_text(selector, default="N/A"):
                    try:
                        elem = await page.query_selector(selector)
                        return (await elem.inner_text()).strip() if elem else default
                    except:
                        return default

                # 가격 및 유형
                price_num = None
                price_type = "유료"
                price_text = await safe_text("#container > div.contents > div.goodsTop > div.goodsInfo > div.goodsName > div > p > span > em")
                if price_text == "N/A" or not price_text:
                    # 무료일 경우
                    price_text = await safe_text("#container > div.contents > div.goodsTop > div.goodsInfo > div.goodsName > div > p > em")
                    if "무료" in price_text:
                        price_num = 0
                        price_type = "무료"
                    else:
                        price_num = price_text
                        price_type = "비정상"
                else:
                    # 유료: 숫자만 추출
                    import re
                    m = re.search(r"[\d,]+", price_text)
                    if m:
                        price_num = int(m.group(0).replace(",", ""))
                    else:
                        price_num = price_text

                # 스키마 컬럼
                columns = []
                ths = await page.query_selector_all("#sampleData > dl > dd > div:nth-child(2) > div.colTable.fixTh.scroll.txtC > table > thead > tr > th")
                for th in ths:
                    columns.append((await th.inner_text()).strip())

                data = {
                    "price_num": price_num,
                    "price_type": price_type,
                    "columns": columns,
                    "name": await safe_text("#container > div.contents > div.goodsTop > div.goodsInfo > div.goodsName > h4"),
                    "category": await safe_text("#container > div.contents > div.goodsTop > div.goodsImgArea > div:nth-child(2) > dl:nth-child(1) > dd"),
                    "format": await safe_text("#prodDetail > dl > dd > div > table > tbody > tr > td:nth-child(7)"),
                    "size": await safe_text("#prodDetail > dl > dd > div > table > tbody > tr > td:nth-child(8)"),
                    "summary": await safe_text("#info > dl > dd > div.grayBgBox.grayBgBoxGdsCn > p"),
                    "detail": await safe_text("#info > dl > dd > div:nth-child(2)"),
                    "seller": await safe_text("#container > div.contents > div.goodsTop > div.goodsImgArea > div:nth-child(2) > dl:nth-child(2) > dd"),
                    "register_date": await safe_text("#container > div.contents > div.goodsTop > div.goodsImgArea > div:nth-child(2) > dl:nth-child(3) > dd"),
                    "modify_date": await safe_text("#container > div.contents > div.goodsTop > div.goodsImgArea > div:nth-child(2) > dl:nth-child(4) > dd"),
                    "tags": [await safe_text("#container > div.contents > div.goodsTop > div.goodsInfo > div.top > div.hashTag.v4 > a:nth-child(2)")],
                    "url": detail_url
                }
                f.write(json.dumps(data, ensure_ascii=False) + "\n")

        await browser.close()
        print(f"\n✅ 크롤링 및 저장 완료: {output_file}")

# 실제 실행
await run()
# Out:
# 출력 파일: findatamall_output-202507190649.jsonl
# 총 수집된 상품 링크: 10
#
# [1] 상세 페이지: https://www.findatamall.or.kr/market/dataProdDetail?gdsSn=178&menuNo=28
#
# [2] 상세 페이지: https://www.findatamall.or.kr/market/dataProdDetail?gdsSn=2325&menuNo=28
#
# [3] 상세 페이지: https://www.findatamall.or.kr/market/dataProdDetail?gdsSn=2326&menuNo=28
#
# [4] 상세 페이지: https://www.findatamall.or.kr/market/dataProdDetail?gdsSn=411&menuNo=28
#
# [5] 상세 페이지: https://www.findatamall.or.kr/market/dataProdDetail?gdsSn=2227&menuNo=28
#
# [6] 상세 페이지: https://www.findatamall.or.kr/market/dataProdDetail?gdsSn=2223&menuNo=28
#
# [7] 상세 페이지: https://www.findatamall.or.kr/market/dataProdDetail?gdsSn=2228&menuNo=28
#
# [8] 상세 페이지: https://www.findatamall.or.kr/market/dataProdDetail?gdsSn=2524&menuNo=28
#
# [9] 상세 페이지: https://www.findatamall.or.kr/market/dataProdDetail?gdsSn=2324&menuNo=28
#
# [10] 상세 페이지: https://www.findatamall.or.kr/market/dataProdDetail?gdsSn=2521&menuNo=28
#
# ✅ 크롤링 및 저장 완료: findatamall_output-202507190649.jsonl

# %%
import nest_asyncio
import asyncio
import json
import re
from datetime import datetime
from playwright.async_api import async_playwright

nest_asyncio.apply()

BASE_URL = "https://www.findatamall.or.kr"
START_URL = "https://www.findatamall.or.kr/market/dataProdList?menuNo=28"

async def run():
    async with async_playwright() as p:
        browser = await p.chromium.launch(headless=True)
        page = await browser.new_page()

        now_str = datetime.now().strftime("%Y%m%d%H%M")
        output_file = f"findatamall_output_10개-{now_str}.jsonl"
        print(f"출력 파일: {output_file}")

        await page.goto(START_URL)
        await page.wait_for_timeout(2000)

        # 1. 첫 화면의 10개 상품 div만 추출
        goods_divs = await page.query_selector_all("#container > div.contents > div > div.goodsList > div")
        goods_divs = goods_divs[:10]  # 최대 10개 제한

        detail_links = []
        for goods_div in goods_divs:
            a_tag = await goods_div.query_selector("div:nth-child(2) > a")
            if a_tag:
                href = await a_tag.get_attribute("href")
                if href:
                    detail_links.append(BASE_URL + href)

        print(f"총 수집 대상 상품 링크: {len(detail_links)}")

        async def safe_text(selector, default="N/A"):
            try:
                elem = await page.query_selector(selector)
                return (await elem.inner_text()).strip() if elem else default
            except:
                return default

        with open(output_file, "w", encoding="utf-8") as f:
            for idx, detail_url in enumerate(detail_links, start=1):
                print(f"\n[{idx}] 상세 페이지: {detail_url}")
                await page.goto(detail_url)
                await page.wait_for_timeout(1200)

                # 가격 유형 처리
                price_num = None
                price_type = None

                # 1. 무료 여부
                price_text_free = await safe_text("#container > div.contents > div.goodsTop > div.goodsInfo > div.goodsName > div > p > em")
                if "무료" in price_text_free:
                    price_num = 0
                    price_type = "무료"
                else:
                    # 2. 유료 or 협의 여부
                    price_text_paid = await safe_text("#container > div.contents > div.goodsTop > div.goodsInfo > div.goodsName > div > p > span > em")
                    if "협의" in price_text_paid:
                        price_num = 0
                        price_type = "협의"
                    else:
                        m = re.search(r"[\d,]+", price_text_paid)
                        if m:
                            price_num = int(m.group(0).replace(",", ""))
                            price_type = "유료"
                        else:
                            price_num = price_text_paid
                            price_type = "확인필요"

                # 스키마 컬럼
                columns = []
                ths = await page.query_selector_all("#sampleData > dl > dd > div:nth-child(2) > div.colTable.fixTh.scroll.txtC > table > thead > tr > th")
                for th in ths:
                    columns.append((await th.inner_text()).strip())

                # 조회수 및 다운로드수
                view_cnt = await safe_text("#container > div.contents > div.goodsTop > div.goodsInfo > div.goodsName > div > div > span.icoView.gray")
                download_cnt = await safe_text("#container > div.contents > div.goodsTop > div.goodsInfo > div.goodsName > div > div > span.icoDownload.black")

                # 태그 수집: 대표 태그 + 관련 태그 (해시 기호 제거)
                tags = []

                # 대표 태그: <span class="tag blue prodList">일반데이터상품</span>
                span_tag = await page.query_selector("div.hashTag.v4 > span.tag.blue.prodList")
                if span_tag:
                    span_text = (await span_tag.inner_text()).strip()
                    if span_text:
                        tags.append(span_text)

                # 관련 키워드 태그들: <a>#소비자특성</a> 등 → # 제거하고 추가
                a_tags = await page.query_selector_all("div.hashTag.v4 > a")
                for a in a_tags:
                    a_text = (await a.inner_text()).strip()
                    if a_text.startswith("#"):
                        a_text = a_text[1:]  # '#' 문자 제거
                    if a_text:
                        tags.append(a_text)

                data = {
                    "price_num": price_num,
                    "price_type": price_type,
                    "columns": columns,
                    "name": await safe_text("#container > div.contents > div.goodsTop > div.goodsInfo > div.goodsName > h4"),
                    "category": await safe_text("#container > div.contents > div.goodsTop > div.goodsImgArea > div:nth-child(2) > dl:nth-child(1) > dd"),
                    "format": await safe_text("#prodDetail > dl > dd > div > table > tbody > tr > td:nth-child(7)"),
                    "size": await safe_text("#prodDetail > dl > dd > div > table > tbody > tr > td:nth-child(8)"),
                    "summary": await safe_text("#info > dl > dd > div.grayBgBox.grayBgBoxGdsCn > p"),
                    "detail": await safe_text("#info > dl > dd > div:nth-child(2)"),
                    "seller": await safe_text("#container > div.contents > div.goodsTop > div.goodsImgArea > div:nth-child(2) > dl:nth-child(2) > dd"),
                    "register_date": await safe_text("#container > div.contents > div.goodsTop > div.goodsImgArea > div:nth-child(2) > dl:nth-child(3) > dd"),
                    "modify_date": await safe_text("#container > div.contents > div.goodsTop > div.goodsImgArea > div:nth-child(2) > dl:nth-child(4) > dd"),
                    "tags": tags,
                    "view_cnt": view_cnt,
                    "download_cnt": download_cnt,
                    "url": detail_url
                }

                f.write(json.dumps(data, ensure_ascii=False) + "\n")

        await browser.close()
        print(f"\n✅ 첫 10개 상품 크롤링 완료 ➜ {output_file}")

# 실행
await run()
# Out:
# 출력 파일: findatamall_output_10개-202507190701.jsonl
# 총 수집 대상 상품 링크: 10
#
# [1] 상세 페이지: https://www.findatamall.or.kr/market/dataProdDetail?gdsSn=178&menuNo=28
#
# [2] 상세 페이지: https://www.findatamall.or.kr/market/dataProdDetail?gdsSn=2325&menuNo=28
#
# [3] 상세 페이지: https://www.findatamall.or.kr/market/dataProdDetail?gdsSn=2326&menuNo=28
#
# [4] 상세 페이지: https://www.findatamall.or.kr/market/dataProdDetail?gdsSn=411&menuNo=28
#
# [5] 상세 페이지: https://www.findatamall.or.kr/market/dataProdDetail?gdsSn=2227&menuNo=28
#
# [6] 상세 페이지: https://www.findatamall.or.kr/market/dataProdDetail?gdsSn=2223&menuNo=28
#
# [7] 상세 페이지: https://www.findatamall.or.kr/market/dataProdDetail?gdsSn=2228&menuNo=28
#
# [8] 상세 페이지: https://www.findatamall.or.kr/market/dataProdDetail?gdsSn=2524&menuNo=28
#
# [9] 상세 페이지: https://www.findatamall.or.kr/market/dataProdDetail?gdsSn=2324&menuNo=28
#
# [10] 상세 페이지: https://www.findatamall.or.kr/market/dataProdDetail?gdsSn=2521&menuNo=28
#
# ✅ 첫 10개 상품 크롤링 완료 ➜ findatamall_output_10개-202507190701.jsonl

# %%
import nest_asyncio
import asyncio
import json
import re
from datetime import datetime
from playwright.async_api import async_playwright

nest_asyncio.apply()

BASE_URL = "https://www.findatamall.or.kr"
START_URL = "https://www.findatamall.or.kr/market/dataProdList?menuNo=28"
SAVE_DIR = "/content/drive/MyDrive/00. 대학원"

async def run():
    async with async_playwright() as p:
        browser = await p.chromium.launch(headless=True)
        page = await browser.new_page()

        now_str = datetime.now().strftime("%Y%m%d%H%M")
        output_file = f"{SAVE_DIR}/findatamall_output_all-{now_str}.jsonl"
        print(f"출력 파일: {output_file}")

        await page.goto(START_URL)
        await page.wait_for_timeout(2000)

        async def safe_text(selector, default="N/A"):
            try:
                elem = await page.query_selector(selector)
                return (await elem.inner_text()).strip() if elem else default
            except:
                return default

        total_crawled = 0
        seen_urls = set()

        with open(output_file, "w", encoding="utf-8") as f:
            while True:
                # 상품 리스트 추출
                goods_divs = await page.query_selector_all("#container > div.contents > div > div.goodsList > div")

                new_links = []
                for goods_div in goods_divs:
                    a_tag = await goods_div.query_selector("div:nth-child(2) > a")
                    if a_tag:
                        href = await a_tag.get_attribute("href")
                        if href:
                            full_url = BASE_URL + href
                            if full_url not in seen_urls:
                                new_links.append(full_url)
                                seen_urls.add(full_url)

                # 새로 발견된 상세 페이지 순회
                for detail_url in new_links:
                    total_crawled += 1
                    print(f"\n[{total_crawled}] 상세 페이지: {detail_url}")
                    await page.goto(detail_url)
                    await page.wait_for_timeout(1200)

                    # 가격 유형 처리
                    price_num = None
                    price_type = None
                    price_text_free = await safe_text("#container > div.contents > div.goodsTop > div.goodsInfo > div.goodsName > div > p > em")
                    if "무료" in price_text_free:
                        price_num = 0
                        price_type = "무료"
                    else:
                        price_text_paid = await safe_text("#container > div.contents > div.goodsTop > div.goodsInfo > div.goodsName > div > p > span > em")
                        if "협의" in price_text_paid:
                            price_num = 0
                            price_type = "협의"
                        else:
                            m = re.search(r"[\d,]+", price_text_paid)
                            if m:
                                price_num = int(m.group(0).replace(",", ""))
                                price_type = "유료"
                            else:
                                price_num = price_text_paid
                                price_type = "확인필요"

                    # 스키마 컬럼
                    columns = []
                    ths = await page.query_selector_all("#sampleData > dl > dd > div:nth-child(2) > div.colTable.fixTh.scroll.txtC > table > thead > tr > th")
                    for th in ths:
                        columns.append((await th.inner_text()).strip())

                    # 조회수 및 다운로드수
                    view_cnt = await safe_text("#container > div.contents > div.goodsTop > div.goodsInfo > div.goodsName > div > div > span.icoView.gray")
                    download_cnt = await safe_text("#container > div.contents > div.goodsTop > div.goodsInfo > div.goodsName > div > div > span.icoDownload.black")

                    # 태그 수집
                    tags = []
                    product_type = "N/A"

                    span_tag = await page.query_selector("div.hashTag.v4 > span.prodList")
                    if span_tag:
                        span_text = (await span_tag.inner_text()).strip()
                        if span_text:
                            tags.append(span_text)
                            product_type = span_text

                    a_tags = await page.query_selector_all("div.hashTag.v4 > a")
                    for a in a_tags:
                        a_text = (await a.inner_text()).strip()
                        if a_text.startswith("#"):
                            a_text = a_text[1:]
                        if a_text:
                            tags.append(a_text)

                    data = {
                        "price_num": price_num,
                        "price_type": price_type,
                        "columns": columns,
                        "name": await safe_text("#container > div.contents > div.goodsTop > div.goodsInfo > div.goodsName > h4"),
                        "category": await safe_text("#container > div.contents > div.goodsTop > div.goodsImgArea > div:nth-child(2) > dl:nth-child(1) > dd"),
                        "format": await safe_text("#prodDetail > dl > dd > div > table > tbody > tr > td:nth-child(7)"),
                        "size": await safe_text("#prodDetail > dl > dd > div > table > tbody > tr > td:nth-child(8)"),
                        "summary": await safe_text("#info > dl > dd > div.grayBgBox.grayBgBoxGdsCn > p"),
                        "detail": await safe_text("#info > dl > dd > div:nth-child(2)"),
                        "seller": await safe_text("#container > div.contents > div.goodsTop > div.goodsImgArea > div:nth-child(2) > dl:nth-child(2) > dd"),
                        "register_date": await safe_text("#container > div.contents > div.goodsTop > div.goodsImgArea > div:nth-child(2) > dl:nth-child(3) > dd"),
                        "modify_date": await safe_text("#container > div.contents > div.goodsTop > div.goodsImgArea > div:nth-child(2) > dl:nth-child(4) > dd"),
                        "product_type": product_type,
                        "tags": tags,
                        "view_cnt": view_cnt,
                        "download_cnt": download_cnt,
                        "url": detail_url
                    }

                    f.write(json.dumps(data, ensure_ascii=False) + "\n")

                    if total_crawled % 10 == 0:
                        print(f"\n✅ 총 {total_crawled}개 크롤링 완료")

                # 📌 더보기 버튼 클릭은 상세 페이지 순회 후 목록 페이지로 복귀해야 함
                await page.goto(START_URL)
                await page.wait_for_timeout(1500)

                # 다시 로딩된 목록에서 더보기 버튼 클릭
                load_more_btn = await page.query_selector('a.moreList')
                if load_more_btn:
                    btn_text = await load_more_btn.inner_text()
                    if "10개 더보기" in btn_text:
                        print("\n🔄 10개 더보기 버튼 클릭")
                        await load_more_btn.click()
                        await page.wait_for_timeout(2000)
                        continue
                else:
                    print("\n⛔ 더보기 버튼 없음, 종료")
                    break

        await browser.close()
        print(f"\n🎉 전체 크롤링 완료: 총 {total_crawled}개 데이터 수집")

# 실행
await run()
# Out:
# 출력 파일: /content/drive/MyDrive/00. 대학원/findatamall_output_all-202507190731.jsonl
#
# [1] 상세 페이지: https://www.findatamall.or.kr/market/dataProdDetail?gdsSn=178&menuNo=28
#
# [2] 상세 페이지: https://www.findatamall.or.kr/market/dataProdDetail?gdsSn=2325&menuNo=28
#
# [3] 상세 페이지: https://www.findatamall.or.kr/market/dataProdDetail?gdsSn=2326&menuNo=28
#
# [4] 상세 페이지: https://www.findatamall.or.kr/market/dataProdDetail?gdsSn=411&menuNo=28
#
# [5] 상세 페이지: https://www.findatamall.or.kr/market/dataProdDetail?gdsSn=2227&menuNo=28
#
# [6] 상세 페이지: https://www.findatamall.or.kr/market/dataProdDetail?gdsSn=2223&menuNo=28
#
# [7] 상세 페이지: https://www.findatamall.or.kr/market/dataProdDetail?gdsSn=2228&menuNo=28
#
# [8] 상세 페이지: https://www.findatamall.or.kr/market/dataProdDetail?gdsSn=2524&menuNo=28
#
# [9] 상세 페이지: https://www.findatamall.or.kr/market/dataProdDetail?gdsSn=2324&menuNo=28
#
# [10] 상세 페이지: https://www.findatamall.or.kr/market/dataProdDetail?gdsSn=2521&menuNo=28
#
# ✅ 총 10개 크롤링 완료
#
# 🔄 10개 더보기 버튼 클릭
#
# 🔄 10개 더보기 버튼 클릭
#
# 🔄 10개 더보기 버튼 클릭
#
# 🔄 10개 더보기 버튼 클릭
#
# 🔄 10개 더보기 버튼 클릭
#
# 🔄 10개 더보기 버튼 클릭
#
# 🔄 10개 더보기 버튼 클릭
# ERROR:asyncio:Future exception was never retrieved
# future: <Future finished exception=TargetClosedError('Target page, context or browser has been closed')>
# playwright._impl._errors.TargetClosedError: Target page, context or browser has been closed
# 🔄 10개 더보기 버튼 클릭
#
# 🔄 10개 더보기 버튼 클릭
# ---------------------------------------------------------------------------
# CancelledError                            Traceback (most recent call last)
# /tmp/ipython-input-9-4186535241.py in <cell line: 1>()
#     153
#     154 # 실행
# --> 155 await run()
#
# /tmp/ipython-input-9-4186535241.py in run()
#     134                 # 📌 더보기 버튼 클릭은 상세 페이지 순회 후 목록 페이지로 복귀해야 함
#     135                 await page.goto(START_URL)
# --> 136                 await page.wait_for_timeout(1500)
#     137
#     138                 # 다시 로딩된 목록에서 더보기 버튼 클릭
#
# /usr/local/lib/python3.11/dist-packages/playwright/async_api/_generated.py in wait_for_timeout(self, timeout)
#   11394
#   11395         return mapping.from_maybe_impl(
# > 11396             await self._impl_obj.wait_for_timeout(timeout=timeout)
#   11397         )
#   11398
#
# /usr/local/lib/python3.11/dist-packages/playwright/_impl/_page.py in wait_for_timeout(self, timeout)
#    1103
#    1104     async def wait_for_timeout(self, timeout: float) -> None:
# -> 1105         await self._main_frame.wait_for_timeout(timeout)
#    1106
#    1107     async def wait_for_function(
#
# /usr/local/lib/python3.11/dist-packages/playwright/_impl/_frame.py in wait_for_timeout(self, timeout)
#     802
#     803     async def wait_for_timeout(self, timeout: float) -> None:
# --> 804         await self._channel.send("waitForTimeout", None, locals_to_params(locals()))
#     805
#     806     async def wait_for_function(
#
# /usr/local/lib/python3.11/dist-packages/playwright/_impl/_connection.py in send(self, method, timeout_calculator, params, is_internal, title)
#      67         title: str = None,
#      68     ) -> Any:
# ---> 69         return await self._connection.wrap_api_call(
#      70             lambda: self._inner_send(method, timeout_calculator, params, False),
#      71             is_internal,
#
# /usr/local/lib/python3.11/dist-packages/playwright/_impl/_connection.py in wrap_api_call(self, cb, is_internal, title)
#     554         self._api_zone.set(parsed_st)
#     555         try:
# --> 556             return await cb()
#     557         except Exception as error:
#     558             raise rewrite_error(error, f"{parsed_st['apiName']}: {error}") from None
#
# /usr/local/lib/python3.11/dist-packages/playwright/_impl/_connection.py in _inner_send(self, method, timeout_calculator, params, return_as_dict)
#     121             self._object, method, _augment_params(params, timeout_calculator)
#     122         )
# --> 123         done, _ = await asyncio.wait(
#     124             {
#     125                 self._connection._transport.on_error_future,
#
# /usr/lib/python3.11/asyncio/tasks.py in wait(fs, timeout, return_when)
#     426
#     427     loop = events.get_running_loop()
# --> 428     return await _wait(fs, timeout, return_when, loop)
#     429
#     430
#
# /usr/lib/python3.11/asyncio/tasks.py in _wait(fs, timeout, return_when, loop)
#     533
#     534     try:
# --> 535         await waiter
#     536     finally:
#     537         if timeout_handle is not None:
#
# /usr/lib/python3.11/asyncio/futures.py in __await__(self)
#     285         if not self.done():
#     286             self._asyncio_future_blocking = True
# --> 287             yield self  # This tells Task to wait for completion.
#     288         if not self.done():
#     289             raise RuntimeError("await wasn't used with future")
#
# /usr/lib/python3.11/asyncio/tasks.py in __wakeup(self, future)
#     347     def __wakeup(self, future):
#     348         try:
# --> 349             future.result()
#     350         except BaseException as exc:
#     351             # This may also be a cancellation.
#
# /usr/lib/python3.11/asyncio/futures.py in result(self)
#     196         if self._state == _CANCELLED:
#     197             exc = self._make_cancelled_error()
# --> 198             raise exc
#     199         if self._state != _FINISHED:
#     200             raise exceptions.InvalidStateError('Result is not ready.')
#
# CancelledError:

# %%
import nest_asyncio
import asyncio
import json
import re
from datetime import datetime
from playwright.async_api import async_playwright

nest_asyncio.apply()

BASE_URL = "https://www.findatamall.or.kr"
START_URL = "https://www.findatamall.or.kr/market/dataProdList?menuNo=28"
SAVE_DIR = "/content/drive/MyDrive/00. 대학원"
CLICK_LIMIT = 850  # '10개 더보기' 클릭 횟수 설정

async def run():
    async with async_playwright() as p:
        browser = await p.chromium.launch(headless=True)
        page = await browser.new_page()

        now_str = datetime.now().strftime("%Y%m%d%H%M")
        output_file = f"{SAVE_DIR}/findatamall_output_all-{now_str}.jsonl"
        print(f"출력 파일: {output_file}")

        await page.goto(START_URL)
        await page.wait_for_timeout(2000)

        # ▶️ 10개 더보기 버튼 클릭 반복
        for i in range(CLICK_LIMIT):
            try:
                load_more_btn = await page.query_selector('a.moreList')
                if load_more_btn:
                    btn_text = await load_more_btn.inner_text()
                    if "10개 더보기" in btn_text:
                        print(f"🔄 '10개 더보기' 클릭: {i+1}/{CLICK_LIMIT}")
                        await load_more_btn.click()
                        await page.wait_for_timeout(3000)
                    else:
                        break
                else:
                    print("⛔ 더보기 버튼 없음")
                    break
            except Exception as e:
                print(f"⚠️ 클릭 실패: {e}")
                break

        # ▶️ 상품 상세 URL만 먼저 수집
        goods_divs = await page.query_selector_all("#container > div.contents > div > div.goodsList > div")
        print(f"✅ 총 {len(goods_divs)}개 상품 발견")

        seen_urls = set()
        detail_urls = []
        for goods_div in goods_divs:
            a_tag = await goods_div.query_selector("div:nth-child(2) > a")
            if a_tag:
                href = await a_tag.get_attribute("href")
                if href:
                    full_url = BASE_URL + href
                    if full_url not in seen_urls:
                        detail_urls.append(full_url)
                        seen_urls.add(full_url)

        # ▶️ 상세 페이지에서 정보 수집
        async def safe_text(selector, default="N/A"):
            try:
                elem = await page.query_selector(selector)
                return (await elem.inner_text()).strip() if elem else default
            except:
                return default

        total_crawled = 0
        with open(output_file, "w", encoding="utf-8") as f:
            for detail_url in detail_urls:
                total_crawled += 1
                print(f"\n[{total_crawled}] 상세 페이지: {detail_url}")
                # await page.goto(detail_url)
                # await page.wait_for_timeout(1200)

                try:
                    await page.goto(detail_url, timeout=15000)  # 타임아웃을 15초로 줄여 빠르게 넘어감
                    await page.wait_for_timeout(1200)
                except Exception as e:
                    print(f"⛔ 상세 페이지 접근 실패: {e}")
                    continue  # 다음 URL로 계속 진행

                # 가격
                price_num = None
                price_type = None
                price_text_free = await safe_text("#container > div.contents > div.goodsTop > div.goodsInfo > div.goodsName > div > p > em")
                if "무료" in price_text_free:
                    price_num = 0
                    price_type = "무료"
                else:
                    price_text_paid = await safe_text("#container > div.contents > div.goodsTop > div.goodsInfo > div.goodsName > div > p > span > em")
                    if "협의" in price_text_paid:
                        price_num = 0
                        price_type = "협의"
                    else:
                        m = re.search(r"[\d,]+", price_text_paid)
                        if m:
                            price_num = int(m.group(0).replace(",", ""))
                            price_type = "유료"
                        else:
                            price_num = price_text_paid
                            price_type = "확인필요"

                # 컬럼명
                columns = []
                ths = await page.query_selector_all("#sampleData > dl > dd > div:nth-child(2) > div.colTable.fixTh.scroll.txtC > table > thead > tr > th")
                for th in ths:
                    columns.append((await th.inner_text()).strip())

                # 태그
                tags = []
                product_type = "N/A"
                span_tag = await page.query_selector("div.hashTag.v4 > span.prodList")
                if span_tag:
                    span_text = (await span_tag.inner_text()).strip()
                    if span_text:
                        tags.append(span_text)
                        product_type = span_text

                a_tags = await page.query_selector_all("div.hashTag.v4 > a")
                for a in a_tags:
                    a_text = (await a.inner_text()).strip()
                    if a_text.startswith("#"):
                        a_text = a_text[1:]
                    if a_text:
                        tags.append(a_text)

                data = {
                    "price_num": price_num,
                    "price_type": price_type,
                    "columns": columns,
                    "name": await safe_text("#container > div.contents > div.goodsTop > div.goodsInfo > div.goodsName > h4"),
                    "category": await safe_text("#container > div.contents > div.goodsTop > div.goodsImgArea > div:nth-child(2) > dl:nth-child(1) > dd"),
                    "format": await safe_text("#prodDetail > dl > dd > div > table > tbody > tr > td:nth-child(7)"),
                    "size": await safe_text("#prodDetail > dl > dd > div > table > tbody > tr > td:nth-child(8)"),
                    "summary": await safe_text("#info > dl > dd > div.grayBgBox.grayBgBoxGdsCn > p"),
                    "detail": await safe_text("#info > dl > dd > div:nth-child(2)"),
                    "seller": await safe_text("#container > div.contents > div.goodsTop > div.goodsImgArea > div:nth-child(2) > dl:nth-child(2) > dd"),
                    "register_date": await safe_text("#container > div.contents > div.goodsTop > div.goodsImgArea > div:nth-child(2) > dl:nth-child(3) > dd"),
                    "modify_date": await safe_text("#container > div.contents > div.goodsTop > div.goodsImgArea > div:nth-child(2) > dl:nth-child(4) > dd"),
                    "product_type": product_type,
                    "tags": tags,
                    "view_cnt": await safe_text("#container > div.contents > div.goodsTop > div.goodsInfo > div.goodsName > div > div > span.icoView.gray"),
                    "download_cnt": await safe_text("#container > div.contents > div.goodsTop > div.goodsInfo > div.goodsName > div > div > span.icoDownload.black"),
                    "url": detail_url
                }

                f.write(json.dumps(data, ensure_ascii=False) + "\n")

                if total_crawled % 10 == 0:
                    print(f"✅ 누적 {total_crawled}개 저장 완료")

        await browser.close()
        print(f"\n🎉 전체 완료: 총 {total_crawled}개 수집")

# 실행
await run()
# Out:
# 출력 파일: /content/drive/MyDrive/00. 대학원/findatamall_output_all-202507190811.jsonl
# 🔄 '10개 더보기' 클릭: 1/850
# 🔄 '10개 더보기' 클릭: 2/850
# 🔄 '10개 더보기' 클릭: 3/850
# 🔄 '10개 더보기' 클릭: 4/850
# 🔄 '10개 더보기' 클릭: 5/850
# 🔄 '10개 더보기' 클릭: 6/850
# 🔄 '10개 더보기' 클릭: 7/850
# 🔄 '10개 더보기' 클릭: 8/850
# 🔄 '10개 더보기' 클릭: 9/850
# 🔄 '10개 더보기' 클릭: 10/850
# 🔄 '10개 더보기' 클릭: 11/850
# 🔄 '10개 더보기' 클릭: 12/850
# 🔄 '10개 더보기' 클릭: 13/850
# 🔄 '10개 더보기' 클릭: 14/850
# 🔄 '10개 더보기' 클릭: 15/850
# 🔄 '10개 더보기' 클릭: 16/850
# 🔄 '10개 더보기' 클릭: 17/850
# 🔄 '10개 더보기' 클릭: 18/850
# 🔄 '10개 더보기' 클릭: 19/850
# 🔄 '10개 더보기' 클릭: 20/850
# 🔄 '10개 더보기' 클릭: 21/850
# 🔄 '10개 더보기' 클릭: 22/850
# 🔄 '10개 더보기' 클릭: 23/850
# 🔄 '10개 더보기' 클릭: 24/850
# 🔄 '10개 더보기' 클릭: 25/850
# 🔄 '10개 더보기' 클릭: 26/850
# 🔄 '10개 더보기' 클릭: 27/850
# 🔄 '10개 더보기' 클릭: 28/850
# 🔄 '10개 더보기' 클릭: 29/850
# 🔄 '10개 더보기' 클릭: 30/850
# 🔄 '10개 더보기' 클릭: 31/850
# 🔄 '10개 더보기' 클릭: 32/850
# 🔄 '10개 더보기' 클릭: 33/850
# 🔄 '10개 더보기' 클릭: 34/850
# 🔄 '10개 더보기' 클릭: 35/850
# 🔄 '10개 더보기' 클릭: 36/850
# 🔄 '10개 더보기' 클릭: 37/850
# 🔄 '10개 더보기' 클릭: 38/850
# 🔄 '10개 더보기' 클릭: 39/850
# 🔄 '10개 더보기' 클릭: 40/850
# 🔄 '10개 더보기' 클릭: 41/850
# 🔄 '10개 더보기' 클릭: 42/850
# 🔄 '10개 더보기' 클릭: 43/850
# 🔄 '10개 더보기' 클릭: 44/850
# 🔄 '10개 더보기' 클릭: 45/850
# 🔄 '10개 더보기' 클릭: 46/850
# 🔄 '10개 더보기' 클릭: 47/850
# 🔄 '10개 더보기' 클릭: 816/850
# 🔄 '10개 더보기' 클릭: 817/850
# 🔄 '10개 더보기' 클릭: 818/850
# 🔄 '10개 더보기' 클릭: 819/850
# 🔄 '10개 더보기' 클릭: 820/850
# 🔄 '10개 더보기' 클릭: 821/850
# 🔄 '10개 더보기' 클릭: 822/850
# 🔄 '10개 더보기' 클릭: 823/850
# 🔄 '10개 더보기' 클릭: 824/850
# 🔄 '10개 더보기' 클릭: 825/850
# 🔄 '10개 더보기' 클릭: 826/850
# 🔄 '10개 더보기' 클릭: 827/850
# 🔄 '10개 더보기' 클릭: 828/850
# 🔄 '10개 더보기' 클릭: 829/850
# 🔄 '10개 더보기' 클릭: 830/850
# 🔄 '10개 더보기' 클릭: 831/850
# 🔄 '10개 더보기' 클릭: 832/850
# 🔄 '10개 더보기' 클릭: 833/850
# 🔄 '10개 더보기' 클릭: 834/850
# 🔄 '10개 더보기' 클릭: 835/850
# 🔄 '10개 더보기' 클릭: 836/850
# 🔄 '10개 더보기' 클릭: 837/850
# 🔄 '10개 더보기' 클릭: 838/850
# 🔄 '10개 더보기' 클릭: 839/850
# 🔄 '10개 더보기' 클릭: 840/850
# 🔄 '10개 더보기' 클릭: 841/850
# 🔄 '10개 더보기' 클릭: 842/850
# 🔄 '10개 더보기' 클릭: 843/850
# 🔄 '10개 더보기' 클릭: 844/850
# 🔄 '10개 더보기' 클릭: 845/850
# 🔄 '10개 더보기' 클릭: 846/850
# 🔄 '10개 더보기' 클릭: 847/850
# 🔄 '10개 더보기' 클릭: 848/850
# 🔄 '10개 더보기' 클릭: 849/850
# 🔄 '10개 더보기' 클릭: 850/850
# ✅ 총 8510개 상품 발견
#
# [1] 상세 페이지: https://www.findatamall.or.kr/market/dataProdDetail?gdsSn=178&menuNo=28
#
# [2] 상세 페이지: https://www.findatamall.or.kr/market/dataProdDetail?gdsSn=2325&menuNo=28
#
# [3] 상세 페이지: https://www.findatamall.or.kr/market/dataProdDetail?gdsSn=2326&menuNo=28
#
# [4] 상세 페이지: https://www.findatamall.or.kr/market/dataProdDetail?gdsSn=411&menuNo=28
#
# [5] 상세 페이지: https://www.findatamall.or.kr/market/dataProdDetail?gdsSn=2227&menuNo=28
#
# [6] 상세 페이지: https://www.findatamall.or.kr/market/dataProdDetail?gdsSn=2223&menuNo=28
#
# [7] 상세 페이지: https://www.findatamall.or.kr/market/dataProdDetail?gdsSn=2228&menuNo=28
#
# [8] 상세 페이지: https://www.findatamall.or.kr/market/dataProdDetail?gdsSn=2524&menuNo=28
#
# [9] 상세 페이지: https://www.findatamall.or.kr/market/dataProdDetail?gdsSn=2324&menuNo=28
#
# [10] 상세 페이지: https://www.findatamall.or.kr/market/dataProdDetail?gdsSn=2521&menuNo=28
# ✅ 누적 10개 저장 완료
#
# [11] 상세 페이지: https://www.findatamall.or.kr/market/dataProdDetail?gdsSn=2520&menuNo=28
#
# [12] 상세 페이지: https://www.findatamall.or.kr/market/dataProdDetail?gdsSn=1612&menuNo=28
#
# [13] 상세 페이지: https://www.findatamall.or.kr/market/dataProdDetail?gdsSn=1929&menuNo=28
#
# [14] 상세 페이지: https://www.findatamall.or.kr/market/dataProdDetail?gdsSn=790&menuNo=28
#
# [15] 상세 페이지: https://www.findatamall.or.kr/market/dataProdDetail?gdsSn=789&menuNo=28
#
# [16] 상세 페이지: https://www.findatamall.or.kr/market/dataProdDetail?gdsSn=144&menuNo=28
#
# [17] 상세 페이지: https://www.findatamall.or.kr/market/dataProdDetail?gdsSn=145&menuNo=28
#
# [18] 상세 페이지: https://www.findatamall.or.kr/market/dataProdDetail?gdsSn=2522&menuNo=28
#
# [19] 상세 페이지: https://www.findatamall.or.kr/market/dataProdDetail?gdsSn=2523&menuNo=28
#
# [20] 상세 페이지: https://www.findatamall.or.kr/market/dataProdDetail?gdsSn=1389&menuNo=28
# ✅ 누적 20개 저장 완료
#
# [21] 상세 페이지: https://www.findatamall.or.kr/market/dataProdDetail?gdsSn=1845&menuNo=28
#
# [22] 상세 페이지: https://www.findatamall.or.kr/market/dataProdDetail?gdsSn=1844&menuNo=28
#
# [23] 상세 페이지: https://www.findatamall.or.kr/market/dataProdDetail?gdsSn=16982&menuNo=28
#
# [24] 상세 페이지: https://www.findatamall.or.kr/market/dataProdDetail?gdsSn=16983&menuNo=28
#
# [25] 상세 페이지: https://www.findatamall.or.kr/market/dataProdDetail?gdsSn=417&menuNo=28
#
# [26] 상세 페이지: https://www.findatamall.or.kr/market/dataProdDetail?gdsSn=1157&menuNo=28
#
# [27] 상세 페이지: https://www.findatamall.or.kr/market/dataProdDetail?gdsSn=1377&menuNo=28
#
# [28] 상세 페이지: https://www.findatamall.or.kr/market/dataProdDetail?gdsSn=800&menuNo=28
#
# [29] 상세 페이지: https://www.findatamall.or.kr/market/dataProdDetail?gdsSn=791&menuNo=28
#
# [30] 상세 페이지: https://www.findatamall.or.kr/market/dataProdDetail?gdsSn=1125&menuNo=28
# ✅ 누적 30개 저장 완료
#
# [31] 상세 페이지: https://www.findatamall.or.kr/market/dataProdDetail?gdsSn=805&menuNo=28
#
# [32] 상세 페이지: https://www.findatamall.or.kr/market/dataProdDetail?gdsSn=788&menuNo=28
#
# [33] 상세 페이지: https://www.findatamall.or.kr/market/dataProdDetail?gdsSn=2500&menuNo=28
#
# [34] 상세 페이지: https://www.findatamall.or.kr/market/dataProdDetail?gdsSn=1380&menuNo=28
#
# [35] 상세 페이지: https://www.findatamall.or.kr/market/dataProdDetail?gdsSn=14050&menuNo=28
#
# [36] 상세 페이지: https://www.findatamall.or.kr/market/dataProdDetail?gdsSn=1846&menuNo=28
#
# [37] 상세 페이지: https://www.findatamall.or.kr/market/dataProdDetail?gdsSn=1787&menuNo=28
#
# [38] 상세 페이지: https://www.findatamall.or.kr/market/dataProdDetail?gdsSn=12433&menuNo=28
#
# [39] 상세 페이지: https://www.findatamall.or.kr/market/dataProdDetail?gdsSn=793&menuNo=28
#
# [40] 상세 페이지: https://www.findatamall.or.kr/market/dataProdDetail?gdsSn=1057&menuNo=28
# ✅ 누적 40개 저장 완료
#
# [41] 상세 페이지: https://www.findatamall.or.kr/market/dataProdDetail?gdsSn=792&menuNo=28
#
# [42] 상세 페이지: https://www.findatamall.or.kr/market/dataProdDetail?gdsSn=9214&menuNo=28
#
# [43] 상세 페이지: https://www.findatamall.or.kr/market/dataProdDetail?gdsSn=1246&menuNo=28
#
# [44] 상세 페이지: https://www.findatamall.or.kr/market/dataProdDetail?gdsSn=16392&menuNo=28
#
# [45] 상세 페이지: https://www.findatamall.or.kr/market/dataProdDetail?gdsSn=7213&menuNo=28
#
# [46] 상세 페이지: https://www.findatamall.or.kr/market/dataProdDetail?gdsSn=16486&menuNo=28
#
# [47] 상세 페이지: https://www.findatamall.or.kr/market/dataProdDetail?gdsSn=16780&menuNo=28
#
# [48] 상세 페이지: https://www.findatamall.or.kr/market/dataProdDetail?gdsSn=2447&menuNo=28
#
# [49] 상세 페이지: https://www.findatamall.or.kr/market/dataProdDetail?gdsSn=14052&menuNo=28
#
# [50] 상세 페이지: https://www.findatamall.or.kr/market/dataProdDetail?gdsSn=16607&menuNo=28
# ✅ 누적 50개 저장 완료
#
# [51] 상세 페이지: https://www.findatamall.or.kr/market/dataProdDetail?gdsSn=1841&menuNo=28
#
# [52] 상세 페이지: https://www.findatamall.or.kr/market/dataProdDetail?gdsSn=1823&menuNo=28
#
# [53] 상세 페이지: https://www.findatamall.or.kr/market/dataProdDetail?gdsSn=1123&menuNo=28
#
# [54] 상세 페이지: https://www.findatamall.or.kr/market/dataProdDetail?gdsSn=14051&menuNo=28
#
# [55] 상세 페이지: https://www.findatamall.or.kr/market/dataProdDetail?gdsSn=16400&menuNo=28
#
# [56] 상세 페이지: https://www.findatamall.or.kr/market/dataProdDetail?gdsSn=16640&menuNo=28
#
# [57] 상세 페이지: https://www.findatamall.or.kr/market/dataProdDetail?gdsSn=1222&menuNo=28
#
# [58] 상세 페이지: https://www.findatamall.or.kr/market/dataProdDetail?gdsSn=16608&menuNo=28
#
# [59] 상세 페이지: https://www.findatamall.or.kr/market/dataProdDetail?gdsSn=16696&menuNo=28
#
# [60] 상세 페이지: https://www.findatamall.or.kr/market/dataProdDetail?gdsSn=441&menuNo=28
# ✅ 누적 60개 저장 완료
#
# [61] 상세 페이지: https://www.findatamall.or.kr/market/dataProdDetail?gdsSn=490&menuNo=28
#
# [62] 상세 페이지: https://www.findatamall.or.kr/market/dataProdDetail?gdsSn=1247&menuNo=28
#
# [63] 상세 페이지: https://www.findatamall.or.kr/market/dataProdDetail?gdsSn=2308&menuNo=28
#
# [64] 상세 페이지: https://www.findatamall.or.kr/market/dataProdDetail?gdsSn=2341&menuNo=28
#
# [65] 상세 페이지: https://www.findatamall.or.kr/market/dataProdDetail?gdsSn=16484&menuNo=28
#
# [66] 상세 페이지: https://www.findatamall.or.kr/market/dataProdDetail?gdsSn=16603&menuNo=28
#
# [67] 상세 페이지: https://www.findatamall.or.kr/market/dataProdDetail?gdsSn=2254&menuNo=28
#
# [68] 상세 페이지: https://www.findatamall.or.kr/market/dataProdDetail?gdsSn=2357&menuNo=28
#
# [69] 상세 페이지: https://www.findatamall.or.kr/market/dataProdDetail?gdsSn=1235&menuNo=28
#
# [70] 상세 페이지: https://www.findatamall.or.kr/market/dataProdDetail?gdsSn=1250&menuNo=28
# ✅ 누적 70개 저장 완료
#
# [71] 상세 페이지: https://www.findatamall.or.kr/market/dataProdDetail?gdsSn=1445&menuNo=28
#
# [72] 상세 페이지: https://www.findatamall.or.kr/market/dataProdDetail?gdsSn=1836&menuNo=28
#
# [73] 상세 페이지: https://www.findatamall.or.kr/market/dataProdDetail?gdsSn=2337&menuNo=28
#
# [74] 상세 페이지: https://www.findatamall.or.kr/market/dataProdDetail?gdsSn=3337&menuNo=28
#
# [75] 상세 페이지: https://www.findatamall.or.kr/market/dataProdDetail?gdsSn=8636&menuNo=28
#
# [76] 상세 페이지: https://www.findatamall.or.kr/market/dataProdDetail?gdsSn=9405&menuNo=28
#
# [77] 상세 페이지: https://www.findatamall.or.kr/market/dataProdDetail?gdsSn=13854&menuNo=28
#
# [78] 상세 페이지: https://www.findatamall.or.kr/market/dataProdDetail?gdsSn=16741&menuNo=28
#
# [79] 상세 페이지: https://www.findatamall.or.kr/market/dataProdDetail?gdsSn=13861&menuNo=28
#
# [80] 상세 페이지: https://www.findatamall.or.kr/market/dataProdDetail?gdsSn=1156&menuNo=28
# ✅ 누적 80개 저장 완료
#
# [81] 상세 페이지: https://www.findatamall.or.kr/market/dataProdDetail?gdsSn=354&menuNo=28
#
# [82] 상세 페이지: https://www.findatamall.or.kr/market/dataProdDetail?gdsSn=1128&menuNo=28
#
# [83] 상세 페이지: https://www.findatamall.or.kr/market/dataProdDetail?gdsSn=355&menuNo=28
#
# [84] 상세 페이지: https://www.findatamall.or.kr/market/dataProdDetail?gdsSn=1249&menuNo=28
#
# [85] 상세 페이지: https://www.findatamall.or.kr/market/dataProdDetail?gdsSn=1838&menuNo=28
#
# [86] 상세 페이지: https://www.findatamall.or.kr/market/dataProdDetail?gdsSn=3546&menuNo=28
#
# [87] 상세 페이지: https://www.findatamall.or.kr/market/dataProdDetail?gdsSn=10764&menuNo=28
#
# [88] 상세 페이지: https://www.findatamall.or.kr/market/dataProdDetail?gdsSn=2067&menuNo=28
#
# [89] 상세 페이지: https://www.findatamall.or.kr/market/dataProdDetail?gdsSn=6913&menuNo=28
#
# [90] 상세 페이지: https://www.findatamall.or.kr/market/dataProdDetail?gdsSn=8641&menuNo=28
# ✅ 누적 90개 저장 완료
#
# [91] 상세 페이지: https://www.findatamall.or.kr/market/dataProdDetail?gdsSn=9325&menuNo=28
#
# [92] 상세 페이지: https://www.findatamall.or.kr/market/dataProdDetail?gdsSn=10803&menuNo=28
#
# [93] 상세 페이지: https://www.findatamall.or.kr/market/dataProdDetail?gdsSn=3412&menuNo=28
#
# [94] 상세 페이지: https://www.findatamall.or.kr/market/dataProdDetail?gdsSn=6304&menuNo=28
#
# [95] 상세 페이지: https://www.findatamall.or.kr/market/dataProdDetail?gdsSn=12745&menuNo=28
#
# [96] 상세 페이지: https://www.findatamall.or.kr/market/dataProdDetail?gdsSn=12333&menuNo=28
#
# [97] 상세 페이지: https://www.findatamall.or.kr/market/dataProdDetail?gdsSn=6194&menuNo=28
#
# [98] 상세 페이지: https://www.findatamall.or.kr/market/dataProdDetail?gdsSn=16641&menuNo=28
#
# [99] 상세 페이지: https://www.findatamall.or.kr/market/dataProdDetail?gdsSn=16602&menuNo=28
#
# [100] 상세 페이지: https://www.findatamall.or.kr/market/dataProdDetail?gdsSn=16587&menuNo=28
# ✅ 누적 100개 저장 완료
#
# [101] 상세 페이지: https://www.findatamall.or.kr/market/dataProdDetail?gdsSn=14049&menuNo=28
#
# [102] 상세 페이지: https://www.findatamall.or.kr/market/dataProdDetail?gdsSn=16653&menuNo=28
#
# [103] 상세 페이지: https://www.findatamall.or.kr/market/dataProdDetail?gdsSn=13866&menuNo=28
#
# [104] 상세 페이지: https://www.findatamall.or.kr/market/dataProdDetail?gdsSn=13849&menuNo=28
#
# [105] 상세 페이지: https://www.findatamall.or.kr/market/dataProdDetail?gdsSn=16689&menuNo=28
#
# [106] 상세 페이지: https://www.findatamall.or.kr/market/dataProdDetail?gdsSn=16572&menuNo=28
#
# [107] 상세 페이지: https://www.findatamall.or.kr/market/dataProdDetail?gdsSn=482&menuNo=28
#
# [108] 상세 페이지: https://www.findatamall.or.kr/market/dataProdDetail?gdsSn=2444&menuNo=28
#
# [109] 상세 페이지: https://www.findatamall.or.kr/market/dataProdDetail?gdsSn=687&menuNo=28
#
# [110] 상세 페이지: https://www.findatamall.or.kr/market/dataProdDetail?gdsSn=1153&menuNo=28
# ✅ 누적 110개 저장 완료
#
# [111] 상세 페이지: https://www.findatamall.or.kr/market/dataProdDetail?gdsSn=1248&menuNo=28
#
# [112] 상세 페이지: https://www.findatamall.or.kr/market/dataProdDetail?gdsSn=1129&menuNo=28
#
# [113] 상세 페이지: https://www.findatamall.or.kr/market/dataProdDetail?gdsSn=1154&menuNo=28
#
# [114] 상세 페이지: https://www.findatamall.or.kr/market/dataProdDetail?gdsSn=357&menuNo=28
#
# [115] 상세 페이지: https://www.findatamall.or.kr/market/dataProdDetail?gdsSn=1840&menuNo=28
#
# [116] 상세 페이지: https://www.findatamall.or.kr/market/dataProdDetail?gdsSn=888&menuNo=28
#
# [117] 상세 페이지: https://www.findatamall.or.kr/market/dataProdDetail?gdsSn=359&menuNo=28
#
# [118] 상세 페이지: https://www.findatamall.or.kr/market/dataProdDetail?gdsSn=679&menuNo=28
#
# [119] 상세 페이지: https://www.findatamall.or.kr/market/dataProdDetail?gdsSn=2342&menuNo=28
#
# [120] 상세 페이지: https://www.findatamall.or.kr/market/dataProdDetail?gdsSn=834&menuNo=28
# ✅ 누적 120개 저장 완료
#
# [121] 상세 페이지: https://www.findatamall.or.kr/market/dataProdDetail?gdsSn=2307&menuNo=28
#
# [122] 상세 페이지: https://www.findatamall.or.kr/market/dataProdDetail?gdsSn=5932&menuNo=28
#
# [123] 상세 페이지: https://www.findatamall.or.kr/market/dataProdDetail?gdsSn=1120&menuNo=28
#
# [124] 상세 페이지: https://www.findatamall.or.kr/market/dataProdDetail?gdsSn=2306&menuNo=28
#
# [125] 상세 페이지: https://www.findatamall.or.kr/market/dataProdDetail?gdsSn=2388&menuNo=28
#
# [126] 상세 페이지: https://www.findatamall.or.kr/market/dataProdDetail?gdsSn=2338&menuNo=28
#
# [127] 상세 페이지: https://www.findatamall.or.kr/market/dataProdDetail?gdsSn=7815&menuNo=28
#
# [128] 상세 페이지: https://www.findatamall.or.kr/market/dataProdDetail?gdsSn=5833&menuNo=28
#
# [129] 상세 페이지: https://www.findatamall.or.kr/market/dataProdDetail?gdsSn=4986&menuNo=28
#
# [130] 상세 페이지: https://www.findatamall.or.kr/market/dataProdDetail?gdsSn=4987&menuNo=28
# ✅ 누적 130개 저장 완료
#
# [131] 상세 페이지: https://www.findatamall.or.kr/market/dataProdDetail?gdsSn=6148&menuNo=28
#
# [132] 상세 페이지: https://www.findatamall.or.kr/market/dataProdDetail?gdsSn=1745&menuNo=28
#
# [133] 상세 페이지: https://www.findatamall.or.kr/market/dataProdDetail?gdsSn=3373&menuNo=28
#
# [134] 상세 페이지: https://www.findatamall.or.kr/market/dataProdDetail?gdsSn=3063&menuNo=28
#
# [135] 상세 페이지: https://www.findatamall.or.kr/market/dataProdDetail?gdsSn=5483&menuNo=28
#
# [136] 상세 페이지: https://www.findatamall.or.kr/market/dataProdDetail?gdsSn=2511&menuNo=28
#
# [137] 상세 페이지: https://www.findatamall.or.kr/market/dataProdDetail?gdsSn=8635&menuNo=28
#
# [138] 상세 페이지: https://www.findatamall.or.kr/market/dataProdDetail?gdsSn=4232&menuNo=28
#
# [139] 상세 페이지: https://www.findatamall.or.kr/market/dataProdDetail?gdsSn=9334&menuNo=28
#
# [140] 상세 페이지: https://www.findatamall.or.kr/market/dataProdDetail?gdsSn=7133&menuNo=28
# ✅ 누적 140개 저장 완료
#
# [141] 상세 페이지: https://www.findatamall.or.kr/market/dataProdDetail?gdsSn=12621&menuNo=28
#
# [142] 상세 페이지: https://www.findatamall.or.kr/market/dataProdDetail?gdsSn=11150&menuNo=28
#
# [143] 상세 페이지: https://www.findatamall.or.kr/market/dataProdDetail?gdsSn=9180&menuNo=28
#
# [144] 상세 페이지: https://www.findatamall.or.kr/market/dataProdDetail?gdsSn=11462&menuNo=28
#
# [145] 상세 페이지: https://www.findatamall.or.kr/market/dataProdDetail?gdsSn=16578&menuNo=28
#
# [146] 상세 페이지: https://www.findatamall.or.kr/market/dataProdDetail?gdsSn=12633&menuNo=28
#
# [147] 상세 페이지: https://www.findatamall.or.kr/market/dataProdDetail?gdsSn=16601&menuNo=28
#
# [148] 상세 페이지: https://www.findatamall.or.kr/market/dataProdDetail?gdsSn=16440&menuNo=28
#
# [149] 상세 페이지: https://www.findatamall.or.kr/market/dataProdDetail?gdsSn=16642&menuNo=28
#
# [150] 상세 페이지: https://www.findatamall.or.kr/market/dataProdDetail?gdsSn=12735&menuNo=28
# ✅ 누적 150개 저장 완료
#
# [151] 상세 페이지: https://www.findatamall.or.kr/market/dataProdDetail?gdsSn=16691&menuNo=28
#
# [152] 상세 페이지: https://www.findatamall.or.kr/market/dataProdDetail?gdsSn=16589&menuNo=28
#
# [153] 상세 페이지: https://www.findatamall.or.kr/market/dataProdDetail?gdsSn=11989&menuNo=28
#
# [154] 상세 페이지: https://www.findatamall.or.kr/market/dataProdDetail?gdsSn=16652&menuNo=28
#
# [155] 상세 페이지: https://www.findatamall.or.kr/market/dataProdDetail?gdsSn=14027&menuNo=28
#
# [156] 상세 페이지: https://www.findatamall.or.kr/market/dataProdDetail?gdsSn=16474&menuNo=28
#
# [157] 상세 페이지: https://www.findatamall.or.kr/market/dataProdDetail?gdsSn=16580&menuNo=28
#
# [158] 상세 페이지: https://www.findatamall.or.kr/market/dataProdDetail?gdsSn=16453&menuNo=28
#
# [159] 상세 페이지: https://www.findatamall.or.kr/market/dataProdDetail?gdsSn=16586&menuNo=28
#
# [160] 상세 페이지: https://www.findatamall.or.kr/market/dataProdDetail?gdsSn=16778&menuNo=28
# ✅ 누적 160개 저장 완료
#
# [161] 상세 페이지: https://www.findatamall.or.kr/market/dataProdDetail?gdsSn=16554&menuNo=28
#
# [162] 상세 페이지: https://www.findatamall.or.kr/market/dataProdDetail?gdsSn=9555&menuNo=28
#
# [163] 상세 페이지: https://www.findatamall.or.kr/market/dataProdDetail?gdsSn=16575&menuNo=28
#
# [164] 상세 페이지: https://www.findatamall.or.kr/market/dataProdDetail?gdsSn=2446&menuNo=28
#
# [165] 상세 페이지: https://www.findatamall.or.kr/market/dataProdDetail?gdsSn=2358&menuNo=28
#
# [166] 상세 페이지: https://www.findatamall.or.kr/market/dataProdDetail?gdsSn=2443&menuNo=28
#
# [167] 상세 페이지: https://www.findatamall.or.kr/market/dataProdDetail?gdsSn=1620&menuNo=28
#
# [168] 상세 페이지: https://www.findatamall.or.kr/market/dataProdDetail?gdsSn=391&menuNo=28
#
# [169] 상세 페이지: https://www.findatamall.or.kr/market/dataProdDetail?gdsSn=390&menuNo=28
#
# [170] 상세 페이지: https://www.findatamall.or.kr/market/dataProdDetail?gdsSn=356&menuNo=28
# ✅ 누적 170개 저장 완료
#
# [171] 상세 페이지: https://www.findatamall.or.kr/market/dataProdDetail?gdsSn=1777&menuNo=28
#
# [172] 상세 페이지: https://www.findatamall.or.kr/market/dataProdDetail?gdsSn=358&menuNo=28
#
# [173] 상세 페이지: https://www.findatamall.or.kr/market/dataProdDetail?gdsSn=1837&menuNo=28
#
# [174] 상세 페이지: https://www.findatamall.or.kr/market/dataProdDetail?gdsSn=439&menuNo=28
#
# [175] 상세 페이지: https://www.findatamall.or.kr/market/dataProdDetail?gdsSn=1059&menuNo=28
#
# [176] 상세 페이지: https://www.findatamall.or.kr/market/dataProdDetail?gdsSn=1610&menuNo=28
#
# [177] 상세 페이지: https://www.findatamall.or.kr/market/dataProdDetail?gdsSn=1842&menuNo=28
#
# [178] 상세 페이지: https://www.findatamall.or.kr/market/dataProdDetail?gdsSn=807&menuNo=28
#
# [179] 상세 페이지: https://www.findatamall.or.kr/market/dataProdDetail?gdsSn=2340&menuNo=28
#
# [180] 상세 페이지: https://www.findatamall.or.kr/market/dataProdDetail?gdsSn=840&menuNo=28
# ✅ 누적 180개 저장 완료
#
# [181] 상세 페이지: https://www.findatamall.or.kr/market/dataProdDetail?gdsSn=806&menuNo=28
#
# [182] 상세 페이지: https://www.findatamall.or.kr/market/dataProdDetail?gdsSn=7816&menuNo=28
#
# [183] 상세 페이지: https://www.findatamall.or.kr/market/dataProdDetail?gdsSn=1476&menuNo=28
#
# [184] 상세 페이지: https://www.findatamall.or.kr/market/dataProdDetail?gdsSn=1259&menuNo=28
#
# [185] 상세 페이지: https://www.findatamall.or.kr/market/dataProdDetail?gdsSn=2339&menuNo=28
#
# [186] 상세 페이지: https://www.findatamall.or.kr/market/dataProdDetail?gdsSn=838&menuNo=28
#
# [187] 상세 페이지: https://www.findatamall.or.kr/market/dataProdDetail?gdsSn=3000&menuNo=28
#
# [188] 상세 페이지: https://www.findatamall.or.kr/market/dataProdDetail?gdsSn=1923&menuNo=28
#
# [189] 상세 페이지: https://www.findatamall.or.kr/market/dataProdDetail?gdsSn=2073&menuNo=28
#
# [190] 상세 페이지: https://www.findatamall.or.kr/market/dataProdDetail?gdsSn=796&menuNo=28
# ✅ 누적 190개 저장 완료
#
# [191] 상세 페이지: https://www.findatamall.or.kr/market/dataProdDetail?gdsSn=1410&menuNo=28
#
# [192] 상세 페이지: https://www.findatamall.or.kr/market/dataProdDetail?gdsSn=2070&menuNo=28
#
# [193] 상세 페이지: https://www.findatamall.or.kr/market/dataProdDetail?gdsSn=1990&menuNo=28
#
# [194] 상세 페이지: https://www.findatamall.or.kr/market/dataProdDetail?gdsSn=6163&menuNo=28
#
# [195] 상세 페이지: https://www.findatamall.or.kr/market/dataProdDetail?gdsSn=3365&menuNo=28
#
# [196] 상세 페이지: https://www.findatamall.or.kr/market/dataProdDetail?gdsSn=2309&menuNo=28
#
# [197] 상세 페이지: https://www.findatamall.or.kr/market/dataProdDetail?gdsSn=2066&menuNo=28
#
# [198] 상세 페이지: https://www.findatamall.or.kr/market/dataProdDetail?gdsSn=3066&menuNo=28
#
# [199] 상세 페이지: https://www.findatamall.or.kr/market/dataProdDetail?gdsSn=10613&menuNo=28
#
# [200] 상세 페이지: https://www.findatamall.or.kr/market/dataProdDetail?gdsSn=3091&menuNo=28
# ✅ 누적 200개 저장 완료
#
# [201] 상세 페이지: https://www.findatamall.or.kr/market/dataProdDetail?gdsSn=3062&menuNo=28
#
# [202] 상세 페이지: https://www.findatamall.or.kr/market/dataProdDetail?gdsSn=1742&menuNo=28
#
# [203] 상세 페이지: https://www.findatamall.or.kr/market/dataProdDetail?gdsSn=3065&menuNo=28
#
# [204] 상세 페이지: https://www.findatamall.or.kr/market/dataProdDetail?gdsSn=2179&menuNo=28
#
# [205] 상세 페이지: https://www.findatamall.or.kr/market/dataProdDetail?gdsSn=6579&menuNo=28
#
# [206] 상세 페이지: https://www.findatamall.or.kr/market/dataProdDetail?gdsSn=3061&menuNo=28
#
# [207] 상세 페이지: https://www.findatamall.or.kr/market/dataProdDetail?gdsSn=2011&menuNo=28
#
# [208] 상세 페이지: https://www.findatamall.or.kr/market/dataProdDetail?gdsSn=1730&menuNo=28
#
# [209] 상세 페이지: https://www.findatamall.or.kr/market/dataProdDetail?gdsSn=2083&menuNo=28
#
# [210] 상세 페이지: https://www.findatamall.or.kr/market/dataProdDetail?gdsSn=12622&menuNo=28
# ✅ 누적 210개 저장 완료
#
# [211] 상세 페이지: https://www.findatamall.or.kr/market/dataProdDetail?gdsSn=9402&menuNo=28
#
# [212] 상세 페이지: https://www.findatamall.or.kr/market/dataProdDetail?gdsSn=7138&menuNo=28
#
# [213] 상세 페이지: https://www.findatamall.or.kr/market/dataProdDetail?gdsSn=2080&menuNo=28
#
# [214] 상세 페이지: https://www.findatamall.or.kr/market/dataProdDetail?gdsSn=6327&menuNo=28
#
# [215] 상세 페이지: https://www.findatamall.or.kr/market/dataProdDetail?gdsSn=6884&menuNo=28
#
# [216] 상세 페이지: https://www.findatamall.or.kr/market/dataProdDetail?gdsSn=3873&menuNo=28
#
# [217] 상세 페이지: https://www.findatamall.or.kr/market/dataProdDetail?gdsSn=6578&menuNo=28
#
# [218] 상세 페이지: https://www.findatamall.or.kr/market/dataProdDetail?gdsSn=6391&menuNo=28
#
# [219] 상세 페이지: https://www.findatamall.or.kr/market/dataProdDetail?gdsSn=9307&menuNo=28
#
# [220] 상세 페이지: https://www.findatamall.or.kr/market/dataProdDetail?gdsSn=9404&menuNo=28
# ✅ 누적 220개 저장 완료
#
# [221] 상세 페이지: https://www.findatamall.or.kr/market/dataProdDetail?gdsSn=4191&menuNo=28
#
# [222] 상세 페이지: https://www.findatamall.or.kr/market/dataProdDetail?gdsSn=5664&menuNo=28
#
# [223] 상세 페이지: https://www.findatamall.or.kr/market/dataProdDetail?gdsSn=3159&menuNo=28
#
# [224] 상세 페이지: https://www.findatamall.or.kr/market/dataProdDetail?gdsSn=6250&menuNo=28
#
# [225] 상세 페이지: https://www.findatamall.or.kr/market/dataProdDetail?gdsSn=3903&menuNo=28
#
# [226] 상세 페이지: https://www.findatamall.or.kr/market/dataProdDetail?gdsSn=12746&menuNo=28
#
# [227] 상세 페이지: https://www.findatamall.or.kr/market/dataProdDetail?gdsSn=4201&menuNo=28
#
# [228] 상세 페이지: https://www.findatamall.or.kr/market/dataProdDetail?gdsSn=6218&menuNo=28
#
# [229] 상세 페이지: https://www.findatamall.or.kr/market/dataProdDetail?gdsSn=4903&menuNo=28
#
# [230] 상세 페이지: https://www.findatamall.or.kr/market/dataProdDetail?gdsSn=4221&menuNo=28
# ✅ 누적 230개 저장 완료
#
# [231] 상세 페이지: https://www.findatamall.or.kr/market/dataProdDetail?gdsSn=7123&menuNo=28
#
# [232] 상세 페이지: https://www.findatamall.or.kr/market/dataProdDetail?gdsSn=5477&menuNo=28
#
# [233] 상세 페이지: https://www.findatamall.or.kr/market/dataProdDetail?gdsSn=10057&menuNo=28
#
# [234] 상세 페이지: https://www.findatamall.or.kr/market/dataProdDetail?gdsSn=3854&menuNo=28
#
# [235] 상세 페이지: https://www.findatamall.or.kr/market/dataProdDetail?gdsSn=10907&menuNo=28
#
# [236] 상세 페이지: https://www.findatamall.or.kr/market/dataProdDetail?gdsSn=3964&menuNo=28
#
# [237] 상세 페이지: https://www.findatamall.or.kr/market/dataProdDetail?gdsSn=4207&menuNo=28
#
# [238] 상세 페이지: https://www.findatamall.or.kr/market/dataProdDetail?gdsSn=9399&menuNo=28
#
# [239] 상세 페이지: https://www.findatamall.or.kr/market/dataProdDetail?gdsSn=6313&menuNo=28
#
# [240] 상세 페이지: https://www.findatamall.or.kr/market/dataProdDetail?gdsSn=3894&menuNo=28
# ✅ 누적 240개 저장 완료
#
# [241] 상세 페이지: https://www.findatamall.or.kr/market/dataProdDetail?gdsSn=6253&menuNo=28
#
# [242] 상세 페이지: https://www.findatamall.or.kr/market/dataProdDetail?gdsSn=6872&menuNo=28
#
# [243] 상세 페이지: https://www.findatamall.or.kr/market/dataProdDetail?gdsSn=6862&menuNo=28
#
# [244] 상세 페이지: https://www.findatamall.or.kr/market/dataProdDetail?gdsSn=5300&menuNo=28
#
# [245] 상세 페이지: https://www.findatamall.or.kr/market/dataProdDetail?gdsSn=4849&menuNo=28
#
# [246] 상세 페이지: https://www.findatamall.or.kr/market/dataProdDetail?gdsSn=8850&menuNo=28
#
# [247] 상세 페이지: https://www.findatamall.or.kr/market/dataProdDetail?gdsSn=6822&menuNo=28
#
# [248] 상세 페이지: https://www.findatamall.or.kr/market/dataProdDetail?gdsSn=14017&menuNo=28
#
# [249] 상세 페이지: https://www.findatamall.or.kr/market/dataProdDetail?gdsSn=6594&menuNo=28
#
# [250] 상세 페이지: https://www.findatamall.or.kr/market/dataProdDetail?gdsSn=16433&menuNo=28
# ✅ 누적 250개 저장 완료
#
# [251] 상세 페이지: https://www.findatamall.or.kr/market/dataProdDetail?gdsSn=6308&menuNo=28
#
# [252] 상세 페이지: https://www.findatamall.or.kr/market/dataProdDetail?gdsSn=16438&menuNo=28
#
# [253] 상세 페이지: https://www.findatamall.or.kr/market/dataProdDetail?gdsSn=10557&menuNo=28
#
# [254] 상세 페이지: https://www.findatamall.or.kr/market/dataProdDetail?gdsSn=6906&menuNo=28
#
# [255] 상세 페이지: https://www.findatamall.or.kr/market/dataProdDetail?gdsSn=6857&menuNo=28
#
# [256] 상세 페이지: https://www.findatamall.or.kr/market/dataProdDetail?gdsSn=3385&menuNo=28
#
# [257] 상세 페이지: https://www.findatamall.or.kr/market/dataProdDetail?gdsSn=6874&menuNo=28
#
# [258] 상세 페이지: https://www.findatamall.or.kr/market/dataProdDetail?gdsSn=6162&menuNo=28
#
# [259] 상세 페이지: https://www.findatamall.or.kr/market/dataProdDetail?gdsSn=11165&menuNo=28
#
# [260] 상세 페이지: https://www.findatamall.or.kr/market/dataProdDetail?gdsSn=9260&menuNo=28
# ✅ 누적 260개 저장 완료
#
# [261] 상세 페이지: https://www.findatamall.or.kr/market/dataProdDetail?gdsSn=8999&menuNo=28
#
# [262] 상세 페이지: https://www.findatamall.or.kr/market/dataProdDetail?gdsSn=6231&menuNo=28
#
# [263] 상세 페이지: https://www.findatamall.or.kr/market/dataProdDetail?gdsSn=6876&menuNo=28
#
# [264] 상세 페이지: https://www.findatamall.or.kr/market/dataProdDetail?gdsSn=8853&menuNo=28
#
# [265] 상세 페이지: https://www.findatamall.or.kr/market/dataProdDetail?gdsSn=8987&menuNo=28
#
# [266] 상세 페이지: https://www.findatamall.or.kr/market/dataProdDetail?gdsSn=6821&menuNo=28
#
# [267] 상세 페이지: https://www.findatamall.or.kr/market/dataProdDetail?gdsSn=16432&menuNo=28
#
# [268] 상세 페이지: https://www.findatamall.or.kr/market/dataProdDetail?gdsSn=8988&menuNo=28
#
# [269] 상세 페이지: https://www.findatamall.or.kr/market/dataProdDetail?gdsSn=7128&menuNo=28
#
# [270] 상세 페이지: https://www.findatamall.or.kr/market/dataProdDetail?gdsSn=6277&menuNo=28
# ✅ 누적 270개 저장 완료
#
# [271] 상세 페이지: https://www.findatamall.or.kr/market/dataProdDetail?gdsSn=6233&menuNo=28
#
# [272] 상세 페이지: https://www.findatamall.or.kr/market/dataProdDetail?gdsSn=9289&menuNo=28
#
# [273] 상세 페이지: https://www.findatamall.or.kr/market/dataProdDetail?gdsSn=9209&menuNo=28
#
# [274] 상세 페이지: https://www.findatamall.or.kr/market/dataProdDetail?gdsSn=6893&menuNo=28
#
# [275] 상세 페이지: https://www.findatamall.or.kr/market/dataProdDetail?gdsSn=6262&menuNo=28
#
# [276] 상세 페이지: https://www.findatamall.or.kr/market/dataProdDetail?gdsSn=9306&menuNo=28
#
# [277] 상세 페이지: https://www.findatamall.or.kr/market/dataProdDetail?gdsSn=9223&menuNo=28
#
# [278] 상세 페이지: https://www.findatamall.or.kr/market/dataProdDetail?gdsSn=9203&menuNo=28
#
# [279] 상세 페이지: https://www.findatamall.or.kr/market/dataProdDetail?gdsSn=9233&menuNo=28
#
# [280] 상세 페이지: https://www.findatamall.or.kr/market/dataProdDetail?gdsSn=6259&menuNo=28
# ✅ 누적 280개 저장 완료
#
# [281] 상세 페이지: https://www.findatamall.or.kr/market/dataProdDetail?gdsSn=8989&menuNo=28
#
# [282] 상세 페이지: https://www.findatamall.or.kr/market/dataProdDetail?gdsSn=10572&menuNo=28
#
# [283] 상세 페이지: https://www.findatamall.or.kr/market/dataProdDetail?gdsSn=10561&menuNo=28
#
# [284] 상세 페이지: https://www.findatamall.or.kr/market/dataProdDetail?gdsSn=9287&menuNo=28
#
# [285] 상세 페이지: https://www.findatamall.or.kr/market/dataProdDetail?gdsSn=6818&menuNo=28
#
# [286] 상세 페이지: https://www.findatamall.or.kr/market/dataProdDetail?gdsSn=6265&menuNo=28
#
# [287] 상세 페이지: https://www.findatamall.or.kr/market/dataProdDetail?gdsSn=7126&menuNo=28
#
# [288] 상세 페이지: https://www.findatamall.or.kr/market/dataProdDetail?gdsSn=6310&menuNo=28
#
# [289] 상세 페이지: https://www.findatamall.or.kr/market/dataProdDetail?gdsSn=9212&menuNo=28
#
# [290] 상세 페이지: https://www.findatamall.or.kr/market/dataProdDetail?gdsSn=8842&menuNo=28
# ✅ 누적 290개 저장 완료
#
# [291] 상세 페이지: https://www.findatamall.or.kr/market/dataProdDetail?gdsSn=6843&menuNo=28
#
# [292] 상세 페이지: https://www.findatamall.or.kr/market/dataProdDetail?gdsSn=9259&menuNo=28
#
# [293] 상세 페이지: https://www.findatamall.or.kr/market/dataProdDetail?gdsSn=9232&menuNo=28
#
# [294] 상세 페이지: https://www.findatamall.or.kr/market/dataProdDetail?gdsSn=9196&menuNo=28
#
# [295] 상세 페이지: https://www.findatamall.or.kr/market/dataProdDetail?gdsSn=6247&menuNo=28
#
# [296] 상세 페이지: https://www.findatamall.or.kr/market/dataProdDetail?gdsSn=9537&menuNo=28
#
# [297] 상세 페이지: https://www.findatamall.or.kr/market/dataProdDetail?gdsSn=9230&menuNo=28
#
# [298] 상세 페이지: https://www.findatamall.or.kr/market/dataProdDetail?gdsSn=6215&menuNo=28
#
# [299] 상세 페이지: https://www.findatamall.or.kr/market/dataProdDetail?gdsSn=5352&menuNo=28
#
# [300] 상세 페이지: https://www.findatamall.or.kr/market/dataProdDetail?gdsSn=6255&menuNo=28
# ✅ 누적 300개 저장 완료
#
# [301] 상세 페이지: https://www.findatamall.or.kr/market/dataProdDetail?gdsSn=6252&menuNo=28
#
# [302] 상세 페이지: https://www.findatamall.or.kr/market/dataProdDetail?gdsSn=6232&menuNo=28
#
# [303] 상세 페이지: https://www.findatamall.or.kr/market/dataProdDetail?gdsSn=6196&menuNo=28
#
# [304] 상세 페이지: https://www.findatamall.or.kr/market/dataProdDetail?gdsSn=6841&menuNo=28
#
# [305] 상세 페이지: https://www.findatamall.or.kr/market/dataProdDetail?gdsSn=6860&menuNo=28
#
# [306] 상세 페이지: https://www.findatamall.or.kr/market/dataProdDetail?gdsSn=9514&menuNo=28
#
# [307] 상세 페이지: https://www.findatamall.or.kr/market/dataProdDetail?gdsSn=5353&menuNo=28
#
# [308] 상세 페이지: https://www.findatamall.or.kr/market/dataProdDetail?gdsSn=6850&menuNo=28
#
# [309] 상세 페이지: https://www.findatamall.or.kr/market/dataProdDetail?gdsSn=9187&menuNo=28
#
# [310] 상세 페이지: https://www.findatamall.or.kr/market/dataProdDetail?gdsSn=6820&menuNo=28
# ✅ 누적 310개 저장 완료
#
# [311] 상세 페이지: https://www.findatamall.or.kr/market/dataProdDetail?gdsSn=6838&menuNo=28
#
# [312] 상세 페이지: https://www.findatamall.or.kr/market/dataProdDetail?gdsSn=6263&menuNo=28
#
# [313] 상세 페이지: https://www.findatamall.or.kr/market/dataProdDetail?gdsSn=6830&menuNo=28
#
# [314] 상세 페이지: https://www.findatamall.or.kr/market/dataProdDetail?gdsSn=9200&menuNo=28
#
# [315] 상세 페이지: https://www.findatamall.or.kr/market/dataProdDetail?gdsSn=8866&menuNo=28
#
# [316] 상세 페이지: https://www.findatamall.or.kr/market/dataProdDetail?gdsSn=6195&menuNo=28
#
# [317] 상세 페이지: https://www.findatamall.or.kr/market/dataProdDetail?gdsSn=12046&menuNo=28
#
# [318] 상세 페이지: https://www.findatamall.or.kr/market/dataProdDetail?gdsSn=6257&menuNo=28
#
# [319] 상세 페이지: https://www.findatamall.or.kr/market/dataProdDetail?gdsSn=9397&menuNo=28
#
# [320] 상세 페이지: https://www.findatamall.or.kr/market/dataProdDetail?gdsSn=9523&menuNo=28
# ✅ 누적 320개 저장 완료
#
# [321] 상세 페이지: https://www.findatamall.or.kr/market/dataProdDetail?gdsSn=11510&menuNo=28
#
# [322] 상세 페이지: https://www.findatamall.or.kr/market/dataProdDetail?gdsSn=5928&menuNo=28
#
# [323] 상세 페이지: https://www.findatamall.or.kr/market/dataProdDetail?gdsSn=10570&menuNo=28
#
# [324] 상세 페이지: https://www.findatamall.or.kr/market/dataProdDetail?gdsSn=16574&menuNo=28
#
# [325] 상세 페이지: https://www.findatamall.or.kr/market/dataProdDetail?gdsSn=11163&menuNo=28
#
# [326] 상세 페이지: https://www.findatamall.or.kr/market/dataProdDetail?gdsSn=12743&menuNo=28
#
# [327] 상세 페이지: https://www.findatamall.or.kr/market/dataProdDetail?gdsSn=16442&menuNo=28
#
# [328] 상세 페이지: https://www.findatamall.or.kr/market/dataProdDetail?gdsSn=12734&menuNo=28
#
# [329] 상세 페이지: https://www.findatamall.or.kr/market/dataProdDetail?gdsSn=12060&menuNo=28
#
# [330] 상세 페이지: https://www.findatamall.or.kr/market/dataProdDetail?gdsSn=16427&menuNo=28
# ✅ 누적 330개 저장 완료
#
# [331] 상세 페이지: https://www.findatamall.or.kr/market/dataProdDetail?gdsSn=9533&menuNo=28
#
# [332] 상세 페이지: https://www.findatamall.or.kr/market/dataProdDetail?gdsSn=10788&menuNo=28
#
# [333] 상세 페이지: https://www.findatamall.or.kr/market/dataProdDetail?gdsSn=12062&menuNo=28
#
# [334] 상세 페이지: https://www.findatamall.or.kr/market/dataProdDetail?gdsSn=9535&menuNo=28
#
# [335] 상세 페이지: https://www.findatamall.or.kr/market/dataProdDetail?gdsSn=12730&menuNo=28
#
# [336] 상세 페이지: https://www.findatamall.or.kr/market/dataProdDetail?gdsSn=12729&menuNo=28
#
# [337] 상세 페이지: https://www.findatamall.or.kr/market/dataProdDetail?gdsSn=9534&menuNo=28
#
# [338] 상세 페이지: https://www.findatamall.or.kr/market/dataProdDetail?gdsSn=16454&menuNo=28
#
# [339] 상세 페이지: https://www.findatamall.or.kr/market/dataProdDetail?gdsSn=9517&menuNo=28
#
# [340] 상세 페이지: https://www.findatamall.or.kr/market/dataProdDetail?gdsSn=9536&menuNo=28
# ✅ 누적 340개 저장 완료
#
# [341] 상세 페이지: https://www.findatamall.or.kr/market/dataProdDetail?gdsSn=16820&menuNo=28
#
# [342] 상세 페이지: https://www.findatamall.or.kr/market/dataProdDetail?gdsSn=16478&menuNo=28
#
# [343] 상세 페이지: https://www.findatamall.or.kr/market/dataProdDetail?gdsSn=9530&menuNo=28
#
# [344] 상세 페이지: https://www.findatamall.or.kr/market/dataProdDetail?gdsSn=9528&menuNo=28
#
# [345] 상세 페이지: https://www.findatamall.or.kr/market/dataProdDetail?gdsSn=16428&menuNo=28
#
# [346] 상세 페이지: https://www.findatamall.or.kr/market/dataProdDetail?gdsSn=9532&menuNo=28
#
# [347] 상세 페이지: https://www.findatamall.or.kr/market/dataProdDetail?gdsSn=9531&menuNo=28
#
# [348] 상세 페이지: https://www.findatamall.or.kr/market/dataProdDetail?gdsSn=16588&menuNo=28
#
# [349] 상세 페이지: https://www.findatamall.or.kr/market/dataProdDetail?gdsSn=16590&menuNo=28
#
# [350] 상세 페이지: https://www.findatamall.or.kr/market/dataProdDetail?gdsSn=16475&menuNo=28
# ✅ 누적 350개 저장 완료
#
# [351] 상세 페이지: https://www.findatamall.or.kr/market/dataProdDetail?gdsSn=9529&menuNo=28
#
# [352] 상세 페이지: https://www.findatamall.or.kr/market/dataProdDetail?gdsSn=16471&menuNo=28
#
# [353] 상세 페이지: https://www.findatamall.or.kr/market/dataProdDetail?gdsSn=16443&menuNo=28
#
# [354] 상세 페이지: https://www.findatamall.or.kr/market/dataProdDetail?gdsSn=13870&menuNo=28
#
# [355] 상세 페이지: https://www.findatamall.or.kr/market/dataProdDetail?gdsSn=9521&menuNo=28
# ---------------------------------------------------------------------------
# TimeoutError                              Traceback (most recent call last)
# /tmp/ipython-input-14-4051546897.py in <cell line: 1>()
#     150
#     151 # 실행
# --> 152 await run()
#
# /tmp/ipython-input-14-4051546897.py in run()
#      73                 total_crawled += 1
#      74                 print(f"\n[{total_crawled}] 상세 페이지: {detail_url}")
# ---> 75                 await page.goto(detail_url)
#      76                 await page.wait_for_timeout(1200)
#      77
#
# /usr/local/lib/python3.11/dist-packages/playwright/async_api/_generated.py in goto(self, url, timeout, wait_until, referer)
#    8973
#    8974         return mapping.from_impl_nullable(
# -> 8975             await self._impl_obj.goto(
#    8976                 url=url, timeout=timeout, waitUntil=wait_until, referer=referer
#    8977             )
#
# /usr/local/lib/python3.11/dist-packages/playwright/_impl/_page.py in goto(self, url, timeout, waitUntil, referer)
#     554         referer: str = None,
#     555     ) -> Optional[Response]:
# --> 556         return await self._main_frame.goto(**locals_to_params(locals()))
#     557
#     558     async def reload(
#
# /usr/local/lib/python3.11/dist-packages/playwright/_impl/_frame.py in goto(self, url, timeout, waitUntil, referer)
#     144             Optional[Response],
#     145             from_nullable_channel(
# --> 146                 await self._channel.send(
#     147                     "goto", self._navigation_timeout, locals_to_params(locals())
#     148                 )
#
# /usr/local/lib/python3.11/dist-packages/playwright/_impl/_connection.py in send(self, method, timeout_calculator, params, is_internal, title)
#      67         title: str = None,
#      68     ) -> Any:
# ---> 69         return await self._connection.wrap_api_call(
#      70             lambda: self._inner_send(method, timeout_calculator, params, False),
#      71             is_internal,
#
# /usr/local/lib/python3.11/dist-packages/playwright/_impl/_connection.py in wrap_api_call(self, cb, is_internal, title)
#     556             return await cb()
#     557         except Exception as error:
# --> 558             raise rewrite_error(error, f"{parsed_st['apiName']}: {error}") from None
#     559         finally:
#     560             self._api_zone.set(None)
#
# TimeoutError: Page.goto: Timeout 30000ms exceeded.
# Call log:
#   - navigating to "https://www.findatamall.or.kr/market/dataProdDetail?gdsSn=9521&menuNo=28", waiting until "load"

# %%
import nest_asyncio
import asyncio
import json
import re
from datetime import datetime
from playwright.async_api import async_playwright

nest_asyncio.apply()

BASE_URL = "https://www.findatamall.or.kr"
START_URL = "https://www.findatamall.or.kr/market/dataProdList?menuNo=28"
SAVE_DIR = "/content/drive/MyDrive/00. 대학원"
CLICK_LIMIT = 850

DETAIL_URL_FILE = f"{SAVE_DIR}/detail_urls.txt"  # 저장할 URL 목록 파일

async def collect_detail_urls():
    async with async_playwright() as p:
        browser = await p.chromium.launch(headless=True)
        page = await browser.new_page()

        await page.goto(START_URL)
        await page.wait_for_timeout(2000)

        for i in range(CLICK_LIMIT):
            try:
                load_more_btn = await page.query_selector('a.moreList')
                if load_more_btn:
                    btn_text = await load_more_btn.inner_text()
                    if "10개 더보기" in btn_text:
                        print(f"🔄 '10개 더보기' 클릭: {i+1}/{CLICK_LIMIT}")
                        await load_more_btn.click()
                        await page.wait_for_timeout(3000)
                    else:
                        break
                else:
                    break
            except Exception as e:
                print(f"⚠️ 클릭 실패: {e}")
                break

        goods_divs = await page.query_selector_all("#container > div.contents > div > div.goodsList > div")
        print(f"✅ 총 {len(goods_divs)}개 상품 발견")

        seen_urls = set()
        detail_urls = []
        for goods_div in goods_divs:
            a_tag = await goods_div.query_selector("div:nth-child(2) > a")
            if a_tag:
                href = await a_tag.get_attribute("href")
                if href:
                    full_url = BASE_URL + href
                    if full_url not in seen_urls:
                        detail_urls.append(full_url)
                        seen_urls.add(full_url)

        # 텍스트 파일로 저장
        with open(DETAIL_URL_FILE, "w", encoding="utf-8") as f:
            for url in detail_urls:
                f.write(url + "\n")

        await browser.close()
        print(f"📁 URL 저장 완료: {DETAIL_URL_FILE}")


async def crawl_details_from_file():
    async with async_playwright() as p:
        browser = await p.chromium.launch(headless=True)
        page = await browser.new_page()

        now_str = datetime.now().strftime("%Y%m%d%H%M")
        output_file = f"{SAVE_DIR}/findatamall_output_all-{now_str}.jsonl"

        with open(DETAIL_URL_FILE, "r", encoding="utf-8") as f:
            detail_urls = [line.strip() for line in f if line.strip()]

        async def safe_text(selector, default="N/A"):
            try:
                elem = await page.query_selector(selector)
                return (await elem.inner_text()).strip() if elem else default
            except:
                return default

        total_crawled = 0
        with open(output_file, "w", encoding="utf-8") as f:
            for detail_url in detail_urls:
                total_crawled += 1
                print(f"\n[{total_crawled}] 상세 페이지: {detail_url}")

                try:
                    await page.goto(detail_url, timeout=15000)
                    await page.wait_for_timeout(1200)
                except Exception as e:
                    print(f"⛔ 상세 페이지 접근 실패: {e}")
                    continue

                # 가격 정보 등 상세 내용 수집 (기존 로직 그대로 유지)
                price_num = None
                price_type = None
                price_text_free = await safe_text("#container > div.contents > div.goodsTop > div.goodsInfo > div.goodsName > div > p > em")
                if "무료" in price_text_free:
                    price_num = 0
                    price_type = "무료"
                else:
                    price_text_paid = await safe_text("#container > div.contents > div.goodsTop > div.goodsInfo > div.goodsName > div > p > span > em")
                    if "협의" in price_text_paid:
                        price_num = 0
                        price_type = "협의"
                    else:
                        m = re.search(r"[\d,]+", price_text_paid)
                        if m:
                            price_num = int(m.group(0).replace(",", ""))
                            price_type = "유료"
                        else:
                            price_num = price_text_paid
                            price_type = "확인필요"

                columns = []
                ths = await page.query_selector_all("#sampleData > dl > dd > div:nth-child(2) > div.colTable.fixTh.scroll.txtC > table > thead > tr > th")
                for th in ths:
                    columns.append((await th.inner_text()).strip())

                tags = []
                product_type = "N/A"
                span_tag = await page.query_selector("div.hashTag.v4 > span.prodList")
                if span_tag:
                    span_text = (await span_tag.inner_text()).strip()
                    if span_text:
                        tags.append(span_text)
                        product_type = span_text

                a_tags = await page.query_selector_all("div.hashTag.v4 > a")
                for a in a_tags:
                    a_text = (await a.inner_text()).strip()
                    if a_text.startswith("#"):
                        a_text = a_text[1:]
                    if a_text:
                        tags.append(a_text)

                data = {
                    "price_num": price_num,
                    "price_type": price_type,
                    "columns": columns,
                    "name": await safe_text("#container > div.contents > div.goodsTop > div.goodsInfo > div.goodsName > h4"),
                    "category": await safe_text("#container > div.contents > div.goodsTop > div.goodsImgArea > div:nth-child(2) > dl:nth-child(1) > dd"),
                    "format": await safe_text("#prodDetail > dl > dd > div > table > tbody > tr > td:nth-child(7)"),
                    "size": await safe_text("#prodDetail > dl > dd > div > table > tbody > tr > td:nth-child(8)"),
                    "summary": await safe_text("#info > dl > dd > div.grayBgBox.grayBgBoxGdsCn > p"),
                    "detail": await safe_text("#info > dl > dd > div:nth-child(2)"),
                    "seller": await safe_text("#container > div.contents > div.goodsTop > div.goodsImgArea > div:nth-child(2) > dl:nth-child(2) > dd"),
                    "register_date": await safe_text("#container > div.contents > div.goodsTop > div.goodsImgArea > div:nth-child(2) > dl:nth-child(3) > dd"),
                    "modify_date": await safe_text("#container > div.contents > div.goodsTop > div.goodsImgArea > div:nth-child(2) > dl:nth-child(4) > dd"),
                    "product_type": product_type,
                    "tags": tags,
                    "view_cnt": await safe_text("#container > div.contents > div.goodsTop > div.goodsInfo > div.goodsName > div > div > span.icoView.gray"),
                    "download_cnt": await safe_text("#container > div.contents > div.goodsTop > div.goodsInfo > div.goodsName > div > div > span.icoDownload.black"),
                    "url": detail_url
                }

                f.write(json.dumps(data, ensure_ascii=False) + "\n")

                if total_crawled % 10 == 0:
                    print(f"✅ 누적 {total_crawled}개 저장 완료")

        await browser.close()
        print(f"\n🎉 전체 완료: 총 {total_crawled}개 수집 완료")


# 필요에 따라 아래 중 하나씩 실행
await collect_detail_urls()

# 확인용 로그
with open(DETAIL_URL_FILE, 'r', encoding='utf-8') as f:
    urls = [line.strip() for line in f if line.strip()]
    print(f"🔍 수집된 상세 URL 수: {len(urls)}")

await crawl_details_from_file()
# Out:
# 스트리밍 출력 내용이 길어서 마지막 5000줄이 삭제되었습니다.
#
# [6069] 상세 페이지: https://www.findatamall.or.kr/market/dataProdDetail?gdsSn=9098&menuNo=28
#
# [6070] 상세 페이지: https://www.findatamall.or.kr/market/dataProdDetail?gdsSn=8813&menuNo=28
# ✅ 누적 6070개 저장 완료
#
# [6071] 상세 페이지: https://www.findatamall.or.kr/market/dataProdDetail?gdsSn=8811&menuNo=28
#
# [6072] 상세 페이지: https://www.findatamall.or.kr/market/dataProdDetail?gdsSn=8202&menuNo=28
#
# [6073] 상세 페이지: https://www.findatamall.or.kr/market/dataProdDetail?gdsSn=8167&menuNo=28
#
# [6074] 상세 페이지: https://www.findatamall.or.kr/market/dataProdDetail?gdsSn=8085&menuNo=28
#
# [6075] 상세 페이지: https://www.findatamall.or.kr/market/dataProdDetail?gdsSn=8082&menuNo=28
#
# [6076] 상세 페이지: https://www.findatamall.or.kr/market/dataProdDetail?gdsSn=7989&menuNo=28
#
# [6077] 상세 페이지: https://www.findatamall.or.kr/market/dataProdDetail?gdsSn=7914&menuNo=28
#
# [6078] 상세 페이지: https://www.findatamall.or.kr/market/dataProdDetail?gdsSn=7822&menuNo=28
#
# [6079] 상세 페이지: https://www.findatamall.or.kr/market/dataProdDetail?gdsSn=7803&menuNo=28
#
# [6080] 상세 페이지: https://www.findatamall.or.kr/market/dataProdDetail?gdsSn=7791&menuNo=28
# ✅ 누적 6080개 저장 완료
#
# [6081] 상세 페이지: https://www.findatamall.or.kr/market/dataProdDetail?gdsSn=7722&menuNo=28
#
# [6082] 상세 페이지: https://www.findatamall.or.kr/market/dataProdDetail?gdsSn=7699&menuNo=28
#
# [6083] 상세 페이지: https://www.findatamall.or.kr/market/dataProdDetail?gdsSn=7634&menuNo=28
#
# [6084] 상세 페이지: https://www.findatamall.or.kr/market/dataProdDetail?gdsSn=6045&menuNo=28
#
# [6085] 상세 페이지: https://www.findatamall.or.kr/market/dataProdDetail?gdsSn=5900&menuNo=28
#
# [6086] 상세 페이지: https://www.findatamall.or.kr/market/dataProdDetail?gdsSn=5795&menuNo=28
#
# [6087] 상세 페이지: https://www.findatamall.or.kr/market/dataProdDetail?gdsSn=5782&menuNo=28
#
# [6088] 상세 페이지: https://www.findatamall.or.kr/market/dataProdDetail?gdsSn=5760&menuNo=28
#
# [6089] 상세 페이지: https://www.findatamall.or.kr/market/dataProdDetail?gdsSn=5632&menuNo=28
#
# [6090] 상세 페이지: https://www.findatamall.or.kr/market/dataProdDetail?gdsSn=5617&menuNo=28
# ✅ 누적 6090개 저장 완료
#
# [6091] 상세 페이지: https://www.findatamall.or.kr/market/dataProdDetail?gdsSn=5607&menuNo=28
#
# [6092] 상세 페이지: https://www.findatamall.or.kr/market/dataProdDetail?gdsSn=5605&menuNo=28
#
# [6093] 상세 페이지: https://www.findatamall.or.kr/market/dataProdDetail?gdsSn=5582&menuNo=28
#
# [6094] 상세 페이지: https://www.findatamall.or.kr/market/dataProdDetail?gdsSn=5572&menuNo=28
#
# [6095] 상세 페이지: https://www.findatamall.or.kr/market/dataProdDetail?gdsSn=5546&menuNo=28
#
# [6096] 상세 페이지: https://www.findatamall.or.kr/market/dataProdDetail?gdsSn=5539&menuNo=28
#
# [6097] 상세 페이지: https://www.findatamall.or.kr/market/dataProdDetail?gdsSn=5523&menuNo=28
#
# [6098] 상세 페이지: https://www.findatamall.or.kr/market/dataProdDetail?gdsSn=5493&menuNo=28
#
# [6099] 상세 페이지: https://www.findatamall.or.kr/market/dataProdDetail?gdsSn=5278&menuNo=28
#
# [6100] 상세 페이지: https://www.findatamall.or.kr/market/dataProdDetail?gdsSn=5247&menuNo=28
# ✅ 누적 6100개 저장 완료
#
# [6101] 상세 페이지: https://www.findatamall.or.kr/market/dataProdDetail?gdsSn=5234&menuNo=28
#
# [6102] 상세 페이지: https://www.findatamall.or.kr/market/dataProdDetail?gdsSn=5009&menuNo=28
#
# [6103] 상세 페이지: https://www.findatamall.or.kr/market/dataProdDetail?gdsSn=17178&menuNo=28
#
# [6104] 상세 페이지: https://www.findatamall.or.kr/market/dataProdDetail?gdsSn=16771&menuNo=28
#
# [6105] 상세 페이지: https://www.findatamall.or.kr/market/dataProdDetail?gdsSn=16543&menuNo=28
#
# [6106] 상세 페이지: https://www.findatamall.or.kr/market/dataProdDetail?gdsSn=16503&menuNo=28
#
# [6107] 상세 페이지: https://www.findatamall.or.kr/market/dataProdDetail?gdsSn=16500&menuNo=28
#
# [6108] 상세 페이지: https://www.findatamall.or.kr/market/dataProdDetail?gdsSn=13660&menuNo=28
#
# [6109] 상세 페이지: https://www.findatamall.or.kr/market/dataProdDetail?gdsSn=13619&menuNo=28
#
# [6110] 상세 페이지: https://www.findatamall.or.kr/market/dataProdDetail?gdsSn=12544&menuNo=28
# ✅ 누적 6110개 저장 완료
#
# [6111] 상세 페이지: https://www.findatamall.or.kr/market/dataProdDetail?gdsSn=12412&menuNo=28
#
# [6112] 상세 페이지: https://www.findatamall.or.kr/market/dataProdDetail?gdsSn=12118&menuNo=28
#
# [6113] 상세 페이지: https://www.findatamall.or.kr/market/dataProdDetail?gdsSn=12102&menuNo=28
#
# [6114] 상세 페이지: https://www.findatamall.or.kr/market/dataProdDetail?gdsSn=12021&menuNo=28
#
# [6115] 상세 페이지: https://www.findatamall.or.kr/market/dataProdDetail?gdsSn=11886&menuNo=28
#
# [6116] 상세 페이지: https://www.findatamall.or.kr/market/dataProdDetail?gdsSn=11579&menuNo=28
#
# [6117] 상세 페이지: https://www.findatamall.or.kr/market/dataProdDetail?gdsSn=11381&menuNo=28
#
# [6118] 상세 페이지: https://www.findatamall.or.kr/market/dataProdDetail?gdsSn=11355&menuNo=28
#
# [6119] 상세 페이지: https://www.findatamall.or.kr/market/dataProdDetail?gdsSn=10870&menuNo=28
#
# [6120] 상세 페이지: https://www.findatamall.or.kr/market/dataProdDetail?gdsSn=10856&menuNo=28
# ✅ 누적 6120개 저장 완료
#
# [6121] 상세 페이지: https://www.findatamall.or.kr/market/dataProdDetail?gdsSn=10842&menuNo=28
#
# [6122] 상세 페이지: https://www.findatamall.or.kr/market/dataProdDetail?gdsSn=10766&menuNo=28
#
# [6123] 상세 페이지: https://www.findatamall.or.kr/market/dataProdDetail?gdsSn=10372&menuNo=28
#
# [6124] 상세 페이지: https://www.findatamall.or.kr/market/dataProdDetail?gdsSn=10362&menuNo=28
#
# [6125] 상세 페이지: https://www.findatamall.or.kr/market/dataProdDetail?gdsSn=10336&menuNo=28
#
# [6126] 상세 페이지: https://www.findatamall.or.kr/market/dataProdDetail?gdsSn=10321&menuNo=28
#
# [6127] 상세 페이지: https://www.findatamall.or.kr/market/dataProdDetail?gdsSn=10309&menuNo=28
#
# [6128] 상세 페이지: https://www.findatamall.or.kr/market/dataProdDetail?gdsSn=10229&menuNo=28
#
# [6129] 상세 페이지: https://www.findatamall.or.kr/market/dataProdDetail?gdsSn=10188&menuNo=28
#
# [6130] 상세 페이지: https://www.findatamall.or.kr/market/dataProdDetail?gdsSn=10176&menuNo=28
# ✅ 누적 6130개 저장 완료
#
# [6131] 상세 페이지: https://www.findatamall.or.kr/market/dataProdDetail?gdsSn=10149&menuNo=28
#
# [6132] 상세 페이지: https://www.findatamall.or.kr/market/dataProdDetail?gdsSn=10094&menuNo=28
#
# [6133] 상세 페이지: https://www.findatamall.or.kr/market/dataProdDetail?gdsSn=10092&menuNo=28
#
# [6134] 상세 페이지: https://www.findatamall.or.kr/market/dataProdDetail?gdsSn=10063&menuNo=28
#
# [6135] 상세 페이지: https://www.findatamall.or.kr/market/dataProdDetail?gdsSn=10062&menuNo=28
#
# [6136] 상세 페이지: https://www.findatamall.or.kr/market/dataProdDetail?gdsSn=10061&menuNo=28
#
# [6137] 상세 페이지: https://www.findatamall.or.kr/market/dataProdDetail?gdsSn=9776&menuNo=28
#
# [6138] 상세 페이지: https://www.findatamall.or.kr/market/dataProdDetail?gdsSn=9683&menuNo=28
#
# [6139] 상세 페이지: https://www.findatamall.or.kr/market/dataProdDetail?gdsSn=9655&menuNo=28
#
# [6140] 상세 페이지: https://www.findatamall.or.kr/market/dataProdDetail?gdsSn=9649&menuNo=28
# ✅ 누적 6140개 저장 완료
#
# [6141] 상세 페이지: https://www.findatamall.or.kr/market/dataProdDetail?gdsSn=9351&menuNo=28
#
# [6142] 상세 페이지: https://www.findatamall.or.kr/market/dataProdDetail?gdsSn=9139&menuNo=28
#
# [6143] 상세 페이지: https://www.findatamall.or.kr/market/dataProdDetail?gdsSn=9136&menuNo=28
#
# [6144] 상세 페이지: https://www.findatamall.or.kr/market/dataProdDetail?gdsSn=9105&menuNo=28
#
# [6145] 상세 페이지: https://www.findatamall.or.kr/market/dataProdDetail?gdsSn=9094&menuNo=28
#
# [6146] 상세 페이지: https://www.findatamall.or.kr/market/dataProdDetail?gdsSn=9085&menuNo=28
#
# [6147] 상세 페이지: https://www.findatamall.or.kr/market/dataProdDetail?gdsSn=9077&menuNo=28
#
# [6148] 상세 페이지: https://www.findatamall.or.kr/market/dataProdDetail?gdsSn=9076&menuNo=28
#
# [6149] 상세 페이지: https://www.findatamall.or.kr/market/dataProdDetail?gdsSn=8815&menuNo=28
#
# [6150] 상세 페이지: https://www.findatamall.or.kr/market/dataProdDetail?gdsSn=8284&menuNo=28
# ✅ 누적 6150개 저장 완료
#
# [6151] 상세 페이지: https://www.findatamall.or.kr/market/dataProdDetail?gdsSn=8268&menuNo=28
#
# [6152] 상세 페이지: https://www.findatamall.or.kr/market/dataProdDetail?gdsSn=8141&menuNo=28
#
# [6153] 상세 페이지: https://www.findatamall.or.kr/market/dataProdDetail?gdsSn=7971&menuNo=28
#
# [6154] 상세 페이지: https://www.findatamall.or.kr/market/dataProdDetail?gdsSn=7829&menuNo=28
#
# [6155] 상세 페이지: https://www.findatamall.or.kr/market/dataProdDetail?gdsSn=7765&menuNo=28
#
# [6156] 상세 페이지: https://www.findatamall.or.kr/market/dataProdDetail?gdsSn=7704&menuNo=28
#
# [6157] 상세 페이지: https://www.findatamall.or.kr/market/dataProdDetail?gdsSn=7624&menuNo=28
#
# [6158] 상세 페이지: https://www.findatamall.or.kr/market/dataProdDetail?gdsSn=7616&menuNo=28
#
# [6159] 상세 페이지: https://www.findatamall.or.kr/market/dataProdDetail?gdsSn=7533&menuNo=28
#
# [6160] 상세 페이지: https://www.findatamall.or.kr/market/dataProdDetail?gdsSn=7456&menuNo=28
# ✅ 누적 6160개 저장 완료
#
# [6161] 상세 페이지: https://www.findatamall.or.kr/market/dataProdDetail?gdsSn=7377&menuNo=28
#
# [6162] 상세 페이지: https://www.findatamall.or.kr/market/dataProdDetail?gdsSn=7358&menuNo=28
#
# [6163] 상세 페이지: https://www.findatamall.or.kr/market/dataProdDetail?gdsSn=6662&menuNo=28
#
# [6164] 상세 페이지: https://www.findatamall.or.kr/market/dataProdDetail?gdsSn=6648&menuNo=28
#
# [6165] 상세 페이지: https://www.findatamall.or.kr/market/dataProdDetail?gdsSn=6646&menuNo=28
#
# [6166] 상세 페이지: https://www.findatamall.or.kr/market/dataProdDetail?gdsSn=6474&menuNo=28
#
# [6167] 상세 페이지: https://www.findatamall.or.kr/market/dataProdDetail?gdsSn=6438&menuNo=28
#
# [6168] 상세 페이지: https://www.findatamall.or.kr/market/dataProdDetail?gdsSn=6436&menuNo=28
#
# [6169] 상세 페이지: https://www.findatamall.or.kr/market/dataProdDetail?gdsSn=6429&menuNo=28
#
# [6170] 상세 페이지: https://www.findatamall.or.kr/market/dataProdDetail?gdsSn=6427&menuNo=28
# ✅ 누적 6170개 저장 완료
#
# [6171] 상세 페이지: https://www.findatamall.or.kr/market/dataProdDetail?gdsSn=6043&menuNo=28
#
# [6172] 상세 페이지: https://www.findatamall.or.kr/market/dataProdDetail?gdsSn=5850&menuNo=28
#
# [6173] 상세 페이지: https://www.findatamall.or.kr/market/dataProdDetail?gdsSn=5776&menuNo=28
#
# [6174] 상세 페이지: https://www.findatamall.or.kr/market/dataProdDetail?gdsSn=5621&menuNo=28
#
# [6175] 상세 페이지: https://www.findatamall.or.kr/market/dataProdDetail?gdsSn=5606&menuNo=28
#
# [6176] 상세 페이지: https://www.findatamall.or.kr/market/dataProdDetail?gdsSn=5565&menuNo=28
#
# [6177] 상세 페이지: https://www.findatamall.or.kr/market/dataProdDetail?gdsSn=5547&menuNo=28
#
# [6178] 상세 페이지: https://www.findatamall.or.kr/market/dataProdDetail?gdsSn=5540&menuNo=28
#
# [6179] 상세 페이지: https://www.findatamall.or.kr/market/dataProdDetail?gdsSn=5527&menuNo=28
#
# [6180] 상세 페이지: https://www.findatamall.or.kr/market/dataProdDetail?gdsSn=5499&menuNo=28
# ✅ 누적 6180개 저장 완료
#
# [6181] 상세 페이지: https://www.findatamall.or.kr/market/dataProdDetail?gdsSn=5072&menuNo=28
#
# [6182] 상세 페이지: https://www.findatamall.or.kr/market/dataProdDetail?gdsSn=5057&menuNo=28
#
# [6183] 상세 페이지: https://www.findatamall.or.kr/market/dataProdDetail?gdsSn=5019&menuNo=28
#
# [6184] 상세 페이지: https://www.findatamall.or.kr/market/dataProdDetail?gdsSn=16650&menuNo=28
#
# [6185] 상세 페이지: https://www.findatamall.or.kr/market/dataProdDetail?gdsSn=16582&menuNo=28
#
# [6186] 상세 페이지: https://www.findatamall.or.kr/market/dataProdDetail?gdsSn=13659&menuNo=28
#
# [6187] 상세 페이지: https://www.findatamall.or.kr/market/dataProdDetail?gdsSn=13495&menuNo=28
#
# [6188] 상세 페이지: https://www.findatamall.or.kr/market/dataProdDetail?gdsSn=13458&menuNo=28
#
# [6189] 상세 페이지: https://www.findatamall.or.kr/market/dataProdDetail?gdsSn=12770&menuNo=28
#
# [6190] 상세 페이지: https://www.findatamall.or.kr/market/dataProdDetail?gdsSn=12754&menuNo=28
# ✅ 누적 6190개 저장 완료
#
# [6191] 상세 페이지: https://www.findatamall.or.kr/market/dataProdDetail?gdsSn=12749&menuNo=28
#
# [6192] 상세 페이지: https://www.findatamall.or.kr/market/dataProdDetail?gdsSn=12644&menuNo=28
#
# [6193] 상세 페이지: https://www.findatamall.or.kr/market/dataProdDetail?gdsSn=12623&menuNo=28
#
# [6194] 상세 페이지: https://www.findatamall.or.kr/market/dataProdDetail?gdsSn=12515&menuNo=28
#
# [6195] 상세 페이지: https://www.findatamall.or.kr/market/dataProdDetail?gdsSn=12092&menuNo=28
#
# [6196] 상세 페이지: https://www.findatamall.or.kr/market/dataProdDetail?gdsSn=12000&menuNo=28
#
# [6197] 상세 페이지: https://www.findatamall.or.kr/market/dataProdDetail?gdsSn=11823&menuNo=28
#
# [6198] 상세 페이지: https://www.findatamall.or.kr/market/dataProdDetail?gdsSn=11589&menuNo=28
#
# [6199] 상세 페이지: https://www.findatamall.or.kr/market/dataProdDetail?gdsSn=11580&menuNo=28
#
# [6200] 상세 페이지: https://www.findatamall.or.kr/market/dataProdDetail?gdsSn=11566&menuNo=28
# ✅ 누적 6200개 저장 완료
#
# [6201] 상세 페이지: https://www.findatamall.or.kr/market/dataProdDetail?gdsSn=11373&menuNo=28
#
# [6202] 상세 페이지: https://www.findatamall.or.kr/market/dataProdDetail?gdsSn=11365&menuNo=28
#
# [6203] 상세 페이지: https://www.findatamall.or.kr/market/dataProdDetail?gdsSn=10779&menuNo=28
#
# [6204] 상세 페이지: https://www.findatamall.or.kr/market/dataProdDetail?gdsSn=10378&menuNo=28
#
# [6205] 상세 페이지: https://www.findatamall.or.kr/market/dataProdDetail?gdsSn=10369&menuNo=28
#
# [6206] 상세 페이지: https://www.findatamall.or.kr/market/dataProdDetail?gdsSn=10360&menuNo=28
#
# [6207] 상세 페이지: https://www.findatamall.or.kr/market/dataProdDetail?gdsSn=10358&menuNo=28
#
# [6208] 상세 페이지: https://www.findatamall.or.kr/market/dataProdDetail?gdsSn=10318&menuNo=28
#
# [6209] 상세 페이지: https://www.findatamall.or.kr/market/dataProdDetail?gdsSn=10260&menuNo=28
#
# [6210] 상세 페이지: https://www.findatamall.or.kr/market/dataProdDetail?gdsSn=10207&menuNo=28
# ✅ 누적 6210개 저장 완료
#
# [6211] 상세 페이지: https://www.findatamall.or.kr/market/dataProdDetail?gdsSn=10205&menuNo=28
#
# [6212] 상세 페이지: https://www.findatamall.or.kr/market/dataProdDetail?gdsSn=10194&menuNo=28
#
# [6213] 상세 페이지: https://www.findatamall.or.kr/market/dataProdDetail?gdsSn=10175&menuNo=28
#
# [6214] 상세 페이지: https://www.findatamall.or.kr/market/dataProdDetail?gdsSn=10107&menuNo=28
#
# [6215] 상세 페이지: https://www.findatamall.or.kr/market/dataProdDetail?gdsSn=10087&menuNo=28
#
# [6216] 상세 페이지: https://www.findatamall.or.kr/market/dataProdDetail?gdsSn=10084&menuNo=28
#
# [6217] 상세 페이지: https://www.findatamall.or.kr/market/dataProdDetail?gdsSn=10049&menuNo=28
#
# [6218] 상세 페이지: https://www.findatamall.or.kr/market/dataProdDetail?gdsSn=10016&menuNo=28
#
# [6219] 상세 페이지: https://www.findatamall.or.kr/market/dataProdDetail?gdsSn=9967&menuNo=28
#
# [6220] 상세 페이지: https://www.findatamall.or.kr/market/dataProdDetail?gdsSn=9961&menuNo=28
# ✅ 누적 6220개 저장 완료
#
# [6221] 상세 페이지: https://www.findatamall.or.kr/market/dataProdDetail?gdsSn=9957&menuNo=28
#
# [6222] 상세 페이지: https://www.findatamall.or.kr/market/dataProdDetail?gdsSn=9950&menuNo=28
#
# [6223] 상세 페이지: https://www.findatamall.or.kr/market/dataProdDetail?gdsSn=9937&menuNo=28
#
# [6224] 상세 페이지: https://www.findatamall.or.kr/market/dataProdDetail?gdsSn=9933&menuNo=28
#
# [6225] 상세 페이지: https://www.findatamall.or.kr/market/dataProdDetail?gdsSn=9778&menuNo=28
#
# [6226] 상세 페이지: https://www.findatamall.or.kr/market/dataProdDetail?gdsSn=9143&menuNo=28
#
# [6227] 상세 페이지: https://www.findatamall.or.kr/market/dataProdDetail?gdsSn=9102&menuNo=28
#
# [6228] 상세 페이지: https://www.findatamall.or.kr/market/dataProdDetail?gdsSn=9086&menuNo=28
#
# [6229] 상세 페이지: https://www.findatamall.or.kr/market/dataProdDetail?gdsSn=8470&menuNo=28
#
# [6230] 상세 페이지: https://www.findatamall.or.kr/market/dataProdDetail?gdsSn=8462&menuNo=28
# ✅ 누적 6230개 저장 완료
#
# [6231] 상세 페이지: https://www.findatamall.or.kr/market/dataProdDetail?gdsSn=8457&menuNo=28
#
# [6232] 상세 페이지: https://www.findatamall.or.kr/market/dataProdDetail?gdsSn=8281&menuNo=28
#
# [6233] 상세 페이지: https://www.findatamall.or.kr/market/dataProdDetail?gdsSn=8275&menuNo=28
#
# [6234] 상세 페이지: https://www.findatamall.or.kr/market/dataProdDetail?gdsSn=8260&menuNo=28
#
# [6235] 상세 페이지: https://www.findatamall.or.kr/market/dataProdDetail?gdsSn=8200&menuNo=28
#
# [6236] 상세 페이지: https://www.findatamall.or.kr/market/dataProdDetail?gdsSn=8143&menuNo=28
#
# [6237] 상세 페이지: https://www.findatamall.or.kr/market/dataProdDetail?gdsSn=8070&menuNo=28
#
# [6238] 상세 페이지: https://www.findatamall.or.kr/market/dataProdDetail?gdsSn=7838&menuNo=28
#
# [6239] 상세 페이지: https://www.findatamall.or.kr/market/dataProdDetail?gdsSn=7825&menuNo=28
#
# [6240] 상세 페이지: https://www.findatamall.or.kr/market/dataProdDetail?gdsSn=7811&menuNo=28
# ✅ 누적 6240개 저장 완료
#
# [6241] 상세 페이지: https://www.findatamall.or.kr/market/dataProdDetail?gdsSn=7676&menuNo=28
#
# [6242] 상세 페이지: https://www.findatamall.or.kr/market/dataProdDetail?gdsSn=7538&menuNo=28
#
# [6243] 상세 페이지: https://www.findatamall.or.kr/market/dataProdDetail?gdsSn=7445&menuNo=28
#
# [6244] 상세 페이지: https://www.findatamall.or.kr/market/dataProdDetail?gdsSn=6635&menuNo=28
#
# [6245] 상세 페이지: https://www.findatamall.or.kr/market/dataProdDetail?gdsSn=6615&menuNo=28
#
# [6246] 상세 페이지: https://www.findatamall.or.kr/market/dataProdDetail?gdsSn=6472&menuNo=28
#
# [6247] 상세 페이지: https://www.findatamall.or.kr/market/dataProdDetail?gdsSn=6381&menuNo=28
#
# [6248] 상세 페이지: https://www.findatamall.or.kr/market/dataProdDetail?gdsSn=6033&menuNo=28
#
# [6249] 상세 페이지: https://www.findatamall.or.kr/market/dataProdDetail?gdsSn=5861&menuNo=28
#
# [6250] 상세 페이지: https://www.findatamall.or.kr/market/dataProdDetail?gdsSn=5849&menuNo=28
# ✅ 누적 6250개 저장 완료
#
# [6251] 상세 페이지: https://www.findatamall.or.kr/market/dataProdDetail?gdsSn=5843&menuNo=28
#
# [6252] 상세 페이지: https://www.findatamall.or.kr/market/dataProdDetail?gdsSn=5802&menuNo=28
#
# [6253] 상세 페이지: https://www.findatamall.or.kr/market/dataProdDetail?gdsSn=5792&menuNo=28
#
# [6254] 상세 페이지: https://www.findatamall.or.kr/market/dataProdDetail?gdsSn=5790&menuNo=28
#
# [6255] 상세 페이지: https://www.findatamall.or.kr/market/dataProdDetail?gdsSn=5781&menuNo=28
#
# [6256] 상세 페이지: https://www.findatamall.or.kr/market/dataProdDetail?gdsSn=5742&menuNo=28
#
# [6257] 상세 페이지: https://www.findatamall.or.kr/market/dataProdDetail?gdsSn=5631&menuNo=28
#
# [6258] 상세 페이지: https://www.findatamall.or.kr/market/dataProdDetail?gdsSn=5609&menuNo=28
#
# [6259] 상세 페이지: https://www.findatamall.or.kr/market/dataProdDetail?gdsSn=5250&menuNo=28
#
# [6260] 상세 페이지: https://www.findatamall.or.kr/market/dataProdDetail?gdsSn=5243&menuNo=28
# ✅ 누적 6260개 저장 완료
#
# [6261] 상세 페이지: https://www.findatamall.or.kr/market/dataProdDetail?gdsSn=5233&menuNo=28
#
# [6262] 상세 페이지: https://www.findatamall.or.kr/market/dataProdDetail?gdsSn=5231&menuNo=28
#
# [6263] 상세 페이지: https://www.findatamall.or.kr/market/dataProdDetail?gdsSn=5078&menuNo=28
#
# [6264] 상세 페이지: https://www.findatamall.or.kr/market/dataProdDetail?gdsSn=5069&menuNo=28
#
# [6265] 상세 페이지: https://www.findatamall.or.kr/market/dataProdDetail?gdsSn=5061&menuNo=28
#
# [6266] 상세 페이지: https://www.findatamall.or.kr/market/dataProdDetail?gdsSn=5052&menuNo=28
#
# [6267] 상세 페이지: https://www.findatamall.or.kr/market/dataProdDetail?gdsSn=5027&menuNo=28
#
# [6268] 상세 페이지: https://www.findatamall.or.kr/market/dataProdDetail?gdsSn=5022&menuNo=28
#
# [6269] 상세 페이지: https://www.findatamall.or.kr/market/dataProdDetail?gdsSn=4367&menuNo=28
#
# [6270] 상세 페이지: https://www.findatamall.or.kr/market/dataProdDetail?gdsSn=1397&menuNo=28
# ✅ 누적 6270개 저장 완료
#
# [6271] 상세 페이지: https://www.findatamall.or.kr/market/dataProdDetail?gdsSn=17052&menuNo=28
#
# [6272] 상세 페이지: https://www.findatamall.or.kr/market/dataProdDetail?gdsSn=16549&menuNo=28
#
# [6273] 상세 페이지: https://www.findatamall.or.kr/market/dataProdDetail?gdsSn=16492&menuNo=28
#
# [6274] 상세 페이지: https://www.findatamall.or.kr/market/dataProdDetail?gdsSn=13638&menuNo=28
#
# [6275] 상세 페이지: https://www.findatamall.or.kr/market/dataProdDetail?gdsSn=13505&menuNo=28
#
# [6276] 상세 페이지: https://www.findatamall.or.kr/market/dataProdDetail?gdsSn=12760&menuNo=28
#
# [6277] 상세 페이지: https://www.findatamall.or.kr/market/dataProdDetail?gdsSn=12758&menuNo=28
#
# [6278] 상세 페이지: https://www.findatamall.or.kr/market/dataProdDetail?gdsSn=12505&menuNo=28
#
# [6279] 상세 페이지: https://www.findatamall.or.kr/market/dataProdDetail?gdsSn=12408&menuNo=28
#
# [6280] 상세 페이지: https://www.findatamall.or.kr/market/dataProdDetail?gdsSn=11891&menuNo=28
# ✅ 누적 6280개 저장 완료
#
# [6281] 상세 페이지: https://www.findatamall.or.kr/market/dataProdDetail?gdsSn=11820&menuNo=28
#
# [6282] 상세 페이지: https://www.findatamall.or.kr/market/dataProdDetail?gdsSn=11785&menuNo=28
#
# [6283] 상세 페이지: https://www.findatamall.or.kr/market/dataProdDetail?gdsSn=11386&menuNo=28
#
# [6284] 상세 페이지: https://www.findatamall.or.kr/market/dataProdDetail?gdsSn=10853&menuNo=28
#
# [6285] 상세 페이지: https://www.findatamall.or.kr/market/dataProdDetail?gdsSn=10782&menuNo=28
#
# [6286] 상세 페이지: https://www.findatamall.or.kr/market/dataProdDetail?gdsSn=10324&menuNo=28
#
# [6287] 상세 페이지: https://www.findatamall.or.kr/market/dataProdDetail?gdsSn=10323&menuNo=28
#
# [6288] 상세 페이지: https://www.findatamall.or.kr/market/dataProdDetail?gdsSn=10315&menuNo=28
#
# [6289] 상세 페이지: https://www.findatamall.or.kr/market/dataProdDetail?gdsSn=10277&menuNo=28
#
# [6290] 상세 페이지: https://www.findatamall.or.kr/market/dataProdDetail?gdsSn=10238&menuNo=28
# ✅ 누적 6290개 저장 완료
#
# [6291] 상세 페이지: https://www.findatamall.or.kr/market/dataProdDetail?gdsSn=10234&menuNo=28
#
# [6292] 상세 페이지: https://www.findatamall.or.kr/market/dataProdDetail?gdsSn=10233&menuNo=28
#
# [6293] 상세 페이지: https://www.findatamall.or.kr/market/dataProdDetail?gdsSn=10180&menuNo=28
#
# [6294] 상세 페이지: https://www.findatamall.or.kr/market/dataProdDetail?gdsSn=10179&menuNo=28
#
# [6295] 상세 페이지: https://www.findatamall.or.kr/market/dataProdDetail?gdsSn=10164&menuNo=28
#
# [6296] 상세 페이지: https://www.findatamall.or.kr/market/dataProdDetail?gdsSn=10147&menuNo=28
#
# [6297] 상세 페이지: https://www.findatamall.or.kr/market/dataProdDetail?gdsSn=10066&menuNo=28
#
# [6298] 상세 페이지: https://www.findatamall.or.kr/market/dataProdDetail?gdsSn=9987&menuNo=28
#
# [6299] 상세 페이지: https://www.findatamall.or.kr/market/dataProdDetail?gdsSn=9985&menuNo=28
#
# [6300] 상세 페이지: https://www.findatamall.or.kr/market/dataProdDetail?gdsSn=9980&menuNo=28
# ✅ 누적 6300개 저장 완료
#
# [6301] 상세 페이지: https://www.findatamall.or.kr/market/dataProdDetail?gdsSn=9953&menuNo=28
#
# [6302] 상세 페이지: https://www.findatamall.or.kr/market/dataProdDetail?gdsSn=9942&menuNo=28
#
# [6303] 상세 페이지: https://www.findatamall.or.kr/market/dataProdDetail?gdsSn=9828&menuNo=28
#
# [6304] 상세 페이지: https://www.findatamall.or.kr/market/dataProdDetail?gdsSn=9754&menuNo=28
#
# [6305] 상세 페이지: https://www.findatamall.or.kr/market/dataProdDetail?gdsSn=9752&menuNo=28
#
# [6306] 상세 페이지: https://www.findatamall.or.kr/market/dataProdDetail?gdsSn=9685&menuNo=28
#
# [6307] 상세 페이지: https://www.findatamall.or.kr/market/dataProdDetail?gdsSn=9387&menuNo=28
#
# [6308] 상세 페이지: https://www.findatamall.or.kr/market/dataProdDetail?gdsSn=9152&menuNo=28
#
# [6309] 상세 페이지: https://www.findatamall.or.kr/market/dataProdDetail?gdsSn=9151&menuNo=28
#
# [6310] 상세 페이지: https://www.findatamall.or.kr/market/dataProdDetail?gdsSn=9125&menuNo=28
# ✅ 누적 6310개 저장 완료
#
# [6311] 상세 페이지: https://www.findatamall.or.kr/market/dataProdDetail?gdsSn=9081&menuNo=28
#
# [6312] 상세 페이지: https://www.findatamall.or.kr/market/dataProdDetail?gdsSn=8480&menuNo=28
#
# [6313] 상세 페이지: https://www.findatamall.or.kr/market/dataProdDetail?gdsSn=8474&menuNo=28
#
# [6314] 상세 페이지: https://www.findatamall.or.kr/market/dataProdDetail?gdsSn=8443&menuNo=28
#
# [6315] 상세 페이지: https://www.findatamall.or.kr/market/dataProdDetail?gdsSn=8300&menuNo=28
#
# [6316] 상세 페이지: https://www.findatamall.or.kr/market/dataProdDetail?gdsSn=8262&menuNo=28
#
# [6317] 상세 페이지: https://www.findatamall.or.kr/market/dataProdDetail?gdsSn=8261&menuNo=28
#
# [6318] 상세 페이지: https://www.findatamall.or.kr/market/dataProdDetail?gdsSn=8233&menuNo=28
#
# [6319] 상세 페이지: https://www.findatamall.or.kr/market/dataProdDetail?gdsSn=8162&menuNo=28
#
# [6320] 상세 페이지: https://www.findatamall.or.kr/market/dataProdDetail?gdsSn=8148&menuNo=28
# ✅ 누적 6320개 저장 완료
#
# [6321] 상세 페이지: https://www.findatamall.or.kr/market/dataProdDetail?gdsSn=8051&menuNo=28
#
# [6322] 상세 페이지: https://www.findatamall.or.kr/market/dataProdDetail?gdsSn=7976&menuNo=28
#
# [6323] 상세 페이지: https://www.findatamall.or.kr/market/dataProdDetail?gdsSn=7911&menuNo=28
#
# [6324] 상세 페이지: https://www.findatamall.or.kr/market/dataProdDetail?gdsSn=7902&menuNo=28
#
# [6325] 상세 페이지: https://www.findatamall.or.kr/market/dataProdDetail?gdsSn=7895&menuNo=28
#
# [6326] 상세 페이지: https://www.findatamall.or.kr/market/dataProdDetail?gdsSn=7883&menuNo=28
#
# [6327] 상세 페이지: https://www.findatamall.or.kr/market/dataProdDetail?gdsSn=7812&menuNo=28
#
# [6328] 상세 페이지: https://www.findatamall.or.kr/market/dataProdDetail?gdsSn=7700&menuNo=28
#
# [6329] 상세 페이지: https://www.findatamall.or.kr/market/dataProdDetail?gdsSn=7673&menuNo=28
#
# [6330] 상세 페이지: https://www.findatamall.or.kr/market/dataProdDetail?gdsSn=7639&menuNo=28
# ✅ 누적 6330개 저장 완료
#
# [6331] 상세 페이지: https://www.findatamall.or.kr/market/dataProdDetail?gdsSn=7427&menuNo=28
#
# [6332] 상세 페이지: https://www.findatamall.or.kr/market/dataProdDetail?gdsSn=7339&menuNo=28
#
# [6333] 상세 페이지: https://www.findatamall.or.kr/market/dataProdDetail?gdsSn=6644&menuNo=28
#
# [6334] 상세 페이지: https://www.findatamall.or.kr/market/dataProdDetail?gdsSn=6481&menuNo=28
#
# [6335] 상세 페이지: https://www.findatamall.or.kr/market/dataProdDetail?gdsSn=6480&menuNo=28
#
# [6336] 상세 페이지: https://www.findatamall.or.kr/market/dataProdDetail?gdsSn=5862&menuNo=28
#
# [6337] 상세 페이지: https://www.findatamall.or.kr/market/dataProdDetail?gdsSn=5714&menuNo=28
#
# [6338] 상세 페이지: https://www.findatamall.or.kr/market/dataProdDetail?gdsSn=5711&menuNo=28
#
# [6339] 상세 페이지: https://www.findatamall.or.kr/market/dataProdDetail?gdsSn=5699&menuNo=28
#
# [6340] 상세 페이지: https://www.findatamall.or.kr/market/dataProdDetail?gdsSn=5561&menuNo=28
# ✅ 누적 6340개 저장 완료
#
# [6341] 상세 페이지: https://www.findatamall.or.kr/market/dataProdDetail?gdsSn=5511&menuNo=28
#
# [6342] 상세 페이지: https://www.findatamall.or.kr/market/dataProdDetail?gdsSn=5255&menuNo=28
#
# [6343] 상세 페이지: https://www.findatamall.or.kr/market/dataProdDetail?gdsSn=5018&menuNo=28
#
# [6344] 상세 페이지: https://www.findatamall.or.kr/market/dataProdDetail?gdsSn=4323&menuNo=28
#
# [6345] 상세 페이지: https://www.findatamall.or.kr/market/dataProdDetail?gdsSn=16684&menuNo=28
#
# [6346] 상세 페이지: https://www.findatamall.or.kr/market/dataProdDetail?gdsSn=16648&menuNo=28
#
# [6347] 상세 페이지: https://www.findatamall.or.kr/market/dataProdDetail?gdsSn=13859&menuNo=28
#
# [6348] 상세 페이지: https://www.findatamall.or.kr/market/dataProdDetail?gdsSn=13555&menuNo=28
#
# [6349] 상세 페이지: https://www.findatamall.or.kr/market/dataProdDetail?gdsSn=12527&menuNo=28
#
# [6350] 상세 페이지: https://www.findatamall.or.kr/market/dataProdDetail?gdsSn=12409&menuNo=28
# ✅ 누적 6350개 저장 완료
#
# [6351] 상세 페이지: https://www.findatamall.or.kr/market/dataProdDetail?gdsSn=12025&menuNo=28
#
# [6352] 상세 페이지: https://www.findatamall.or.kr/market/dataProdDetail?gdsSn=12023&menuNo=28
#
# [6353] 상세 페이지: https://www.findatamall.or.kr/market/dataProdDetail?gdsSn=12010&menuNo=28
#
# [6354] 상세 페이지: https://www.findatamall.or.kr/market/dataProdDetail?gdsSn=12005&menuNo=28
#
# [6355] 상세 페이지: https://www.findatamall.or.kr/market/dataProdDetail?gdsSn=11993&menuNo=28
#
# [6356] 상세 페이지: https://www.findatamall.or.kr/market/dataProdDetail?gdsSn=11797&menuNo=28
#
# [6357] 상세 페이지: https://www.findatamall.or.kr/market/dataProdDetail?gdsSn=11780&menuNo=28
#
# [6358] 상세 페이지: https://www.findatamall.or.kr/market/dataProdDetail?gdsSn=11568&menuNo=28
#
# [6359] 상세 페이지: https://www.findatamall.or.kr/market/dataProdDetail?gdsSn=11477&menuNo=28
#
# [6360] 상세 페이지: https://www.findatamall.or.kr/market/dataProdDetail?gdsSn=11358&menuNo=28
# ✅ 누적 6360개 저장 완료
#
# [6361] 상세 페이지: https://www.findatamall.or.kr/market/dataProdDetail?gdsSn=11265&menuNo=28
#
# [6362] 상세 페이지: https://www.findatamall.or.kr/market/dataProdDetail?gdsSn=10820&menuNo=28
#
# [6363] 상세 페이지: https://www.findatamall.or.kr/market/dataProdDetail?gdsSn=10364&menuNo=28
#
# [6364] 상세 페이지: https://www.findatamall.or.kr/market/dataProdDetail?gdsSn=10342&menuNo=28
#
# [6365] 상세 페이지: https://www.findatamall.or.kr/market/dataProdDetail?gdsSn=10326&menuNo=28
#
# [6366] 상세 페이지: https://www.findatamall.or.kr/market/dataProdDetail?gdsSn=10320&menuNo=28
#
# [6367] 상세 페이지: https://www.findatamall.or.kr/market/dataProdDetail?gdsSn=10307&menuNo=28
#
# [6368] 상세 페이지: https://www.findatamall.or.kr/market/dataProdDetail?gdsSn=10306&menuNo=28
#
# [6369] 상세 페이지: https://www.findatamall.or.kr/market/dataProdDetail?gdsSn=10297&menuNo=28
#
# [6370] 상세 페이지: https://www.findatamall.or.kr/market/dataProdDetail?gdsSn=10269&menuNo=28
# ✅ 누적 6370개 저장 완료
#
# [6371] 상세 페이지: https://www.findatamall.or.kr/market/dataProdDetail?gdsSn=10190&menuNo=28
#
# [6372] 상세 페이지: https://www.findatamall.or.kr/market/dataProdDetail?gdsSn=10169&menuNo=28
#
# [6373] 상세 페이지: https://www.findatamall.or.kr/market/dataProdDetail?gdsSn=10099&menuNo=28
#
# [6374] 상세 페이지: https://www.findatamall.or.kr/market/dataProdDetail?gdsSn=10086&menuNo=28
#
# [6375] 상세 페이지: https://www.findatamall.or.kr/market/dataProdDetail?gdsSn=10073&menuNo=28
#
# [6376] 상세 페이지: https://www.findatamall.or.kr/market/dataProdDetail?gdsSn=10059&menuNo=28
#
# [6377] 상세 페이지: https://www.findatamall.or.kr/market/dataProdDetail?gdsSn=10051&menuNo=28
#
# [6378] 상세 페이지: https://www.findatamall.or.kr/market/dataProdDetail?gdsSn=10037&menuNo=28
#
# [6379] 상세 페이지: https://www.findatamall.or.kr/market/dataProdDetail?gdsSn=10028&menuNo=28
#
# [6380] 상세 페이지: https://www.findatamall.or.kr/market/dataProdDetail?gdsSn=9983&menuNo=28
# ✅ 누적 6380개 저장 완료
#
# [6381] 상세 페이지: https://www.findatamall.or.kr/market/dataProdDetail?gdsSn=9898&menuNo=28
#
# [6382] 상세 페이지: https://www.findatamall.or.kr/market/dataProdDetail?gdsSn=9824&menuNo=28
#
# [6383] 상세 페이지: https://www.findatamall.or.kr/market/dataProdDetail?gdsSn=9717&menuNo=28
#
# [6384] 상세 페이지: https://www.findatamall.or.kr/market/dataProdDetail?gdsSn=9598&menuNo=28
#
# [6385] 상세 페이지: https://www.findatamall.or.kr/market/dataProdDetail?gdsSn=9567&menuNo=28
#
# [6386] 상세 페이지: https://www.findatamall.or.kr/market/dataProdDetail?gdsSn=9149&menuNo=28
#
# [6387] 상세 페이지: https://www.findatamall.or.kr/market/dataProdDetail?gdsSn=9124&menuNo=28
#
# [6388] 상세 페이지: https://www.findatamall.or.kr/market/dataProdDetail?gdsSn=9118&menuNo=28
#
# [6389] 상세 페이지: https://www.findatamall.or.kr/market/dataProdDetail?gdsSn=9074&menuNo=28
#
# [6390] 상세 페이지: https://www.findatamall.or.kr/market/dataProdDetail?gdsSn=8465&menuNo=28
# ✅ 누적 6390개 저장 완료
#
# [6391] 상세 페이지: https://www.findatamall.or.kr/market/dataProdDetail?gdsSn=8454&menuNo=28
#
# [6392] 상세 페이지: https://www.findatamall.or.kr/market/dataProdDetail?gdsSn=8258&menuNo=28
#
# [6393] 상세 페이지: https://www.findatamall.or.kr/market/dataProdDetail?gdsSn=8163&menuNo=28
#
# [6394] 상세 페이지: https://www.findatamall.or.kr/market/dataProdDetail?gdsSn=8021&menuNo=28
#
# [6395] 상세 페이지: https://www.findatamall.or.kr/market/dataProdDetail?gdsSn=7802&menuNo=28
#
# [6396] 상세 페이지: https://www.findatamall.or.kr/market/dataProdDetail?gdsSn=7623&menuNo=28
#
# [6397] 상세 페이지: https://www.findatamall.or.kr/market/dataProdDetail?gdsSn=7610&menuNo=28
#
# [6398] 상세 페이지: https://www.findatamall.or.kr/market/dataProdDetail?gdsSn=7448&menuNo=28
#
# [6399] 상세 페이지: https://www.findatamall.or.kr/market/dataProdDetail?gdsSn=6653&menuNo=28
#
# [6400] 상세 페이지: https://www.findatamall.or.kr/market/dataProdDetail?gdsSn=6605&menuNo=28
# ✅ 누적 6400개 저장 완료
#
# [6401] 상세 페이지: https://www.findatamall.or.kr/market/dataProdDetail?gdsSn=6467&menuNo=28
#
# [6402] 상세 페이지: https://www.findatamall.or.kr/market/dataProdDetail?gdsSn=6433&menuNo=28
#
# [6403] 상세 페이지: https://www.findatamall.or.kr/market/dataProdDetail?gdsSn=6150&menuNo=28
#
# [6404] 상세 페이지: https://www.findatamall.or.kr/market/dataProdDetail?gdsSn=6035&menuNo=28
#
# [6405] 상세 페이지: https://www.findatamall.or.kr/market/dataProdDetail?gdsSn=5854&menuNo=28
#
# [6406] 상세 페이지: https://www.findatamall.or.kr/market/dataProdDetail?gdsSn=5765&menuNo=28
#
# [6407] 상세 페이지: https://www.findatamall.or.kr/market/dataProdDetail?gdsSn=5754&menuNo=28
#
# [6408] 상세 페이지: https://www.findatamall.or.kr/market/dataProdDetail?gdsSn=5750&menuNo=28
#
# [6409] 상세 페이지: https://www.findatamall.or.kr/market/dataProdDetail?gdsSn=5600&menuNo=28
#
# [6410] 상세 페이지: https://www.findatamall.or.kr/market/dataProdDetail?gdsSn=5564&menuNo=28
# ✅ 누적 6410개 저장 완료
#
# [6411] 상세 페이지: https://www.findatamall.or.kr/market/dataProdDetail?gdsSn=5538&menuNo=28
#
# [6412] 상세 페이지: https://www.findatamall.or.kr/market/dataProdDetail?gdsSn=5521&menuNo=28
#
# [6413] 상세 페이지: https://www.findatamall.or.kr/market/dataProdDetail?gdsSn=5068&menuNo=28
#
# [6414] 상세 페이지: https://www.findatamall.or.kr/market/dataProdDetail?gdsSn=5067&menuNo=28
#
# [6415] 상세 페이지: https://www.findatamall.or.kr/market/dataProdDetail?gdsSn=5023&menuNo=28
#
# [6416] 상세 페이지: https://www.findatamall.or.kr/market/dataProdDetail?gdsSn=5020&menuNo=28
#
# [6417] 상세 페이지: https://www.findatamall.or.kr/market/dataProdDetail?gdsSn=5011&menuNo=28
#
# [6418] 상세 페이지: https://www.findatamall.or.kr/market/dataProdDetail?gdsSn=16762&menuNo=28
#
# [6419] 상세 페이지: https://www.findatamall.or.kr/market/dataProdDetail?gdsSn=16566&menuNo=28
#
# [6420] 상세 페이지: https://www.findatamall.or.kr/market/dataProdDetail?gdsSn=16564&menuNo=28
# ✅ 누적 6420개 저장 완료
#
# [6421] 상세 페이지: https://www.findatamall.or.kr/market/dataProdDetail?gdsSn=16458&menuNo=28
#
# [6422] 상세 페이지: https://www.findatamall.or.kr/market/dataProdDetail?gdsSn=14048&menuNo=28
#
# [6423] 상세 페이지: https://www.findatamall.or.kr/market/dataProdDetail?gdsSn=14044&menuNo=28
#
# [6424] 상세 페이지: https://www.findatamall.or.kr/market/dataProdDetail?gdsSn=14043&menuNo=28
#
# [6425] 상세 페이지: https://www.findatamall.or.kr/market/dataProdDetail?gdsSn=13623&menuNo=28
#
# [6426] 상세 페이지: https://www.findatamall.or.kr/market/dataProdDetail?gdsSn=13582&menuNo=28
#
# [6427] 상세 페이지: https://www.findatamall.or.kr/market/dataProdDetail?gdsSn=13504&menuNo=28
#
# [6428] 상세 페이지: https://www.findatamall.or.kr/market/dataProdDetail?gdsSn=13463&menuNo=28
#
# [6429] 상세 페이지: https://www.findatamall.or.kr/market/dataProdDetail?gdsSn=13456&menuNo=28
#
# [6430] 상세 페이지: https://www.findatamall.or.kr/market/dataProdDetail?gdsSn=12965&menuNo=28
# ✅ 누적 6430개 저장 완료
#
# [6431] 상세 페이지: https://www.findatamall.or.kr/market/dataProdDetail?gdsSn=12724&menuNo=28
#
# [6432] 상세 페이지: https://www.findatamall.or.kr/market/dataProdDetail?gdsSn=12513&menuNo=28
#
# [6433] 상세 페이지: https://www.findatamall.or.kr/market/dataProdDetail?gdsSn=12416&menuNo=28
#
# [6434] 상세 페이지: https://www.findatamall.or.kr/market/dataProdDetail?gdsSn=12372&menuNo=28
#
# [6435] 상세 페이지: https://www.findatamall.or.kr/market/dataProdDetail?gdsSn=12117&menuNo=28
#
# [6436] 상세 페이지: https://www.findatamall.or.kr/market/dataProdDetail?gdsSn=12104&menuNo=28
#
# [6437] 상세 페이지: https://www.findatamall.or.kr/market/dataProdDetail?gdsSn=12016&menuNo=28
#
# [6438] 상세 페이지: https://www.findatamall.or.kr/market/dataProdDetail?gdsSn=12009&menuNo=28
#
# [6439] 상세 페이지: https://www.findatamall.or.kr/market/dataProdDetail?gdsSn=11893&menuNo=28
#
# [6440] 상세 페이지: https://www.findatamall.or.kr/market/dataProdDetail?gdsSn=11885&menuNo=28
# ✅ 누적 6440개 저장 완료
#
# [6441] 상세 페이지: https://www.findatamall.or.kr/market/dataProdDetail?gdsSn=11842&menuNo=28
#
# [6442] 상세 페이지: https://www.findatamall.or.kr/market/dataProdDetail?gdsSn=11829&menuNo=28
#
# [6443] 상세 페이지: https://www.findatamall.or.kr/market/dataProdDetail?gdsSn=11828&menuNo=28
#
# [6444] 상세 페이지: https://www.findatamall.or.kr/market/dataProdDetail?gdsSn=11827&menuNo=28
#
# [6445] 상세 페이지: https://www.findatamall.or.kr/market/dataProdDetail?gdsSn=11791&menuNo=28
#
# [6446] 상세 페이지: https://www.findatamall.or.kr/market/dataProdDetail?gdsSn=11787&menuNo=28
#
# [6447] 상세 페이지: https://www.findatamall.or.kr/market/dataProdDetail?gdsSn=11742&menuNo=28
#
# [6448] 상세 페이지: https://www.findatamall.or.kr/market/dataProdDetail?gdsSn=11567&menuNo=28
#
# [6449] 상세 페이지: https://www.findatamall.or.kr/market/dataProdDetail?gdsSn=11562&menuNo=28
#
# [6450] 상세 페이지: https://www.findatamall.or.kr/market/dataProdDetail?gdsSn=11560&menuNo=28
# ✅ 누적 6450개 저장 완료
#
# [6451] 상세 페이지: https://www.findatamall.or.kr/market/dataProdDetail?gdsSn=11468&menuNo=28
#
# [6452] 상세 페이지: https://www.findatamall.or.kr/market/dataProdDetail?gdsSn=11375&menuNo=28
#
# [6453] 상세 페이지: https://www.findatamall.or.kr/market/dataProdDetail?gdsSn=11360&menuNo=28
#
# [6454] 상세 페이지: https://www.findatamall.or.kr/market/dataProdDetail?gdsSn=10872&menuNo=28
#
# [6455] 상세 페이지: https://www.findatamall.or.kr/market/dataProdDetail?gdsSn=10839&menuNo=28
#
# [6456] 상세 페이지: https://www.findatamall.or.kr/market/dataProdDetail?gdsSn=10775&menuNo=28
#
# [6457] 상세 페이지: https://www.findatamall.or.kr/market/dataProdDetail?gdsSn=10355&menuNo=28
#
# [6458] 상세 페이지: https://www.findatamall.or.kr/market/dataProdDetail?gdsSn=10335&menuNo=28
#
# [6459] 상세 페이지: https://www.findatamall.or.kr/market/dataProdDetail?gdsSn=10331&menuNo=28
#
# [6460] 상세 페이지: https://www.findatamall.or.kr/market/dataProdDetail?gdsSn=10313&menuNo=28
# ✅ 누적 6460개 저장 완료
#
# [6461] 상세 페이지: https://www.findatamall.or.kr/market/dataProdDetail?gdsSn=10301&menuNo=28
#
# [6462] 상세 페이지: https://www.findatamall.or.kr/market/dataProdDetail?gdsSn=10285&menuNo=28
#
# [6463] 상세 페이지: https://www.findatamall.or.kr/market/dataProdDetail?gdsSn=10266&menuNo=28
#
# [6464] 상세 페이지: https://www.findatamall.or.kr/market/dataProdDetail?gdsSn=10186&menuNo=28
#
# [6465] 상세 페이지: https://www.findatamall.or.kr/market/dataProdDetail?gdsSn=10171&menuNo=28
#
# [6466] 상세 페이지: https://www.findatamall.or.kr/market/dataProdDetail?gdsSn=10160&menuNo=28
#
# [6467] 상세 페이지: https://www.findatamall.or.kr/market/dataProdDetail?gdsSn=10104&menuNo=28
#
# [6468] 상세 페이지: https://www.findatamall.or.kr/market/dataProdDetail?gdsSn=10100&menuNo=28
#
# [6469] 상세 페이지: https://www.findatamall.or.kr/market/dataProdDetail?gdsSn=10091&menuNo=28
#
# [6470] 상세 페이지: https://www.findatamall.or.kr/market/dataProdDetail?gdsSn=10088&menuNo=28
# ✅ 누적 6470개 저장 완료
#
# [6471] 상세 페이지: https://www.findatamall.or.kr/market/dataProdDetail?gdsSn=10085&menuNo=28
#
# [6472] 상세 페이지: https://www.findatamall.or.kr/market/dataProdDetail?gdsSn=10071&menuNo=28
#
# [6473] 상세 페이지: https://www.findatamall.or.kr/market/dataProdDetail?gdsSn=10035&menuNo=28
#
# [6474] 상세 페이지: https://www.findatamall.or.kr/market/dataProdDetail?gdsSn=10022&menuNo=28
#
# [6475] 상세 페이지: https://www.findatamall.or.kr/market/dataProdDetail?gdsSn=9994&menuNo=28
#
# [6476] 상세 페이지: https://www.findatamall.or.kr/market/dataProdDetail?gdsSn=9973&menuNo=28
#
# [6477] 상세 페이지: https://www.findatamall.or.kr/market/dataProdDetail?gdsSn=9936&menuNo=28
#
# [6478] 상세 페이지: https://www.findatamall.or.kr/market/dataProdDetail?gdsSn=9926&menuNo=28
#
# [6479] 상세 페이지: https://www.findatamall.or.kr/market/dataProdDetail?gdsSn=9818&menuNo=28
#
# [6480] 상세 페이지: https://www.findatamall.or.kr/market/dataProdDetail?gdsSn=9801&menuNo=28
# ✅ 누적 6480개 저장 완료
#
# [6481] 상세 페이지: https://www.findatamall.or.kr/market/dataProdDetail?gdsSn=9715&menuNo=28
#
# [6482] 상세 페이지: https://www.findatamall.or.kr/market/dataProdDetail?gdsSn=9611&menuNo=28
#
# [6483] 상세 페이지: https://www.findatamall.or.kr/market/dataProdDetail?gdsSn=9607&menuNo=28
#
# [6484] 상세 페이지: https://www.findatamall.or.kr/market/dataProdDetail?gdsSn=9127&menuNo=28
#
# [6485] 상세 페이지: https://www.findatamall.or.kr/market/dataProdDetail?gdsSn=9103&menuNo=28
#
# [6486] 상세 페이지: https://www.findatamall.or.kr/market/dataProdDetail?gdsSn=9075&menuNo=28
#
# [6487] 상세 페이지: https://www.findatamall.or.kr/market/dataProdDetail?gdsSn=8804&menuNo=28
#
# [6488] 상세 페이지: https://www.findatamall.or.kr/market/dataProdDetail?gdsSn=8303&menuNo=28
#
# [6489] 상세 페이지: https://www.findatamall.or.kr/market/dataProdDetail?gdsSn=8231&menuNo=28
#
# [6490] 상세 페이지: https://www.findatamall.or.kr/market/dataProdDetail?gdsSn=8219&menuNo=28
# ✅ 누적 6490개 저장 완료
#
# [6491] 상세 페이지: https://www.findatamall.or.kr/market/dataProdDetail?gdsSn=8199&menuNo=28
#
# [6492] 상세 페이지: https://www.findatamall.or.kr/market/dataProdDetail?gdsSn=8102&menuNo=28
#
# [6493] 상세 페이지: https://www.findatamall.or.kr/market/dataProdDetail?gdsSn=8050&menuNo=28
#
# [6494] 상세 페이지: https://www.findatamall.or.kr/market/dataProdDetail?gdsSn=7968&menuNo=28
#
# [6495] 상세 페이지: https://www.findatamall.or.kr/market/dataProdDetail?gdsSn=7913&menuNo=28
#
# [6496] 상세 페이지: https://www.findatamall.or.kr/market/dataProdDetail?gdsSn=7759&menuNo=28
#
# [6497] 상세 페이지: https://www.findatamall.or.kr/market/dataProdDetail?gdsSn=7711&menuNo=28
#
# [6498] 상세 페이지: https://www.findatamall.or.kr/market/dataProdDetail?gdsSn=7705&menuNo=28
#
# [6499] 상세 페이지: https://www.findatamall.or.kr/market/dataProdDetail?gdsSn=7580&menuNo=28
#
# [6500] 상세 페이지: https://www.findatamall.or.kr/market/dataProdDetail?gdsSn=7568&menuNo=28
# ✅ 누적 6500개 저장 완료
#
# [6501] 상세 페이지: https://www.findatamall.or.kr/market/dataProdDetail?gdsSn=7470&menuNo=28
#
# [6502] 상세 페이지: https://www.findatamall.or.kr/market/dataProdDetail?gdsSn=7439&menuNo=28
#
# [6503] 상세 페이지: https://www.findatamall.or.kr/market/dataProdDetail?gdsSn=7362&menuNo=28
#
# [6504] 상세 페이지: https://www.findatamall.or.kr/market/dataProdDetail?gdsSn=6640&menuNo=28
#
# [6505] 상세 페이지: https://www.findatamall.or.kr/market/dataProdDetail?gdsSn=6460&menuNo=28
#
# [6506] 상세 페이지: https://www.findatamall.or.kr/market/dataProdDetail?gdsSn=6066&menuNo=28
#
# [6507] 상세 페이지: https://www.findatamall.or.kr/market/dataProdDetail?gdsSn=5904&menuNo=28
#
# [6508] 상세 페이지: https://www.findatamall.or.kr/market/dataProdDetail?gdsSn=5757&menuNo=28
#
# [6509] 상세 페이지: https://www.findatamall.or.kr/market/dataProdDetail?gdsSn=5704&menuNo=28
#
# [6510] 상세 페이지: https://www.findatamall.or.kr/market/dataProdDetail?gdsSn=5581&menuNo=28
# ✅ 누적 6510개 저장 완료
#
# [6511] 상세 페이지: https://www.findatamall.or.kr/market/dataProdDetail?gdsSn=5500&menuNo=28
#
# [6512] 상세 페이지: https://www.findatamall.or.kr/market/dataProdDetail?gdsSn=5322&menuNo=28
#
# [6513] 상세 페이지: https://www.findatamall.or.kr/market/dataProdDetail?gdsSn=5262&menuNo=28
#
# [6514] 상세 페이지: https://www.findatamall.or.kr/market/dataProdDetail?gdsSn=5075&menuNo=28
#
# [6515] 상세 페이지: https://www.findatamall.or.kr/market/dataProdDetail?gdsSn=5059&menuNo=28
#
# [6516] 상세 페이지: https://www.findatamall.or.kr/market/dataProdDetail?gdsSn=5031&menuNo=28
#
# [6517] 상세 페이지: https://www.findatamall.or.kr/market/dataProdDetail?gdsSn=5013&menuNo=28
#
# [6518] 상세 페이지: https://www.findatamall.or.kr/market/dataProdDetail?gdsSn=16934&menuNo=28
#
# [6519] 상세 페이지: https://www.findatamall.or.kr/market/dataProdDetail?gdsSn=14047&menuNo=28
#
# [6520] 상세 페이지: https://www.findatamall.or.kr/market/dataProdDetail?gdsSn=13614&menuNo=28
# ✅ 누적 6520개 저장 완료
#
# [6521] 상세 페이지: https://www.findatamall.or.kr/market/dataProdDetail?gdsSn=13502&menuNo=28
#
# [6522] 상세 페이지: https://www.findatamall.or.kr/market/dataProdDetail?gdsSn=13500&menuNo=28
#
# [6523] 상세 페이지: https://www.findatamall.or.kr/market/dataProdDetail?gdsSn=13034&menuNo=28
#
# [6524] 상세 페이지: https://www.findatamall.or.kr/market/dataProdDetail?gdsSn=13004&menuNo=28
#
# [6525] 상세 페이지: https://www.findatamall.or.kr/market/dataProdDetail?gdsSn=12753&menuNo=28
#
# [6526] 상세 페이지: https://www.findatamall.or.kr/market/dataProdDetail?gdsSn=12514&menuNo=28
#
# [6527] 상세 페이지: https://www.findatamall.or.kr/market/dataProdDetail?gdsSn=12391&menuNo=28
#
# [6528] 상세 페이지: https://www.findatamall.or.kr/market/dataProdDetail?gdsSn=12022&menuNo=28
#
# [6529] 상세 페이지: https://www.findatamall.or.kr/market/dataProdDetail?gdsSn=12017&menuNo=28
#
# [6530] 상세 페이지: https://www.findatamall.or.kr/market/dataProdDetail?gdsSn=12004&menuNo=28
# ✅ 누적 6530개 저장 완료
#
# [6531] 상세 페이지: https://www.findatamall.or.kr/market/dataProdDetail?gdsSn=11894&menuNo=28
#
# [6532] 상세 페이지: https://www.findatamall.or.kr/market/dataProdDetail?gdsSn=11883&menuNo=28
#
# [6533] 상세 페이지: https://www.findatamall.or.kr/market/dataProdDetail?gdsSn=11832&menuNo=28
#
# [6534] 상세 페이지: https://www.findatamall.or.kr/market/dataProdDetail?gdsSn=11819&menuNo=28
#
# [6535] 상세 페이지: https://www.findatamall.or.kr/market/dataProdDetail?gdsSn=11818&menuNo=28
#
# [6536] 상세 페이지: https://www.findatamall.or.kr/market/dataProdDetail?gdsSn=11815&menuNo=28
#
# [6537] 상세 페이지: https://www.findatamall.or.kr/market/dataProdDetail?gdsSn=11813&menuNo=28
#
# [6538] 상세 페이지: https://www.findatamall.or.kr/market/dataProdDetail?gdsSn=11762&menuNo=28
#
# [6539] 상세 페이지: https://www.findatamall.or.kr/market/dataProdDetail?gdsSn=11572&menuNo=28
#
# [6540] 상세 페이지: https://www.findatamall.or.kr/market/dataProdDetail?gdsSn=11563&menuNo=28
# ✅ 누적 6540개 저장 완료
#
# [6541] 상세 페이지: https://www.findatamall.or.kr/market/dataProdDetail?gdsSn=11561&menuNo=28
#
# [6542] 상세 페이지: https://www.findatamall.or.kr/market/dataProdDetail?gdsSn=11262&menuNo=28
#
# [6543] 상세 페이지: https://www.findatamall.or.kr/market/dataProdDetail?gdsSn=10815&menuNo=28
#
# [6544] 상세 페이지: https://www.findatamall.or.kr/market/dataProdDetail?gdsSn=10337&menuNo=28
#
# [6545] 상세 페이지: https://www.findatamall.or.kr/market/dataProdDetail?gdsSn=10248&menuNo=28
#
# [6546] 상세 페이지: https://www.findatamall.or.kr/market/dataProdDetail?gdsSn=10243&menuNo=28
#
# [6547] 상세 페이지: https://www.findatamall.or.kr/market/dataProdDetail?gdsSn=10239&menuNo=28
#
# [6548] 상세 페이지: https://www.findatamall.or.kr/market/dataProdDetail?gdsSn=10198&menuNo=28
#
# [6549] 상세 페이지: https://www.findatamall.or.kr/market/dataProdDetail?gdsSn=10185&menuNo=28
#
# [6550] 상세 페이지: https://www.findatamall.or.kr/market/dataProdDetail?gdsSn=10172&menuNo=28
# ✅ 누적 6550개 저장 완료
#
# [6551] 상세 페이지: https://www.findatamall.or.kr/market/dataProdDetail?gdsSn=10151&menuNo=28
#
# [6552] 상세 페이지: https://www.findatamall.or.kr/market/dataProdDetail?gdsSn=10095&menuNo=28
#
# [6553] 상세 페이지: https://www.findatamall.or.kr/market/dataProdDetail?gdsSn=10083&menuNo=28
#
# [6554] 상세 페이지: https://www.findatamall.or.kr/market/dataProdDetail?gdsSn=10079&menuNo=28
#
# [6555] 상세 페이지: https://www.findatamall.or.kr/market/dataProdDetail?gdsSn=10053&menuNo=28
#
# [6556] 상세 페이지: https://www.findatamall.or.kr/market/dataProdDetail?gdsSn=10029&menuNo=28
#
# [6557] 상세 페이지: https://www.findatamall.or.kr/market/dataProdDetail?gdsSn=10026&menuNo=28
#
# [6558] 상세 페이지: https://www.findatamall.or.kr/market/dataProdDetail?gdsSn=10024&menuNo=28
#
# [6559] 상세 페이지: https://www.findatamall.or.kr/market/dataProdDetail?gdsSn=10018&menuNo=28
#
# [6560] 상세 페이지: https://www.findatamall.or.kr/market/dataProdDetail?gdsSn=10012&menuNo=28
# ✅ 누적 6560개 저장 완료
#
# [6561] 상세 페이지: https://www.findatamall.or.kr/market/dataProdDetail?gdsSn=10010&menuNo=28
#
# [6562] 상세 페이지: https://www.findatamall.or.kr/market/dataProdDetail?gdsSn=9995&menuNo=28
#
# [6563] 상세 페이지: https://www.findatamall.or.kr/market/dataProdDetail?gdsSn=9991&menuNo=28
#
# [6564] 상세 페이지: https://www.findatamall.or.kr/market/dataProdDetail?gdsSn=9986&menuNo=28
#
# [6565] 상세 페이지: https://www.findatamall.or.kr/market/dataProdDetail?gdsSn=9969&menuNo=28
#
# [6566] 상세 페이지: https://www.findatamall.or.kr/market/dataProdDetail?gdsSn=9956&menuNo=28
#
# [6567] 상세 페이지: https://www.findatamall.or.kr/market/dataProdDetail?gdsSn=9955&menuNo=28
#
# [6568] 상세 페이지: https://www.findatamall.or.kr/market/dataProdDetail?gdsSn=9940&menuNo=28
#
# [6569] 상세 페이지: https://www.findatamall.or.kr/market/dataProdDetail?gdsSn=9939&menuNo=28
#
# [6570] 상세 페이지: https://www.findatamall.or.kr/market/dataProdDetail?gdsSn=9792&menuNo=28
# ✅ 누적 6570개 저장 완료
#
# [6571] 상세 페이지: https://www.findatamall.or.kr/market/dataProdDetail?gdsSn=9784&menuNo=28
#
# [6572] 상세 페이지: https://www.findatamall.or.kr/market/dataProdDetail?gdsSn=9777&menuNo=28
#
# [6573] 상세 페이지: https://www.findatamall.or.kr/market/dataProdDetail?gdsSn=9697&menuNo=28
#
# [6574] 상세 페이지: https://www.findatamall.or.kr/market/dataProdDetail?gdsSn=9688&menuNo=28
#
# [6575] 상세 페이지: https://www.findatamall.or.kr/market/dataProdDetail?gdsSn=9653&menuNo=28
#
# [6576] 상세 페이지: https://www.findatamall.or.kr/market/dataProdDetail?gdsSn=9596&menuNo=28
#
# [6577] 상세 페이지: https://www.findatamall.or.kr/market/dataProdDetail?gdsSn=9575&menuNo=28
#
# [6578] 상세 페이지: https://www.findatamall.or.kr/market/dataProdDetail?gdsSn=8283&menuNo=28
#
# [6579] 상세 페이지: https://www.findatamall.or.kr/market/dataProdDetail?gdsSn=8149&menuNo=28
#
# [6580] 상세 페이지: https://www.findatamall.or.kr/market/dataProdDetail?gdsSn=7917&menuNo=28
# ✅ 누적 6580개 저장 완료
#
# [6581] 상세 페이지: https://www.findatamall.or.kr/market/dataProdDetail?gdsSn=7888&menuNo=28
#
# [6582] 상세 페이지: https://www.findatamall.or.kr/market/dataProdDetail?gdsSn=7884&menuNo=28
#
# [6583] 상세 페이지: https://www.findatamall.or.kr/market/dataProdDetail?gdsSn=7788&menuNo=28
#
# [6584] 상세 페이지: https://www.findatamall.or.kr/market/dataProdDetail?gdsSn=7729&menuNo=28
#
# [6585] 상세 페이지: https://www.findatamall.or.kr/market/dataProdDetail?gdsSn=7727&menuNo=28
#
# [6586] 상세 페이지: https://www.findatamall.or.kr/market/dataProdDetail?gdsSn=7670&menuNo=28
#
# [6587] 상세 페이지: https://www.findatamall.or.kr/market/dataProdDetail?gdsSn=7464&menuNo=28
#
# [6588] 상세 페이지: https://www.findatamall.or.kr/market/dataProdDetail?gdsSn=7372&menuNo=28
#
# [6589] 상세 페이지: https://www.findatamall.or.kr/market/dataProdDetail?gdsSn=7360&menuNo=28
#
# [6590] 상세 페이지: https://www.findatamall.or.kr/market/dataProdDetail?gdsSn=7354&menuNo=28
# ✅ 누적 6590개 저장 완료
#
# [6591] 상세 페이지: https://www.findatamall.or.kr/market/dataProdDetail?gdsSn=7351&menuNo=28
#
# [6592] 상세 페이지: https://www.findatamall.or.kr/market/dataProdDetail?gdsSn=7262&menuNo=28
#
# [6593] 상세 페이지: https://www.findatamall.or.kr/market/dataProdDetail?gdsSn=6458&menuNo=28
#
# [6594] 상세 페이지: https://www.findatamall.or.kr/market/dataProdDetail?gdsSn=5859&menuNo=28
#
# ...
#
# [8267] 상세 페이지: https://www.findatamall.or.kr/market/dataProdDetail?gdsSn=9889&menuNo=28
#
# [8268] 상세 페이지: https://www.findatamall.or.kr/market/dataProdDetail?gdsSn=9829&menuNo=28
#
# [8269] 상세 페이지: https://www.findatamall.or.kr/market/dataProdDetail?gdsSn=9744&menuNo=28
#
# [8270] 상세 페이지: https://www.findatamall.or.kr/market/dataProdDetail?gdsSn=9583&menuNo=28
# ✅ 누적 8270개 저장 완료
#
# [8271] 상세 페이지: https://www.findatamall.or.kr/market/dataProdDetail?gdsSn=9564&menuNo=28
#
# [8272] 상세 페이지: https://www.findatamall.or.kr/market/dataProdDetail?gdsSn=8204&menuNo=28
#
# [8273] 상세 페이지: https://www.findatamall.or.kr/market/dataProdDetail?gdsSn=8045&menuNo=28
#
# [8274] 상세 페이지: https://www.findatamall.or.kr/market/dataProdDetail?gdsSn=8023&menuNo=28
#
# [8275] 상세 페이지: https://www.findatamall.or.kr/market/dataProdDetail?gdsSn=8002&menuNo=28
#
# [8276] 상세 페이지: https://www.findatamall.or.kr/market/dataProdDetail?gdsSn=8000&menuNo=28
#
# [8277] 상세 페이지: https://www.findatamall.or.kr/market/dataProdDetail?gdsSn=7590&menuNo=28
#
# [8278] 상세 페이지: https://www.findatamall.or.kr/market/dataProdDetail?gdsSn=7576&menuNo=28
#
# [8279] 상세 페이지: https://www.findatamall.or.kr/market/dataProdDetail?gdsSn=7529&menuNo=28
#
# [8280] 상세 페이지: https://www.findatamall.or.kr/market/dataProdDetail?gdsSn=7528&menuNo=28
# ✅ 누적 8280개 저장 완료
#
# [8281] 상세 페이지: https://www.findatamall.or.kr/market/dataProdDetail?gdsSn=7389&menuNo=28
#
# [8282] 상세 페이지: https://www.findatamall.or.kr/market/dataProdDetail?gdsSn=17176&menuNo=28
#
# [8283] 상세 페이지: https://www.findatamall.or.kr/market/dataProdDetail?gdsSn=17128&menuNo=28
#
# [8284] 상세 페이지: https://www.findatamall.or.kr/market/dataProdDetail?gdsSn=17046&menuNo=28
#
# [8285] 상세 페이지: https://www.findatamall.or.kr/market/dataProdDetail?gdsSn=17034&menuNo=28
#
# [8286] 상세 페이지: https://www.findatamall.or.kr/market/dataProdDetail?gdsSn=16989&menuNo=28
#
# [8287] 상세 페이지: https://www.findatamall.or.kr/market/dataProdDetail?gdsSn=16953&menuNo=28
#
# [8288] 상세 페이지: https://www.findatamall.or.kr/market/dataProdDetail?gdsSn=16952&menuNo=28
#
# [8289] 상세 페이지: https://www.findatamall.or.kr/market/dataProdDetail?gdsSn=16951&menuNo=28
#
# [8290] 상세 페이지: https://www.findatamall.or.kr/market/dataProdDetail?gdsSn=16921&menuNo=28
# ✅ 누적 8290개 저장 완료
#
# [8291] 상세 페이지: https://www.findatamall.or.kr/market/dataProdDetail?gdsSn=16847&menuNo=28
#
# [8292] 상세 페이지: https://www.findatamall.or.kr/market/dataProdDetail?gdsSn=16836&menuNo=28
#
# [8293] 상세 페이지: https://www.findatamall.or.kr/market/dataProdDetail?gdsSn=16834&menuNo=28
#
# [8294] 상세 페이지: https://www.findatamall.or.kr/market/dataProdDetail?gdsSn=16833&menuNo=28
#
# [8295] 상세 페이지: https://www.findatamall.or.kr/market/dataProdDetail?gdsSn=16826&menuNo=28
#
# [8296] 상세 페이지: https://www.findatamall.or.kr/market/dataProdDetail?gdsSn=16806&menuNo=28
#
# [8297] 상세 페이지: https://www.findatamall.or.kr/market/dataProdDetail?gdsSn=16805&menuNo=28
#
# [8298] 상세 페이지: https://www.findatamall.or.kr/market/dataProdDetail?gdsSn=16764&menuNo=28
#
# [8299] 상세 페이지: https://www.findatamall.or.kr/market/dataProdDetail?gdsSn=16750&menuNo=28
#
# [8300] 상세 페이지: https://www.findatamall.or.kr/market/dataProdDetail?gdsSn=16729&menuNo=28
# ✅ 누적 8300개 저장 완료
#
# [8301] 상세 페이지: https://www.findatamall.or.kr/market/dataProdDetail?gdsSn=16715&menuNo=28
#
# [8302] 상세 페이지: https://www.findatamall.or.kr/market/dataProdDetail?gdsSn=16624&menuNo=28
#
# [8303] 상세 페이지: https://www.findatamall.or.kr/market/dataProdDetail?gdsSn=13646&menuNo=28
#
# [8304] 상세 페이지: https://www.findatamall.or.kr/market/dataProdDetail?gdsSn=13603&menuNo=28
#
# [8305] 상세 페이지: https://www.findatamall.or.kr/market/dataProdDetail?gdsSn=13599&menuNo=28
#
# [8306] 상세 페이지: https://www.findatamall.or.kr/market/dataProdDetail?gdsSn=10251&menuNo=28
#
# [8307] 상세 페이지: https://www.findatamall.or.kr/market/dataProdDetail?gdsSn=10217&menuNo=28
#
# [8308] 상세 페이지: https://www.findatamall.or.kr/market/dataProdDetail?gdsSn=9904&menuNo=28
#
# [8309] 상세 페이지: https://www.findatamall.or.kr/market/dataProdDetail?gdsSn=9900&menuNo=28
#
# [8310] 상세 페이지: https://www.findatamall.or.kr/market/dataProdDetail?gdsSn=9892&menuNo=28
# ✅ 누적 8310개 저장 완료
#
# [8311] 상세 페이지: https://www.findatamall.or.kr/market/dataProdDetail?gdsSn=9850&menuNo=28
#
# [8312] 상세 페이지: https://www.findatamall.or.kr/market/dataProdDetail?gdsSn=9846&menuNo=28
#
# [8313] 상세 페이지: https://www.findatamall.or.kr/market/dataProdDetail?gdsSn=9821&menuNo=28
#
# [8314] 상세 페이지: https://www.findatamall.or.kr/market/dataProdDetail?gdsSn=7997&menuNo=28
#
# [8315] 상세 페이지: https://www.findatamall.or.kr/market/dataProdDetail?gdsSn=7995&menuNo=28
#
# [8316] 상세 페이지: https://www.findatamall.or.kr/market/dataProdDetail?gdsSn=7992&menuNo=28
#
# [8317] 상세 페이지: https://www.findatamall.or.kr/market/dataProdDetail?gdsSn=7981&menuNo=28
#
# [8318] 상세 페이지: https://www.findatamall.or.kr/market/dataProdDetail?gdsSn=7751&menuNo=28
#
# [8319] 상세 페이지: https://www.findatamall.or.kr/market/dataProdDetail?gdsSn=7596&menuNo=28
#
# [8320] 상세 페이지: https://www.findatamall.or.kr/market/dataProdDetail?gdsSn=7589&menuNo=28
# ✅ 누적 8320개 저장 완료
#
# [8321] 상세 페이지: https://www.findatamall.or.kr/market/dataProdDetail?gdsSn=7416&menuNo=28
#
# [8322] 상세 페이지: https://www.findatamall.or.kr/market/dataProdDetail?gdsSn=7367&menuNo=28
#
# [8323] 상세 페이지: https://www.findatamall.or.kr/market/dataProdDetail?gdsSn=1582&menuNo=28
#
# [8324] 상세 페이지: https://www.findatamall.or.kr/market/dataProdDetail?gdsSn=17171&menuNo=28
#
# [8325] 상세 페이지: https://www.findatamall.or.kr/market/dataProdDetail?gdsSn=17130&menuNo=28
#
# [8326] 상세 페이지: https://www.findatamall.or.kr/market/dataProdDetail?gdsSn=17096&menuNo=28
#
# [8327] 상세 페이지: https://www.findatamall.or.kr/market/dataProdDetail?gdsSn=17033&menuNo=28
#
# [8328] 상세 페이지: https://www.findatamall.or.kr/market/dataProdDetail?gdsSn=16986&menuNo=28
#
# [8329] 상세 페이지: https://www.findatamall.or.kr/market/dataProdDetail?gdsSn=16976&menuNo=28
#
# [8330] 상세 페이지: https://www.findatamall.or.kr/market/dataProdDetail?gdsSn=16966&menuNo=28
# ✅ 누적 8330개 저장 완료
#
# [8331] 상세 페이지: https://www.findatamall.or.kr/market/dataProdDetail?gdsSn=16955&menuNo=28
#
# [8332] 상세 페이지: https://www.findatamall.or.kr/market/dataProdDetail?gdsSn=16944&menuNo=28
#
# [8333] 상세 페이지: https://www.findatamall.or.kr/market/dataProdDetail?gdsSn=16926&menuNo=28
#
# [8334] 상세 페이지: https://www.findatamall.or.kr/market/dataProdDetail?gdsSn=16920&menuNo=28
#
# [8335] 상세 페이지: https://www.findatamall.or.kr/market/dataProdDetail?gdsSn=16918&menuNo=28
#
# [8336] 상세 페이지: https://www.findatamall.or.kr/market/dataProdDetail?gdsSn=16914&menuNo=28
#
# [8337] 상세 페이지: https://www.findatamall.or.kr/market/dataProdDetail?gdsSn=16832&menuNo=28
#
# [8338] 상세 페이지: https://www.findatamall.or.kr/market/dataProdDetail?gdsSn=16827&menuNo=28
#
# [8339] 상세 페이지: https://www.findatamall.or.kr/market/dataProdDetail?gdsSn=16722&menuNo=28
#
# [8340] 상세 페이지: https://www.findatamall.or.kr/market/dataProdDetail?gdsSn=16627&menuNo=28
# ✅ 누적 8340개 저장 완료
#
# [8341] 상세 페이지: https://www.findatamall.or.kr/market/dataProdDetail?gdsSn=16617&menuNo=28
#
# [8342] 상세 페이지: https://www.findatamall.or.kr/market/dataProdDetail?gdsSn=16591&menuNo=28
#
# [8343] 상세 페이지: https://www.findatamall.or.kr/market/dataProdDetail?gdsSn=16528&menuNo=28
#
# [8344] 상세 페이지: https://www.findatamall.or.kr/market/dataProdDetail?gdsSn=9722&menuNo=28
#
# [8345] 상세 페이지: https://www.findatamall.or.kr/market/dataProdDetail?gdsSn=17179&menuNo=28
#
# [8346] 상세 페이지: https://www.findatamall.or.kr/market/dataProdDetail?gdsSn=17175&menuNo=28
#
# [8347] 상세 페이지: https://www.findatamall.or.kr/market/dataProdDetail?gdsSn=17038&menuNo=28
#
# [8348] 상세 페이지: https://www.findatamall.or.kr/market/dataProdDetail?gdsSn=17020&menuNo=28
#
# [8349] 상세 페이지: https://www.findatamall.or.kr/market/dataProdDetail?gdsSn=16999&menuNo=28
#
# [8350] 상세 페이지: https://www.findatamall.or.kr/market/dataProdDetail?gdsSn=16980&menuNo=28
# ✅ 누적 8350개 저장 완료
#
# [8351] 상세 페이지: https://www.findatamall.or.kr/market/dataProdDetail?gdsSn=16969&menuNo=28
#
# [8352] 상세 페이지: https://www.findatamall.or.kr/market/dataProdDetail?gdsSn=16968&menuNo=28
#
# [8353] 상세 페이지: https://www.findatamall.or.kr/market/dataProdDetail?gdsSn=16967&menuNo=28
#
# [8354] 상세 페이지: https://www.findatamall.or.kr/market/dataProdDetail?gdsSn=16965&menuNo=28
#
# [8355] 상세 페이지: https://www.findatamall.or.kr/market/dataProdDetail?gdsSn=16830&menuNo=28
#
# [8356] 상세 페이지: https://www.findatamall.or.kr/market/dataProdDetail?gdsSn=16769&menuNo=28
#
# [8357] 상세 페이지: https://www.findatamall.or.kr/market/dataProdDetail?gdsSn=16730&menuNo=28
#
# [8358] 상세 페이지: https://www.findatamall.or.kr/market/dataProdDetail?gdsSn=16717&menuNo=28
#
# [8359] 상세 페이지: https://www.findatamall.or.kr/market/dataProdDetail?gdsSn=16626&menuNo=28
#
# [8360] 상세 페이지: https://www.findatamall.or.kr/market/dataProdDetail?gdsSn=16512&menuNo=28
# ✅ 누적 8360개 저장 완료
#
# [8361] 상세 페이지: https://www.findatamall.or.kr/market/dataProdDetail?gdsSn=9823&menuNo=28
#
# [8362] 상세 페이지: https://www.findatamall.or.kr/market/dataProdDetail?gdsSn=17139&menuNo=28
#
# [8363] 상세 페이지: https://www.findatamall.or.kr/market/dataProdDetail?gdsSn=17036&menuNo=28
#
# [8364] 상세 페이지: https://www.findatamall.or.kr/market/dataProdDetail?gdsSn=16993&menuNo=28
#
# [8365] 상세 페이지: https://www.findatamall.or.kr/market/dataProdDetail?gdsSn=16975&menuNo=28
#
# [8366] 상세 페이지: https://www.findatamall.or.kr/market/dataProdDetail?gdsSn=16970&menuNo=28
#
# [8367] 상세 페이지: https://www.findatamall.or.kr/market/dataProdDetail?gdsSn=16917&menuNo=28
#
# [8368] 상세 페이지: https://www.findatamall.or.kr/market/dataProdDetail?gdsSn=16844&menuNo=28
#
# [8369] 상세 페이지: https://www.findatamall.or.kr/market/dataProdDetail?gdsSn=16831&menuNo=28
#
# [8370] 상세 페이지: https://www.findatamall.or.kr/market/dataProdDetail?gdsSn=16752&menuNo=28
# ✅ 누적 8370개 저장 완료
#
# [8371] 상세 페이지: https://www.findatamall.or.kr/market/dataProdDetail?gdsSn=16728&menuNo=28
#
# [8372] 상세 페이지: https://www.findatamall.or.kr/market/dataProdDetail?gdsSn=16725&menuNo=28
#
# [8373] 상세 페이지: https://www.findatamall.or.kr/market/dataProdDetail?gdsSn=16716&menuNo=28
#
# [8374] 상세 페이지: https://www.findatamall.or.kr/market/dataProdDetail?gdsSn=17177&menuNo=28
#
# [8375] 상세 페이지: https://www.findatamall.or.kr/market/dataProdDetail?gdsSn=17137&menuNo=28
#
# [8376] 상세 페이지: https://www.findatamall.or.kr/market/dataProdDetail?gdsSn=17123&menuNo=28
#
# [8377] 상세 페이지: https://www.findatamall.or.kr/market/dataProdDetail?gdsSn=17091&menuNo=28
#
# [8378] 상세 페이지: https://www.findatamall.or.kr/market/dataProdDetail?gdsSn=17090&menuNo=28
#
# [8379] 상세 페이지: https://www.findatamall.or.kr/market/dataProdDetail?gdsSn=17085&menuNo=28
#
# [8380] 상세 페이지: https://www.findatamall.or.kr/market/dataProdDetail?gdsSn=17047&menuNo=28
# ✅ 누적 8380개 저장 완료
#
# [8381] 상세 페이지: https://www.findatamall.or.kr/market/dataProdDetail?gdsSn=17037&menuNo=28
#
# [8382] 상세 페이지: https://www.findatamall.or.kr/market/dataProdDetail?gdsSn=17035&menuNo=28
#
# [8383] 상세 페이지: https://www.findatamall.or.kr/market/dataProdDetail?gdsSn=17012&menuNo=28
#
# [8384] 상세 페이지: https://www.findatamall.or.kr/market/dataProdDetail?gdsSn=16956&menuNo=28
#
# [8385] 상세 페이지: https://www.findatamall.or.kr/market/dataProdDetail?gdsSn=16891&menuNo=28
#
# [8386] 상세 페이지: https://www.findatamall.or.kr/market/dataProdDetail?gdsSn=16727&menuNo=28
#
# [8387] 상세 페이지: https://www.findatamall.or.kr/market/dataProdDetail?gdsSn=16723&menuNo=28
#
# [8388] 상세 페이지: https://www.findatamall.or.kr/market/dataProdDetail?gdsSn=16714&menuNo=28
#
# [8389] 상세 페이지: https://www.findatamall.or.kr/market/dataProdDetail?gdsSn=16629&menuNo=28
#
# [8390] 상세 페이지: https://www.findatamall.or.kr/market/dataProdDetail?gdsSn=16614&menuNo=28
# ✅ 누적 8390개 저장 완료
#
# [8391] 상세 페이지: https://www.findatamall.or.kr/market/dataProdDetail?gdsSn=16596&menuNo=28
#
# [8392] 상세 페이지: https://www.findatamall.or.kr/market/dataProdDetail?gdsSn=17129&menuNo=28
#
# [8393] 상세 페이지: https://www.findatamall.or.kr/market/dataProdDetail?gdsSn=17092&menuNo=28
#
# [8394] 상세 페이지: https://www.findatamall.or.kr/market/dataProdDetail?gdsSn=17029&menuNo=28
#
# [8395] 상세 페이지: https://www.findatamall.or.kr/market/dataProdDetail?gdsSn=17025&menuNo=28
#
# [8396] 상세 페이지: https://www.findatamall.or.kr/market/dataProdDetail?gdsSn=17013&menuNo=28
#
# [8397] 상세 페이지: https://www.findatamall.or.kr/market/dataProdDetail?gdsSn=16972&menuNo=28
#
# [8398] 상세 페이지: https://www.findatamall.or.kr/market/dataProdDetail?gdsSn=16971&menuNo=28
#
# [8399] 상세 페이지: https://www.findatamall.or.kr/market/dataProdDetail?gdsSn=16829&menuNo=28
#
# [8400] 상세 페이지: https://www.findatamall.or.kr/market/dataProdDetail?gdsSn=16765&menuNo=28
# ✅ 누적 8400개 저장 완료
#
# [8401] 상세 페이지: https://www.findatamall.or.kr/market/dataProdDetail?gdsSn=16758&menuNo=28
#
# [8402] 상세 페이지: https://www.findatamall.or.kr/market/dataProdDetail?gdsSn=16753&menuNo=28
#
# [8403] 상세 페이지: https://www.findatamall.or.kr/market/dataProdDetail?gdsSn=16720&menuNo=28
#
# [8404] 상세 페이지: https://www.findatamall.or.kr/market/dataProdDetail?gdsSn=16712&menuNo=28
#
# [8405] 상세 페이지: https://www.findatamall.or.kr/market/dataProdDetail?gdsSn=16711&menuNo=28
#
# [8406] 상세 페이지: https://www.findatamall.or.kr/market/dataProdDetail?gdsSn=16625&menuNo=28
#
# [8407] 상세 페이지: https://www.findatamall.or.kr/market/dataProdDetail?gdsSn=16570&menuNo=28
#
# [8408] 상세 페이지: https://www.findatamall.or.kr/market/dataProdDetail?gdsSn=17174&menuNo=28
#
# [8409] 상세 페이지: https://www.findatamall.or.kr/market/dataProdDetail?gdsSn=17127&menuNo=28
#
# [8410] 상세 페이지: https://www.findatamall.or.kr/market/dataProdDetail?gdsSn=17126&menuNo=28
# ✅ 누적 8410개 저장 완료
#
# [8411] 상세 페이지: https://www.findatamall.or.kr/market/dataProdDetail?gdsSn=17125&menuNo=28
#
# [8412] 상세 페이지: https://www.findatamall.or.kr/market/dataProdDetail?gdsSn=17089&menuNo=28
#
# [8413] 상세 페이지: https://www.findatamall.or.kr/market/dataProdDetail?gdsSn=17088&menuNo=28
#
# [8414] 상세 페이지: https://www.findatamall.or.kr/market/dataProdDetail?gdsSn=17057&menuNo=28
#
# [8415] 상세 페이지: https://www.findatamall.or.kr/market/dataProdDetail?gdsSn=17030&menuNo=28
#
# [8416] 상세 페이지: https://www.findatamall.or.kr/market/dataProdDetail?gdsSn=17017&menuNo=28
#
# [8417] 상세 페이지: https://www.findatamall.or.kr/market/dataProdDetail?gdsSn=16957&menuNo=28
#
# [8418] 상세 페이지: https://www.findatamall.or.kr/market/dataProdDetail?gdsSn=16913&menuNo=28
#
# [8419] 상세 페이지: https://www.findatamall.or.kr/market/dataProdDetail?gdsSn=16767&menuNo=28
#
# [8420] 상세 페이지: https://www.findatamall.or.kr/market/dataProdDetail?gdsSn=16763&menuNo=28
# ✅ 누적 8420개 저장 완료
#
# [8421] 상세 페이지: https://www.findatamall.or.kr/market/dataProdDetail?gdsSn=16731&menuNo=28
#
# [8422] 상세 페이지: https://www.findatamall.or.kr/market/dataProdDetail?gdsSn=16721&menuNo=28
#
# [8423] 상세 페이지: https://www.findatamall.or.kr/market/dataProdDetail?gdsSn=16594&menuNo=28
#
# [8424] 상세 페이지: https://www.findatamall.or.kr/market/dataProdDetail?gdsSn=16592&menuNo=28
#
# [8425] 상세 페이지: https://www.findatamall.or.kr/market/dataProdDetail?gdsSn=17138&menuNo=28
#
# [8426] 상세 페이지: https://www.findatamall.or.kr/market/dataProdDetail?gdsSn=17136&menuNo=28
#
# [8427] 상세 페이지: https://www.findatamall.or.kr/market/dataProdDetail?gdsSn=17058&menuNo=28
#
# [8428] 상세 페이지: https://www.findatamall.or.kr/market/dataProdDetail?gdsSn=17053&menuNo=28
#
# [8429] 상세 페이지: https://www.findatamall.or.kr/market/dataProdDetail?gdsSn=17028&menuNo=28
#
# [8430] 상세 페이지: https://www.findatamall.or.kr/market/dataProdDetail?gdsSn=17027&menuNo=28
# ✅ 누적 8430개 저장 완료
#
# [8431] 상세 페이지: https://www.findatamall.or.kr/market/dataProdDetail?gdsSn=17026&menuNo=28
#
# [8432] 상세 페이지: https://www.findatamall.or.kr/market/dataProdDetail?gdsSn=17023&menuNo=28
#
# [8433] 상세 페이지: https://www.findatamall.or.kr/market/dataProdDetail?gdsSn=17015&menuNo=28
#
# [8434] 상세 페이지: https://www.findatamall.or.kr/market/dataProdDetail?gdsSn=16959&menuNo=28
#
# [8435] 상세 페이지: https://www.findatamall.or.kr/market/dataProdDetail?gdsSn=16945&menuNo=28
#
# [8436] 상세 페이지: https://www.findatamall.or.kr/market/dataProdDetail?gdsSn=16943&menuNo=28
#
# [8437] 상세 페이지: https://www.findatamall.or.kr/market/dataProdDetail?gdsSn=16938&menuNo=28
#
# [8438] 상세 페이지: https://www.findatamall.or.kr/market/dataProdDetail?gdsSn=16916&menuNo=28
#
# [8439] 상세 페이지: https://www.findatamall.or.kr/market/dataProdDetail?gdsSn=16907&menuNo=28
#
# [8440] 상세 페이지: https://www.findatamall.or.kr/market/dataProdDetail?gdsSn=16759&menuNo=28
# ✅ 누적 8440개 저장 완료
#
# 🎉 전체 완료: 총 8440개 수집 완료

# %%
import json

# 경로 정의
file1 = '/content/drive/MyDrive/00. 대학원/data-price-1.jsonl'
file2 = '/content/drive/MyDrive/00. 대학원/data-price-2.jsonl'
output_file = '/content/drive/MyDrive/00. 대학원/data-price-20250722.jsonl'

# 리스트형, 숫자형 필드 정의 (이외는 문자열로 처리)
list_fields = {'columns', 'tags'}
int_fields = {'price_num', 'view_cnt', 'download_cnt'}

# 전체 필드 목록 수집
all_fields = set()
records = []
for fname in [file1, file2]:
    with open(fname, 'r', encoding='utf-8') as f:
        for line in f:
            item = json.loads(line)
            records.append(item)
            all_fields.update(item.keys())

# 각 레코드별 필드 보정
standardized_records = []
for item in records:
    new_item = {}
    for field in all_fields:
        if field in item:
            new_item[field] = item[field]
        else:
            if field in list_fields:
                new_item[field] = []
            elif field in int_fields:
                new_item[field] = 0
            else:
                new_item[field] = ""
    standardized_records.append(new_item)

# 파일로 저장
with open(output_file, 'w', encoding='utf-8') as f:
    for item in standardized_records:
        f.write(json.dumps(item, ensure_ascii=False) + '\n')

print('✅ 병합 및 필드 보정 완료:', output_file)
# Out:
# ✅ 병합 및 필드 보정 완료: /content/drive/MyDrive/00. 대학원/data-price-20250722.jsonl

# %% [markdown]
# # 20250723 - 데이터 머지 및 시각화 수행

# %%
   # !sudo apt-get update -qq
   # !sudo apt-get install -y fonts-nanum*
   # !sudo fc-cache -fv
   # !rm -rf ~/.cache/matplotlib

   import matplotlib.pyplot as plt
   import matplotlib.font_manager as fm
   font_path = '/usr/share/fonts/truetype/nanum/NanumBarunGothic.ttf'
   prop = fm.FontProperties(fname=font_path, size=12)
   plt.rc('font', family='NanumBarunGothic')
# Out:
# W: Skipping acquire of configured file 'main/source/Sources' as repository 'https://r2u.stat.illinois.edu/ubuntu jammy InRelease' does not seem to provide it (sources.list entry misspelt?)
# Reading package lists... Done
# Building dependency tree... Done
# Reading state information... Done
# Note, selecting 'fonts-nanum-extra' for glob 'fonts-nanum*'
# Note, selecting 'fonts-nanum-coding' for glob 'fonts-nanum*'
# Note, selecting 'fonts-nanum-eco' for glob 'fonts-nanum*'
# Note, selecting 'fonts-nanum' for glob 'fonts-nanum*'
# fonts-nanum is already the newest version (20200506-1).
# fonts-nanum-coding is already the newest version (2.5-3).
# fonts-nanum-eco is already the newest version (1.000-7).
# fonts-nanum-extra is already the newest version (20200506-1).
# 0 upgraded, 0 newly installed, 0 to remove and 35 not upgraded.
# /usr/share/fonts: caching, new cache contents: 0 fonts, 1 dirs
# /usr/share/fonts/truetype: caching, new cache contents: 0 fonts, 3 dirs
# /usr/share/fonts/truetype/humor-sans: caching, new cache contents: 1 fonts, 0 dirs
# /usr/share/fonts/truetype/liberation: caching, new cache contents: 16 fonts, 0 dirs
# /usr/share/fonts/truetype/nanum: caching, new cache contents: 39 fonts, 0 dirs
# /usr/local/share/fonts: caching, new cache contents: 0 fonts, 0 dirs
# /root/.local/share/fonts: skipping, no such directory
# /root/.fonts: skipping, no such directory
# /usr/share/fonts/truetype: skipping, looped directory detected
# /usr/share/fonts/truetype/humor-sans: skipping, looped directory detected
# /usr/share/fonts/truetype/liberation: skipping, looped directory detected
# /usr/share/fonts/truetype/nanum: skipping, looped directory detected
# /var/cache/fontconfig: cleaning cache directory
# /root/.cache/fontconfig: not cleaning non-existent cache directory
# /root/.fontconfig: not cleaning non-existent cache directory
# fc-cache: succeeded

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import matplotlib.font_manager as fm
import json
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import matplotlib.font_manager as fm
import matplotlib.ticker as mticker
import json

# ✅ 구글 드라이브 마운트
from google.colab import drive
drive.mount('/content/drive')

# 파일 경로
file_path = "/content/drive/MyDrive/00. 대학원/data-price-20250722.jsonl"

# JSONL 파일 로드
df = pd.read_json(file_path, lines=True)

# ✅ 한글 폰트 개별 지정 객체 생성
import matplotlib.font_manager as fm

# ✅ JSONL 파일 읽기
records = []
with open(file_path, 'r', encoding='utf-8') as f:
    for line in f:
        line = line.strip()
        if line:
            records.append(json.loads(line))

# ✅ DataFrame 변환
df = pd.DataFrame(records)

# ✅ price_type별 데이터 건수 집계
type_counts = df['price_type'].value_counts().reset_index()
type_counts.columns = ['price_type', 'count']

plt.figure(figsize=(7, 5))
ax = sns.barplot(x='price_type', y='count', data=type_counts)
ax.set_title('Price Type별 데이터 건수', fontproperties=prop)
ax.set_xlabel('Price Type', fontproperties=prop)
ax.set_ylabel('Count', fontproperties=prop)
for label in ax.get_xticklabels():
    label.set_fontproperties(prop)
for label in ax.get_yticklabels():
    label.set_fontproperties(prop)
plt.tight_layout()
plt.show()


# seller 별 데이터건수 집계
# 판매자별 데이터 상품 건수(상위 20개)
seller_counts = df['seller'].value_counts().reset_index()
seller_counts.columns = ['seller', 'count']

plt.figure(figsize=(12, 6))
ax = sns.barplot(x='seller', y='count', data=seller_counts.head(10))

ax.set_title('판매자별 데이터 상품 건수(상위 10개)', fontproperties=prop)
ax.set_xlabel('판매자', fontproperties=prop)
ax.set_ylabel('상품 개수', fontproperties=prop)

# x축 tick 한글 및 각도, 위치 정렬
plt.xticks(rotation=40, ha='right', fontproperties=prop, fontsize=11)
plt.yticks(fontproperties=prop, fontsize=11)

plt.tight_layout()
plt.show()


# ✅ 고정 또는 무료만 남기기(범위나 협의는 가격이 명확하지 않으므로 제외)
df_filtered = df[ (df['price_type'] == '고정') | (df['price_type'] == '무료') ]

# ✅ seaborn 스타일 설정
sns.set(style="whitegrid")

# ---- 카테고리별 가격 분포 boxplot ----
plt.figure(figsize=(12, 6))
ax1 = sns.boxplot(x='category', y='price_num', data=df_filtered)
ax1.set_title('카테고리별 가격 분포', fontproperties=prop)
ax1.set_ylabel('가격 (원)', fontproperties=prop)
ax1.set_xlabel('카테고리', fontproperties=prop)
for label in ax1.get_xticklabels():
    label.set_fontproperties(prop)
for label in ax1.get_yticklabels():
    label.set_fontproperties(prop)

# Y축 천 단위 콤마 표기 적용
ax1.yaxis.set_major_formatter(mticker.FuncFormatter(lambda x, p: format(int(x), ',')))

# ✅ x축 레이블 45도~60도 기울이기 (여기서 60도 예시)
plt.xticks(rotation=60, ha='right', fontsize=12, fontproperties=prop)

plt.tight_layout()
plt.show()

# ---- 포맷별 가격 분포 boxplot ----
plt.figure(figsize=(18, 7))  # 폭을 넓게 (기존 10, 6 → 18, 7)
ax2 = sns.boxplot(x='format', y='price_num', data=df_filtered)
ax2.set_title('포맷별 가격 분포', fontproperties=prop)
ax2.set_ylabel('가격 (원)', fontproperties=prop)
ax2.set_xlabel('포맷', fontproperties=prop)
for label in ax2.get_xticklabels():
    label.set_fontproperties(prop)
for label in ax2.get_yticklabels():
    label.set_fontproperties(prop)
ax2.yaxis.set_major_formatter(mticker.FuncFormatter(lambda x, p: format(int(x), ',')))

# ✅ x축 레이블 60도 이상 크게 기울이기 (기본 45 → 60 or 75)
plt.xticks(rotation=60, ha='right', fontsize=11, fontproperties=prop)

plt.tight_layout()
plt.show()

# ---- 카테고리 & 포맷 조합별 가격 분포 boxplot ----
plt.figure(figsize=(14, 6))
ax3 = sns.boxplot(x='category', y='price_num', hue='format', data=df_filtered)
ax3.set_title('카테고리 & 포맷별 가격 분포', fontproperties=prop)
ax3.set_ylabel('가격 (원)', fontproperties=prop)
ax3.set_xlabel('카테고리', fontproperties=prop)
for label in ax3.get_xticklabels():
    label.set_fontproperties(prop)
for label in ax3.get_yticklabels():
    label.set_fontproperties(prop)
leg = ax3.legend(title='포맷', bbox_to_anchor=(1.05, 1), loc='upper left')
leg.set_title('포맷', prop=prop)
for text in leg.get_texts():
    text.set_fontproperties(prop)
ax3.yaxis.set_major_formatter(mticker.FuncFormatter(lambda x, p: format(int(x), ',')))
plt.tight_layout()
plt.show()


# ---- 카테고리 & 포맷 조합별 가격 분포 boxplot(subplot 2개) ----
from matplotlib.ticker import FuncFormatter

# ✅ 카테고리 정렬(원하는 순서 지정 가능)
categories = sorted(df_filtered['category'].unique())
n = 2  # subplot마다 표시할 카테고리 수
category_groups = [categories[i:i+n] for i in range(0, len(categories), n)]

fig, axes = plt.subplots(3, 2, figsize=(18, 18), sharey=True)
axes = axes.flatten()

# ✅ y축 1000단위 콤마 formatter 함수
def comma_formatter(x, pos):
    return f"{int(x):,}"

for idx, cat_group in enumerate(category_groups):
    ax = axes[idx]
    data = df_filtered[df_filtered['category'].isin(cat_group)].copy()
    # 카테고리별 상위 3개 포맷만 추출
    data_filtered = pd.DataFrame()
    for category in cat_group:
        temp = data[data['category'] == category]
        top_formats = temp['format'].value_counts().nlargest(3).index
        data_filtered = pd.concat([data_filtered, temp[temp['format'].isin(top_formats)]])
    # Boxplot
    sns.boxplot(
        x='category', y='price_num', hue='format',
        data=data_filtered, ax=ax
    )
    # 제목/축이름 한글
    ax.set_title(f"카테고리: {', '.join(cat_group)}", fontproperties=prop, fontsize=14)
    ax.set_ylabel("가격 (원)", fontproperties=prop)
    ax.set_xlabel("카테고리", fontproperties=prop)
    # x축 ticklabels 한글
    for label in ax.get_xticklabels():
        label.set_fontproperties(prop)
        label.set_fontsize(12)
        label.set_rotation(30)
    # y축 ticklabels 한글 + 콤마 포매팅
    ax.yaxis.set_major_formatter(FuncFormatter(comma_formatter))
    for label in ax.get_yticklabels():
        label.set_fontproperties(prop)
        label.set_fontsize(12)
    # 모든 subplot에서 범례 표시(한글)
    leg = ax.legend(title='포맷', fontsize=10, prop=prop, title_fontproperties=prop, bbox_to_anchor=(1.02, 1), loc='upper left')
    if leg is not None:
        leg.get_title().set_fontproperties(prop)
        for text in leg.get_texts():
            text.set_fontproperties(prop)

# 남는 subplot은 숨김 처리(카테고리 개수 짝수가 아니면)
for j in range(idx+1, len(axes)):
    axes[j].set_visible(False)

plt.tight_layout()
plt.show()



# ---- 카테고리별 평균 가격 barplot ----
plt.figure(figsize=(12, 6))
avg_prices = df_filtered.groupby('category')['price_num'].mean().reset_index()
ax4 = sns.barplot(x='category', y='price_num', data=avg_prices)
ax4.set_title('카테고리별 평균 가격', fontproperties=prop)
ax4.set_ylabel('평균 가격 (원)', fontproperties=prop)
ax4.set_xlabel('카테고리', fontproperties=prop)
for label in ax4.get_xticklabels():
    label.set_fontproperties(prop)
for label in ax4.get_yticklabels():
    label.set_fontproperties(prop)
ax4.yaxis.set_major_formatter(mticker.FuncFormatter(lambda x, p: format(int(x), ',')))
plt.tight_layout()
plt.show()


# 카테고리별 가격 박스플롯 (한글폰트 적용)

plt.figure(figsize=(14, 7))
ax = sns.boxplot(x='category', y='price_num', data=df_filtered)
ax.set_title('카테고리별 가격 분포', fontproperties=prop, fontsize=16)
ax.set_xlabel('카테고리', fontproperties=prop, fontsize=13)
ax.set_ylabel('가격 (원)', fontproperties=prop, fontsize=13)

# x축 레이블 한글, 기울이기, 사이즈
for label in ax.get_xticklabels():
    label.set_fontproperties(prop)
    label.set_fontsize(11)
    label.set_rotation(40)
    label.set_ha('right')

# y축 레이블 한글, 콤마 포매팅
from matplotlib.ticker import FuncFormatter
def comma_formatter(x, pos):
    return f"{int(x):,}"
ax.yaxis.set_major_formatter(FuncFormatter(comma_formatter))
for label in ax.get_yticklabels():
    label.set_fontproperties(prop)
    label.set_fontsize(11)

plt.tight_layout()
plt.show()


# ✅ 상위 N개 판매자만 추출
top_n = 10
top_sellers = df_filtered['seller'].value_counts().nlargest(top_n).index
df_top_sellers = df_filtered[df_filtered['seller'].isin(top_sellers)].copy()

plt.figure(figsize=(14, 6))
ax = sns.boxplot(x='seller', y='price_num', data=df_top_sellers)
ax.set_title(f'상위 판매자별 가격 분포 TOP {top_n}', fontproperties=prop, fontsize=15)
ax.set_xlabel('판매자', fontproperties=prop, fontsize=13)
ax.set_ylabel('가격 (원)', fontproperties=prop, fontsize=13)
plt.xticks(rotation=30, ha='right', fontproperties=prop, fontsize=11)
ax.yaxis.set_major_formatter(FuncFormatter(lambda x, _: f'{int(x):,}'))
for label in ax.get_yticklabels():
    label.set_fontproperties(prop)
    label.set_fontsize(11)
plt.tight_layout()
plt.show()
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# /tmp/ipython-input-4-4212131948.py in <cell line: 0>()
#     151
#     152 for idx, cat_group in enumerate(category_groups):
# --> 153     ax = axes[idx]
#     154     data = df_filtered[df_filtered['category'].isin(cat_group)].copy()
#     155     # 카테고리별 상위 3개 포맷만 추출
#
# IndexError: index 6 is out of bounds for axis 0 with size 6

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import matplotlib.font_manager as fm
import matplotlib.ticker as mticker
import json

# 1. 구글 드라이브 마운트
from google.colab import drive
drive.mount('/content/drive')

# 파일 경로
file_path = "/content/drive/MyDrive/00. 대학원/data-price-20250722.jsonl"

# 2. 데이터 불러오기
records = []
with open(file_path, 'r', encoding='utf-8') as f:
    for line in f:
        line = line.strip()
        if line:
            records.append(json.loads(line))
df = pd.DataFrame(records)

# 3. 시각화를 위한 필터링
df_filtered = df[df['price_type'].isin(['고정', '무료'])].copy()
df_filtered['price_num'] = pd.to_numeric(df_filtered['price_num'], errors='coerce')

# ---------- ✅ 시각화 시작 ----------

# 1. 가격 유형별 데이터 건수 막대그래프
plt.figure(figsize=(7, 5))
type_counts = df['price_type'].value_counts().reset_index()
type_counts.columns = ['price_type', 'count']
ax = sns.barplot(x='price_type', y='count', data=type_counts)
ax.set_title('Price Type별 데이터 건수', fontproperties=prop)
ax.set_xlabel('Price Type', fontproperties=prop)
ax.set_ylabel('Count', fontproperties=prop)
for label in ax.get_xticklabels() + ax.get_yticklabels():
    label.set_fontproperties(prop)
plt.tight_layout()
plt.show()

# 2. 카테고리별 가격 분포 박스 플롯 (상위 10개)
top_categories = df_filtered['category'].value_counts().nlargest(10).index
df_top10 = df_filtered[df_filtered['category'].isin(top_categories)]

plt.figure(figsize=(14, 7))
ax = sns.boxplot(x='category', y='price_num', data=df_top10)
ax.set_title('카테고리별 가격 분포 (상위 10개)', fontproperties=prop)
ax.set_xlabel('카테고리', fontproperties=prop)
ax.set_ylabel('가격 (원)', fontproperties=prop)
for label in ax.get_xticklabels():
    label.set_fontproperties(prop)
    label.set_fontsize(10)
    label.set_rotation(45)
ax.yaxis.set_major_formatter(mticker.FuncFormatter(lambda x, _: f'{int(x):,}'))
plt.tight_layout()
plt.show()

# 3. 포맷별 가격 분포 박스 플롯
plt.figure(figsize=(18, 7))
ax = sns.boxplot(x='format', y='price_num', data=df_filtered)
ax.set_title('포맷별 가격 분포', fontproperties=prop)
ax.set_xlabel('포맷', fontproperties=prop)
ax.set_ylabel('가격 (원)', fontproperties=prop)
for label in ax.get_xticklabels() + ax.get_yticklabels():
    label.set_fontproperties(prop)
    label.set_fontsize(11)
ax.yaxis.set_major_formatter(mticker.FuncFormatter(lambda x, _: f'{int(x):,}'))
plt.xticks(rotation=60, ha='right')
plt.tight_layout()
plt.show()

# 4. 상위 판매자별 가격 분포 (TOP 10)
top_sellers = df_filtered['seller'].value_counts().nlargest(10).index
df_top_sellers = df_filtered[df_filtered['seller'].isin(top_sellers)]

plt.figure(figsize=(14, 6))
ax = sns.boxplot(x='seller', y='price_num', data=df_top_sellers)
ax.set_title('상위 판매자별 가격 분포 TOP 10', fontproperties=prop)
ax.set_xlabel('판매자', fontproperties=prop)
ax.set_ylabel('가격 (원)', fontproperties=prop)
plt.xticks(rotation=30, ha='right', fontproperties=prop, fontsize=11)
ax.yaxis.set_major_formatter(mticker.FuncFormatter(lambda x, _: f'{int(x):,}'))
for label in ax.get_yticklabels():
    label.set_fontproperties(prop)
    label.set_fontsize(11)
plt.tight_layout()
plt.show()


# ✅ 판매자별 데이터 상품 개수 상위 10개 막대그래프

# 판매자별 데이터 상품 개수 계산
seller_counts = df['seller'].value_counts().nlargest(10).reset_index()
seller_counts.columns = ['seller', 'count']

plt.figure(figsize=(12, 6))
ax = sns.barplot(x='seller', y='count', data=seller_counts)
ax.set_title('판매자별 데이터 상품 개수 (TOP 10)', fontproperties=prop)
ax.set_xlabel('판매자', fontproperties=prop)
ax.set_ylabel('상품 수', fontproperties=prop)

# x축 텍스트 스타일
plt.xticks(rotation=45, ha='right', fontproperties=prop, fontsize=11)
plt.yticks(fontproperties=prop, fontsize=11)

plt.tight_layout()
plt.show()


# ✅ 상위 N개 판매자만 추출
top_n = 10
top_sellers = df_filtered['seller'].value_counts().nlargest(top_n).index
df_top_sellers = df_filtered[df_filtered['seller'].isin(top_sellers)].copy()

plt.figure(figsize=(14, 6))
ax = sns.boxplot(x='seller', y='price_num', data=df_top_sellers)
ax.set_title(f'상위 판매자별 가격 분포 TOP {top_n}', fontproperties=prop, fontsize=15)
ax.set_xlabel('판매자', fontproperties=prop, fontsize=13)
ax.set_ylabel('가격 (원)', fontproperties=prop, fontsize=13)
plt.xticks(rotation=30, ha='right', fontproperties=prop, fontsize=11)
ax.yaxis.set_major_formatter(mticker.FuncFormatter(lambda x, _: f'{int(x):,}'))
for label in ax.get_yticklabels():
    label.set_fontproperties(prop)
    label.set_fontsize(11)
plt.tight_layout()
plt.show()
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %% [markdown]
# # 20250723 - 정규화 사전 구축

# %%
import json
from collections import defaultdict
import re
import pandas as pd


def normalize_text(text):
    text = text.lower()
    text = re.sub(r'\s+', '', text)
    text = re.sub(r'[^가-힣a-z0-9]', '', text)
    return text

def build_normalization_dict_from_json(json_file_path, output_json_path, fields):
    # JSONL 로딩
    records = []
    with open(json_file_path, 'r', encoding='utf-8') as f:
        for line in f:
            line = line.strip()
            if line:
                records.append(json.loads(line))
    df = pd.DataFrame(records)

    # 필드별 정규화 후보 수집
    fieldwise_groups = defaultdict(lambda: defaultdict(set))
    for field in fields:
        if field not in df.columns:
            continue
        if field == 'columns':
            for row in df['columns'].dropna():
                for item in row:
                    norm = normalize_text(item)
                    if norm:
                        fieldwise_groups[field][norm].add(item)
        else:
            for val in df[field].dropna().unique():
                norm = normalize_text(val)
                if norm:
                    fieldwise_groups[field][norm].add(val)

    # 정규화 사전 구성
    fieldwise_normalized_dict = {}
    for field, groups in fieldwise_groups.items():
        normalized_list = []
        for norm, originals in groups.items():
            if len(originals) > 1:
                normalized_list.append({
                    "original": sorted(list(originals)),
                    "normalized": sorted(list(originals), key=len)[0]
                })
        fieldwise_normalized_dict[field] = normalized_list

    # 저장
    with open(output_json_path, "w", encoding="utf-8") as f:
        json.dump(fieldwise_normalized_dict, f, ensure_ascii=False, indent=2)
    return output_json_path

# 1. 구글 드라이브 마운트
from google.colab import drive
drive.mount('/content/drive')

# 테스트 실행
input_path = "/content/drive/MyDrive/00. 대학원/data-price-20250722.jsonl"
output_path = "/content/drive/MyDrive/00. 대학원/normalized-20250722.json"
target_fields = ['category', 'format', 'columns']

build_normalization_dict_from_json(input_path, output_path, target_fields)
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# '/content/drive/MyDrive/00. 대학원/normalized-20250722.json'

# %% [markdown]
# # 20250727 - 데이터 프로파일링 및 클렌징

# %%
# ✅ 코랩 환경에서 필요한 패키지 설치
# !pip install playwright nest_asyncio

# ✅ Playwright 초기화 (처음 한 번만 실행하면 됨)
# !playwright install
# Out:
# Collecting playwright
#   Downloading playwright-1.54.0-py3-none-manylinux1_x86_64.whl.metadata (3.5 kB)
# Requirement already satisfied: nest_asyncio in /usr/local/lib/python3.11/dist-packages (1.6.0)
# Collecting pyee<14,>=13 (from playwright)
#   Downloading pyee-13.0.0-py3-none-any.whl.metadata (2.9 kB)
# Requirement already satisfied: greenlet<4.0.0,>=3.1.1 in /usr/local/lib/python3.11/dist-packages (from playwright) (3.2.3)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.11/dist-packages (from pyee
] 57% 0.5s94.4 MiB [] 60% 0.4s94.4 MiB [] 63% 0.4s94.4 MiB [] 66% 0.3s94.4 MiB [] 70% 0.3s94.4 MiB [] 73% 0.3s94.4 MiB [] 76% 0.2s94.4 MiB [] 79% 0.2s94.4 MiB [] 82% 0.2s94.4 MiB [] 85% 0.1s94.4 MiB [] 86% 0.1s94.4 MiB [] 88% 0.1s94.4 MiB [] 90% 0.1s94.4 MiB [] 91% 0.1s94.4 MiB [] 92% 0.1s94.4 MiB [] 93% 0.1s94.4 MiB [] 94% 0.0s94.4 MiB [] 95% 0.0s94.4 MiB [] 96% 0.0s94.4 MiB [] 97% 0.0s94.4 MiB [] 98% 0.0s94.4 MiB [] 99% 0.0s94.4 MiB [] 100% 0.0s
# Webkit 26.0 (playwright build v2191) downloaded to /root/.cache/ms-playwright/webkit-2191
# Downloading FFMPEG playwright build v1011 from https://cdn.playwright.dev/dbazure/download/playwright/builds/ffmpeg/1011/ffmpeg-linux.zip
# 2.3 MiB [] 0% 0.0s2.3 MiB [] 2% 0.7s2.3 MiB [] 11% 0.3s2.3 MiB [] 29% 0.1s2.3 MiB [] 70% 0.0s2.3 MiB [] 100% 0.0s
# FFMPEG playwright build v1011 downloaded to /root/.cache/ms-playwright/ffmpeg-1011
# Playwright Host validation warning:
# ╔══════════════════════════════════════════════════════╗
# ║ Host system is missing dependencies to run browsers. ║
# ║ Missing libraries:                                   ║
# ║     libwoff2dec.so.1.0.2                             ║
# ║     libgstgl-1.0.so.0                                ║
# ║     libgstcodecparsers-1.0.so.0                      ║
# ║     libavif.so.13                                    ║
# ║     libharfbuzz-icu.so.0                             ║
# ║     libenchant-2.so.2                                ║
# ║     libsecret-1.so.0                                 ║
# ║     libhyphen.so.0                                   ║
# ║     libmanette-0.2.so.0                              ║
# ╚══════════════════════════════════════════════════════╝
#     at validateDependenciesLinux (/usr/local/lib/python3.11/dist-packages/playwright/driver/package/lib/server/registry/dependencies.js:269:9)
#     at async Registry._validateHostRequirements (/usr/local/lib/python3.11/dist-packages/playwright/driver/package/lib/server/registry/index.js:914:14)
#     at async Registry._validateHostRequirementsForExecutableIfNeeded (/usr/local/lib/python3.11/dist-packages/playwright/driver/package/lib/server/registry/index.js:1036:7)
#     at async Registry.validateHostRequirementsForExecutablesIfNeeded (/usr/local/lib/python3.11/dist-packages/playwright/driver/package/lib/server/registry/index.js:1025:7)
#     at async i.<anonymous> (/usr/local/lib/python3.11/dist-packages/playwright/driver/package/lib/cli/program.js:222:7)

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import matplotlib.font_manager as fm
import matplotlib.ticker as mticker
import json

# 1. 구글 드라이브 마운트
from google.colab import drive
drive.mount('/content/drive')

# df.info()
# df["price_type"].value_counts()
# price_type
# 무료	4686
# 협의	4138
# 고정	1829
# 유료	156
# 확인필요	147
# 범위	70
# 에러	2

# 에러에 해당하는 데이터는 협의로 변경 필요
# 확인필요 데이터는 체크하여 실제 가격값으로 변경 필요

# 데이터 내용 출력 길이 제한 해제
import pandas as pd
import json

# 파일 경로
input_path = "/content/drive/MyDrive/00. 대학원/data-price-20250727-v8.jsonl"
# output_path = "/content/drive/MyDrive/00. 대학원/data-price-20250727-v9.jsonl"

# 1. JSONL 파일 읽기
records = []
with open(input_path, 'r', encoding='utf-8') as f:
    for line in f:
        line = line.strip()
        if line:
            records.append(json.loads(line))

# 2. pandas DataFrame 변환
df = pd.DataFrame(records)

df["price_type"].value_counts()


df[df["price_type"] == "확인필요"]["url"]
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# 2619     https://www.findatamall.or.kr/market/dataProdDetail?gdsSn=16982&menuNo=28
# 2620     https://www.findatamall.or.kr/market/dataProdDetail?gdsSn=16983&menuNo=28
# 2642     https://www.findatamall.or.kr/market/dataProdDetail?gdsSn=16486&menuNo=28
# 3116     https://www.findatamall.or.kr/market/dataProdDetail?gdsSn=16430&menuNo=28
# 3125       https://www.findatamall.or.kr/market/dataProdDetail?gdsSn=118&menuNo=28
#                                            ...
# 11001    https://www.findatamall.or.kr/market/dataProdDetail?gdsSn=17057&menuNo=28
# 11012    https://www.findatamall.or.kr/market/dataProdDetail?gdsSn=17138&menuNo=28
# 11013    https://www.findatamall.or.kr/market/dataProdDetail?gdsSn=17136&menuNo=28
# 11014    https://www.findatamall.or.kr/market/dataProdDetail?gdsSn=17058&menuNo=28
# 11015    https://www.findatamall.or.kr/market/dataProdDetail?gdsSn=17053&menuNo=28
# Name: url, Length: 147, dtype: object

# %%
import nest_asyncio
import asyncio
import json
from playwright.async_api import async_playwright

nest_asyncio.apply()

input_jsonl = "/content/drive/MyDrive/00. 대학원/data-price-20250727-v8.jsonl"
output_jsonl = "/content/drive/MyDrive/00. 대학원/data-price-20250727-v9.jsonl"

# 1. '확인필요' 대상만 추출
records = []
with open(input_jsonl, 'r', encoding='utf-8') as f:
    for line in f:
        if line.strip():
            obj = json.loads(line)
            if obj.get("price_type") == "확인필요":
                records.append(obj)

print(f"🔍 '확인필요' 대상: {len(records)}건")

# 2. 가격 재파싱 함수
async def fix_prices(records):
    async with async_playwright() as p:
        browser = await p.chromium.launch(headless=True)
        page = await browser.new_page()
        fixed_records = []

        async def safe_text(selector, default=""):
            try:
                await page.wait_for_selector(selector, state="visible", timeout=5000)
                el = await page.query_selector(selector)
                return (await el.inner_text()).strip() if el else default
            except:
                return default

        for i, record in enumerate(records, 1):
            url = record.get("url")
            print(f"\n[{i}] 재확인: {url}")
            try:
                await page.goto(url, timeout=15000)
                await page.wait_for_timeout(1000)

                # 가격 힌트 추출
                hint = await safe_text("p.price", "")

                if "무료" in hint:
                    price_type = "무료"
                    price_num = "0"

                elif "협의" in hint or "문의" in hint:
                    price_type = "협의"
                    price_num = "0"

                elif "부터" in hint:
                    # 범위형 → 테이블에서 실제 가격 추출
                    price_num = await safe_text("#prodDetail > dl > dd > div > table > tbody > tr > td.txtR", None)
                    if price_num:
                        price_type = "범위"
                    else:
                        price_type = "확인필요"
                        price_num = None

                elif "원" in hint:
                    # 고정가
                    price_type = "유료"
                    price_num = hint

                else:
                    price_type = "확인필요"
                    price_num = None

                record["price_type"] = price_type
                record["price_num"] = price_num
                fixed_records.append(record)

                print(f"➡️ {price_type} / {price_num}")

            except Exception as e:
                print(f"⛔ 에러 발생: {e}")
                fixed_records.append(record)

        await browser.close()
        return fixed_records

# 사용법 (Google Colab 등에서)
updated = await fix_prices(records)
with open(output_jsonl, 'w', encoding='utf-8') as f:
    for r in updated:
        f.write(json.dumps(r, ensure_ascii=False) + "\n")
print("✅ 저장 완료:", output_jsonl)
# Out:
# 🔍 '확인필요' 대상: 147건
#
# [1] 재확인: https://www.findatamall.or.kr/market/dataProdDetail?gdsSn=16982&menuNo=28
# ➡️ 유료 / 450,000원
#
# [2] 재확인: https://www.findatamall.or.kr/market/dataProdDetail?gdsSn=16983&menuNo=28
# ➡️ 유료 / 300,000원
#
# [3] 재확인: https://www.findatamall.or.kr/market/dataProdDetail?gdsSn=16486&menuNo=28
# ➡️ 유료 / 100,000원
#
# [4] 재확인: https://www.findatamall.or.kr/market/dataProdDetail?gdsSn=16430&menuNo=28
# ➡️ 범위 / 5,000,000 ~ 50,000,000
#
# [5] 재확인: https://www.findatamall.or.kr/market/dataProdDetail?gdsSn=118&menuNo=28
# ➡️ 범위 / 1,500,000 ~ 10,000,000
#
# [6] 재확인: https://www.findatamall.or.kr/market/dataProdDetail?gdsSn=14086&menuNo=28
# ➡️ 범위 / 100,000,000 ~ 300,000,000
#
# [7] 재확인: https://www.findatamall.or.kr/market/dataProdDetail?gdsSn=14122&menuNo=28
# ➡️ 범위 / 1,500,000 ~ 17,099,476
#
# [8] 재확인: https://www.findatamall.or.kr/market/dataProdDetail?gdsSn=114&menuNo=28
# ➡️ 범위 / 1,500,000 ~ 10,000,000
#
# [9] 재확인: https://www.findatamall.or.kr/market/dataProdDetail?gdsSn=91&menuNo=28
# ➡️ 범위 / 1,500,000 ~ 10,000,000
#
# [10] 재확인: https://www.findatamall.or.kr/market/dataProdDetail?gdsSn=146&menuNo=28
# ➡️ 범위 / 1,500,000 ~ 10,000,000
#
# [11] 재확인: https://www.findatamall.or.kr/market/dataProdDetail?gdsSn=147&menuNo=28
# ➡️ 범위 / 1,500,000 ~ 10,000,000
#
# [12] 재확인: https://www.findatamall.or.kr/market/dataProdDetail?gdsSn=159&menuNo=28
# ➡️ 범위 / 1,500,000 ~ 10,000,000
#
# [13] 재확인: https://www.findatamall.or.kr/market/dataProdDetail?gdsSn=14085&menuNo=28
# ➡️ 범위 / 90,000,000 ~ 300,000,000
#
# [14] 재확인: https://www.findatamall.or.kr/market/dataProdDetail?gdsSn=16883&menuNo=28
# ➡️ 범위 / 500,000 ~ 100,000,000
#
# [15] 재확인: https://www.findatamall.or.kr/market/dataProdDetail?gdsSn=158&menuNo=28
# ➡️ 범위 / 1,500,000 ~ 10,000,000
#
# [16] 재확인: https://www.findatamall.or.kr/market/dataProdDetail?gdsSn=14116&menuNo=28
# ➡️ 범위 / 1,000,000 ~ 10,209,000
#
# [17] 재확인: https://www.findatamall.or.kr/market/dataProdDetail?gdsSn=14099&menuNo=28
# ➡️ 범위 / 1,100 ~ 198,000
#
# [18] 재확인: https://www.findatamall.or.kr/market/dataProdDetail?gdsSn=14119&menuNo=28
# ➡️ 유료 / 3,000,000원
#
# [19] 재확인: https://www.findatamall.or.kr/market/dataProdDetail?gdsSn=148&menuNo=28
# ➡️ 범위 / 1,500,000 ~ 10,000,000
#
# [20] 재확인: https://www.findatamall.or.kr/market/dataProdDetail?gdsSn=14121&menuNo=28
# ➡️ 유료 / 2,000,000원
#
# [21] 재확인: https://www.findatamall.or.kr/market/dataProdDetail?gdsSn=14118&menuNo=28
# ➡️ 유료 / 5,000,000원
#
# [22] 재확인: https://www.findatamall.or.kr/market/dataProdDetail?gdsSn=14076&menuNo=28
# ➡️ 범위 / 60,000,000 ~ 150,000,000
#
# [23] 재확인: https://www.findatamall.or.kr/market/dataProdDetail?gdsSn=16556&menuNo=28
# ➡️ 유료 / 300,000원
#
# [24] 재확인: https://www.findatamall.or.kr/market/dataProdDetail?gdsSn=14082&menuNo=28
# ➡️ 범위 / 60,000,000 ~ 150,000,000
#
# [25] 재확인: https://www.findatamall.or.kr/market/dataProdDetail?gdsSn=14110&menuNo=28
# ➡️ 유료 / 10,000,000원
#
# [26] 재확인: https://www.findatamall.or.kr/market/dataProdDetail?gdsSn=14124&menuNo=28
# ➡️ 범위 / 4,000,000 ~ 44,430,540
#
# [27] 재확인: https://www.findatamall.or.kr/market/dataProdDetail?gdsSn=16604&menuNo=28
# ➡️ 범위 / 10,000,000 ~ 100,000,000
#
# [28] 재확인: https://www.findatamall.or.kr/market/dataProdDetail?gdsSn=16611&menuNo=28
# ➡️ 유료 / 300,000원
#
# [29] 재확인: https://www.findatamall.or.kr/market/dataProdDetail?gdsSn=16636&menuNo=28
# ➡️ 범위 / 67,500,000 ~ 120,000,000
#
# [30] 재확인: https://www.findatamall.or.kr/market/dataProdDetail?gdsSn=4510&menuNo=28
# ➡️ 범위 / 1,500,000 ~ 10,000,000
#
# [31] 재확인: https://www.findatamall.or.kr/market/dataProdDetail?gdsSn=16693&menuNo=28
# ➡️ 범위 / 3,000,000 ~ 30,000,000
#
# [32] 재확인: https://www.findatamall.or.kr/market/dataProdDetail?gdsSn=16605&menuNo=28
# ➡️ 범위 / 10,000,000 ~ 100,000,000
#
# [33] 재확인: https://www.findatamall.or.kr/market/dataProdDetail?gdsSn=14080&menuNo=28
# ➡️ 범위 / 60,000,000 ~ 150,000,000
#
# [34] 재확인: https://www.findatamall.or.kr/market/dataProdDetail?gdsSn=14079&menuNo=28
# ➡️ 범위 / 60,000,000 ~ 150,000,000
#
# [35] 재확인: https://www.findatamall.or.kr/market/dataProdDetail?gdsSn=14123&menuNo=28
# ➡️ 유료 / 5,000,000원
#
# [36] 재확인: https://www.findatamall.or.kr/market/dataProdDetail?gdsSn=16444&menuNo=28
# ➡️ 유료 / 300,000원
#
# [37] 재확인: https://www.findatamall.or.kr/market/dataProdDetail?gdsSn=14113&menuNo=28
# ➡️ 유료 / 10,000,000원
#
# [38] 재확인: https://www.findatamall.or.kr/market/dataProdDetail?gdsSn=16403&menuNo=28
# ➡️ 유료 / 300,000원
#
# [39] 재확인: https://www.findatamall.or.kr/market/dataProdDetail?gdsSn=16406&menuNo=28
# ➡️ 유료 / 35,000원
#
# [40] 재확인: https://www.findatamall.or.kr/market/dataProdDetail?gdsSn=16657&menuNo=28
# ➡️ 유료 / 300,000원
#
# [41] 재확인: https://www.findatamall.or.kr/market/dataProdDetail?gdsSn=16824&menuNo=28
# ➡️ 범위 / 50,000,000 ~ 100,000,000
#
# [42] 재확인: https://www.findatamall.or.kr/market/dataProdDetail?gdsSn=16788&menuNo=28
# ➡️ 유료 / 29,700,000원
#
# [43] 재확인: https://www.findatamall.or.kr/market/dataProdDetail?gdsSn=16487&menuNo=28
# ➡️ 유료 / 200,000원
#
# [44] 재확인: https://www.findatamall.or.kr/market/dataProdDetail?gdsSn=16405&menuNo=28
# ➡️ 유료 / 300,000원
#
# [45] 재확인: https://www.findatamall.or.kr/market/dataProdDetail?gdsSn=16705&menuNo=28
# ➡️ 유료 / 70,000원
#
# [46] 재확인: https://www.findatamall.or.kr/market/dataProdDetail?gdsSn=16639&menuNo=28
# ➡️ 범위 / 10,000,000 ~ 100,000,000
#
# [47] 재확인: https://www.findatamall.or.kr/market/dataProdDetail?gdsSn=16638&menuNo=28
# ➡️ 범위 / 10,000,000 ~ 100,000,000
#
# [48] 재확인: https://www.findatamall.or.kr/market/dataProdDetail?gdsSn=14081&menuNo=28
# ➡️ 범위 / 60,000,000 ~ 150,000,000
#
# [49] 재확인: https://www.findatamall.or.kr/market/dataProdDetail?gdsSn=16446&menuNo=28
# ➡️ 유료 / 300,000원
#
# [50] 재확인: https://www.findatamall.or.kr/market/dataProdDetail?gdsSn=16874&menuNo=28
# ➡️ 범위 / 500,000 ~ 100,000,000
#
# [51] 재확인: https://www.findatamall.or.kr/market/dataProdDetail?gdsSn=16656&menuNo=28
# ➡️ 유료 / 200,000원
#
# [52] 재확인: https://www.findatamall.or.kr/market/dataProdDetail?gdsSn=16637&menuNo=28
# ➡️ 범위 / 55,000,000 ~ 107,500,000
#
# [53] 재확인: https://www.findatamall.or.kr/market/dataProdDetail?gdsSn=16557&menuNo=28
# ➡️ 유료 / 70,000원
#
# [54] 재확인: https://www.findatamall.or.kr/market/dataProdDetail?gdsSn=16709&menuNo=28
# ➡️ 유료 / 70,000원
#
# [55] 재확인: https://www.findatamall.or.kr/market/dataProdDetail?gdsSn=16695&menuNo=28
# ➡️ 범위 / 1,000,000 ~ 10,000,000
#
# [56] 재확인: https://www.findatamall.or.kr/market/dataProdDetail?gdsSn=16708&menuNo=28
# ➡️ 유료 / 300,000원
#
# [57] 재확인: https://www.findatamall.or.kr/market/dataProdDetail?gdsSn=16873&menuNo=28
# ➡️ 범위 / 500,000 ~ 100,000,000
#
# [58] 재확인: https://www.findatamall.or.kr/market/dataProdDetail?gdsSn=16447&menuNo=28
# ➡️ 유료 / 35,000원
#
# [59] 재확인: https://www.findatamall.or.kr/market/dataProdDetail?gdsSn=16747&menuNo=28
# ➡️ 유료 / 300,000원
#
# [60] 재확인: https://www.findatamall.or.kr/market/dataProdDetail?gdsSn=16707&menuNo=28
# ➡️ 유료 / 300,000원
#
# [61] 재확인: https://www.findatamall.or.kr/market/dataProdDetail?gdsSn=16522&menuNo=28
# ➡️ 유료 / 500,000원
#
# [62] 재확인: https://www.findatamall.or.kr/market/dataProdDetail?gdsSn=16609&menuNo=28
# ➡️ 유료 / 300,000원
#
# [63] 재확인: https://www.findatamall.or.kr/market/dataProdDetail?gdsSn=16561&menuNo=28
# ➡️ 유료 / 300,000원
#
# [64] 재확인: https://www.findatamall.or.kr/market/dataProdDetail?gdsSn=16889&menuNo=28
# ➡️ 범위 / 500,000 ~ 100,000,000
#
# [65] 재확인: https://www.findatamall.or.kr/market/dataProdDetail?gdsSn=16748&menuNo=28
# ➡️ 유료 / 300,000원
#
# [66] 재확인: https://www.findatamall.or.kr/market/dataProdDetail?gdsSn=16744&menuNo=28
# ➡️ 유료 / 300,000원
#
# [67] 재확인: https://www.findatamall.or.kr/market/dataProdDetail?gdsSn=16610&menuNo=28
# ➡️ 유료 / 100,000원
#
# [68] 재확인: https://www.findatamall.or.kr/market/dataProdDetail?gdsSn=16998&menuNo=28
# ➡️ 범위 / 10,000,000 ~ 100,000,000
#
# [69] 재확인: https://www.findatamall.or.kr/market/dataProdDetail?gdsSn=16841&menuNo=28
# ➡️ 유료 / 300,000원
#
# [70] 재확인: https://www.findatamall.or.kr/market/dataProdDetail?gdsSn=16787&menuNo=28
# ➡️ 유료 / 70,000원
#
# [71] 재확인: https://www.findatamall.or.kr/market/dataProdDetail?gdsSn=16704&menuNo=28
# ➡️ 유료 / 300,000원
#
# [72] 재확인: https://www.findatamall.or.kr/market/dataProdDetail?gdsSn=16555&menuNo=28
# ➡️ 유료 / 200,000원
#
# [73] 재확인: https://www.findatamall.or.kr/market/dataProdDetail?gdsSn=16880&menuNo=28
# ➡️ 범위 / 500,000 ~ 100,000,000
#
# [74] 재확인: https://www.findatamall.or.kr/market/dataProdDetail?gdsSn=16872&menuNo=28
# ➡️ 범위 / 500,000 ~ 100,000,000
#
# [75] 재확인: https://www.findatamall.or.kr/market/dataProdDetail?gdsSn=16749&menuNo=28
# ➡️ 유료 / 70,000원
#
# [76] 재확인: https://www.findatamall.or.kr/market/dataProdDetail?gdsSn=16867&menuNo=28
# ➡️ 범위 / 50,000,000 ~ 100,000,000
#
# [77] 재확인: https://www.findatamall.or.kr/market/dataProdDetail?gdsSn=16784&menuNo=28
# ➡️ 유료 / 300,000원
#
# [78] 재확인: https://www.findatamall.or.kr/market/dataProdDetail?gdsSn=16825&menuNo=28
# ➡️ 유료 / 100,000원
#
# [79] 재확인: https://www.findatamall.or.kr/market/dataProdDetail?gdsSn=17049&menuNo=28
# ➡️ 범위 / 1,000,000 ~ 10,000,000
#
# [80] 재확인: https://www.findatamall.or.kr/market/dataProdDetail?gdsSn=16954&menuNo=28
# ➡️ 범위 / 10,000,000 ~ 100,000,000
#
# [81] 재확인: https://www.findatamall.or.kr/market/dataProdDetail?gdsSn=16887&menuNo=28
# ➡️ 범위 / 500,000 ~ 100,000,000
#
# [82] 재확인: https://www.findatamall.or.kr/market/dataProdDetail?gdsSn=16745&menuNo=28
# ➡️ 유료 / 70,000원
#
# [83] 재확인: https://www.findatamall.or.kr/market/dataProdDetail?gdsSn=16863&menuNo=28
# ➡️ 범위 / 500,000 ~ 100,000,000
#
# [84] 재확인: https://www.findatamall.or.kr/market/dataProdDetail?gdsSn=16876&menuNo=28
# ➡️ 범위 / 500,000 ~ 100,000,000
#
# [85] 재확인: https://www.findatamall.or.kr/market/dataProdDetail?gdsSn=16868&menuNo=28
# ➡️ 범위 / 500,000 ~ 100,000,000
#
# [86] 재확인: https://www.findatamall.or.kr/market/dataProdDetail?gdsSn=16746&menuNo=28
# ➡️ 유료 / 150,000원
#
# [87] 재확인: https://www.findatamall.or.kr/market/dataProdDetail?gdsSn=16888&menuNo=28
# ➡️ 범위 / 500,000 ~ 100,000,000
#
# [88] 재확인: https://www.findatamall.or.kr/market/dataProdDetail?gdsSn=17045&menuNo=28
# ➡️ 유료 / 70,000원
#
# [89] 재확인: https://www.findatamall.or.kr/market/dataProdDetail?gdsSn=16885&menuNo=28
# ➡️ 범위 / 500,000 ~ 100,000,000
#
# [90] 재확인: https://www.findatamall.or.kr/market/dataProdDetail?gdsSn=17095&menuNo=28
# ➡️ 범위 / 1,000,000 ~ 10,000,000
#
# [91] 재확인: https://www.findatamall.or.kr/market/dataProdDetail?gdsSn=17003&menuNo=28
# ➡️ 범위 / 10,000,000 ~ 100,000,000
#
# [92] 재확인: https://www.findatamall.or.kr/market/dataProdDetail?gdsSn=16871&menuNo=28
# ➡️ 범위 / 500,000 ~ 100,000,000
#
# [93] 재확인: https://www.findatamall.or.kr/market/dataProdDetail?gdsSn=16984&menuNo=28
# ➡️ 범위 / 10,000,000 ~ 100,000,000
#
# [94] 재확인: https://www.findatamall.or.kr/market/dataProdDetail?gdsSn=17050&menuNo=28
# ➡️ 유료 / 150,000원
#
# [95] 재확인: https://www.findatamall.or.kr/market/dataProdDetail?gdsSn=16892&menuNo=28
# ➡️ 유료 / 300,000원
#
# [96] 재확인: https://www.findatamall.or.kr/market/dataProdDetail?gdsSn=16878&menuNo=28
# ➡️ 범위 / 500,000 ~ 100,000,000
#
# [97] 재확인: https://www.findatamall.or.kr/market/dataProdDetail?gdsSn=16985&menuNo=28
# ➡️ 범위 / 10,000,000 ~ 100,000,000
#
# [98] 재확인: https://www.findatamall.or.kr/market/dataProdDetail?gdsSn=16893&menuNo=28
# ➡️ 유료 / 70,000원
#
# [99] 재확인: https://www.findatamall.or.kr/market/dataProdDetail?gdsSn=16877&menuNo=28
# ➡️ 범위 / 500,000 ~ 100,000,000
#
# [100] 재확인: https://www.findatamall.or.kr/market/dataProdDetail?gdsSn=16842&menuNo=28
# ➡️ 유료 / 70,000원
#
# [101] 재확인: https://www.findatamall.or.kr/market/dataProdDetail?gdsSn=16886&menuNo=28
# ➡️ 범위 / 500,000 ~ 100,000,000
#
# [102] 재확인: https://www.findatamall.or.kr/market/dataProdDetail?gdsSn=16884&menuNo=28
# ➡️ 범위 / 500,000 ~ 100,000,000
#
# [103] 재확인: https://www.findatamall.or.kr/market/dataProdDetail?gdsSn=16882&menuNo=28
# ➡️ 범위 / 500,000 ~ 100,000,000
#
# [104] 재확인: https://www.findatamall.or.kr/market/dataProdDetail?gdsSn=16881&menuNo=28
# ➡️ 범위 / 500,000 ~ 100,000,000
#
# [105] 재확인: https://www.findatamall.or.kr/market/dataProdDetail?gdsSn=16950&menuNo=28
# ➡️ 범위 / 10,000,000 ~ 100,000,000
#
# [106] 재확인: https://www.findatamall.or.kr/market/dataProdDetail?gdsSn=16930&menuNo=28
# ➡️ 유료 / 100,000원
#
# [107] 재확인: https://www.findatamall.or.kr/market/dataProdDetail?gdsSn=16870&menuNo=28
# ➡️ 범위 / 500,000 ~ 100,000,000
#
# [108] 재확인: https://www.findatamall.or.kr/market/dataProdDetail?gdsSn=16875&menuNo=28
# ➡️ 범위 / 500,000 ~ 100,000,000
#
# [109] 재확인: https://www.findatamall.or.kr/market/dataProdDetail?gdsSn=17097&menuNo=28
# ➡️ 유료 / 70,000원
#
# [110] 재확인: https://www.findatamall.or.kr/market/dataProdDetail?gdsSn=16786&menuNo=28
# ➡️ 유료 / 300,000원
#
# [111] 재확인: https://www.findatamall.or.kr/market/dataProdDetail?gdsSn=16991&menuNo=28
# ➡️ 범위 / 10,000,000 ~ 100,000,000
#
# [112] 재확인: https://www.findatamall.or.kr/market/dataProdDetail?gdsSn=16879&menuNo=28
# ➡️ 범위 / 500,000 ~ 100,000,000
#
# [113] 재확인: https://www.findatamall.or.kr/market/dataProdDetail?gdsSn=16987&menuNo=28
# ➡️ 범위 / 10,000,000 ~ 100,000,000
#
# [114] 재확인: https://www.findatamall.or.kr/market/dataProdDetail?gdsSn=16992&menuNo=28
# ➡️ 범위 / 10,000,000 ~ 100,000,000
#
# [115] 재확인: https://www.findatamall.or.kr/market/dataProdDetail?gdsSn=17059&menuNo=28
# ➡️ 범위 / 1,000,000 ~ 10,000,000
#
# [116] 재확인: https://www.findatamall.or.kr/market/dataProdDetail?gdsSn=17055&menuNo=28
# ➡️ 유료 / 300,000원
#
# [117] 재확인: https://www.findatamall.or.kr/market/dataProdDetail?gdsSn=16997&menuNo=28
# ➡️ 범위 / 10,000,000 ~ 100,000,000
#
# [118] 재확인: https://www.findatamall.or.kr/market/dataProdDetail?gdsSn=17044&menuNo=28
# ➡️ 유료 / 300,000원
#
# [119] 재확인: https://www.findatamall.or.kr/market/dataProdDetail?gdsSn=17001&menuNo=28
# ➡️ 범위 / 10,000,000 ~ 100,000,000
#
# [120] 재확인: https://www.findatamall.or.kr/market/dataProdDetail?gdsSn=16996&menuNo=28
# ➡️ 범위 / 10,000,000 ~ 100,000,000
#
# [121] 재확인: https://www.findatamall.or.kr/market/dataProdDetail?gdsSn=16990&menuNo=28
# ➡️ 범위 / 10,000,000 ~ 100,000,000
#
# [122] 재확인: https://www.findatamall.or.kr/market/dataProdDetail?gdsSn=16988&menuNo=28
# ➡️ 범위 / 10,000,000 ~ 100,000,000
#
# [123] 재확인: https://www.findatamall.or.kr/market/dataProdDetail?gdsSn=17048&menuNo=28
# ➡️ 범위 / 1,000,000 ~ 10,000,000
#
# [124] 재확인: https://www.findatamall.or.kr/market/dataProdDetail?gdsSn=17002&menuNo=28
# ➡️ 범위 / 10,000,000 ~ 100,000,000
#
# [125] 재확인: https://www.findatamall.or.kr/market/dataProdDetail?gdsSn=17000&menuNo=28
# ➡️ 범위 / 10,000,000 ~ 100,000,000
#
# [126] 재확인: https://www.findatamall.or.kr/market/dataProdDetail?gdsSn=16869&menuNo=28
# ➡️ 범위 / 500,000 ~ 100,000,000
#
# [127] 재확인: https://www.findatamall.or.kr/market/dataProdDetail?gdsSn=17176&menuNo=28
# ➡️ 유료 / 300,000원
#
# [128] 재확인: https://www.findatamall.or.kr/market/dataProdDetail?gdsSn=17046&menuNo=28
# ➡️ 범위 / 1,000,000 ~ 10,000,000
#
# [129] 재확인: https://www.findatamall.or.kr/market/dataProdDetail?gdsSn=16989&menuNo=28
# ➡️ 범위 / 10,000,000 ~ 100,000,000
#
# [130] 재확인: https://www.findatamall.or.kr/market/dataProdDetail?gdsSn=16953&menuNo=28
# ➡️ 범위 / 10,000,000 ~ 100,000,000
#
# [131] 재확인: https://www.findatamall.or.kr/market/dataProdDetail?gdsSn=16952&menuNo=28
# ➡️ 범위 / 10,000,000 ~ 100,000,000
#
# [132] 재확인: https://www.findatamall.or.kr/market/dataProdDetail?gdsSn=16951&menuNo=28
# ➡️ 범위 / 10,000,000 ~ 100,000,000
#
# [133] 재확인: https://www.findatamall.or.kr/market/dataProdDetail?gdsSn=17096&menuNo=28
# ➡️ 유료 / 300,000원
#
# [134] 재확인: https://www.findatamall.or.kr/market/dataProdDetail?gdsSn=16986&menuNo=28
# ➡️ 범위 / 10,000,000 ~ 100,000,000
#
# [135] 재확인: https://www.findatamall.or.kr/market/dataProdDetail?gdsSn=16999&menuNo=28
# ➡️ 범위 / 10,000,000 ~ 100,000,000
#
# [136] 재확인: https://www.findatamall.or.kr/market/dataProdDetail?gdsSn=16980&menuNo=28
# ➡️ 유료 / 300,000원
#
# [137] 재확인: https://www.findatamall.or.kr/market/dataProdDetail?gdsSn=17139&menuNo=28
# ➡️ 유료 / 100,000원
#
# [138] 재확인: https://www.findatamall.or.kr/market/dataProdDetail?gdsSn=16993&menuNo=28
# ➡️ 유료 / 300,000원
#
# [139] 재확인: https://www.findatamall.or.kr/market/dataProdDetail?gdsSn=17177&menuNo=28
# ➡️ 유료 / 100,000원
#
# [140] 재확인: https://www.findatamall.or.kr/market/dataProdDetail?gdsSn=17137&menuNo=28
# ➡️ 유료 / 300,000원
#
# [141] 재확인: https://www.findatamall.or.kr/market/dataProdDetail?gdsSn=17047&menuNo=28
# ➡️ 범위 / 1,000,000 ~ 10,000,000
#
# [142] 재확인: https://www.findatamall.or.kr/market/dataProdDetail?gdsSn=16891&menuNo=28
# ➡️ 유료 / 300,000원
#
# [143] 재확인: https://www.findatamall.or.kr/market/dataProdDetail?gdsSn=17057&menuNo=28
# ➡️ 범위 / 1,000,000 ~ 10,000,000
#
# [144] 재확인: https://www.findatamall.or.kr/market/dataProdDetail?gdsSn=17138&menuNo=28
# ➡️ 유료 / 300,000원
#
# [145] 재확인: https://www.findatamall.or.kr/market/dataProdDetail?gdsSn=17136&menuNo=28
# ➡️ 유료 / 300,000원
#
# [146] 재확인: https://www.findatamall.or.kr/market/dataProdDetail?gdsSn=17058&menuNo=28
# ➡️ 범위 / 1,000,000 ~ 10,000,000
#
# [147] 재확인: https://www.findatamall.or.kr/market/dataProdDetail?gdsSn=17053&menuNo=28
# ➡️ 범위 / 1,000,000 ~ 10,000,000
# ✅ 저장 완료: /content/drive/MyDrive/00. 대학원/data-price-20250727-v9.jsonl

# %%
import json

# 파일 경로
original_file = "/content/drive/MyDrive/00. 대학원/data-price-20250727-v8.jsonl"
patch_file = "/content/drive/MyDrive/00. 대학원/data-price-20250727-v9.jsonl"
output_file = "/content/drive/MyDrive/00. 대학원/data-price-20250727-v10.jsonl"

# 원본 전체 로드
with open(original_file, 'r', encoding='utf-8') as f:
    original_records = [json.loads(line.strip()) for line in f if line.strip()]

# 수정 레코드 로드 (url 기준 매핑)
with open(patch_file, 'r', encoding='utf-8') as f:
    patch_records = [json.loads(line.strip()) for line in f if line.strip()]
patch_map = {r["url"]: r for r in patch_records}

# 갱신
updated_records = []
for rec in original_records:
    url = rec.get("url")
    if url in patch_map:
        patch = patch_map[url]
        rec["price_type"] = patch.get("price_type", rec.get("price_type"))
        rec["price_num"] = patch.get("price_num", rec.get("price_num"))
    updated_records.append(rec)

# 저장
with open(output_file, 'w', encoding='utf-8') as f:
    for r in updated_records:
        f.write(json.dumps(r, ensure_ascii=False) + "\n")

print(f"✅ 저장 완료: {output_file}")
# Out:
# ✅ 저장 완료: /content/drive/MyDrive/00. 대학원/data-price-20250727-v10.jsonl
